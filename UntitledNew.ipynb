# %%
import os
from os.path import join, getmtime
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
today = datetime.today()
weekday = today.weekday()  # 0 = Monday, 6 = Sunday

# 轉換成中文星期
week_map = ['星期一', '星期二', '星期三', '星期四', '星期五', '星期六', '星期日']
print("今天是：", week_map[weekday])
#######
diffdays=0
#########
if weekday==5:   
    diffdays=1
if weekday==6:
    diffdays=2

today=(datetime.now()-timedelta(days=diffdays)).date()
adate=(datetime.now()-timedelta(days=diffdays)).strftime("%Y-%m-%d")
    
print(today)
print(adate)
# Out:
# 今天是： 星期三
# 2025-07-09
# 2025-07-09

# %%
start_month = '2023-01-01'
start_date = datetime.strptime(start_month, "%Y-%m-%d").date()
dateList = []
current_date = start_date
while current_date <= today:
    dateList.append(f"{current_date.year}-{current_date.month:02d}-{current_date.day:02d}")
    current_date += timedelta(days=1)
    
dateList=dateList[-15:]
print('Base 資料',dateList)
print('============================')
print('join 新資料日',adate)
# Out:
# Base 資料 ['2025-06-25', '2025-06-26', '2025-06-27', '2025-06-28', '2025-06-29', '2025-06-30', '2025-07-01', '2025-07-02', '2025-07-03', '2025-07-04', '2025-07-05', '2025-07-06', '2025-07-07', '2025-07-08', '2025-07-09']
# ============================
# join 新資料日 2025-07-09

# %%
new_DailyResult_path_List=[]
new_RunRealTimeStock_path_List = [f'D:\\Project\\Jupyter\\Stock\\Main\\Result\\DailyRunRealTimeStock\\{adate}.xlsx']
new_DailyResult_path_List = [ f"D:\Project\Jupyter\Stock\Main\Result\DailyFiles\\{date}.xlsx" for date in dateList] 
#new_RunRealTimeStock_path_List = [f'\\\\auohqeshtt02\\d$\\Production\\CMMM\\Result\\DailyRunRealTimeStock\\{adate}.xlsx']
#new_DailyResult_path_List = [ f"\\\\auohqeshtt02\\d$\\Production\\CMMM\\Result\\DailyFiles\\{date}.xlsx" for date in dateList] 

data=StockBaseData=pd.read_csv('BaseInfo/StockBaseData.csv', converters={'公司代號': str})

_df =  pd.DataFrame()
for path in new_RunRealTimeStock_path_List:
    try:
        _df=pd.concat([pd.read_excel(path), _df])
    except:
        print('error----->'+path)
    
_df2 = pd.DataFrame()
for path in new_DailyResult_path_List:
    try:
        _df2=pd.concat([pd.read_excel(path), _df2])
    except:
        print('error----->'+path)
        
df=pd.merge( _df2,_df[pd.notna(_df['now_price'])], left_on='stock_number', right_on='stock_number', how='outer')

#print(_df2.dtypes)
#print(_df.dtypes)
# Out:
# error----->D:\Project\Jupyter\Stock\Main\Result\DailyFiles\2025-06-28.xlsx
# error----->D:\Project\Jupyter\Stock\Main\Result\DailyFiles\2025-06-29.xlsx
# error----->D:\Project\Jupyter\Stock\Main\Result\DailyFiles\2025-07-05.xlsx
# error----->D:\Project\Jupyter\Stock\Main\Result\DailyFiles\2025-07-06.xlsx

# %%
def  GetStockInfoByID(StocKID,strtype):
    try :
        result=data[data['公司代號']==StocKID]
        if strtype=='name':
            return result.iloc[0]['公司簡稱']
        if strtype=='category':
            if result.iloc[0]['Type']=="上櫃" :
                return result.iloc[0]['上櫃公司產業類別']
            else:
                return result.iloc[0]['上市公司產業類別']
        if strtype=='type':
            return result.iloc[0]['Type']
    except :
        print(StocKID)

# %%
def stock_LevelArea(row):
    _level=float( row['level'])

    if row['interval_type']=='正區間': 
        _level=_level*1

    if row['interval_type']=='負區間':
        _level=_level*-1
    return _level

def stock_quote(row):
    try:
        open_price = float(row['開盤價'])
        if open_price == 0:
            return 0.0
        return round(float(row['漲跌價差']) / open_price * 100, 2)
    except (ValueError, TypeError):
        return 0.0
def  diff_quote(row):
    try :
        if float(row['收盤價_y'])!=0:
            return format((  float(row['收盤價_y']) - float(row['now_price']) ) /float(row['收盤價_y'])*100, '.2f')

    except FileNotFoundError:
        print(row['_quote'])

def trading_volume(row):
    data=row['成交股數']
    try :
         if row['Type2']=='上市': 
                data=data/1000
    except FileNotFoundError:
          print(data)
        
    return data

# %% [markdown]
# df.columns.values

# %%
# Rename columns in one go to avoid repeating `df.rename()`
rename_dict = {
    '日期_x': '日期',
    'now_price_x': 'now_price',
    'change_price_x': 'change_price',
    'change_quote_x': 'change_quote'
}
df.rename(columns=rename_dict, inplace=True)

# Convert date columns
date_columns = ['日期', 'highlight_date', 'highlight_enddate']
for col in date_columns:
    df[col] = pd.to_datetime(df[col], errors='coerce')  # 先轉換成 datetime，無法轉換的設為 NaT
    df[col] = df[col].dt.strftime('%Y-%m-%d')

# Apply stock information based on 'stock_number' and add new columns
stock_columns = ['Type0', 'Type1', 'Type2']
stock_info_types = ['name', 'category', 'type']
for i, col in enumerate(stock_columns):
    df[col] = df.apply(lambda x: f"{GetStockInfoByID(str(x['stock_number']), stock_info_types[i])}", axis=1)

df['Type'] = df['Type0'] + '-' + df['Type1'] + '-' + df['Type2']

# %%
df['MA5_%']=(df['收盤價']-df['MA_short'])/ abs(df['MA_short'])
df['均價_%']=(df['MA_short']-df['MA_long'])/ abs(df['MA_long'])
df['均價long_%']=(df['MA_long']-df['MA_longlong'])/ abs(df['MA_longlong'])
df['MACD_%']=(df['MACD']-df['MACD-SL'])/ abs(df['MACD-SL'])
df['VPC_MA_%']=(df['Volume_MA_short']-df['Volume_MA_long'])/ abs(df['Volume_MA_long'])

df['MA5_%'] =( 100*df['MA5_%']).astype(float).apply(lambda x: f"{x:.2f}").astype(str)
df['均價_%'] = (100*df['均價_%']).astype(float).apply(lambda x: f"{x:.2f}").astype(str)
df['均價long_%'] = (100*df['均價long_%']).astype(float).apply(lambda x: f"{x:.2f}").astype(str)
df['MACD_%'] = (100*df['MACD_%']).astype(float).apply(lambda x: f"{x:.2f}").astype(str)
df['VPC_MA_%']=(100*df['VPC_MA_%']).astype(float).apply(lambda x: f"{x:.2f}").astype(str)

#處理數值 NA ,浮點與轉str
df['change_quote'] = df['change_quote'].astype(str).str.replace("+", "", regex=False).str.replace("%", "", regex=False)
df['change_quote'] = pd.to_numeric(df['change_quote'], errors='coerce').fillna('0.00').astype(str)
df['MACD'] = df['MACD'] .astype(float).apply(lambda x: f"{x:.2f}").astype(str)
df['MACD-SL'] = df['MACD-SL'].astype(float).apply(lambda x: f"{x:.2f}").astype(str)
df['now_price'] = pd.to_numeric(df['now_price'], errors='coerce').fillna('0.00').astype(str)
df['收盤價'] = pd.to_numeric(df['收盤價'], errors='coerce').fillna('0.00').astype(str)

df['MA_break'] = df['MA_break'].fillna(False)
df['MACD_golden_cross'] = df['MACD_golden_cross'].fillna(False)
df['stock_number'] = df['stock_number'].astype(str)


df['Volume_Oscillator'] = (
    df['Volume_Oscillator']
    .replace([np.inf, -np.inf], 0)  # 把 inf/-inf 換成 0
    .fillna(0)                      # 把 NaN 補 0
    .astype(int)                    # 安全轉 int
    .astype(str)                    # 再轉成文字
)
df['level'] = (df['level'] * 100).astype(str)
df['now_price'] = df['now_price'].astype(str)


df['漲跌價差'] = pd.to_numeric(df['漲跌價差'], errors='coerce').fillna(0)
df['短交易量'] = pd.to_numeric(df['短交易量'], errors='coerce').fillna('0.00').astype(float).apply(lambda x: f"{x:.2f}").astype(float)
df['遠交易量'] = pd.to_numeric(df['遠交易量'], errors='coerce').fillna('0.00').astype(float).apply(lambda x: f"{x:.2f}").astype(float)

df['Volume_Price_Change_sum'] = df['VPC_MACD'].fillna('0').astype(float).apply(lambda x: f"{x:.2f}").astype(float)
df['VPC_SIGNAL'] = df['VPC_SIGNAL'].fillna('0').astype(float).apply(lambda x: f"{x:.2f}").astype(float)
df['Volume_%'] = (df['VPC_MACD'] - df['VPC_SIGNAL']) / abs(df['VPC_SIGNAL'])
df['Volume_%'] = df['Volume_%'].round(2)

# Apply custom functions for additional calculations
df['_quote'] = df.apply(stock_quote, axis=1)

df['LevelArea'] = df.apply(stock_LevelArea, axis=1)
df['成交股數'] = df.apply(trading_volume, axis=1)

# Handle 'Typelevel' logic more efficiently
df['Typelevel'] = df.apply(lambda x: f"{x['Type1']}右上" if x['LevelArea'] >= 50 else (
    f"{x['Type1']}平" if -40 <= x['LevelArea'] < 50 else f"{x['Type1']}右下"), axis=1)

# Replace all '-' values with 0
df.replace('-', 0, inplace=True)

# %%
df[ (df['stock_number']=='1101')]
# Out:
#             日期       成交股數          成交金額    開盤價    最高價    最低價    收盤價  漲跌價差  \
# 11  2025-07-09  14566.482  3.514965e+08  24.35  24.35  24.05   24.1 -0.25
# 12  2025-07-08  27641.539  6.746233e+08  24.75  25.05  24.20  24.35 -0.50
# 13  2025-07-07  14205.951  3.521651e+08  25.00  25.00  24.60  24.85 -0.15
# 14  2025-07-04  16588.626  4.157750e+08  25.45  25.45  25.00   25.0 -0.35
# 15  2025-07-03  13115.130  3.321674e+08  25.30  25.45  25.20  25.35  0.10
# 16  2025-07-02  21251.256  5.374096e+08  25.55  25.65  25.15  25.25  0.00
# 17  2025-07-01  54915.619  1.431632e+09  25.80  26.60  25.55  26.15  0.65
# 18  2025-06-30  21430.048  5.500019e+08  26.00  26.05  25.50   25.5 -0.70
# 19  2025-06-27  17125.138  4.485934e+08  26.15  26.40  26.00   26.2  0.40
# 20  2025-06-26  16521.929  4.292966e+08  25.75  26.25  25.70   25.8  0.10
# 21  2025-06-25  11763.685  3.035254e+08  25.90  25.95  25.60   25.7 -0.05
#
#        成交筆數         年月日  前日收盤價   MACD MACD-SL  MACD_golden_cross         %K  \
# 11   8060.0  2025-07-09  24.35  -0.93   -0.89              False   0.000000
# 12  12689.0  2025-07-08  24.85  -0.89   -0.88              False   0.000000
# 13   6664.0  2025-07-07  25.00  -0.85   -0.87              False   0.000000
# 14   7697.0  2025-07-04  25.35  -0.84   -0.88              False   0.000000
# 15   5768.0  2025-07-03  25.25  -0.83   -0.89              False  22.727273
# 16   9753.0  2025-07-02  26.15  -0.84   -0.90              False  13.636364
# 17  18571.0  2025-07-01  25.50  -0.84   -0.92              False  95.454545
# 18   8358.0  2025-06-30  26.20  -0.90   -0.94              False  28.571429
# 19   6589.0  2025-06-27  25.80  -0.91   -0.95               True  66.666667
# 20   7091.0  2025-06-26  25.70  -0.98   -0.96              False  41.176471
# 21   5508.0  2025-06-25  25.75  -1.02   -0.95              False  33.333333
#
#            %D KD_golden_cross  MA_short  MA_long  MA_longlong  MA_break  \
# 11   0.000000           False     24.73  25.7325       27.907     False
# 12   0.000000           False     24.96  25.8925       28.010     False
# 13   7.575758           False     25.32  26.0325       28.108     False
# 14  12.121212           False     25.45  26.1500       28.183     False
# 15  43.939394           False     25.69  26.2775       28.257     False
# 16  45.887446           False     25.78  26.3850       28.329     False
# 17  63.564214            True     25.87  26.4725       28.411     False
# 18  45.471522           False     25.79  26.5075       28.478     False
# 19  47.058824           False     25.71  26.6175       28.566     False
# 20  35.947712           False     25.57  26.7750       28.640     False
# 21  22.222222           False     25.62  26.9400       28.724     False
#
#           RSI RSI_rebound  Volume_Price_Change  Volume_MA_short  \
# 11  33.043478       False        -3.514965e+08     -292378508.8
# 12  31.932773       False        -6.746233e+08     -329561125.4
# 13  33.333333       False        -3.521651e+08       91690032.2
# 14  33.928571       False        -4.157750e+08       52122662.4
# 15  35.514019       False         3.321674e+08      224996332.8
# 16  33.333333       False        -5.374096e+08      244422176.0
# 17  37.894737       False         1.431632e+09      291199014.0
# 18  30.588235       False        -5.500019e+08       91405379.2
# 19  36.111111        True         4.485934e+08       82193436.8
# 20  25.352113       False         4.292966e+08     -180839466.2
# 21  24.285714       False        -3.035254e+08     -402259283.8
#
#     Volume_MA_long Volume_Oscillator      VPC_MACD   VPC_SIGNAL       VPC_DIF  \
# 11     -23978166.4              1119 -5.155742e+07    177171.04 -5.173460e+07
# 12     -19181055.7              1618 -4.559472e+07  13110819.82 -5.870554e+07
# 13      91547705.7                 0 -8.274451e+05  27787203.67 -2.861465e+07
# 14      67158049.6               -22  2.860625e+07  34940865.86 -6.334615e+06
# 15      22078433.3               919  7.644808e+07  36524519.64  3.992356e+07
# 16     -78918553.9              -409  6.192659e+07  26543629.10  3.538296e+07
# 17     -82115395.0              -454  1.321389e+08  17697889.35  1.144410e+08
# 18    -271373660.0              -133  1.675414e+07 -10912360.99  2.766651e+07
# 19    -268289226.6              -130  6.363840e+07 -17828987.47  8.146739e+07
# 20    -360471269.2               -49  2.135075e+07 -38195834.44  5.954659e+07
# 21    -430349650.3                -6 -3.775518e+07 -53082481.59  1.532730e+07
#
#     volume_threshold Volume_Price_Change_break   短交易量    遠交易量       短增量  \
# 11      2.441865e+06                     False  -81.0  1119.0  0.000000
# 12      1.225992e+07                     False -149.0  1618.0  0.613244
# 13      2.277894e+07                     False -132.0     0.0  0.613244
# 14      2.707101e+07                     False -176.0   -22.0  0.893300
# 15      2.679188e+07                     False   52.0   919.0  0.280056
# 16      1.776348e+07                     False  -24.0  -409.0  0.683415
# 17      9.733820e+06                      True   34.0  -454.0  1.047420
# 18     -1.252165e+07                      True  -82.0  -133.0  1.161977
# 19     -1.784452e+07                     False   56.0  -130.0  1.079556
# 20     -3.265959e+07                     False   15.0   -49.0  0.690548
# 21     -4.247966e+07                     False  127.0    -6.0  0.892219
#
#    highlight highlight_date highlight_enddate macd_golden_crosses_area  \
# 11     False            NaN               NaN                    False
# 12     False            NaN               NaN                    False
# 13     False            NaN               NaN                     True
# 14     False            NaN               NaN                     True
# 15     False            NaN               NaN                     True
# 16     False            NaN               NaN                     True
# 17     False            NaN               NaN                     True
# 18     False            NaN               NaN                     True
# 19     False            NaN               NaN                    False
# 20     False            NaN               NaN                    False
# 21     False            NaN               NaN                    False
#
#    VPC_break VO_Positive  VO_Positive_Count buy_points Bar_Color  \
# 11     False        True                2.0      False     green
# 12     False        True                1.0      False     green
# 13     False       False                1.0      False     green
# 14     False       False                1.0      False     green
# 15     False        True                1.0      False       red
# 16     False       False                0.0      False     green
# 17     False       False                0.0      False       red
# 18     False       False                0.0      False     green
# 19     False       False                0.0      False       red
# 20     False       False                1.0      False       red
# 21     False       False                2.0      False     green
#
#                                          Full_Summary  實體長度        K棒型態    上影  \
# 11  <b>分類：</b>空頭排列<br><b>建議：</b><br><b>評分：</b>0<br...  0.25        長黑K棒  0.00
# 12  <b>分類：</b>空頭排列<br><b>建議：</b>建議留意風險<br><b>評分：</...  0.40         NaN  0.30
# 13  <b>分類：</b>空頭排列<br><b>建議：</b><br><b>評分：</b>0<br...  0.15       |下影線長  0.00
# 14  <b>分類：</b>空頭排列<br><b>建議：</b><br><b>評分：</b>0<br...  0.45   長黑K棒|空頭吞噬  0.00
# 15  <b>分類：</b>空頭排列,爆量上攻<br><b>建議：</b><br><b>評分：</b...  0.05  |上影線長|下影線長  0.10
# 16  <b>分類：</b>空頭排列<br><b>建議：</b><br><b>評分：</b>0<br...  0.30         NaN  0.10
# 17  <b>分類：</b>空頭排列,爆量上攻<br><b>建議：</b><br><b>評分：</b...  0.35       |上影線長  0.45
# 18  <b>分類：</b>空頭排列<br><b>建議：</b><br><b>評分：</b>0<br...  0.50        長黑K棒  0.05
# 19  <b>分類：</b>空頭排列,爆量上攻<br><b>建議：</b><br><b>評分：</b...  0.05  |上影線長|下影線長  0.20
# 20  <b>分類：</b>低檔翻揚,空頭排列,爆量上攻<br><b>建議：</b><br><b>評...  0.05    十字線|上影線長  0.45
# 21  <b>分類：</b>空頭排列<br><b>建議：</b><br><b>評分：</b>0<br...  0.20         NaN  0.05
#
#       下影     昨收     昨開     昨高     昨低     今高     今低 K棒方向    K棒續強確認 多日K棒型態  \
# 11  0.05  24.35  24.75  24.75  24.35  24.35  24.10   負向       NaN  |三隻烏鴉
# 12  0.15  24.85  25.00  25.00  24.85  24.75  24.35   中性       NaN  |三隻烏鴉
# 13  0.25  25.00  25.45  25.45  25.00  25.00  24.85   正向       NaN    NaN
# 14  0.00  25.35  25.30  25.35  25.30  25.45  25.00   負向       NaN    NaN
# 15  0.10  25.25  25.55  25.55  25.25  25.35  25.30   負向       NaN    NaN
# 16  0.10  26.15  25.80  26.15  25.80  25.55  25.25   中性       NaN    NaN
# 17  0.25  25.50  26.00  26.00  25.50  26.15  25.80   負向       NaN    NaN
# 18  0.00  26.20  26.15  26.20  26.15  26.00  25.50   負向       NaN    NaN
# 19  0.15  25.80  25.75  25.80  25.75  26.20  26.15   負向  下影大於實體兩倍    |晨星
# 20  0.05  25.70  25.90  25.90  25.70  25.80  25.75   觀望       NaN    NaN
# 21  0.10  25.75  25.20  25.75  25.20  25.90  25.70   中性       NaN    NaN
#
#    多日K棒方向    三白兵   三隻烏鴉     晨星     暮星    Market_State Buy_Signal Sell_Signal  \
# 11     負向  False   True  False  False            空頭排列        NaN         NaN
# 12     負向  False   True  False  False            空頭排列        NaN      建議留意風險
# 13    NaN  False  False  False  False            空頭排列        NaN         NaN
# 14    NaN  False  False  False  False            空頭排列        NaN         NaN
# 15    NaN  False  False  False  False       空頭排列,爆量上攻        NaN         NaN
# 16    NaN  False  False  False  False            空頭排列        NaN         NaN
# 17    NaN  False  False  False  False       空頭排列,爆量上攻        NaN         NaN
# 18    NaN  False  False  False  False            空頭排列        NaN         NaN
# 19     正向  False  False   True  False       空頭排列,爆量上攻        NaN         NaN
# 20    NaN  False  False  False  False  低檔翻揚,空頭排列,爆量上攻        NaN         NaN
# 21    NaN  False  False  False  False            空頭排列        NaN         NaN
#
#    Watch_Signal Reversal_Signal   RSI_diff Action_Advice  Advice_Score  \
# 11          NaN             NaN   1.110705           NaN           0.0
# 12          NaN             NaN  -1.400560        建議留意風險           4.0
# 13          NaN             NaN  -0.595238           NaN           0.0
# 14          NaN             NaN  -1.585447           NaN           0.0
# 15          NaN             NaN   2.180685           NaN           0.0
# 16          NaN             NaN  -4.561404           NaN           0.0
# 17          NaN             NaN   7.306502           NaN           0.0
# 18          NaN             NaN  -5.522876           NaN           0.0
# 19          NaN             NaN  10.758998           NaN           0.0
# 20          NaN             NaN   1.066398           NaN           0.0
# 21          NaN             NaN  -9.891501           NaN           0.0
#
#    stock_number  level interval_type  lower_bound  upper_bound now_price  \
# 11         1101  100.0           負區間         24.1         24.1      24.1
# 12         1101  100.0           負區間         24.1         24.1     24.35
# 13         1101  100.0           負區間         24.1         24.1     24.85
# 14         1101  100.0           負區間         24.1         24.1      25.0
# 15         1101  100.0           負區間         24.1         24.1     25.35
# 16         1101  100.0           負區間         24.1         24.1     25.25
# 17         1101  100.0           負區間         24.1         24.1     26.15
# 18         1101  100.0           負區間         24.1         24.1      25.5
# 19         1101  100.0           負區間         24.1         24.1      26.2
# 20         1101  100.0           負區間         24.1         24.1      25.8
# 21         1101  100.0           負區間         24.1         24.1      25.7
#
#     change_price change_quote       日期_y  now_price_y  change_price_y  \
# 11         -0.25        -1.03 2025-07-09         24.1           -0.25
# 12         -0.50        -2.02 2025-07-09         24.1           -0.25
# 13         -0.15         -0.6 2025-07-09         24.1           -0.25
# 14         -0.35        -1.38 2025-07-09         24.1           -0.25
# 15          0.10          0.4 2025-07-09         24.1           -0.25
# 16           NaN          0.0 2025-07-09         24.1           -0.25
# 17          0.65         2.52 2025-07-09         24.1           -0.25
# 18         -0.70        -2.69 2025-07-09         24.1           -0.25
# 19          0.40         1.53 2025-07-09         24.1           -0.25
# 20          0.10         0.39 2025-07-09         24.1           -0.25
# 21         -0.05        -0.19 2025-07-09         24.1           -0.25
#
#    change_quote_y Type0 Type1 Type2        Type  MA5_%   均價_% 均價long_% MACD_%  \
# 11         -1.03%    台泥  水泥工業    上市  台泥-水泥工業-上市  -2.55  -3.90    -7.79  -4.72
# 12         -1.03%    台泥  水泥工業    上市  台泥-水泥工業-上市  -2.44  -3.60    -7.56  -1.47
# 13         -1.03%    台泥  水泥工業    上市  台泥-水泥工業-上市  -1.86  -2.74    -7.38   2.50
# 14         -1.03%    台泥  水泥工業    上市  台泥-水泥工業-上市  -1.77  -2.68    -7.21   4.24
# 15         -1.03%    台泥  水泥工業    上市  台泥-水泥工業-上市  -1.32  -2.24    -7.01   6.34
# 16         -1.03%    台泥  水泥工業    上市  台泥-水泥工業-上市  -2.06  -2.29    -6.86   6.57
# 17         -1.03%    台泥  水泥工業    上市  台泥-水泥工業-上市   1.08  -2.28    -6.82   8.99
# 18         -1.03%    台泥  水泥工業    上市  台泥-水泥工業-上市  -1.12  -2.71    -6.92   3.65
# 19         -1.03%    台泥  水泥工業    上市  台泥-水泥工業-上市   1.91  -3.41    -6.82   3.62
# 20         -1.03%    台泥  水泥工業    上市  台泥-水泥工業-上市   0.90  -4.50    -6.51  -2.73
# 21         -1.03%    台泥  水泥工業    上市  台泥-水泥工業-上市   0.31  -4.90    -6.21  -6.91
#
#     VPC_MA_%  Volume_Price_Change_sum  Volume_%  _quote  LevelArea Typelevel
# 11  -1119.35            -5.155742e+07   -292.00   -1.03     -100.0    水泥工業右下
# 12  -1618.16            -4.559472e+07     -4.48   -2.02     -100.0    水泥工業右下
# 13      0.16            -8.274451e+05     -1.03   -0.60     -100.0    水泥工業右下
# 14    -22.39             2.860625e+07     -0.18   -1.38     -100.0    水泥工業右下
# 15    919.08             7.644808e+07      1.09    0.40     -100.0    水泥工業右下
# 16    409.71             6.192659e+07      1.33    0.00     -100.0    水泥工業右下
# 17    454.62             1.321389e+08      6.47    2.52     -100.0    水泥工業右下
# 18    133.68             1.675414e+07      2.54   -2.69     -100.0    水泥工業右下
# 19    130.64             6.363840e+07      4.57    1.53     -100.0    水泥工業右下
# 20     49.83             2.135075e+07      1.56    0.39     -100.0    水泥工業右下
# 21      6.53            -3.775518e+07      0.29   -0.19     -100.0    水泥工業右下

# %%
aa=df
aa['VPC_MACD'] = pd.to_numeric(aa['VPC_MACD'], errors='coerce')
aa['遠交易量'] = pd.to_numeric(aa['遠交易量'], errors='coerce')
aa['短交易量'] = pd.to_numeric(aa['短交易量'], errors='coerce')
aa['_quote'] = pd.to_numeric(aa['_quote'], errors='coerce')
aa['now_price'] = pd.to_numeric(aa['now_price'], errors='coerce')
aa['收盤價'] = pd.to_numeric(aa['收盤價'], errors='coerce')
aa['收盤價'] =pd.to_numeric(aa['收盤價'], errors='coerce').apply(lambda x: f"{x:.2f}" if pd.notna(x) else "0").astype(float)
aa['最低價'] =pd.to_numeric(aa['最低價'], errors='coerce').apply(lambda x: f"{x:.2f}" if pd.notna(x) else "0").astype(float)
aa['最高價'] =pd.to_numeric(aa['最高價'], errors='coerce').apply(lambda x: f"{x:.2f}" if pd.notna(x) else "0").astype(float)
#aa['短增量'] =pd.to_numeric(aa['短增量'], errors='coerce').apply(lambda x: f"{x:.2f}" if pd.notna(x) else "0").astype(float)

# %%
## 取得其他資訊
stock_info = pd.read_excel('Result/StockInfo.xlsx', engine='openpyxl')
stock_type = pd.read_excel('Result/StockType.xlsx', engine='openpyxl')

stock_info=pd.merge(left=stock_info, right=stock_type, on="stock_number",how='left')

# 确保两个 DataFrame 的 `stock_number` 列为字符串类型
aa['stock_number'] = aa['stock_number'].astype(str)

stock_info['stock_number'] = stock_info['stock_number'].astype(str)
stock_info['desc'] = stock_info['desc'].fillna("-")
stock_info['成交量'] = (stock_info['成交量'] .str.replace(",", ""))
stock_info['殖利率']=stock_info['殖利率'].str.replace("%", "")
stock_info['總市值'] = (stock_info['總市值'] .str.replace(",", ""))
stock_info['一年內最大量'] = (stock_info['一年內最大量'] .str.replace(",", ""))
stock_info['一年內最低量'] = (stock_info['一年內最低量'] .str.replace(",", ""))

stock_info['營業毛利率']=stock_info['營業毛利率'].replace("%", "")
stock_info['營業利益率']=stock_info['營業利益率'].replace("%", "")


# 合并两个 DataFrame
aa = pd.merge(left=aa, right=stock_info, on="stock_number",how='left')

aa['營收比重'] = aa['營收比重'].fillna("-")
aa['量能'] = aa['成交股數'].astype(float)/ aa['一年內最大量'].fillna(0).astype(int) 
aa['量能'] = (aa['量能'] *100) .apply(lambda x: f"{x:.2f}").astype(str)

aa['now_price']=aa['now_price'].replace(",", "").astype(float)

aa['每股淨值(元)'] = aa['每股淨值(元)'].str.strip()  # 去掉前後空白
aa['每股淨值(元)'] = aa['每股淨值(元)'].str.replace(",", "", regex=True).astype(float)
aa['淨值倍率']=(aa['now_price']/aa['每股淨值(元)']).astype(float).apply(lambda x: f"{x:.2f}")
aa['diff_quote'] = aa.apply(diff_quote, axis=1)


aa['_quote'] = pd.to_numeric(aa['_quote'], errors='coerce')
aa['短交易量'] = pd.to_numeric(aa['短交易量'], errors='coerce')
aa['本益比'] = pd.to_numeric(aa['本益比'], errors='coerce')
aa['diff_quote'] = pd.to_numeric(aa['diff_quote'], errors='coerce')

aa['成交量']=aa['成交量'].fillna('0').astype(int).astype(str)


rename_dict = {
    '收盤價_x': '收盤價',
    '最低價_x': '最低價',
    '最高價_x': '最高價',
    '開盤價_x': '開盤價'
}
aa.rename(columns=rename_dict, inplace=True)

#偏多程度 - 偏空程度
#正數 → 偏多（收盤價偏向高點）
#負數 → 偏空（收盤價偏向低點）
#接近 0 → 收盤在高低之間，盤整或不明顯

aa['價能'] =((aa['收盤價']-aa['最低價'])/aa['最低價'])-((aa['最高價']-aa['收盤價'])/aa['收盤價']) 
aa['價能'] = (aa['價能']*100 ) .apply(lambda x: f"{x:.2f}").astype(str)

aa['rt_price']  =''
aa['rt_量']=''

# %%
aa[ (aa['stock_number']=='1101')]
# Out:
#             日期       成交股數          成交金額    開盤價    最高價    最低價    收盤價  漲跌價差  \
# 11  2025-07-09  14566.482  3.514965e+08  24.35  24.35  24.05  24.10 -0.25
# 12  2025-07-08  27641.539  6.746233e+08  24.75  25.05  24.20  24.35 -0.50
# 13  2025-07-07  14205.951  3.521651e+08  25.00  25.00  24.60  24.85 -0.15
# 14  2025-07-04  16588.626  4.157750e+08  25.45  25.45  25.00  25.00 -0.35
# 15  2025-07-03  13115.130  3.321674e+08  25.30  25.45  25.20  25.35  0.10
# 16  2025-07-02  21251.256  5.374096e+08  25.55  25.65  25.15  25.25  0.00
# 17  2025-07-01  54915.619  1.431632e+09  25.80  26.60  25.55  26.15  0.65
# 18  2025-06-30  21430.048  5.500019e+08  26.00  26.05  25.50  25.50 -0.70
# 19  2025-06-27  17125.138  4.485934e+08  26.15  26.40  26.00  26.20  0.40
# 20  2025-06-26  16521.929  4.292966e+08  25.75  26.25  25.70  25.80  0.10
# 21  2025-06-25  11763.685  3.035254e+08  25.90  25.95  25.60  25.70 -0.05
#
#        成交筆數         年月日  前日收盤價   MACD MACD-SL  MACD_golden_cross         %K  \
# 11   8060.0  2025-07-09  24.35  -0.93   -0.89              False   0.000000
# 12  12689.0  2025-07-08  24.85  -0.89   -0.88              False   0.000000
# 13   6664.0  2025-07-07  25.00  -0.85   -0.87              False   0.000000
# 14   7697.0  2025-07-04  25.35  -0.84   -0.88              False   0.000000
# 15   5768.0  2025-07-03  25.25  -0.83   -0.89              False  22.727273
# 16   9753.0  2025-07-02  26.15  -0.84   -0.90              False  13.636364
# 17  18571.0  2025-07-01  25.50  -0.84   -0.92              False  95.454545
# 18   8358.0  2025-06-30  26.20  -0.90   -0.94              False  28.571429
# 19   6589.0  2025-06-27  25.80  -0.91   -0.95               True  66.666667
# 20   7091.0  2025-06-26  25.70  -0.98   -0.96              False  41.176471
# 21   5508.0  2025-06-25  25.75  -1.02   -0.95              False  33.333333
#
#            %D KD_golden_cross  MA_short  MA_long  MA_longlong  MA_break  \
# 11   0.000000           False     24.73  25.7325       27.907     False
# 12   0.000000           False     24.96  25.8925       28.010     False
# 13   7.575758           False     25.32  26.0325       28.108     False
# 14  12.121212           False     25.45  26.1500       28.183     False
# 15  43.939394           False     25.69  26.2775       28.257     False
# 16  45.887446           False     25.78  26.3850       28.329     False
# 17  63.564214            True     25.87  26.4725       28.411     False
# 18  45.471522           False     25.79  26.5075       28.478     False
# 19  47.058824           False     25.71  26.6175       28.566     False
# 20  35.947712           False     25.57  26.7750       28.640     False
# 21  22.222222           False     25.62  26.9400       28.724     False
#
#           RSI RSI_rebound  Volume_Price_Change  Volume_MA_short  \
# 11  33.043478       False        -3.514965e+08     -292378508.8
# 12  31.932773       False        -6.746233e+08     -329561125.4
# 13  33.333333       False        -3.521651e+08       91690032.2
# 14  33.928571       False        -4.157750e+08       52122662.4
# 15  35.514019       False         3.321674e+08      224996332.8
# 16  33.333333       False        -5.374096e+08      244422176.0
# 17  37.894737       False         1.431632e+09      291199014.0
# 18  30.588235       False        -5.500019e+08       91405379.2
# 19  36.111111        True         4.485934e+08       82193436.8
# 20  25.352113       False         4.292966e+08     -180839466.2
# 21  24.285714       False        -3.035254e+08     -402259283.8
#
#     Volume_MA_long Volume_Oscillator      VPC_MACD   VPC_SIGNAL       VPC_DIF  \
# 11     -23978166.4              1119 -5.155742e+07    177171.04 -5.173460e+07
# 12     -19181055.7              1618 -4.559472e+07  13110819.82 -5.870554e+07
# 13      91547705.7                 0 -8.274451e+05  27787203.67 -2.861465e+07
# 14      67158049.6               -22  2.860625e+07  34940865.86 -6.334615e+06
# 15      22078433.3               919  7.644808e+07  36524519.64  3.992356e+07
# 16     -78918553.9              -409  6.192659e+07  26543629.10  3.538296e+07
# 17     -82115395.0              -454  1.321389e+08  17697889.35  1.144410e+08
# 18    -271373660.0              -133  1.675414e+07 -10912360.99  2.766651e+07
# 19    -268289226.6              -130  6.363840e+07 -17828987.47  8.146739e+07
# 20    -360471269.2               -49  2.135075e+07 -38195834.44  5.954659e+07
# 21    -430349650.3                -6 -3.775518e+07 -53082481.59  1.532730e+07
#
#     volume_threshold Volume_Price_Change_break   短交易量    遠交易量       短增量  \
# 11      2.441865e+06                     False  -81.0  1119.0  0.000000
# 12      1.225992e+07                     False -149.0  1618.0  0.613244
# 13      2.277894e+07                     False -132.0     0.0  0.613244
# 14      2.707101e+07                     False -176.0   -22.0  0.893300
# 15      2.679188e+07                     False   52.0   919.0  0.280056
# 16      1.776348e+07                     False  -24.0  -409.0  0.683415
# 17      9.733820e+06                      True   34.0  -454.0  1.047420
# 18     -1.252165e+07                      True  -82.0  -133.0  1.161977
# 19     -1.784452e+07                     False   56.0  -130.0  1.079556
# 20     -3.265959e+07                     False   15.0   -49.0  0.690548
# 21     -4.247966e+07                     False  127.0    -6.0  0.892219
#
#    highlight highlight_date highlight_enddate macd_golden_crosses_area  \
# 11     False            NaN               NaN                    False
# 12     False            NaN               NaN                    False
# 13     False            NaN               NaN                     True
# 14     False            NaN               NaN                     True
# 15     False            NaN               NaN                     True
# 16     False            NaN               NaN                     True
# 17     False            NaN               NaN                     True
# 18     False            NaN               NaN                     True
# 19     False            NaN               NaN                    False
# 20     False            NaN               NaN                    False
# 21     False            NaN               NaN                    False
#
#    VPC_break VO_Positive  VO_Positive_Count buy_points Bar_Color  \
# 11     False        True                2.0      False     green
# 12     False        True                1.0      False     green
# 13     False       False                1.0      False     green
# 14     False       False                1.0      False     green
# 15     False        True                1.0      False       red
# 16     False       False                0.0      False     green
# 17     False       False                0.0      False       red
# 18     False       False                0.0      False     green
# 19     False       False                0.0      False       red
# 20     False       False                1.0      False       red
# 21     False       False                2.0      False     green
#
#                                          Full_Summary  實體長度        K棒型態    上影  \
# 11  <b>分類：</b>空頭排列<br><b>建議：</b><br><b>評分：</b>0<br...  0.25        長黑K棒  0.00
# 12  <b>分類：</b>空頭排列<br><b>建議：</b>建議留意風險<br><b>評分：</...  0.40         NaN  0.30
# 13  <b>分類：</b>空頭排列<br><b>建議：</b><br><b>評分：</b>0<br...  0.15       |下影線長  0.00
# 14  <b>分類：</b>空頭排列<br><b>建議：</b><br><b>評分：</b>0<br...  0.45   長黑K棒|空頭吞噬  0.00
# 15  <b>分類：</b>空頭排列,爆量上攻<br><b>建議：</b><br><b>評分：</b...  0.05  |上影線長|下影線長  0.10
# 16  <b>分類：</b>空頭排列<br><b>建議：</b><br><b>評分：</b>0<br...  0.30         NaN  0.10
# 17  <b>分類：</b>空頭排列,爆量上攻<br><b>建議：</b><br><b>評分：</b...  0.35       |上影線長  0.45
# 18  <b>分類：</b>空頭排列<br><b>建議：</b><br><b>評分：</b>0<br...  0.50        長黑K棒  0.05
# 19  <b>分類：</b>空頭排列,爆量上攻<br><b>建議：</b><br><b>評分：</b...  0.05  |上影線長|下影線長  0.20
# 20  <b>分類：</b>低檔翻揚,空頭排列,爆量上攻<br><b>建議：</b><br><b>評...  0.05    十字線|上影線長  0.45
# 21  <b>分類：</b>空頭排列<br><b>建議：</b><br><b>評分：</b>0<br...  0.20         NaN  0.05
#
#       下影     昨收     昨開     昨高     昨低     今高     今低 K棒方向    K棒續強確認 多日K棒型態  \
# 11  0.05  24.35  24.75  24.75  24.35  24.35  24.10   負向       NaN  |三隻烏鴉
# 12  0.15  24.85  25.00  25.00  24.85  24.75  24.35   中性       NaN  |三隻烏鴉
# 13  0.25  25.00  25.45  25.45  25.00  25.00  24.85   正向       NaN    NaN
# 14  0.00  25.35  25.30  25.35  25.30  25.45  25.00   負向       NaN    NaN
# 15  0.10  25.25  25.55  25.55  25.25  25.35  25.30   負向       NaN    NaN
# 16  0.10  26.15  25.80  26.15  25.80  25.55  25.25   中性       NaN    NaN
# 17  0.25  25.50  26.00  26.00  25.50  26.15  25.80   負向       NaN    NaN
# 18  0.00  26.20  26.15  26.20  26.15  26.00  25.50   負向       NaN    NaN
# 19  0.15  25.80  25.75  25.80  25.75  26.20  26.15   負向  下影大於實體兩倍    |晨星
# 20  0.05  25.70  25.90  25.90  25.70  25.80  25.75   觀望       NaN    NaN
# 21  0.10  25.75  25.20  25.75  25.20  25.90  25.70   中性       NaN    NaN
#
#    多日K棒方向    三白兵   三隻烏鴉     晨星     暮星    Market_State Buy_Signal Sell_Signal  \
# 11     負向  False   True  False  False            空頭排列        NaN         NaN
# 12     負向  False   True  False  False            空頭排列        NaN      建議留意風險
# 13    NaN  False  False  False  False            空頭排列        NaN         NaN
# 14    NaN  False  False  False  False            空頭排列        NaN         NaN
# 15    NaN  False  False  False  False       空頭排列,爆量上攻        NaN         NaN
# 16    NaN  False  False  False  False            空頭排列        NaN         NaN
# 17    NaN  False  False  False  False       空頭排列,爆量上攻        NaN         NaN
# 18    NaN  False  False  False  False            空頭排列        NaN         NaN
# 19     正向  False  False   True  False       空頭排列,爆量上攻        NaN         NaN
# 20    NaN  False  False  False  False  低檔翻揚,空頭排列,爆量上攻        NaN         NaN
# 21    NaN  False  False  False  False            空頭排列        NaN         NaN
#
#    Watch_Signal Reversal_Signal   RSI_diff Action_Advice  Advice_Score  \
# 11          NaN             NaN   1.110705           NaN           0.0
# 12          NaN             NaN  -1.400560        建議留意風險           4.0
# 13          NaN             NaN  -0.595238           NaN           0.0
# 14          NaN             NaN  -1.585447           NaN           0.0
# 15          NaN             NaN   2.180685           NaN           0.0
# 16          NaN             NaN  -4.561404           NaN           0.0
# 17          NaN             NaN   7.306502           NaN           0.0
# 18          NaN             NaN  -5.522876           NaN           0.0
# 19          NaN             NaN  10.758998           NaN           0.0
# 20          NaN             NaN   1.066398           NaN           0.0
# 21          NaN             NaN  -9.891501           NaN           0.0
#
#    stock_number  level interval_type  lower_bound  upper_bound  now_price  \
# 11         1101  100.0           負區間         24.1         24.1      24.10
# 12         1101  100.0           負區間         24.1         24.1      24.35
# 13         1101  100.0           負區間         24.1         24.1      24.85
# 14         1101  100.0           負區間         24.1         24.1      25.00
# 15         1101  100.0           負區間         24.1         24.1      25.35
# 16         1101  100.0           負區間         24.1         24.1      25.25
# 17         1101  100.0           負區間         24.1         24.1      26.15
# 18         1101  100.0           負區間         24.1         24.1      25.50
# 19         1101  100.0           負區間         24.1         24.1      26.20
# 20         1101  100.0           負區間         24.1         24.1      25.80
# 21         1101  100.0           負區間         24.1         24.1      25.70
#
#     change_price change_quote       日期_y  now_price_y  change_price_y  \
# 11         -0.25        -1.03 2025-07-09         24.1           -0.25
# 12         -0.50        -2.02 2025-07-09         24.1           -0.25
# 13         -0.15         -0.6 2025-07-09         24.1           -0.25
# 14         -0.35        -1.38 2025-07-09         24.1           -0.25
# 15          0.10          0.4 2025-07-09         24.1           -0.25
# 16           NaN          0.0 2025-07-09         24.1           -0.25
# 17          0.65         2.52 2025-07-09         24.1           -0.25
# 18         -0.70        -2.69 2025-07-09         24.1           -0.25
# 19          0.40         1.53 2025-07-09         24.1           -0.25
# 20          0.10         0.39 2025-07-09         24.1           -0.25
# 21         -0.05        -0.19 2025-07-09         24.1           -0.25
#
#    change_quote_y Type0 Type1 Type2        Type  MA5_%   均價_% 均價long_% MACD_%  \
# 11         -1.03%    台泥  水泥工業    上市  台泥-水泥工業-上市  -2.55  -3.90    -7.79  -4.72
# 12         -1.03%    台泥  水泥工業    上市  台泥-水泥工業-上市  -2.44  -3.60    -7.56  -1.47
# 13         -1.03%    台泥  水泥工業    上市  台泥-水泥工業-上市  -1.86  -2.74    -7.38   2.50
# 14         -1.03%    台泥  水泥工業    上市  台泥-水泥工業-上市  -1.77  -2.68    -7.21   4.24
# 15         -1.03%    台泥  水泥工業    上市  台泥-水泥工業-上市  -1.32  -2.24    -7.01   6.34
# 16         -1.03%    台泥  水泥工業    上市  台泥-水泥工業-上市  -2.06  -2.29    -6.86   6.57
# 17         -1.03%    台泥  水泥工業    上市  台泥-水泥工業-上市   1.08  -2.28    -6.82   8.99
# 18         -1.03%    台泥  水泥工業    上市  台泥-水泥工業-上市  -1.12  -2.71    -6.92   3.65
# 19         -1.03%    台泥  水泥工業    上市  台泥-水泥工業-上市   1.91  -3.41    -6.82   3.62
# 20         -1.03%    台泥  水泥工業    上市  台泥-水泥工業-上市   0.90  -4.50    -6.51  -2.73
# 21         -1.03%    台泥  水泥工業    上市  台泥-水泥工業-上市   0.31  -4.90    -6.21  -6.91
#
#     VPC_MA_%  Volume_Price_Change_sum  Volume_%  _quote  LevelArea Typelevel  \
# 11  -1119.35            -5.155742e+07   -292.00   -1.03     -100.0    水泥工業右下
# 12  -1618.16            -4.559472e+07     -4.48   -2.02     -100.0    水泥工業右下
# 13      0.16            -8.274451e+05     -1.03   -0.60     -100.0    水泥工業右下
# 14    -22.39             2.860625e+07     -0.18   -1.38     -100.0    水泥工業右下
# 15    919.08             7.644808e+07      1.09    0.40     -100.0    水泥工業右下
# 16    409.71             6.192659e+07      1.33    0.00     -100.0    水泥工業右下
# 17    454.62             1.321389e+08      6.47    2.52     -100.0    水泥工業右下
# 18    133.68             1.675414e+07      2.54   -2.69     -100.0    水泥工業右下
# 19    130.64             6.363840e+07      4.57    1.53     -100.0    水泥工業右下
# 20     49.83             2.135075e+07      1.56    0.39     -100.0    水泥工業右下
# 21      6.53            -3.775518e+07      0.29   -0.19     -100.0    水泥工業右下
#
#     開盤價_y  最高價_y  最低價_y  收盤價_y    漲跌  一年內最高價  一年內最低價    本益比  一年內最大量 一年內最低量  \
# 11  24.35  24.35  24.05   24.1 -0.25   35.45   24.05  18.98  118749   4397
# 12  24.35  24.35  24.05   24.1 -0.25   35.45   24.05  18.98  118749   4397
# 13  24.35  24.35  24.05   24.1 -0.25   35.45   24.05  18.98  118749   4397
# 14  24.35  24.35  24.05   24.1 -0.25   35.45   24.05  18.98  118749   4397
# 15  24.35  24.35  24.05   24.1 -0.25   35.45   24.05  18.98  118749   4397
# 16  24.35  24.35  24.05   24.1 -0.25   35.45   24.05  18.98  118749   4397
# 17  24.35  24.35  24.05   24.1 -0.25   35.45   24.05  18.98  118749   4397
# 18  24.35  24.35  24.05   24.1 -0.25   35.45   24.05  18.98  118749   4397
# 19  24.35  24.35  24.05   24.1 -0.25   35.45   24.05  18.98  118749   4397
# 20  24.35  24.35  24.05   24.1 -0.25   35.45   24.05  18.98  118749   4397
# 21  24.35  24.35  24.05   24.1 -0.25   35.45   24.05  18.98  118749   4397
#
#       成交量  同業平均本益比 一年來最高本益比 一年來最低本益比  盤後量   殖利率     總市值 85年來最高總市值 85年來最低總市值  \
# 11  14566    17.15    35.96    18.98  259  4.15  181983   323,631    17,104
# 12  14566    17.15    35.96    18.98  259  4.15  181983   323,631    17,104
# 13  14566    17.15    35.96    18.98  259  4.15  181983   323,631    17,104
# 14  14566    17.15    35.96    18.98  259  4.15  181983   323,631    17,104
# 15  14566    17.15    35.96    18.98  259  4.15  181983   323,631    17,104
# 16  14566    17.15    35.96    18.98  259  4.15  181983   323,631    17,104
# 17  14566    17.15    35.96    18.98  259  4.15  181983   323,631    17,104
# 18  14566    17.15    35.96    18.98  259  4.15  181983   323,631    17,104
# 19  14566    17.15    35.96    18.98  259  4.15  181983   323,631    17,104
# 20  14566    17.15    35.96    18.98  259  4.15  181983   323,631    17,104
# 21  14566    17.15    35.96    18.98  259  4.15  181983   323,631    17,104
#
#     投資報酬率(07/09) 獲利能力(114.1Q)     今年以來  每股淨值(元)   營業毛利率   貝他值    最近一週  \
# 11  財務比例(114.1Q)  投資風險(07/09)  -20.95%    33.02  16.86%  0.43  -4.55%
# 12  財務比例(114.1Q)  投資風險(07/09)  -20.95%    33.02  16.86%  0.43  -4.55%
# 13  財務比例(114.1Q)  投資風險(07/09)  -20.95%    33.02  16.86%  0.43  -4.55%
# 14  財務比例(114.1Q)  投資風險(07/09)  -20.95%    33.02  16.86%  0.43  -4.55%
# 15  財務比例(114.1Q)  投資風險(07/09)  -20.95%    33.02  16.86%  0.43  -4.55%
# 16  財務比例(114.1Q)  投資風險(07/09)  -20.95%    33.02  16.86%  0.43  -4.55%
# 17  財務比例(114.1Q)  投資風險(07/09)  -20.95%    33.02  16.86%  0.43  -4.55%
# 18  財務比例(114.1Q)  投資風險(07/09)  -20.95%    33.02  16.86%  0.43  -4.55%
# 19  財務比例(114.1Q)  投資風險(07/09)  -20.95%    33.02  16.86%  0.43  -4.55%
# 20  財務比例(114.1Q)  投資風險(07/09)  -20.95%    33.02  16.86%  0.43  -4.55%
# 21  財務比例(114.1Q)  投資風險(07/09)  -20.95%    33.02  16.86%  0.43  -4.55%
#
#     每人營收(仟元)  營業利益率    標準差   最近一個月  每股營收(元)  稅前淨利率    最近二個月    負債比例  資產報酬率  \
# 11  3,501.00  6.58%  1.41%  -7.87%     4.52  5.41%  -18.51%  49.09%  0.31%
# 12  3,501.00  6.58%  1.41%  -7.87%     4.52  5.41%  -18.51%  49.09%  0.31%
# 13  3,501.00  6.58%  1.41%  -7.87%     4.52  5.41%  -18.51%  49.09%  0.31%
# 14  3,501.00  6.58%  1.41%  -7.87%     4.52  5.41%  -18.51%  49.09%  0.31%
# 15  3,501.00  6.58%  1.41%  -7.87%     4.52  5.41%  -18.51%  49.09%  0.31%
# 16  3,501.00  6.58%  1.41%  -7.87%     4.52  5.41%  -18.51%  49.09%  0.31%
# 17  3,501.00  6.58%  1.41%  -7.87%     4.52  5.41%  -18.51%  49.09%  0.31%
# 18  3,501.00  6.58%  1.41%  -7.87%     4.52  5.41%  -18.51%  49.09%  0.31%
# 19  3,501.00  6.58%  1.41%  -7.87%     4.52  5.41%  -18.51%  49.09%  0.31%
# 20  3,501.00  6.58%  1.41%  -7.87%     4.52  5.41%  -18.51%  49.09%  0.31%
# 21  3,501.00  6.58%  1.41%  -7.87%     4.52  5.41%  -18.51%  49.09%  0.31%
#
#       最近三個月  股價淨值比 股東權益報酬率                                               營收比重  \
# 11  -12.08%   0.73   0.25%  水泥,預拌混擬土76.31%、電力供給及儲能,可充式鋰離20.52%、海陸運輸3.17% (...
# 12  -12.08%   0.73   0.25%  水泥,預拌混擬土76.31%、電力供給及儲能,可充式鋰離20.52%、海陸運輸3.17% (...
# 13  -12.08%   0.73   0.25%  水泥,預拌混擬土76.31%、電力供給及儲能,可充式鋰離20.52%、海陸運輸3.17% (...
# 14  -12.08%   0.73   0.25%  水泥,預拌混擬土76.31%、電力供給及儲能,可充式鋰離20.52%、海陸運輸3.17% (...
# 15  -12.08%   0.73   0.25%  水泥,預拌混擬土76.31%、電力供給及儲能,可充式鋰離20.52%、海陸運輸3.17% (...
# 16  -12.08%   0.73   0.25%  水泥,預拌混擬土76.31%、電力供給及儲能,可充式鋰離20.52%、海陸運輸3.17% (...
# 17  -12.08%   0.73   0.25%  水泥,預拌混擬土76.31%、電力供給及儲能,可充式鋰離20.52%、海陸運輸3.17% (...
# 18  -12.08%   0.73   0.25%  水泥,預拌混擬土76.31%、電力供給及儲能,可充式鋰離20.52%、海陸運輸3.17% (...
# 19  -12.08%   0.73   0.25%  水泥,預拌混擬土76.31%、電力供給及儲能,可充式鋰離20.52%、海陸運輸3.17% (...
# 20  -12.08%   0.73   0.25%  水泥,預拌混擬土76.31%、電力供給及儲能,可充式鋰離20.52%、海陸運輸3.17% (...
# 21  -12.08%   0.73   0.25%  水泥,預拌混擬土76.31%、電力供給及儲能,可充式鋰離20.52%、海陸運輸3.17% (...
#
#    獲利能力(113.3Q)                              desc     量能  淨值倍率  diff_quote  \
# 11          NaN  ** 水泥 - 石灰石、水泥生料、水泥熟料、水泥成品、預拌混凝土  12.27  0.73        0.00
# 12          NaN  ** 水泥 - 石灰石、水泥生料、水泥熟料、水泥成品、預拌混凝土  23.28  0.74       -1.04
# 13          NaN  ** 水泥 - 石灰石、水泥生料、水泥熟料、水泥成品、預拌混凝土  11.96  0.75       -3.11
# 14          NaN  ** 水泥 - 石灰石、水泥生料、水泥熟料、水泥成品、預拌混凝土  13.97  0.76       -3.73
# 15          NaN  ** 水泥 - 石灰石、水泥生料、水泥熟料、水泥成品、預拌混凝土  11.04  0.77       -5.19
# 16          NaN  ** 水泥 - 石灰石、水泥生料、水泥熟料、水泥成品、預拌混凝土  17.90  0.76       -4.77
# 17          NaN  ** 水泥 - 石灰石、水泥生料、水泥熟料、水泥成品、預拌混凝土  46.25  0.79       -8.51
# 18          NaN  ** 水泥 - 石灰石、水泥生料、水泥熟料、水泥成品、預拌混凝土  18.05  0.77       -5.81
# 19          NaN  ** 水泥 - 石灰石、水泥生料、水泥熟料、水泥成品、預拌混凝土  14.42  0.79       -8.71
# 20          NaN  ** 水泥 - 石灰石、水泥生料、水泥熟料、水泥成品、預拌混凝土  13.91  0.78       -7.05
# 21          NaN  ** 水泥 - 石灰石、水泥生料、水泥熟料、水泥成品、預拌混凝土   9.91  0.78       -6.64
#
#        價能 rt_price rt_量
# 11  -0.83
# 12  -2.25
# 13   0.41
# 14  -1.80
# 15   0.20
# 16  -1.19
# 17   0.63
# 18  -2.16
# 19   0.01
# 20  -1.36
# 21  -0.58

# %%
def calc_js_equivalent(df: pd.DataFrame, n: int = 5) -> pd.DataFrame:
    df = df.copy()
    df['日期_'] = pd.to_datetime(df['日期'])
    def generate_textdesc(row):
        price_desc = "漲" if row['漲跌BYN天Diff'] > 2 else "跌" if row['漲跌BYN天Diff'] < -3 else "-"
        volume_desc = "增" if row['增縮BYN天Diff'] > 2 else "縮" if row['增縮BYN天Diff'] < -10 else "-"
        return f"價{price_desc}量{volume_desc}"
    def process_group(group):
        group = group.sort_values('日期_').reset_index(drop=True)
    
        group['增縮BYN天'] = group['量能'].rolling(window=n).apply(lambda x: sum(x.dropna()), raw=False).fillna(0).astype(int) 
        group['增縮BYN天Diff'] = group['增縮BYN天'].rolling(window=2).apply(lambda x: sum(x.diff().dropna()), raw=False)
        
        group['漲跌BYN天'] = group['_quote'].rolling(window=n).apply(lambda x: sum(x.dropna()), raw=False).fillna(0).astype(int) 
        group['漲跌BYN天Diff'] = group['漲跌BYN天'].rolling(window=2).apply(lambda x: sum(x.diff().dropna()), raw=False)
            
        group['textdesc'] = group.apply(generate_textdesc, axis=1)
        return group
    
    if 'stock_number' in df.columns:
        df = df.groupby('stock_number', group_keys=False).apply(process_group)
    else:
        df = process_group(df)

    return df
aa = calc_js_equivalent(aa, n=3)
#qq=aa[ (aa['stock_number']=='6776')]
#qq = calc_js_equivalent(qq, n=5)
#qq[ (qq['stock_number']=='6776')][['日期','_quote','量能','漲跌BYN天','增縮BYN天','漲跌BYN天Diff','增縮BYN天Diff','textdesc']]

# %%
#aa[ (aa['highlight'] == True)]

# %%
### COL
aa.columns.values
# Out:
# array(['日期', '成交股數', '成交金額', '開盤價', '最高價', '最低價', '收盤價', '漲跌價差', '成交筆數',
#        '年月日', '前日收盤價', 'MACD', 'MACD-SL', 'MACD_golden_cross', '%K', '%D',
#        'KD_golden_cross', 'MA_short', 'MA_long', 'MA_longlong',
#        'MA_break', 'RSI', 'RSI_rebound', 'Volume_Price_Change',
#        'Volume_MA_short', 'Volume_MA_long', 'Volume_Oscillator',
#        'VPC_MACD', 'VPC_SIGNAL', 'VPC_DIF', 'volume_threshold',
#        'Volume_Price_Change_break', '短交易量', '遠交易量', '短增量', 'highlight',
#        'highlight_date', 'highlight_enddate', 'macd_golden_crosses_area',
#        'VPC_break', 'VO_Positive', 'VO_Positive_Count', 'buy_points',
#        'Bar_Color', 'Full_Summary', '實體長度', 'K棒型態', '上影', '下影', '昨收',
#        '昨開', '昨高', '昨低', '今高', '今低', 'K棒方向', 'K棒續強確認', '多日K棒型態', '多日K棒方向',
#        '三白兵', '三隻烏鴉', '晨星', '暮星', 'Market_State', 'Buy_Signal',
#        'Sell_Signal', 'Watch_Signal', 'Reversal_Signal', 'RSI_diff',
#        'Action_Advice', 'Advice_Score', 'stock_number', 'level',
#        'interval_type', 'lower_bound', 'upper_bound', 'now_price',
#        'change_price', 'change_quote', '日期_y', 'now_price_y',
#        'change_price_y', 'change_quote_y', 'Type0', 'Type1', 'Type2',
#        'Type', 'MA5_%', '均價_%', '均價long_%', 'MACD_%', 'VPC_MA_%',
#        'Volume_Price_Change_sum', 'Volume_%', '_quote', 'LevelArea',
#        'Typelevel', '開盤價_y', '最高價_y', '最低價_y', '收盤價_y', '漲跌', '一年內最高價',
#        '一年內最低價', '本益比', '一年內最大量', '一年內最低量', '成交量', '同業平均本益比', '一年來最高本益比',
#        '一年來最低本益比', '盤後量', '殖利率', '總市值', '85年來最高總市值', '85年來最低總市值',
#        '投資報酬率(07/09)', '獲利能力(114.1Q)', '今年以來', '每股淨值(元)', '營業毛利率', '貝他值',
#        '最近一週', '每人營收(仟元)', '營業利益率', '標準差', '最近一個月', '每股營收(元)', '稅前淨利率',
#        '最近二個月', '負債比例', '資產報酬率', '最近三個月', '股價淨值比', '股東權益報酬率', '營收比重',
#        '獲利能力(113.3Q)', 'desc', '量能', '淨值倍率', 'diff_quote', '價能',
#        'rt_price', 'rt_量', '日期_', '增縮BYN天', '增縮BYN天Diff', '漲跌BYN天',
#        '漲跌BYN天Diff', 'textdesc'], dtype=object)

# %% [markdown]
# ### Distinct Type
# sorted(aa['Type1'].astype(str).unique())

# %%
targetday=today.strftime('%Y-%m-%d')
print(targetday)
#--------------------------------------------------------
output_col=['分類標籤',#'進榜分類紀錄',
            '日期','stock_number','_quote' ,
            
            '成交股數','rt_量', '量能','價能',   #'短增量',
            'now_price', 'rt_price','diff_quote', 
            
            '漲跌BYN天','增縮BYN天','漲跌BYN天Diff','增縮BYN天Diff','textdesc',
            '盤後量','成交量',
            
            'MA5_%', '均價_%','均價long_%' ,'MA_long','MA_longlong', # 'MA_break',
            'MACD_%', 'MACD','MACD-SL',# 'MACD_golden_cross',
            '%K', '%D',        
            
            'VPC_MA_%','VPC_break','短交易量','遠交易量',
            'Volume_MA_short','Volume_MA_long','Volume_Oscillator',
            #'Volume_Price_Change_sum',  'VPC_SIGNAL', 'Volume_Price_Change_break','Volume_%',
            'highlight_date','highlight_enddate',
            'Type0', 'Type1', 'Type2','Full_Summary',
            '淨值倍率','殖利率','每股營收(元)','本益比','營業毛利率','營業利益率',
            '同業平均本益比','總市值','營收比重','Type','Typelevel',
            
            '每股淨值(元)','desc'
           ]

#--------------------------------------------------------
aa['分類標籤']=''
aa['進榜分類紀錄']=''
aa[output_col] = aa[output_col].fillna("0")
aa[output_col] = aa[output_col].astype(str)
aa[output_col] = aa[output_col].replace(["NaN","nan","None", ""], "0")

########################################################################################################
###【太陽圖】當日  表現好 +highlight +Volume_Price_Change_break 整併 


# ========== Step 1：五種分流邏輯 A ~ E ==========

# A 分流：強勢股（MACD 向上交叉、動能轉強、搭配 highlight 或 VPC 突破）
cond_a = (
    (aa['MACD-SL'] >= str(0)) &
    (aa['MACD_%'] > str(0)) &
    (aa['日期'] == targetday) &
    ((aa['highlight'] == True) | (aa['Volume_Price_Change_break'] == True))
)

# B 分流：反彈型股（MACD 尚未交叉，但動能已轉正，屬於初期反彈）
cond_b = (
    (aa['MACD-SL'] < str(0)) &
    (aa['MACD_%'] > str(0)) &
    (aa['日期'] == targetday) &
    ((aa['highlight'] == True) | (aa['Volume_Price_Change_break'] == True))
)

# C 分流：弱勢突破股（MACD 仍為負但有異常行為，疑似主力卡位）
cond_c = (
    (aa['MACD_%'] < str(0)) &
    (aa['日期'] == targetday) &
    ((aa['highlight'] == True) | (aa['Volume_Price_Change_break'] == True))
)

# D 分流：建議關注股（文字摘要中包含「建議關注買點」）
cond_d = (
    aa['stock_number'].isin(
        aa[aa['Full_Summary'].str.contains('建議關注買點', na=False)]['stock_number'].drop_duplicates()
    )
)

# E 分流：多頭排列股（文字摘要中包含「多頭排列」）
cond_e = (
     
    aa['stock_number'].isin(
        aa[  (aa['日期'] == targetday) &
           aa['Full_Summary'].str.contains('多頭排列', na=False)]['stock_number'].drop_duplicates()
    )
)

# ========== Step 2：標記分類標籤 ==========
# 建立「分類標籤」欄位，用於後續輸出及視覺化用途


def add_tag(df, condition, label):
    # 僅在分類標籤中尚未包含該類別時才加入
    df.loc[condition & (~df['分類標籤'].str.contains(label, na=False)), '分類標籤'] += f'{label};'

# 初始化欄位
aa['分類標籤'] = ''

# 累加類別（避免重複）
add_tag(aa, cond_a, '強勢股')
add_tag(aa, cond_b, '反彈型股')
add_tag(aa, cond_c, '弱勢突破股')
add_tag(aa, cond_d, '建議關注股')
add_tag(aa, cond_e, '多頭排列股')

# 清除尾端分號
aa['分類標籤'] = aa['分類標籤'].str.strip(';')
# ========== Step 3：依分類輸出 A ~ E Excel ==========
# 每個類型各自輸出成一份報表
分類對應檔名 = {
    '強勢股': 'Result/checksun_a.xlsx',
    '反彈型股': 'Result/checksun_b.xlsx',
    '弱勢突破股': 'Result/checksun_c.xlsx',
    '建議關注股': 'Result/checksun_d.xlsx',
    '多頭排列股': 'Result/checksun_e.xlsx'
}

for label, filepath in 分類對應檔名.items():
    # Step 1：找出所有「當日符合該類別」的 (股票代號, 日期)
    matched_rows = aa[
        aa['分類標籤'].str.contains(label, na=False)
    ][['stock_number', '日期']].drop_duplicates()

    # ====== 🔒 [進榜分類紀錄寫入] 此區塊已標註，如需啟用可解除註解 ======
    """
    for _, row in matched_rows.iterrows():
        stock = row['stock_number']
        date = row['日期']
        match_idx = aa[aa['stock_number'] == stock].index
        for idx in match_idx:
            entry = f"{label}({date})"
            if entry not in aa.at[idx, '進榜分類紀錄']:
                aa.at[idx, '進榜分類紀錄'] += entry + ';'
    """
    # ======================================================

    # Step 2：從 aa 把這些股票的所有歷史資料撈出來
    matched_stocks = matched_rows['stock_number'].drop_duplicates().tolist()
    df_filtered = aa[aa['stock_number'].isin(matched_stocks)]

    # Step 3：輸出分類檔案（完整歷史資料）
    df_filtered[output_col].drop_duplicates().sort_values(
        by=['stock_number', '日期'], ascending=False
    ).to_excel(filepath, index=False)
# ========== Step 4：F 分流（法人關注度 _quote > 4）==========
# 多日處理，每天輸出一份，放入 Result/checksun_f 資料夾
# 用於觀察法人評分較高的潛力股
os.makedirs('Result/checksun_f', exist_ok=True)

for _date in dateList:
    datalist = aa[(aa['日期'] == _date) & (aa['_quote'] > str(4))]['stock_number'].drop_duplicates().tolist()
    maskfilter = aa['stock_number'].isin(datalist)
    filepath = f'Result/checksun_f/{_date}.xlsx'
    aa[output_col][maskfilter].drop_duplicates().sort_values(
        by=['stock_number', '日期'], ascending=False
    ).to_excel(filepath, index=False)

# ========== Step 5：VPC_break 分流 ==========
# 價量同步突破：VPC_break 為 True
# 對應技術型主力突破行為，屬於短線強勢追蹤股
os.makedirs('Result/checksun_v', exist_ok=True)

datalist = aa[(aa['VPC_break'] == 'True')]['stock_number'].drop_duplicates().tolist()
maskfilter = aa['stock_number'].isin(datalist)
filepath = f'Result/checksun_v/{targetday}.xlsx'
aa[output_col][maskfilter].drop_duplicates().sort_values(by=['stock_number', '日期'], ascending=False).to_excel(filepath, index=False)


# ========== Step 6：其他未分類股票 ==========
# 不在 A～E 類別、非法人關注（F）、也不是 VPC_break（V）

# 先取得所有已有分類的股票代號
classified_stocks = set()

# 加入 A~E 分類股票
for label in 分類對應檔名:
    classified_stocks.update(
        aa[aa['分類標籤'].str.contains(label, na=False)]['stock_number'].drop_duplicates().tolist()
    )

# 加入法人關注 F 類
for _date in dateList:
    classified_stocks.update(
        aa[(aa['日期'] == _date) & (aa['_quote'] > str(2))]['stock_number'].drop_duplicates().tolist()
    )

# 加入 VPC_break 分類
classified_stocks.update(
    aa[
        (aa['VPC_break'] == 'True')
    ]['stock_number'].drop_duplicates().tolist()
)

# 所有股票 - 已分類的 = 其他未分類
all_stocks = aa[aa['日期'] == targetday]['stock_number'].drop_duplicates().tolist()
unclassified_stocks = list(set(all_stocks) - classified_stocks)

# 篩選資料並輸出
maskfilter = aa['stock_number'].isin(unclassified_stocks) & (aa['日期'] == targetday)
filepath = f'Result/checksun_others/{targetday}.xlsx'
os.makedirs('Result/checksun_others', exist_ok=True)

aa[output_col][maskfilter].drop_duplicates().sort_values(
    by=['stock_number', '日期'], ascending=False
).to_excel(filepath, index=False)









###########################################################################################################
#【太陽圖】自定 持有 --------------------------------------------------------------------------------------
#-----------------------------------------------------------------------------------------------
to_excel='Result/checksunmy.xlsx' 
datalist=[ '1101', '1599','2062', '2301', '2349','2542','3066','4966','6789']
maskfilter=(aa['stock_number'].isin(datalist))
aa[output_col][maskfilter].drop_duplicates().sort_values(by=['stock_number','日期',], ascending=False).to_excel(to_excel, index=False)

#【】自定 (By 簡稱)--------------------------------------------------------------------------------------
#-----------------------------------------------------------------------------------------------
#to_excel1='Result/checksundangchong.xlsx'   
#myList=['陽明','長榮','華經','華星光']
#maskfilter=(aa['Type0'].isin(myList))
#aa[output_col][maskfilter].drop_duplicates().sort_values(by=['stock_number','日期',], ascending=False).to_excel(to_excel1, index=False)

###########################################################################################################
########################################################################################################

###【太陽圖】分類別 BY日  -----------------------------------------------------------------------------------
#----------------------------------------------------------------------------------------------------------
os.makedirs('Result/checksun', exist_ok=True)
for Type1 in sorted(aa['Type1'].astype(str).unique()): 
    to_excel1='Result/checksun/'+Type1+'.xlsx'
    datalist=aa[ (aa['Type1']==Type1)]['stock_number'].drop_duplicates().tolist()
    maskfilter=(aa['stock_number'].isin(datalist))# & (aa['highlight']==True) 
    aa[output_col][maskfilter].drop_duplicates().sort_values(by=['stock_number','日期',], ascending=False).to_excel(to_excel1, index=False)


##############################################################################################
##############################################################################################
cc=aa.copy()
cc[output_col] = cc[output_col].astype(str)
cc[output_col] = cc[output_col].replace(["NaN","nan","None", ""], "0")

###【RowData】所有股票 BY日 --------------------------------------------------------------------------------
#-----------------------------------------------------------------------------------------------
os.makedirs('Result/checkall', exist_ok=True)
for _date in dateList: 
    maskfilter=(aa['日期']==_date) 
    to_excel1='Result/checkall/'+_date+'.xlsx'
    cc[output_col][ maskfilter].drop_duplicates().sort_values(by=['stock_number','日期',], ascending=False).to_excel(to_excel1, index=False) 
    
###【RowData】自定 持有---------------------------------------------------------------------------------------
#-----------------------------------------------------------------------------------------------    
to_excel1='Result/checkmy.xlsx'   
myList=[ '1101', '1599','2062', '2301', '2349', '2376', '2542','3066','4966','6789']
maskfilter= (aa['日期']==targetday) & (aa['stock_number'].isin(myList))
cc[output_col][maskfilter].drop_duplicates().sort_values(by=['stock_number','日期',], ascending=False).to_excel(to_excel1, index=False)

##################################################################################################################
# Out:
# 2025-07-09

# %% [markdown]
# analyze_ = aa.copy()
# analyze_['Volume_Price_Change_sum'] = analyze_['Volume_Price_Change_sum'].fillna('0').astype(float)
# analyze_.groupby(['日期', 'Typelevel'])['Volume_Price_Change_sum'].sum().reset_index()
# analyze_.groupby(['日期', 'Typelevel'])['stock_number'].count().reset_index(name='count')
# analyze_[analyze_['_quote'] > 6] .groupby(['日期', 'Typelevel'])['stock_number'].count() .reset_index(name='count')

# %%
analyze_ = aa.copy() 
analyze_['Volume_Price_Change_sum'] = pd.to_numeric(analyze_['Volume_Price_Change_sum'], errors='coerce')

# 1. Volume_Price_Change_sum 總和
#sum_df = analyze_.groupby(['日期', 'Typelevel'])['Volume_Price_Change_sum'].sum()/10000000.reset_index()
sum_df = (analyze_.groupby(['日期', 'Typelevel'])['Volume_Price_Change_sum'].sum() / 1000000).reset_index()

# 2. 全部 stock_number 計數
count_all_df = analyze_.groupby(['日期', 'Typelevel'])['stock_number'].count().reset_index(name='count_total')

# 3. _quote > 6 條件下的 stock_number 計數
count_quote_df = analyze_[analyze_['_quote'] > str(6)].groupby(['日期', 'Typelevel'])['stock_number'].count().reset_index(name='count_quote_gt_6')

# 合併三個結果
merged_df = sum_df.merge(count_all_df, on=['日期', 'Typelevel'], how='left') \
                  .merge(count_quote_df, on=['日期', 'Typelevel'], how='left')

# 若 count_quote_gt_6 有缺值，補 0
merged_df['count_quote_gt_6'] = merged_df['count_quote_gt_6'].fillna(0).astype(int)

# 若 count_quote_gt_6 有缺值，補 0
merged_df['count_total'] = merged_df['count_total'].fillna(0).astype(int)

merged_df['quote_ratio_str'] = merged_df['count_quote_gt_6'].astype(str) + '　/　' + merged_df['count_total'].astype(str)

#ivot_df = 
#merged_df[merged_df['Typelevel']=='通信網路業右上']
merged_df.pivot(index='Typelevel', columns='日期',values='count_total').to_excel( 'Result/analyze.xlsx') 
merged_df.pivot(index='Typelevel', columns='日期',values='count_quote_gt_6').to_excel( 'Result/analyze_1.xlsx') 
merged_df.pivot(index='Typelevel', columns='日期',values='Volume_Price_Change_sum').to_excel( 'Result/analyze_2.xlsx')

# %%
#----------------------------------------------------------

# %% [markdown]
# datalist=[ '6240']#[ '3570']
# maskfilter=(aa['stock_number'].isin(datalist))
# aa[output_col][maskfilter].drop_duplicates().sort_values(by=['stock_number','日期',], ascending=False)

# %%
# JS CHECK DATA

# %% [markdown]
# function getMissingElements(array1, array2) {
#     return array1.filter(element => !array2.includes(element));
#
# }
# array1=app.jsonData.map(x=>x.stock_number)
# array2=app.filteredData.map(x=>x.stock_number)
# getMissingElements(array1, array2);
