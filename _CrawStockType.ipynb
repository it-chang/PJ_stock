# %%
# %run _BaseInfo.ipynb
import time
from openpyxl import load_workbook
from collections import defaultdict 

def save_excel(file_name,df):
    sheet_name='Sheet1'
    try:
        # 嘗試加載現有的 Excel 文件
        book = load_workbook(file_name)
        with pd.ExcelWriter(file_name, engine='openpyxl', mode='a', if_sheet_exists='overlay') as writer:
            # 加載現有數據
            writer.book = book
            if sheet_name in book.sheetnames:
                existing_df = pd.read_excel(file_name, sheet_name=sheet_name)
                #df = pd.concat([existing_df, df], ignore_index=True)
            # 將 DataFrame 寫入指定的 Sheet
            df.to_excel(writer, sheet_name=sheet_name, index=False)
    except FileNotFoundError:
        # 如果文件不存在，創建新文件並寫入 DataFrame
        with pd.ExcelWriter(file_name, engine='openpyxl') as writer:
            df.to_excel(writer, sheet_name=sheet_name, index=False)

# %% [markdown]
#  # 爬蟲 個體公司所屬產業鏈
# 	https://ic.tpex.org.tw/company_chain.php?stk_code=2308

# %%
df_data_all= pd.DataFrame()
stock_list = _baseInfo.dropna()['公司代號'].iloc[::-1]
#stock_list=['1101','2308']
for code in stock_list:
    print(code)
    try:
        time.sleep(1)
        url='https://ic.tpex.org.tw/company_chain.php?stk_code='+code
        print(url)
        response = requests.get(url,verify = False)
        response.encoding = 'utf-8'
        df = pd.DataFrame()
        df = pd.concat([df, pd.DataFrame([[str(code)]], columns=['stock_number'])], ignore_index=True)
        
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, "html.parser")

            content_div = soup.select_one('.content')
            h4_tags = content_div.find_all('h4')

            result = []
            for h4 in h4_tags:
                # 如果包含 > 字符代表是步道資料
                if '>' in h4.text:
                    link_text = h4.find('a').text.strip()
                    right_part = h4.text.split('>')[-1].strip()
                    result.append(f"{link_text} - {right_part}")

            # 輸出
            raw_data=''
            for item in result:
                raw_data+=','+item


            # 初始化分類字典
            category_dict = defaultdict(list)

            # 用逗號分割項目
            for line in raw_data.split(','):
                line = line.strip()
                if ' - ' in line:
                    category, item = line.split(' - ', 1)
                    category_dict[category].append(item)


            # 輸出整理結果
            stringall=''
            for category, items in category_dict.items():
                combined_items = '、'.join(items)
                stringall+=f"** {category} - {combined_items}"
                print(f"** {category} - {combined_items}")
            df['desc']=stringall
            save_df=df   
            df_data_all=pd.concat([ df_data_all,save_df], axis=0)

    except Exception as error:
        print('error'+code)
        print('error'+error)
# Out:
# 9962
# https://ic.tpex.org.tw/company_chain.php?stk_code=9962
# ** 鋼鐵 - 冷熱軋不鏽鋼板捲
# 9960
# https://ic.tpex.org.tw/company_chain.php?stk_code=9960
# ** 休閒娛樂 - 高爾夫球具業
# 9951
# https://ic.tpex.org.tw/company_chain.php?stk_code=9951
# ** 電機機械 - 車用機械傳動設備及零配件
# ** 汽車 - 其他
# 9950
# https://ic.tpex.org.tw/company_chain.php?stk_code=9950
# ** 石化及塑橡膠 - 塑膠製品
# 9949
# https://ic.tpex.org.tw/company_chain.php?stk_code=9949
# ** 其他 - 文化印刷業
# ** 文化創意業 - 工藝產業
# 8942
# https://ic.tpex.org.tw/company_chain.php?stk_code=8942
# ** 建材營造 - 個人、民間企業、政府機構
# ** 其他 - 其他
# 8941
# https://ic.tpex.org.tw/company_chain.php?stk_code=8941
# ** 貿易百貨 - 製造商、貿易商、代理商、經銷商、零售通路
# 8938
# https://ic.tpex.org.tw/company_chain.php?stk_code=8938
# ** 休閒娛樂 - 高爾夫球具業
# 8937
# https://ic.tpex.org.tw/company_chain.php?stk_code=8937
# ** 休閒娛樂 - 休閒車業
# ** 電動車輛產業 - 電動汽車、電動機車、電動自行車
# 8936
# https://ic.tpex.org.tw/company_chain.php?stk_code=8936
# ** 鋼鐵 - 製管
# ** 建材營造 - 營造業
# 8935
# https://ic.tpex.org.tw/company_chain.php?stk_code=8935
# ** 石化及塑橡膠 - 塑膠製品
# 8933
# https://ic.tpex.org.tw/company_chain.php?stk_code=8933
# ** 休閒娛樂 - 休閒車業
# ** 電動車輛產業 - 電動汽車、電動機車、電動自行車
# 8932
# https://ic.tpex.org.tw/company_chain.php?stk_code=8932
# ** 其他 - 其他
# 8931
# https://ic.tpex.org.tw/company_chain.php?stk_code=8931
# ** 油電燃氣 - 汽電共生
# 8930
# https://ic.tpex.org.tw/company_chain.php?stk_code=8930
# ** 鋼鐵 - 金屬製品
# ** 建材營造 - 建材原料
# 8929
# https://ic.tpex.org.tw/company_chain.php?stk_code=8929
# ** 醫療器材 - 衛生用品
# 8928
# https://ic.tpex.org.tw/company_chain.php?stk_code=8928
# ** 休閒娛樂 - 高爾夫球具業
# 8927
# https://ic.tpex.org.tw/company_chain.php?stk_code=8927
# ** 油電燃氣 - 加油站
# 8924
# https://ic.tpex.org.tw/company_chain.php?stk_code=8924
# ** 休閒娛樂 - 高爾夫球具業
# ** 運動科技 - 運動用品
# 8923
# https://ic.tpex.org.tw/company_chain.php?stk_code=8923
# ** 文化創意業 - 出版產業
# 8921
# https://ic.tpex.org.tw/company_chain.php?stk_code=8921
# ** 其他 - 文化印刷業
# 8917
# https://ic.tpex.org.tw/company_chain.php?stk_code=8917
# ** 油電燃氣 - 天然瓦斯供應
# 8916
# https://ic.tpex.org.tw/company_chain.php?stk_code=8916
# ** 紡織 - 成衣及其它家居紡織類品
# ** 貿易百貨 - 製造商、零售通路
# 8908
# https://ic.tpex.org.tw/company_chain.php?stk_code=8908
# ** 油電燃氣 - 天然瓦斯供應
# 8906
# https://ic.tpex.org.tw/company_chain.php?stk_code=8906
# ** 其他 - 文化印刷業
# 8905
# https://ic.tpex.org.tw/company_chain.php?stk_code=8905
# ** 食品 - 原物料、加工食品、冷凍、罐頭、脫水、醃漬食品
# ** 建材營造 - 建設業
# ** 其他 - 其他
# 8489
# https://ic.tpex.org.tw/company_chain.php?stk_code=8489
# ** 其他 - 其他
# ** 文化創意業 - 數位內容產業
# 8477
# https://ic.tpex.org.tw/company_chain.php?stk_code=8477
# ** 電子商務 - 一般零售
# 8472
# https://ic.tpex.org.tw/company_chain.php?stk_code=8472
# ** 食品 - 原物料
# ** 電子商務 - 一般零售、票券銷售
# ** 貿易百貨 - 零售通路
# 8455
# https://ic.tpex.org.tw/company_chain.php?stk_code=8455
# ** 電腦及週邊設備 - 其他電腦及週邊設備之零組件
# 8450
# https://ic.tpex.org.tw/company_chain.php?stk_code=8450
# ** 文化創意業 - 流行音樂及文化內容產業
# 8446
# https://ic.tpex.org.tw/company_chain.php?stk_code=8446
# ** 其他 - 文化印刷業
# ** 文化創意業 - 流行音樂及文化內容產業
# 8444
# https://ic.tpex.org.tw/company_chain.php?stk_code=8444
# ** 其他 - 其他
# 8440
# https://ic.tpex.org.tw/company_chain.php?stk_code=8440
# ** 其他 - 環保潔能服務產業
# 8437
# https://ic.tpex.org.tw/company_chain.php?stk_code=8437
# ** 其他 - 其他
# 8436
# https://ic.tpex.org.tw/company_chain.php?stk_code=8436
# ** 食品生技 - 加工製成品
# 8435
# https://ic.tpex.org.tw/company_chain.php?stk_code=8435
# ** 其他 - 環保潔能服務產業、其他
# 8433
# https://ic.tpex.org.tw/company_chain.php?stk_code=8433
# ** 貿易百貨 - 貿易商、代理商、經銷商
# 8432
# https://ic.tpex.org.tw/company_chain.php?stk_code=8432
# ** 製藥 - 藥品代理銷售及通路
# 8431
# https://ic.tpex.org.tw/company_chain.php?stk_code=8431
# ** 連接器 - 電鍍材料
# ** 其他 - 其他
# 8426
# https://ic.tpex.org.tw/company_chain.php?stk_code=8426
# ** 其他 - 其他
# 8424
# https://ic.tpex.org.tw/company_chain.php?stk_code=8424
# ** 建材營造 - 建材原料
# 8423
# https://ic.tpex.org.tw/company_chain.php?stk_code=8423
# ** 其他 - 環保潔能服務產業
# 8421
# https://ic.tpex.org.tw/company_chain.php?stk_code=8421
# ** 電機機械 - 專用機械(如紡織成衣生產用機械、食品飲料生產用機械、農林用機械等)
# ** 其他 - 其他
# 8416
# https://ic.tpex.org.tw/company_chain.php?stk_code=8416
# ** 軟體服務 - 系統整合服務
# 8415
# https://ic.tpex.org.tw/company_chain.php?stk_code=8415
# ** 鋼鐵 - 螺絲螺帽
# ** 貿易百貨 - 零售通路
# 8410
# https://ic.tpex.org.tw/company_chain.php?stk_code=8410
# ** 電腦及週邊設備 - 機殼
# 8409
# https://ic.tpex.org.tw/company_chain.php?stk_code=8409
# ** 醫療器材 - 其他
# 8403
# https://ic.tpex.org.tw/company_chain.php?stk_code=8403
# ** 製藥 - 藥品代理銷售及通路
# ** 食品生技 - 保健食品代理銷售及通路
# ** 醫療器材 - 醫療器材代理、醫療院所、醫療器材專賣店、藥局等通路
# 8401
# https://ic.tpex.org.tw/company_chain.php?stk_code=8401
# ** 其他 - 文化印刷業
# 8390
# https://ic.tpex.org.tw/company_chain.php?stk_code=8390
# ** 其他 - 環保潔能服務產業
# 8383
# https://ic.tpex.org.tw/company_chain.php?stk_code=8383
# ** 半導體 - 生產製程及檢測設備
# ** 平面顯示器 - 其他零組件
# ** 電機機械 - 機電系統工程、金屬加工處理
# ** 建材營造 - 機電工程、工程設計、工程承攬
# ** 其他 - 其他
# 8358
# https://ic.tpex.org.tw/company_chain.php?stk_code=8358
# ** 印刷電路板 - 銅箔
# ** 電動車輛產業 - 鋰電池材料
# 8354
# https://ic.tpex.org.tw/company_chain.php?stk_code=8354
# ** 其他 - 其他
# 8349
# https://ic.tpex.org.tw/company_chain.php?stk_code=8349
# ** 鋼鐵 - 螺絲螺帽
# ** 電動車輛產業 - 大功率鋰電池芯/模組、電池管理系統、動力馬達等零組件
# 8342
# https://ic.tpex.org.tw/company_chain.php?stk_code=8342
# ** 其他 - 其他
# 8299
# https://ic.tpex.org.tw/company_chain.php?stk_code=8299
# ** 半導體 - IC模組、IC通路、IP設計/IC設計代工服務、記憶體控制IC
# ** 電腦及週邊設備 - 記憶體、隨身碟、記憶卡讀卡機、其他電腦及週邊設備之零組件
# 8291
# https://ic.tpex.org.tw/company_chain.php?stk_code=8291
# ** 印刷電路板 - 銅箔基板
# 8289
# https://ic.tpex.org.tw/company_chain.php?stk_code=8289
# ** 被動元件 - 濾波器、振盪器
# 8284
# https://ic.tpex.org.tw/company_chain.php?stk_code=8284
# ** 軟體服務 - 應用/系統軟體設計開發、系統整合服務
# ** 電子商務 - 資訊系統建置服務、資料分析處理服務、行銷廣告服務、資訊聚合
# ** 金融科技 - 理財投資
# 8279
# https://ic.tpex.org.tw/company_chain.php?stk_code=8279
# ** 食品生技 - 原料、加工製成品、保健食品代理銷售及通路
# 8277
# https://ic.tpex.org.tw/company_chain.php?stk_code=8277
# ** 半導體 - IC模組
# ** 電腦及週邊設備 - 記憶體
# ** 雲端運算 - 電腦設備、伺服器、儲存、網路
# ** 資通訊安全 - 資料安全、網頁內容安全、雲端安全、身分認證與訪問管理
# 8272
# https://ic.tpex.org.tw/company_chain.php?stk_code=8272
# ** 資通訊安全 - 資料安全、雲端安全、網路安全防護、物聯網安全、端點安全防護、身分認證與訪問管理、行動安全
# 8255
# https://ic.tpex.org.tw/company_chain.php?stk_code=8255
# ** 電機機械 - 車用機械傳動設備及零配件
# ** 電動車輛產業 - 大功率鋰電池芯/模組、電池管理系統、動力馬達等零組件
# 8240
# https://ic.tpex.org.tw/company_chain.php?stk_code=8240
# ** 電腦及週邊設備 - 散熱片、風扇馬達、散熱模組
# ** 平面顯示器 - 稜鏡片、擴散膜、增亮膜、導光板
# ** 觸控面板 - ITO導電薄膜
# ** 通信網路 - 塑膠/金屬機殼
# ** 連接器 - 塑膠材料
# ** 印刷電路板 - 玻璃纖維/玻纖布、環氧樹脂
# 8234
# https://ic.tpex.org.tw/company_chain.php?stk_code=8234
# ** 電腦及週邊設備 - 工業電腦
# 8227
# https://ic.tpex.org.tw/company_chain.php?stk_code=8227
# ** 半導體 - IP設計/IC設計代工服務
# 8183
# https://ic.tpex.org.tw/company_chain.php?stk_code=8183
# ** 印刷電路板 - 基板組裝加工及相關製造
# ** 電動車輛產業 - 大功率鋰電池芯/模組、電池管理系統、動力馬達等零組件
# ** 醫療器材 - 顯示器
# 8182
# https://ic.tpex.org.tw/company_chain.php?stk_code=8182
# ** 被動元件 - 濾波器、振盪器
# 8176
# https://ic.tpex.org.tw/company_chain.php?stk_code=8176
# ** 通信網路 - 網路設備(如數據機、網路卡、閘道器、路由器、網路電話)
# 8171
# https://ic.tpex.org.tw/company_chain.php?stk_code=8171
# ** 通信網路 - 其他零組件
# ** 電動車輛產業 - 大功率鋰電池芯/模組、電池管理系統、動力馬達等零組件
# ** 能源元件 - 電池模組
# 8155
# https://ic.tpex.org.tw/company_chain.php?stk_code=8155
# ** 印刷電路板 - 硬板、軟板、IC載板製造
# 8147
# https://ic.tpex.org.tw/company_chain.php?stk_code=8147
# ** 連接器 - 連接器設計、組裝及製造
# 8121
# https://ic.tpex.org.tw/company_chain.php?stk_code=8121
# ** 被動元件 - 電感器材料(如鐵氧體、導電漿墨)
# 8111
# https://ic.tpex.org.tw/company_chain.php?stk_code=8111
# ** LED照明產業 - 封裝/模組、燈具/應用
# 8109
# https://ic.tpex.org.tw/company_chain.php?stk_code=8109
# ** 半導體 - IC封裝測試
# ** 通信網路 - 其他零組件
# ** 電機機械 - 電控元件
# ** 交通運輸及航運 - 海陸空大眾運輸
# ** 其他 - 其他電子產品及電子服務產業
# ** 醫療器材 - 電子零組件、塑膠零件、五金零件、塑化材料、金屬零件
# ** LED照明產業 - 生產製程、檢測設備及原物料
# ** 電動車輛產業 - 大功率鋰電池芯/模組、電池管理系統、動力馬達等零組件
# ** 太陽能產業 - 太陽能電池模組、太陽能發電設備/系統及系統工程
# ** 能源元件 - 電池模組
# 8107
# https://ic.tpex.org.tw/company_chain.php?stk_code=8107
# ** 汽車 - 其他
# 8099
# https://ic.tpex.org.tw/company_chain.php?stk_code=8099
# ** 電腦及週邊設備 - 筆記型電腦、桌上型電腦、伺服器、其他電腦及週邊設備
# ** 通信網路 - 網路設備(如數據機、網路卡、閘道器、路由器、網路電話)、有線通訊設備(如電話機、傳真機)
# ** 軟體服務 - 應用/系統軟體設計開發、系統整合服務、資料處理服務、通路經銷
# ** 人工智慧 - 系統整合、領域解決方案、機器學習、自然語言處理、運算設備、雲端平台、資料處理
# ** 雲端運算 - 設備管理軟體、營運管理軟體、虛擬化軟體、雲端作業系統、資安防護軟體、雲端應用服務、系統整合、顧問諮詢、設備安裝服務、IaaS、PaaS、SaaS
# ** 大數據 - 系統整合、顧問諮詢、領域解決方案、分析工具、應用軟體、雲端平台
# ** 體驗科技 - 資服、系統整合、IT服務
# ** 智慧電網 - 系統整合服務
# 8097
# https://ic.tpex.org.tw/company_chain.php?stk_code=8097
# ** 通信網路 - 網路設備(如數據機、網路卡、閘道器、路由器、網路電話)
# 8096
# https://ic.tpex.org.tw/company_chain.php?stk_code=8096
# ** 半導體 - IC通路
# ** 電腦及週邊設備 - 中央處理器
# ** 通信網路 - 網路IC、微處理器、記憶體
# 8093
# https://ic.tpex.org.tw/company_chain.php?stk_code=8093
# ** 電腦及週邊設備 - 電源供應器
# 8092
# https://ic.tpex.org.tw/company_chain.php?stk_code=8092
# ** 半導體 - 生產製程及檢測設備
# ** 電機機械 - 金屬加工用機械、專用機械(如紡織成衣生產用機械、食品飲料生產用機械、農林用機械等)
# 8091
# https://ic.tpex.org.tw/company_chain.php?stk_code=8091
# ** 半導體 - 生產製程及檢測設備
# ** LED照明產業 - 生產製程、檢測設備及原物料
# 8089
# https://ic.tpex.org.tw/company_chain.php?stk_code=8089
# ** 通信網路 - 網路設備(如數據機、網路卡、閘道器、路由器、網路電話)、光通訊設備(如光纖電纜、光傳輸設備)
# 8088
# https://ic.tpex.org.tw/company_chain.php?stk_code=8088
# ** 半導體 - IC模組
# ** 電腦及週邊設備 - 記憶體、隨身碟、記憶卡讀卡機
# ** 通信網路 - 記憶體
# 8087
# https://ic.tpex.org.tw/company_chain.php?stk_code=8087
# ** 太陽能產業 - 太陽能發電設備/系統及系統工程、太陽能電廠
# 8086
# https://ic.tpex.org.tw/company_chain.php?stk_code=8086
# ** 半導體 - 晶圓製造
# 8085
# https://ic.tpex.org.tw/company_chain.php?stk_code=8085
# ** 電腦及週邊設備 - 其他電腦及週邊設備
# ** 平面顯示器 - 背光模組、顯示器模組
# ** 被動元件 - 電阻器
# ** LED照明產業 - 封裝/模組、燈具/應用
# 8084
# https://ic.tpex.org.tw/company_chain.php?stk_code=8084
# ** 半導體 - IC通路
# ** 通信網路 - 記憶體
# 8083
# https://ic.tpex.org.tw/company_chain.php?stk_code=8083
# ** 電機機械 - 輸送機械及零配件、車用機械傳動設備及零配件
# 8080
# https://ic.tpex.org.tw/company_chain.php?stk_code=8080
# ** 建材營造 - 基礎工程
# 8077
# https://ic.tpex.org.tw/company_chain.php?stk_code=8077
# ** 休閒娛樂 - 旅館服務業
# 8076
# https://ic.tpex.org.tw/company_chain.php?stk_code=8076
# ** 電腦及週邊設備 - 工業電腦
# 8074
# https://ic.tpex.org.tw/company_chain.php?stk_code=8074
# ** 印刷電路板 - 硬板、軟板、IC載板製造
# 8071
# https://ic.tpex.org.tw/company_chain.php?stk_code=8071
# ** 電腦及週邊設備 - 印表機、傳真機、掃瞄器、多功能事務機、投影機
# ** 被動元件 - 電阻器、電容器、電感器、濾波器、振盪器
# ** 運動科技 - 運動用品
# ** 醫療器材 - 隱型眼鏡、光學鏡片
# 8069
# https://ic.tpex.org.tw/company_chain.php?stk_code=8069
# ** 平面顯示器 - 面板、電子書
# 8068
# https://ic.tpex.org.tw/company_chain.php?stk_code=8068
# ** 半導體 - IC通路
# 8067
# https://ic.tpex.org.tw/company_chain.php?stk_code=8067
# ** 半導體 - IC通路
# 8066
# https://ic.tpex.org.tw/company_chain.php?stk_code=8066
# ** 貿易百貨 - 貿易商、代理商、經銷商
# 8064
# https://ic.tpex.org.tw/company_chain.php?stk_code=8064
# ** 半導體 - 生產製程及檢測設備
# ** 平面顯示器 - 生產製程及檢測設備
# 8059
# https://ic.tpex.org.tw/company_chain.php?stk_code=8059
# ** 通信網路 - 網路設備(如數據機、網路卡、閘道器、路由器、網路電話)
# 8054
# https://ic.tpex.org.tw/company_chain.php?stk_code=8054
# ** 半導體 - IC模組、IP設計/IC設計代工服務、消費性IC、輸出入介面IC
# ** 大數據 - 儲存處理
# ** 雲端運算 - 儲存
# 8050
# https://ic.tpex.org.tw/company_chain.php?stk_code=8050
# ** 電腦及週邊設備 - 工業電腦
# 8049
# https://ic.tpex.org.tw/company_chain.php?stk_code=8049
# ** 平面顯示器 - 顯示器模組
# 8048
# https://ic.tpex.org.tw/company_chain.php?stk_code=8048
# ** 通信網路 - 網路設備(如數據機、網路卡、閘道器、路由器、網路電話)、光通訊設備(如光纖電纜、光傳輸設備)、無線通訊設備(如行動電話、衛星定位系統、衛星通訊設備、微波通訊設備、數位機上盒)
# 8047
# https://ic.tpex.org.tw/company_chain.php?stk_code=8047
# ** 其他 - 其他電子產品及電子服務產業
# 8044
# https://ic.tpex.org.tw/company_chain.php?stk_code=8044
# ** 電子商務 - 物流倉儲服務、資訊系統建置服務、金流串接處理服務、資料分析處理服務、行銷廣告服務、店點開設管理、資訊聚合、一般零售、票券銷售
# 8043
# https://ic.tpex.org.tw/company_chain.php?stk_code=8043
# ** 被動元件 - 電容器
# 8042
# https://ic.tpex.org.tw/company_chain.php?stk_code=8042
# ** 被動元件 - 電容器
# 8040
# https://ic.tpex.org.tw/company_chain.php?stk_code=8040
# ** 半導體 - 網路通訊IC
# 8038
# https://ic.tpex.org.tw/company_chain.php?stk_code=8038
# ** 電動車輛產業 - 鋰電池材料、大功率鋰電池芯/模組、電池管理系統、動力馬達等零組件
# ** 能源元件 - 原材料、電池芯、電池模組
# 8034
# https://ic.tpex.org.tw/company_chain.php?stk_code=8034
# ** 通信網路 - 網路設備(如數據機、網路卡、閘道器、路由器、網路電話)、光通訊設備(如光纖電纜、光傳輸設備)、有線通訊設備(如電話機、傳真機)
# ** 其他 - 其他電子產品及電子服務產業
# 8032
# https://ic.tpex.org.tw/company_chain.php?stk_code=8032
# ** 半導體 - IC通路
# 8027
# https://ic.tpex.org.tw/company_chain.php?stk_code=8027
# ** 自動化 - 自動化機台
# ** 半導體 - 生產製程及檢測設備、生產製程及檢測設備
# ** 電機機械 - 專用機械(如紡織成衣生產用機械、食品飲料生產用機械、農林用機械等)
# 8024
# https://ic.tpex.org.tw/company_chain.php?stk_code=8024
# ** 半導體 - 消費性IC、微控制器IC
# 7782
# https://ic.tpex.org.tw/company_chain.php?stk_code=7782
# ** 電子商務 - 資訊系統建置服務、行銷廣告服務、自有產品(服務)銷售、一般零售
# ** 貿易百貨 - 零售通路
# 7757
# https://ic.tpex.org.tw/company_chain.php?stk_code=7757
# ** 食品 - 餐飲連鎖
# 7753
# https://ic.tpex.org.tw/company_chain.php?stk_code=7753
# ** LED照明產業 - 燈具/應用
# 7751
# https://ic.tpex.org.tw/company_chain.php?stk_code=7751
# ** 半導體 - 生產製程及檢測設備、IC封裝測試
# 7747
# https://ic.tpex.org.tw/company_chain.php?stk_code=7747
# ** 軟體服務 - 通路經銷
# ** 人工智慧 - 系統整合、領域解決方案、雲端平台
# ** 雲端運算 - 設備管理軟體、虛擬化軟體、雲端作業系統、資安防護軟體、IaaS、SaaS
# ** 資通訊安全 - 安全營運與事件回應、資料安全、網頁內容安全、雲端安全、網路基礎設施、網路安全防護、物聯網安全、端點安全防護、身分認證與訪問管理、資安顧問服務
# ** 大數據 - 資料庫、分析工具、應用軟體、雲端平台
# 7743
# https://ic.tpex.org.tw/company_chain.php?stk_code=7743
# ** 食品 - 加工食品
# 7738
# https://ic.tpex.org.tw/company_chain.php?stk_code=7738
# ** 金融科技 - 支付
# 7734
# https://ic.tpex.org.tw/company_chain.php?stk_code=7734
# ** 半導體 - 生產製程及檢測設備
# 7728
# https://ic.tpex.org.tw/company_chain.php?stk_code=7728
# ** 半導體 - 生產製程及檢測設備、生產製程及檢測設備
# ** 其他 - 其他電子產品及電子服務產業
# 7723
# https://ic.tpex.org.tw/company_chain.php?stk_code=7723
# ** 食品 - 餐飲連鎖
# 7718
# https://ic.tpex.org.tw/company_chain.php?stk_code=7718
# ** 汽車 - 其他
# 7716
# https://ic.tpex.org.tw/company_chain.php?stk_code=7716
# ** 交通運輸及航運 - 海陸空貨運承攬
# 7715
# https://ic.tpex.org.tw/company_chain.php?stk_code=7715
# ** 其他 - 環保潔能服務產業
# 7714
# https://ic.tpex.org.tw/company_chain.php?stk_code=7714
# ** 通信網路 - 網路設備(如數據機、網路卡、閘道器、路由器、網路電話)
# ** 軟體服務 - 系統整合服務、通路經銷
# ** 金融科技 - 數據分析、數位身分
# ** 人工智慧 - 系統整合、顧問諮詢、領域解決方案、機器學習、自然語言處理、雲端平台、資料處理
# ** 雲端運算 - 設備管理軟體、營運管理軟體、資安防護軟體、系統整合、顧問諮詢、SaaS
# ** 資通訊安全 - 安全營運與事件回應、資安治理、資料安全、網頁內容安全、雲端安全、網路基礎設施、網路安全防護、物聯網安全、端點安全防護、身分認證與訪問管理、行動安全、資安防護能力分析與鑑識服務、資安營運管理服務、資安顧問服務
# 7713
# https://ic.tpex.org.tw/company_chain.php?stk_code=7713
# ** 食品生技 - 保健食品代理銷售及通路
# ** 雲端運算 - SaaS
# ** 醫療器材 - 醫療器材代理
# 7712
# https://ic.tpex.org.tw/company_chain.php?stk_code=7712
# ** 半導體 - 電源管理IC
# 7709
# https://ic.tpex.org.tw/company_chain.php?stk_code=7709
# ** 自動化 - 自動化機台
# ** 電機機械 - 金屬加工用機械
# 7708
# https://ic.tpex.org.tw/company_chain.php?stk_code=7708
# ** 食品 - 餐飲連鎖
# 7704
# https://ic.tpex.org.tw/company_chain.php?stk_code=7704
# ** 半導體 - 生產製程及檢測設備
# 7703
# https://ic.tpex.org.tw/company_chain.php?stk_code=7703
# ** 半導體 - 生產製程及檢測設備
# ** 平面顯示器 - 生產製程及檢測設備
# ** 其他 - 其他電子產品及電子服務產業
# 7642
# https://ic.tpex.org.tw/company_chain.php?stk_code=7642
# ** 電機機械 - 電控元件、機電系統工程
# 7584
# https://ic.tpex.org.tw/company_chain.php?stk_code=7584
# ** 文化創意業 - 數位內容產業
# ** 休閒娛樂 - 營運發行
# 7556
# https://ic.tpex.org.tw/company_chain.php?stk_code=7556
# ** 半導體 - 生產製程及檢測設備、生產製程及檢測設備
# 7547
# https://ic.tpex.org.tw/company_chain.php?stk_code=7547
# ** 軟體服務 - 應用/系統軟體設計開發、系統整合服務、資料處理服務
# ** 人工智慧 - 系統整合、顧問諮詢、領域解決方案、機器學習、自然語言處理、雲端平台、資料處理
# ** 雲端運算 - 營運管理軟體、雲端應用服務、系統整合、顧問諮詢、IaaS、PaaS、SaaS
# ** 大數據 - 系統整合、顧問諮詢、應用軟體、雲端平台
# 7402
# https://ic.tpex.org.tw/company_chain.php?stk_code=7402
# ** 電腦及週邊設備 - 其他電腦及週邊設備
# 6997
# https://ic.tpex.org.tw/company_chain.php?stk_code=6997
# ** 軟體服務 - 通路經銷
# ** 人工智慧 - 系統整合、顧問諮詢、領域解決方案、智慧設備、機器學習、電腦視覺、自然語言處理、移動控制、雲端平台、資料處理
# ** 雲端運算 - 營運管理軟體、虛擬化軟體、雲端作業系統、資安防護軟體、系統整合、顧問諮詢、IaaS
# ** 大數據 - 系統整合、顧問諮詢、領域解決方案、資料庫、分析工具、應用軟體、雲端平台、儲存處理
# 6996
# https://ic.tpex.org.tw/company_chain.php?stk_code=6996
# ** 半導體 - 平面顯示器驅動IC
# 6982
# https://ic.tpex.org.tw/company_chain.php?stk_code=6982
# ** 電機機械 - 傳動元件
# 6971
# https://ic.tpex.org.tw/company_chain.php?stk_code=6971
# ** 其他 - 環保潔能服務產業
# 6968
# https://ic.tpex.org.tw/company_chain.php?stk_code=6968
# ** 貿易百貨 - 貿易商、代理商、經銷商、零售通路
# 6967
# https://ic.tpex.org.tw/company_chain.php?stk_code=6967
# ** 電腦及週邊設備 - 其他電腦及週邊設備之零組件
# ** 通信網路 - 其他零組件
# 6953
# https://ic.tpex.org.tw/company_chain.php?stk_code=6953
# ** 半導體 - 生產製程及檢測設備
# 6929
# https://ic.tpex.org.tw/company_chain.php?stk_code=6929
# ** 醫療器材 - 醫療院所、醫療器材專賣店、藥局等通路
# 6925
# https://ic.tpex.org.tw/company_chain.php?stk_code=6925
# ** 軟體服務 - 應用/系統軟體設計開發、系統整合服務、資料處理服務
# ** 電子商務 - 資訊系統建置服務、資料分析處理服務、行銷廣告服務、資訊聚合
# ** 人工智慧 - 系統整合、顧問諮詢、領域解決方案、機器學習、自然語言處理、雲端平台、資料處理
# ** 雲端運算 - 系統整合、顧問諮詢、SaaS
# ** 大數據 - 系統整合、顧問諮詢、領域解決方案、資料庫、分析工具、應用軟體、雲端平台
# 6922
# https://ic.tpex.org.tw/company_chain.php?stk_code=6922
# ** 電腦及週邊設備 - 工業電腦
# 6913
# https://ic.tpex.org.tw/company_chain.php?stk_code=6913
# ** 電腦及週邊設備 - 連接線
# ** 通信網路 - 線材
# ** 連接器 - 連接器設計、組裝及製造
# ** 醫療器材 - 電子零組件、塑膠零件、五金零件、塑化材料、金屬零件
# 6904
# https://ic.tpex.org.tw/company_chain.php?stk_code=6904
# ** 其他 - 其他
# 6903
# https://ic.tpex.org.tw/company_chain.php?stk_code=6903
# ** 其他 - 其他電子產品及電子服務產業
# 6899
# https://ic.tpex.org.tw/company_chain.php?stk_code=6899
# ** 觸控面板 - 膠材、觸控面板
# 6895
# https://ic.tpex.org.tw/company_chain.php?stk_code=6895
# ** 半導體 - 生產製程及檢測設備
# 6894
# https://ic.tpex.org.tw/company_chain.php?stk_code=6894
# ** 其他 - 環保潔能服務產業
# 6881
# https://ic.tpex.org.tw/company_chain.php?stk_code=6881
# ** 其他 - 其他
# 6877
# https://ic.tpex.org.tw/company_chain.php?stk_code=6877
# ** 半導體 - 生產製程及檢測設備
# ** 平面顯示器 - 生產製程及檢測設備
# ** 印刷電路板 - 生產製程及檢測設備
# ** 其他 - 其他電子產品及電子服務產業
# ** 人工智慧 - 智慧設備
# 6875
# https://ic.tpex.org.tw/company_chain.php?stk_code=6875
# ** 製藥 - 中、西藥製劑
# 6874
# https://ic.tpex.org.tw/company_chain.php?stk_code=6874
# ** 軟體服務 - 應用/系統軟體設計開發、系統整合服務、資料處理服務、通路經銷
# 6872
# https://ic.tpex.org.tw/company_chain.php?stk_code=6872
# ** 醫療器材 - 其他
# 6870
# https://ic.tpex.org.tw/company_chain.php?stk_code=6870
# ** 軟體服務 - 應用/系統軟體設計開發、系統整合服務
# ** 電子商務 - 資訊系統建置服務、金流串接處理服務、資料分析處理服務、行銷廣告服務、店點開設管理、資訊聚合
# ** 金融科技 - 支付、數據分析、資料聚合
# ** 人工智慧 - 系統整合、顧問諮詢、領域解決方案、智慧設備、機器學習、自然語言處理、雲端平台、資料處理
# ** 雲端運算 - 雲端應用服務、系統整合、顧問諮詢、IaaS、PaaS、SaaS
# ** 大數據 - 系統整合、顧問諮詢、領域解決方案、分析工具、應用軟體
# 6865
# https://ic.tpex.org.tw/company_chain.php?stk_code=6865
# ** 金融科技 - 監理法遵、數據分析、資料聚合、數位身分
# ** 人工智慧 - 系統整合、顧問諮詢、領域解決方案、智慧設備、機器學習、電腦視覺、自然語言處理、移動控制、運算設備、雲端平台、資料處理
# ** 雲端運算 - 設備管理軟體、營運管理軟體、虛擬化軟體、雲端作業系統、資安防護軟體、雲端應用服務、系統整合、顧問諮詢、設備安裝服務、IaaS、PaaS、SaaS
# ** 資通訊安全 - 安全營運與事件回應、資安治理、資料安全、網頁內容安全、雲端安全、網路基礎設施、網路安全防護、物聯網安全、端點安全防護、身分認證與訪問管理、行動安全、資安防護能力分析與鑑識服務、資安營運管理服務、資安顧問服務
# ** 大數據 - 系統整合、顧問諮詢、領域解決方案、資料庫、分析工具、應用軟體、運算元件與設備、雲端平台、儲存處理
# 6859
# https://ic.tpex.org.tw/company_chain.php?stk_code=6859
# ** 電腦及週邊設備 - 光學鏡片、鏡頭
# 6856
# https://ic.tpex.org.tw/company_chain.php?stk_code=6856
# ** 電子商務 - 一般零售
# ** 文化創意業 - 廣播電視/電影產業、流行音樂及文化內容產業
# 6855
# https://ic.tpex.org.tw/company_chain.php?stk_code=6855
# ** 其他 - 其他電子產品及電子服務產業
# 6846
# https://ic.tpex.org.tw/company_chain.php?stk_code=6846
# ** 食品 - 原物料、加工食品、營養食品
# ** 食品生技 - 原料、加工製成品
# 6844
# https://ic.tpex.org.tw/company_chain.php?stk_code=6844
# ** 製藥 - 藥品代理銷售及通路
# ** 食品生技 - 保健食品代理銷售及通路
# ** 醫療器材 - 醫療院所、醫療器材專賣店、藥局等通路
# 6843
# https://ic.tpex.org.tw/company_chain.php?stk_code=6843
# ** 電機機械 - 輸送機械及零配件
# 6841
# https://ic.tpex.org.tw/company_chain.php?stk_code=6841
# ** 人工智慧 - 領域解決方案
# ** 醫療器材 - 生物檢測
# 6840
# https://ic.tpex.org.tw/company_chain.php?stk_code=6840
# ** 其他 - 其他電子產品及電子服務產業
# 6829
# https://ic.tpex.org.tw/company_chain.php?stk_code=6829
# ** 半導體 - 生產製程及檢測設備
# ** 平面顯示器 - 其他零組件
# ** 電機機械 - 金屬加工處理
# 6823
# https://ic.tpex.org.tw/company_chain.php?stk_code=6823
# ** 半導體 - 生產製程及檢測設備、生產製程及檢測設備
# 6821
# https://ic.tpex.org.tw/company_chain.php?stk_code=6821
# ** 被動元件 - 電感器、濾波器、振盪器
# 6811
# https://ic.tpex.org.tw/company_chain.php?stk_code=6811
# ** 軟體服務 - 應用/系統軟體設計開發、系統整合服務、資料處理服務、通路經銷
# ** 人工智慧 - 系統整合、顧問諮詢、領域解決方案、雲端平台、資料處理
# ** 雲端運算 - 設備管理軟體、營運管理軟體、虛擬化軟體、雲端作業系統、資安防護軟體、系統整合、顧問諮詢、設備安裝服務、IaaS、PaaS
# ** 大數據 - 系統整合、顧問諮詢、領域解決方案、資料庫、分析工具、應用軟體、雲端平台、儲存處理
# ** 體驗科技 - 資服、系統整合、IT服務、工作流程引導、其他
# 6804
# https://ic.tpex.org.tw/company_chain.php?stk_code=6804
# ** 休閒娛樂 - 休閒車業
# 6803
# https://ic.tpex.org.tw/company_chain.php?stk_code=6803
# ** 其他 - 環保潔能服務產業
# 6791
# https://ic.tpex.org.tw/company_chain.php?stk_code=6791
# ** 軟體服務 - 系統整合服務
# ** 人工智慧 - 領域解決方案
# ** 大數據 - 領域解決方案
# ** 雲端運算 - SaaS
# 6788
# https://ic.tpex.org.tw/company_chain.php?stk_code=6788
# ** 半導體 - 生產製程及檢測設備
# 6785
# https://ic.tpex.org.tw/company_chain.php?stk_code=6785
# ** 製藥 - 中、西藥製劑
# 6767
# https://ic.tpex.org.tw/company_chain.php?stk_code=6767
# ** 醫療器材 - 人工關節、其他
# 6763
# https://ic.tpex.org.tw/company_chain.php?stk_code=6763
# ** 電子商務 - 金流串接處理服務
# ** 金融科技 - 支付
# 6762
# https://ic.tpex.org.tw/company_chain.php?stk_code=6762
# ** 醫療器材 - 醫療耗材
# 6761
# https://ic.tpex.org.tw/company_chain.php?stk_code=6761
# ** 其他 - 其他電子產品及電子服務產業
# 6752
# https://ic.tpex.org.tw/company_chain.php?stk_code=6752
# ** 軟體服務 - 應用/系統軟體設計開發
# ** 人工智慧 - 系統整合、顧問諮詢、領域解決方案、智慧設備、機器學習、電腦視覺、自然語言處理、移動控制、運算設備、雲端平台、資料處理
# ** 雲端運算 - 電腦設備、電力設備、冷卻設備、設備管理軟體、營運管理軟體、虛擬化軟體、雲端作業系統、資安防護軟體、雲端應用服務、系統整合、顧問諮詢、設備安裝服務、伺服器、儲存、網路、IaaS、PaaS、SaaS
# ** 資通訊安全 - 安全營運與事件回應、資安治理、資料安全、網頁內容安全、雲端安全、網路基礎設施、網路安全防護、物聯網安全、端點安全防護、身分認證與訪問管理、行動安全、資安防護能力分析與鑑識服務、資安營運管理服務、資安顧問服務
# 6751
# https://ic.tpex.org.tw/company_chain.php?stk_code=6751
# ** 軟體服務 - 系統整合服務
# 6747
# https://ic.tpex.org.tw/company_chain.php?stk_code=6747
# ** 醫療器材 - 隱型眼鏡、光學鏡片、醫療器材代理
# 6739
# https://ic.tpex.org.tw/company_chain.php?stk_code=6739
# ** 自動化 - 自動化機台、控制器、工業型機器人、AGV及AMR
# ** 其他 - 其他電子產品及電子服務產業
# ** 人工智慧 - 系統整合、顧問諮詢、領域解決方案、智慧設備
# ** 雲端運算 - 設備管理軟體、營運管理軟體、虛擬化軟體、系統整合、顧問諮詢、設備安裝服務、PaaS
# ** 資通訊安全 - 安全營運與事件回應
# ** 大數據 - 系統整合、顧問諮詢、領域解決方案、資料庫、分析工具、應用軟體
# 6735
# https://ic.tpex.org.tw/company_chain.php?stk_code=6735
# ** 半導體 - 生產製程及檢測設備、生產製程及檢測設備
# ** 其他 - 其他電子產品及電子服務產業
# 6733
# https://ic.tpex.org.tw/company_chain.php?stk_code=6733
# ** 醫療器材 - 醫療耗材
# 6732
# https://ic.tpex.org.tw/company_chain.php?stk_code=6732
# ** 半導體 - 光源管理IC
# 6728
# https://ic.tpex.org.tw/company_chain.php?stk_code=6728
# ** 貿易百貨 - 貿易商、代理商、經銷商
# ** 其他 - 其他
# 6727
# https://ic.tpex.org.tw/company_chain.php?stk_code=6727
# ** 印刷電路板 - 生產製程及檢測設備
# 6721
# https://ic.tpex.org.tw/company_chain.php?stk_code=6721
# ** 其他 - 環保潔能服務產業、其他
# 6720
# https://ic.tpex.org.tw/company_chain.php?stk_code=6720
# ** 半導體 - 消費性IC
# 6716
# https://ic.tpex.org.tw/company_chain.php?stk_code=6716
# ** 半導體 - 微控制器IC
# 6712
# https://ic.tpex.org.tw/company_chain.php?stk_code=6712
# ** 再生醫療 - 幹細胞收集儲存、幹細胞開發、臨床實驗、移植技術、疾病治療
# 6708
# https://ic.tpex.org.tw/company_chain.php?stk_code=6708
# ** 半導體 - 網路通訊IC
# ** 雲端運算 - PaaS、SaaS
# 6703
# https://ic.tpex.org.tw/company_chain.php?stk_code=6703
# ** 電子商務 - 自有產品(服務)銷售、一般零售
# ** 食品生技 - 保健食品代理銷售及通路
# 6697
# https://ic.tpex.org.tw/company_chain.php?stk_code=6697
# ** 軟體服務 - 系統整合服務
# ** 人工智慧 - 系統整合、顧問諮詢、資料處理
# ** 雲端運算 - 虛擬化軟體、雲端應用服務、系統整合、顧問諮詢、IaaS、PaaS、SaaS
# ** 資通訊安全 - 資料安全、網路基礎設施、網路安全防護、端點安全防護、資安防護能力分析與鑑識服務、資安營運管理服務、資安顧問服務
# ** 大數據 - 顧問諮詢、領域解決方案、雲端平台
# 6693
# https://ic.tpex.org.tw/company_chain.php?stk_code=6693
# ** 半導體 - 電源管理IC
# 6692
# https://ic.tpex.org.tw/company_chain.php?stk_code=6692
# ** 太陽能產業 - 太陽能發電設備/系統及系統工程
# 6690
# https://ic.tpex.org.tw/company_chain.php?stk_code=6690
# ** 軟體服務 - 系統整合服務
# ** 資通訊安全 - 安全營運與事件回應、資安治理、資料安全、網頁內容安全、雲端安全、網路基礎設施、網路安全防護、物聯網安全、端點安全防護、身分認證與訪問管理、行動安全、資安防護能力分析與鑑識服務、資安營運管理服務、資安顧問服務
# 6684
# https://ic.tpex.org.tw/company_chain.php?stk_code=6684
# ** 半導體 - 消費性IC、輸出入介面IC
# 6683
# https://ic.tpex.org.tw/company_chain.php?stk_code=6683
# ** 半導體 - 生產製程及檢測設備
# 6680
# https://ic.tpex.org.tw/company_chain.php?stk_code=6680
# ** 電腦及週邊設備 - 工業電腦
# ** 人工智慧 - 智慧設備、運算設備
# ** 雲端運算 - 電腦設備、伺服器、儲存、網路
# 6679
# https://ic.tpex.org.tw/company_chain.php?stk_code=6679
# ** 運動科技 - 感測裝置
# ** 半導體 - 微控制器IC、電源管理IC、輸出入介面IC
# 6667
# https://ic.tpex.org.tw/company_chain.php?stk_code=6667
# ** 半導體 - 生產製程及檢測設備
# ** 平面顯示器 - 生產製程及檢測設備
# ** 其他 - 其他電子產品及電子服務產業
# 6664
# https://ic.tpex.org.tw/company_chain.php?stk_code=6664
# ** 自動化 - 自動化機台
# ** 半導體 - 生產製程及檢測設備
# ** 平面顯示器 - 生產製程及檢測設備
# ** 觸控面板 - 工業用設備
# ** 印刷電路板 - 生產製程及檢測設備
# ** 人工智慧 - 智慧設備
# 6662
# https://ic.tpex.org.tw/company_chain.php?stk_code=6662
# ** 製藥 - 中、西藥製劑
# ** 食品生技 - 加工製成品
# ** 再生醫療 - 臨床實驗、移植技術、疾病治療
# ** 醫療器材 - 生物檢測
# 6661
# https://ic.tpex.org.tw/company_chain.php?stk_code=6661
# ** 製藥 - 原材料、中藥材、西藥原料藥、中、西藥製劑、藥品代理銷售及通路、醫療院所
# ** 醫療器材 - 醫療耗材、生物檢測、醫療器材代理
# 6654
# https://ic.tpex.org.tw/company_chain.php?stk_code=6654
# ** 其他 - 其他電子產品及電子服務產業
# 6651
# https://ic.tpex.org.tw/company_chain.php?stk_code=6651
# ** 半導體 - 電源管理IC
# 6649
# https://ic.tpex.org.tw/company_chain.php?stk_code=6649
# ** 醫療器材 - 醫療耗材
# 6643
# https://ic.tpex.org.tw/company_chain.php?stk_code=6643
# ** 半導體 - IP設計/IC設計代工服務
# 6642
# https://ic.tpex.org.tw/company_chain.php?stk_code=6642
# ** 被動元件 - 電阻器
# 6640
# https://ic.tpex.org.tw/company_chain.php?stk_code=6640
# ** 半導體 - 生產製程及檢測設備
# 6637
# https://ic.tpex.org.tw/company_chain.php?stk_code=6637
# ** 醫療器材 - 醫療器材代理銷售及通路、醫療器材代理、醫療院所、醫療器材專賣店、藥局等通路
# 6629
# https://ic.tpex.org.tw/company_chain.php?stk_code=6629
# ** 貿易百貨 - 製造商
# 6624
# https://ic.tpex.org.tw/company_chain.php?stk_code=6624
# ** 其他 - 環保潔能服務產業
# 6617
# https://ic.tpex.org.tw/company_chain.php?stk_code=6617
# ** 製藥 - 中藥材、西藥原料藥、中、西藥製劑
# 6616
# https://ic.tpex.org.tw/company_chain.php?stk_code=6616
# ** 其他 - 其他
# 6615
# https://ic.tpex.org.tw/company_chain.php?stk_code=6615
# ** 其他 - 其他
# 6613
# https://ic.tpex.org.tw/company_chain.php?stk_code=6613
# ** 半導體 - 生產製程及檢測設備
# ** 平面顯示器 - 生產製程及檢測設備
# ** LED照明產業 - 生產製程、檢測設備及原物料
# 6612
# https://ic.tpex.org.tw/company_chain.php?stk_code=6612
# ** 醫療器材 - 醫療耗材、其他
# 6609
# https://ic.tpex.org.tw/company_chain.php?stk_code=6609
# ** 電機機械 - 金屬加工用機械
# 6603
# https://ic.tpex.org.tw/company_chain.php?stk_code=6603
# ** 電機機械 - 專用機械(如紡織成衣生產用機械、食品飲料生產用機械、農林用機械等)
# 6597
# https://ic.tpex.org.tw/company_chain.php?stk_code=6597
# ** 通信網路 - 其他零組件
# ** 印刷電路板 - 硬板、軟板、IC載板製造
# ** LED照明產業 - 生產製程、檢測設備及原物料
# 6596
# https://ic.tpex.org.tw/company_chain.php?stk_code=6596
# ** 文化創意業 - 流行音樂及文化內容產業
# 6593
# https://ic.tpex.org.tw/company_chain.php?stk_code=6593
# ** 軟體服務 - 資料處理服務
# 6590
# https://ic.tpex.org.tw/company_chain.php?stk_code=6590
# ** 軟體服務 - 應用/系統軟體設計開發、系統整合服務
# ** 電子商務 - 資訊系統建置服務、金流串接處理服務、資料分析處理服務、行銷廣告服務、店點開設管理、交易撮(媒)合、資訊聚合、自有產品(服務)銷售、一般零售、票券銷售
# ** 金融科技 - 支付
# ** 資通訊安全 - 資料安全
# 6588
# https://ic.tpex.org.tw/company_chain.php?stk_code=6588
# ** 通信網路 - 其他零組件
# 6584
# https://ic.tpex.org.tw/company_chain.php?stk_code=6584
# ** 電腦及週邊設備 - 其他電腦及週邊設備之零組件
# ** 電機機械 - 五金元件及零配件
# 6578
# https://ic.tpex.org.tw/company_chain.php?stk_code=6578
# ** 食品 - 原物料
# 6577
# https://ic.tpex.org.tw/company_chain.php?stk_code=6577
# ** 平面顯示器 - 塑膠框、背光模組、其他零組件
# ** 醫療器材 - 電子零組件、塑膠零件、五金零件、醫療器材研發、設計、製造、塑化材料、金屬零件、體溫計、血壓計、人工關節、隱型眼鏡、光學鏡片、衛生用品、醫療耗材、生物檢測、顯示器、其他
# 6576
# https://ic.tpex.org.tw/company_chain.php?stk_code=6576
# ** 製藥 - 中、西藥製劑
# 6574
# https://ic.tpex.org.tw/company_chain.php?stk_code=6574
# ** 食品生技 - 保健食品代理銷售及通路
# 6570
# https://ic.tpex.org.tw/company_chain.php?stk_code=6570
# ** 電腦及週邊設備 - 工業電腦
# 6569
# https://ic.tpex.org.tw/company_chain.php?stk_code=6569
# ** 醫療器材 - 顯示器、其他
# 6568
# https://ic.tpex.org.tw/company_chain.php?stk_code=6568
# ** 半導體 - 光通訊IC、消費性IC、網路通訊IC、輸出入介面IC
# 6561
# https://ic.tpex.org.tw/company_chain.php?stk_code=6561
# ** 通信網路 - 網路設備(如數據機、網路卡、閘道器、路由器、網路電話)
# ** 雲端運算 - 雲端應用服務、系統整合、顧問諮詢、設備安裝服務、IaaS、PaaS、SaaS
# ** 資通訊安全 - 網頁內容安全、雲端安全、網路安全防護
# ** 大數據 - 領域解決方案、資料庫、分析工具、應用軟體、運算元件與設備、雲端平台、儲存處理
# 6560
# https://ic.tpex.org.tw/company_chain.php?stk_code=6560
# ** 電腦及週邊設備 - 安全監控系統
# 6556
# https://ic.tpex.org.tw/company_chain.php?stk_code=6556
# ** 電腦及週邊設備 - 安全監控系統
# 6548
# https://ic.tpex.org.tw/company_chain.php?stk_code=6548
# ** 半導體 - 導線架
# 6547
# https://ic.tpex.org.tw/company_chain.php?stk_code=6547
# ** 製藥 - 中藥材、西藥原料藥、中、西藥製劑
# 6546
# https://ic.tpex.org.tw/company_chain.php?stk_code=6546
# ** 通信網路 - 其他零組件
# 6542
# https://ic.tpex.org.tw/company_chain.php?stk_code=6542
# ** 休閒娛樂 - 線上遊戲業、設計開發、營運發行
# 6538
# https://ic.tpex.org.tw/company_chain.php?stk_code=6538
# ** 其他 - 其他電子產品及電子服務產業
# 6535
# https://ic.tpex.org.tw/company_chain.php?stk_code=6535
# ** 製藥 - 原材料
# 6532
# https://ic.tpex.org.tw/company_chain.php?stk_code=6532
# ** 半導體 - 生產製程及檢測設備
# 6530
# https://ic.tpex.org.tw/company_chain.php?stk_code=6530
# ** 通信網路 - 主/被動元件
# ** 資通訊安全 - 網路基礎設施
# 6527
# https://ic.tpex.org.tw/company_chain.php?stk_code=6527
# ** 醫療器材 - 其他
# 6523
# https://ic.tpex.org.tw/company_chain.php?stk_code=6523
# ** 食品生技 - 保健食品代理銷售及通路
# 6517
# https://ic.tpex.org.tw/company_chain.php?stk_code=6517
# ** 電腦及週邊設備 - 光學鏡片、鏡頭
# 6516
# https://ic.tpex.org.tw/company_chain.php?stk_code=6516
# ** 軟體服務 - 應用/系統軟體設計開發、系統整合服務
# ** 人工智慧 - 領域解決方案
# ** 大數據 - 領域解決方案
# 6512
# https://ic.tpex.org.tw/company_chain.php?stk_code=6512
# ** 通信網路 - 網路設備(如數據機、網路卡、閘道器、路由器、網路電話)、光通訊設備(如光纖電纜、光傳輸設備)、無線通訊設備(如行動電話、衛星定位系統、衛星通訊設備、微波通訊設備、數位機上盒)
# 6510
# https://ic.tpex.org.tw/company_chain.php?stk_code=6510
# ** 半導體 - 生產製程及檢測設備
# 6509
# https://ic.tpex.org.tw/company_chain.php?stk_code=6509
# ** 石化及塑橡膠 - 清潔用品、顏染料、農藥
# ** 造紙 - 文化用紙、工業用紙
# ** 製藥 - 原材料、中、西藥製劑
# ** 印刷電路板 - 銅箔基板
# ** 電動車輛產業 - 大功率鋰電池芯/模組、電池管理系統、動力馬達等零組件
# ** 能源元件 - 原材料、電池芯、電池模組
# 6508
# https://ic.tpex.org.tw/company_chain.php?stk_code=6508
# ** 石化及塑橡膠 - 塑膠製品、農藥
# ** 其他 - 農業科技業
# 6506
# https://ic.tpex.org.tw/company_chain.php?stk_code=6506
# ** 石化及塑橡膠 - 接著劑(合成樹脂)
# ** 紡織 - 成衣及其它家居紡織類品
# 6499
# https://ic.tpex.org.tw/company_chain.php?stk_code=6499
# ** 醫療器材 - 醫療耗材
# 6498
# https://ic.tpex.org.tw/company_chain.php?stk_code=6498
# ** 電腦及週邊設備 - 光學鏡片、鏡頭
# 6496
# https://ic.tpex.org.tw/company_chain.php?stk_code=6496
# ** 製藥 - 原材料、中藥材、西藥原料藥、中、西藥製劑、藥品代理銷售及通路、醫療院所
# ** 食品生技 - 保健食品代理銷售及通路
# 6494
# https://ic.tpex.org.tw/company_chain.php?stk_code=6494
# ** 半導體 - 消費性IC
# 6492
# https://ic.tpex.org.tw/company_chain.php?stk_code=6492
# ** 製藥 - 原材料
# 6488
# https://ic.tpex.org.tw/company_chain.php?stk_code=6488
# ** 半導體 - 晶圓製造
# 6486
# https://ic.tpex.org.tw/company_chain.php?stk_code=6486
# ** 通信網路 - 網路設備(如數據機、網路卡、閘道器、路由器、網路電話)、光通訊設備(如光纖電纜、光傳輸設備)、無線通訊設備(如行動電話、衛星定位系統、衛星通訊設備、微波通訊設備、數位機上盒)
# ** 軟體服務 - 系統整合服務
# 6485
# https://ic.tpex.org.tw/company_chain.php?stk_code=6485
# ** 半導體 - 記憶體控制IC
# 6482
# https://ic.tpex.org.tw/company_chain.php?stk_code=6482
# ** 文化創意業 - 數位內容產業
# 6470
# https://ic.tpex.org.tw/company_chain.php?stk_code=6470
# ** 通信網路 - 網路IC、微處理器、記憶體、主/被動元件、印刷電路板、塑膠/金屬機殼、線材、其他零組件、網路設備(如數據機、網路卡、閘道器、路由器、網路電話)、光通訊設備(如光纖電纜、光傳輸設備)、無線通訊設備(如行動電話、衛星定位系統、衛星通訊設備、微波通訊設備、數位機上盒)、有線通訊設備(如電話機、傳真機)、電信服務業
# 6469
# https://ic.tpex.org.tw/company_chain.php?stk_code=6469
# ** 製藥 - 藥品代理銷售及通路
# ** 食品生技 - 保健食品代理銷售及通路
# ** 醫療器材 - 醫療院所、醫療器材專賣店、藥局等通路
# 6465
# https://ic.tpex.org.tw/company_chain.php?stk_code=6465
# ** 通信網路 - 無線通訊設備(如行動電話、衛星定位系統、衛星通訊設備、微波通訊設備、數位機上盒)
# 6462
# https://ic.tpex.org.tw/company_chain.php?stk_code=6462
# ** 軟體服務 - 應用/系統軟體設計開發
# ** 資通訊安全 - 端點安全防護、身分認證與訪問管理
# ** 半導體 - 消費性IC
# 6461
# https://ic.tpex.org.tw/company_chain.php?stk_code=6461
# ** 製藥 - 中、西藥製劑、藥品代理銷售及通路
# ** 食品生技 - 原料、加工製成品、保健食品代理銷售及通路
# ** 再生醫療 - 幹細胞收集儲存、幹細胞開發、臨床實驗、移植技術、疾病治療
# 6441
# https://ic.tpex.org.tw/company_chain.php?stk_code=6441
# ** 電腦及週邊設備 - 工業電腦
# ** 能源元件 - 電池模組
# ** 智慧電網 - 配電管理設施
# 6435
# https://ic.tpex.org.tw/company_chain.php?stk_code=6435
# ** 半導體 - 電源管理IC
# 6432
# https://ic.tpex.org.tw/company_chain.php?stk_code=6432
# ** 被動元件 - 電感器
# 6425
# https://ic.tpex.org.tw/company_chain.php?stk_code=6425
# ** 自動化 - 自動化機台
# ** 平面顯示器 - 生產製程及檢測設備
# 6419
# https://ic.tpex.org.tw/company_chain.php?stk_code=6419
# ** 電腦及週邊設備 - 安全監控系統
# 6418
# https://ic.tpex.org.tw/company_chain.php?stk_code=6418
# ** 電腦及週邊設備 - 連接線
# ** 連接器 - 連接器設計、組裝及製造
# 6417
# https://ic.tpex.org.tw/company_chain.php?stk_code=6417
# ** 通信網路 - 無線通訊設備(如行動電話、衛星定位系統、衛星通訊設備、微波通訊設備、數位機上盒)
# 6411
# https://ic.tpex.org.tw/company_chain.php?stk_code=6411
# ** 半導體 - 輸出入介面IC
# 6294
# https://ic.tpex.org.tw/company_chain.php?stk_code=6294
# ** 文化創意業 - 數位內容產業
# 6292
# https://ic.tpex.org.tw/company_chain.php?stk_code=6292
# ** 被動元件 - 電感器
# 6291
# https://ic.tpex.org.tw/company_chain.php?stk_code=6291
# ** 半導體 - 電源管理IC
# 6290
# https://ic.tpex.org.tw/company_chain.php?stk_code=6290
# ** 連接器 - 連接器設計、組裝及製造
# 6284
# https://ic.tpex.org.tw/company_chain.php?stk_code=6284
# ** 通信網路 - 主/被動元件
# ** 被動元件 - 電容器、電感器、濾波器、振盪器
# 6279
# https://ic.tpex.org.tw/company_chain.php?stk_code=6279
# ** 連接器 - 連接器設計、組裝及製造
# ** 汽車 - 其他
# 6276
# https://ic.tpex.org.tw/company_chain.php?stk_code=6276
# ** 電腦及週邊設備 - 記憶體、機殼、電源供應器、散熱片、風扇馬達、散熱模組、其他電腦及週邊設備
# 6275
# https://ic.tpex.org.tw/company_chain.php?stk_code=6275
# ** 電腦及週邊設備 - 散熱片、風扇馬達、散熱模組
# ** 通信網路 - 其他零組件
# ** 電機機械 - 車用機械傳動設備及零配件、冷凍空調設備及零件、機電系統工程
# ** 電動車輛產業 - 大功率鋰電池芯/模組、電池管理系統、動力馬達等零組件
# ** 醫療器材 - 塑化材料
# 6274
# https://ic.tpex.org.tw/company_chain.php?stk_code=6274
# ** 印刷電路板 - 銅箔基板
# 6270
# https://ic.tpex.org.tw/company_chain.php?stk_code=6270
# ** 半導體 - IC通路
# 6266
# https://ic.tpex.org.tw/company_chain.php?stk_code=6266
# ** 印刷電路板 - 基板組裝加工及相關製造
# 6265
# https://ic.tpex.org.tw/company_chain.php?stk_code=6265
# ** 半導體 - IC通路
# 6264
# https://ic.tpex.org.tw/company_chain.php?stk_code=6264
# ** 休閒娛樂 - 旅館服務業
# ** 建材營造 - 營造業、建設業
# 6263
# https://ic.tpex.org.tw/company_chain.php?stk_code=6263
# ** 通信網路 - 網路設備(如數據機、網路卡、閘道器、路由器、網路電話)、光通訊設備(如光纖電纜、光傳輸設備)、無線通訊設備(如行動電話、衛星定位系統、衛星通訊設備、微波通訊設備、數位機上盒)、有線通訊設備(如電話機、傳真機)
# ** 人工智慧 - 智慧設備、雲端平台
# ** 雲端運算 - 電腦設備、設備管理軟體、營運管理軟體、雲端應用服務、系統整合、伺服器、儲存、網路、IaaS、PaaS、SaaS
# ** 資通訊安全 - 資料安全、網路基礎設施、物聯網安全
# ** 大數據 - 應用軟體、運算元件與設備
# ** 體驗科技 - 資服、系統整合、IT服務
# 6261
# https://ic.tpex.org.tw/company_chain.php?stk_code=6261
# ** 半導體 - 生產製程及檢測設備、IC封裝測試
# ** LED照明產業 - 生產製程、檢測設備及原物料、封裝/模組
# 6259
# https://ic.tpex.org.tw/company_chain.php?stk_code=6259
# ** 被動元件 - 電感器
# 6248
# https://ic.tpex.org.tw/company_chain.php?stk_code=6248
# ** 鋼鐵 - 裁剪加工
# 6246
# https://ic.tpex.org.tw/company_chain.php?stk_code=6246
# ** 平面顯示器 - 背光源(發光二極體、冷陰極管)、塑膠框、背光模組
# ** 觸控面板 - 玻璃基板
# 6245
# https://ic.tpex.org.tw/company_chain.php?stk_code=6245
# ** 電腦及週邊設備 - 主機板、工業電腦
# ** 通信網路 - 網路設備(如數據機、網路卡、閘道器、路由器、網路電話)
# 6244
# https://ic.tpex.org.tw/company_chain.php?stk_code=6244
# ** 太陽能產業 - 太陽能電池、太陽能電池模組、太陽能發電設備/系統及系統工程、太陽能電廠
# 6242
# https://ic.tpex.org.tw/company_chain.php?stk_code=6242
# ** 食品生技 - 原料、加工製成品、保健食品代理銷售及通路
# 6241
# https://ic.tpex.org.tw/company_chain.php?stk_code=6241
# ** 通信網路 - 網路設備(如數據機、網路卡、閘道器、路由器、網路電話)
# 6240
# https://ic.tpex.org.tw/company_chain.php?stk_code=6240
# ** 軟體服務 - 應用/系統軟體設計開發
# ** 其他 - 其他
# 6237
# https://ic.tpex.org.tw/company_chain.php?stk_code=6237
# ** 半導體 - 消費性IC
# 6236
# https://ic.tpex.org.tw/company_chain.php?stk_code=6236
# ** 食品生技 - 加工製成品、保健食品代理銷售及通路
# 6234
# https://ic.tpex.org.tw/company_chain.php?stk_code=6234
# ** 自動化 - 自動化機台、整體解決方案
# ** 平面顯示器 - 生產製程及檢測設備
# ** 電機機械 - 輸送機械及零配件、機電系統工程
# ** 太陽能產業 - 太陽能發電設備/系統及系統工程
# 6233
# https://ic.tpex.org.tw/company_chain.php?stk_code=6233
# ** 電腦及週邊設備 - 晶片組
# ** 半導體 - 輸出入介面IC
# 6231
# https://ic.tpex.org.tw/company_chain.php?stk_code=6231
# ** 電腦及週邊設備 - BIOS(嵌入式軟體)
# 6229
# https://ic.tpex.org.tw/company_chain.php?stk_code=6229
# ** 半導體 - 微控制器IC
# 6228
# https://ic.tpex.org.tw/company_chain.php?stk_code=6228
# ** 電腦及週邊設備 - 印表機、傳真機、掃瞄器、多功能事務機、投影機
# ** 建材營造 - 建材原料、機電工程、工程設計、工程承攬、裝潢業
# ** 貿易百貨 - 貿易商、代理商、經銷商、零售通路
# ** 醫療器材 - 生物檢測
# 6227
# https://ic.tpex.org.tw/company_chain.php?stk_code=6227
# ** 半導體 - IC通路
# 6223
# https://ic.tpex.org.tw/company_chain.php?stk_code=6223
# ** 半導體 - 生產製程及檢測設備、生產製程及檢測設備
# ** LED照明產業 - 生產製程、檢測設備及原物料
# 6222
# https://ic.tpex.org.tw/company_chain.php?stk_code=6222
# ** LED照明產業 - 光源/磊晶、封裝/模組、燈具/應用
# 6221
# https://ic.tpex.org.tw/company_chain.php?stk_code=6221
# ** 電腦及週邊設備 - 伺服器、其他電腦及週邊設備
# ** 軟體服務 - 應用/系統軟體設計開發、系統整合服務、通路經銷
# ** 雲端運算 - 電腦設備、設備管理軟體、虛擬化軟體、資安防護軟體、雲端應用服務、系統整合、顧問諮詢、設備安裝服務、伺服器、儲存、網路、IaaS、PaaS、SaaS
# 6220
# https://ic.tpex.org.tw/company_chain.php?stk_code=6220
# ** 電腦及週邊設備 - 電源供應器、連接線
# ** 通信網路 - 線材
# ** 電子商務 - 自有產品(服務)銷售、一般零售
# 6219
# https://ic.tpex.org.tw/company_chain.php?stk_code=6219
# ** 建材營造 - 建設業
# 6218
# https://ic.tpex.org.tw/company_chain.php?stk_code=6218
# ** 自動化 - 自動化機台
# ** 半導體 - 生產製程及檢測設備
# ** 電腦及週邊設備 - 伺服器、安全監控系統
# ** 通信網路 - 網路設備(如數據機、網路卡、閘道器、路由器、網路電話)
# ** 軟體服務 - 系統整合服務
# ** 雲端運算 - 設備管理軟體、虛擬化軟體、雲端作業系統、資安防護軟體、系統整合、顧問諮詢、設備安裝服務
# ** 資通訊安全 - 安全營運與事件回應、資料安全、網頁內容安全、雲端安全、網路基礎設施、網路安全防護、物聯網安全、端點安全防護、身分認證與訪問管理、行動安全
# ** 大數據 - 系統整合、顧問諮詢、領域解決方案、資料庫、分析工具、應用軟體、運算元件與設備、雲端平台、儲存處理
# ** LED照明產業 - 生產製程、檢測設備及原物料
# 6217
# https://ic.tpex.org.tw/company_chain.php?stk_code=6217
# ** 連接器 - 連接器設計、組裝及製造
# 6212
# https://ic.tpex.org.tw/company_chain.php?stk_code=6212
# ** 建材營造 - 建設業
# 6210
# https://ic.tpex.org.tw/company_chain.php?stk_code=6210
# ** 印刷電路板 - 硬板、軟板、IC載板製造
# 6208
# https://ic.tpex.org.tw/company_chain.php?stk_code=6208
# ** 半導體 - 生產製程及檢測設備
# 6207
# https://ic.tpex.org.tw/company_chain.php?stk_code=6207
# ** 半導體 - 生產製程及檢測設備、基板、IC封裝測試
# ** 被動元件 - 電阻器、電容器
# ** 印刷電路板 - 硬板、軟板、IC載板製造
# ** LED照明產業 - 生產製程、檢測設備及原物料、封裝/模組、燈具/應用
# 6204
# https://ic.tpex.org.tw/company_chain.php?stk_code=6204
# ** 電腦及週邊設備 - 其他電腦及週邊設備
# ** 通信網路 - 主/被動元件
# ** 被動元件 - 電阻器材料(氧化鋁陶瓷基板、導電漿墨)、電阻器
# ** 體驗科技 - 感測器/模組、環境感知、深度感測、SLAM、其他、使用者感知、視覺、語音、手勢/動作、觸覺
# ** 運動科技 - 感測裝置
# 6203
# https://ic.tpex.org.tw/company_chain.php?stk_code=6203
# ** 電腦及週邊設備 - 電源供應器
# 6199
# https://ic.tpex.org.tw/company_chain.php?stk_code=6199
# ** 其他 - 其他
# 6198
# https://ic.tpex.org.tw/company_chain.php?stk_code=6198
# ** 建材營造 - 建設業
# 6195
# https://ic.tpex.org.tw/company_chain.php?stk_code=6195
# ** 貿易百貨 - 零售通路
# 6194
# https://ic.tpex.org.tw/company_chain.php?stk_code=6194
# ** 印刷電路板 - 硬板、軟板、IC載板製造
# 6190
# https://ic.tpex.org.tw/company_chain.php?stk_code=6190
# ** 通信網路 - 線材
# 6188
# https://ic.tpex.org.tw/company_chain.php?stk_code=6188
# ** 電腦及週邊設備 - 其他電腦及週邊設備
# 6187
# https://ic.tpex.org.tw/company_chain.php?stk_code=6187
# ** 其他 - 其他電子產品及電子服務產業
# 6186
# https://ic.tpex.org.tw/company_chain.php?stk_code=6186
# ** 建材營造 - 建設業
# 6185
# https://ic.tpex.org.tw/company_chain.php?stk_code=6185
# ** 連接器 - 連接器設計、組裝及製造
# 6182
# https://ic.tpex.org.tw/company_chain.php?stk_code=6182
# ** 半導體 - 晶圓製造
# 6180
# https://ic.tpex.org.tw/company_chain.php?stk_code=6180
# ** 文化創意業 - 數位內容產業
# ** 休閒娛樂 - 設計開發、營運發行
# 6179
# https://ic.tpex.org.tw/company_chain.php?stk_code=6179
# ** 建材營造 - 工程承攬
# 6175
# https://ic.tpex.org.tw/company_chain.php?stk_code=6175
# ** 被動元件 - 電容器材料(如電蝕／化成鋁箔、介面瓷粉)
# 6174
# https://ic.tpex.org.tw/company_chain.php?stk_code=6174
# ** 被動元件 - 濾波器、振盪器
# 6173
# https://ic.tpex.org.tw/company_chain.php?stk_code=6173
# ** 被動元件 - 電容器材料(如電蝕／化成鋁箔、介面瓷粉)、電阻器、電容器、電感器
# 6171
# https://ic.tpex.org.tw/company_chain.php?stk_code=6171
# ** 建材營造 - 建設業
# 6170
# https://ic.tpex.org.tw/company_chain.php?stk_code=6170
# ** 通信網路 - 電信服務業
# 6169
# https://ic.tpex.org.tw/company_chain.php?stk_code=6169
# ** 休閒娛樂 - 線上遊戲業、設計開發、營運發行
# ** 文化創意業 - 數位內容產業
# 6167
# https://ic.tpex.org.tw/company_chain.php?stk_code=6167
# ** 電腦及週邊設備 - 面板、顯示器模組
# ** 平面顯示器 - 顯示器模組
# 6163
# https://ic.tpex.org.tw/company_chain.php?stk_code=6163
# ** 通信網路 - 網路設備(如數據機、網路卡、閘道器、路由器、網路電話)、光通訊設備(如光纖電纜、光傳輸設備)、無線通訊設備(如行動電話、衛星定位系統、衛星通訊設備、微波通訊設備、數位機上盒)
# ** 軟體服務 - 應用/系統軟體設計開發、系統整合服務
# ** 人工智慧 - 系統整合、領域解決方案、智慧設備、機器學習、電腦視覺、資料處理
# ** 資通訊安全 - 資安治理、網頁內容安全、雲端安全、網路基礎設施、網路安全防護、物聯網安全、端點安全防護、資安防護能力分析與鑑識服務、資安顧問服務
# ** 智慧電網 - 能源管理服務、系統整合服務
# 6161
# https://ic.tpex.org.tw/company_chain.php?stk_code=6161
# ** 電腦及週邊設備 - 主機板、顯示卡
# 6160
# https://ic.tpex.org.tw/company_chain.php?stk_code=6160
# ** 電腦及週邊設備 - 工業電腦
# 6158
# https://ic.tpex.org.tw/company_chain.php?stk_code=6158
# ** 連接器 - 連接器設計、組裝及製造
# 6156
# https://ic.tpex.org.tw/company_chain.php?stk_code=6156
# ** 被動元件 - 電感器
# ** 印刷電路板 - 硬板、軟板、IC載板製造
# 6154
# https://ic.tpex.org.tw/company_chain.php?stk_code=6154
# ** 電腦及週邊設備 - 筆記型電腦、桌上型電腦、工業電腦、精簡型電腦、伺服器、印表機、傳真機、掃瞄器、多功能事務機、投影機、安全監控系統、其他電腦及週邊設備之零組件
# ** 軟體服務 - 通路經銷
# ** 貿易百貨 - 零售通路
# ** 其他 - 其他電子產品及電子服務產業
# 6151
# https://ic.tpex.org.tw/company_chain.php?stk_code=6151
# ** 連接器 - 塑膠材料
# ** 醫療器材 - 塑化材料
# 6150
# https://ic.tpex.org.tw/company_chain.php?stk_code=6150
# ** 電腦及週邊設備 - 顯示卡
# ** 區塊鏈 - 元件裝置
# 6148
# https://ic.tpex.org.tw/company_chain.php?stk_code=6148
# ** 軟體服務 - 系統整合服務
# ** 雲端運算 - 系統整合
# ** 大數據 - 系統整合
# 6147
# https://ic.tpex.org.tw/company_chain.php?stk_code=6147
# ** 半導體 - IC封裝測試
# ** 平面顯示器 - 驅動IC
# 6146
# https://ic.tpex.org.tw/company_chain.php?stk_code=6146
# ** 其他 - 其他電子產品及電子服務產業
# 6144
# https://ic.tpex.org.tw/company_chain.php?stk_code=6144
# ** 其他 - 其他
# ** 文化創意業 - 廣播電視/電影產業
# 6143
# https://ic.tpex.org.tw/company_chain.php?stk_code=6143
# ** 電腦及週邊設備 - 網路卡、工業電腦
# ** 平面顯示器 - 電子書
# ** 通信網路 - 網路設備(如數據機、網路卡、閘道器、路由器、網路電話)、光通訊設備(如光纖電纜、光傳輸設備)、無線通訊設備(如行動電話、衛星定位系統、衛星通訊設備、微波通訊設備、數位機上盒)
# 6140
# https://ic.tpex.org.tw/company_chain.php?stk_code=6140
# ** 電腦及週邊設備 - 筆記型電腦、桌上型電腦、伺服器、其他電腦及週邊設備
# ** 通信網路 - 網路設備(如數據機、網路卡、閘道器、路由器、網路電話)、有線通訊設備(如電話機、傳真機)
# ** 軟體服務 - 應用/系統軟體設計開發、系統整合服務、通路經銷
# ** 人工智慧 - 系統整合、運算設備
# ** 雲端運算 - 設備管理軟體、營運管理軟體、虛擬化軟體、資安防護軟體、系統整合、顧問諮詢、設備安裝服務
# 6138
# https://ic.tpex.org.tw/company_chain.php?stk_code=6138
# ** 半導體 - LED驅動IC、電源管理IC、網路通訊IC
# ** 電動車輛產業 - 大功率鋰電池芯/模組、電池管理系統、動力馬達等零組件
# 6134
# https://ic.tpex.org.tw/company_chain.php?stk_code=6134
# ** 電腦及週邊設備 - 連接線
# 6130
# https://ic.tpex.org.tw/company_chain.php?stk_code=6130
# ** 製藥 - 藥品代理銷售及通路
# ** 半導體 - 電源管理IC
# ** 太陽能產業 - 太陽能電廠
# ** 醫療器材 - 醫療器材代理
# 6129
# https://ic.tpex.org.tw/company_chain.php?stk_code=6129
# ** 半導體 - LED驅動IC、消費性IC、微控制器IC、電源管理IC、平面顯示器控制IC、平面顯示器驅動IC
# 6127
# https://ic.tpex.org.tw/company_chain.php?stk_code=6127
# ** 被動元件 - 電阻器材料(氧化鋁陶瓷基板、導電漿墨)
# 6126
# https://ic.tpex.org.tw/company_chain.php?stk_code=6126
# ** 連接器 - 連接器設計、組裝及製造
# 6125
# https://ic.tpex.org.tw/company_chain.php?stk_code=6125
# ** 自動化 - 整體解決方案
# ** 平面顯示器 - 生產製程及檢測設備
# ** 電機機械 - 輸送機械及零配件、機電系統工程
# ** 太陽能產業 - 太陽能發電設備/系統及系統工程
# 6124
# https://ic.tpex.org.tw/company_chain.php?stk_code=6124
# ** 電腦及週邊設備 - 散熱片、風扇馬達、散熱模組
# ** LED照明產業 - 燈具/應用
# 6123
# https://ic.tpex.org.tw/company_chain.php?stk_code=6123
# ** 軟體服務 - 系統整合服務、通路經銷
# ** 雲端運算 - 營運管理軟體、虛擬化軟體、雲端作業系統、資安防護軟體、雲端應用服務、系統整合、顧問諮詢、設備安裝服務、IaaS、PaaS、SaaS
# 6122
# https://ic.tpex.org.tw/company_chain.php?stk_code=6122
# ** 電機機械 - 機電系統工程
# ** 建材營造 - 機電工程、工程承攬
# 6121
# https://ic.tpex.org.tw/company_chain.php?stk_code=6121
# ** 電腦及週邊設備 - 電池
# ** 電動車輛產業 - 大功率鋰電池芯/模組、電池管理系統、動力馬達等零組件
# ** 能源元件 - 電池模組
# 6118
# https://ic.tpex.org.tw/company_chain.php?stk_code=6118
# ** 其他 - 其他電子產品及電子服務產業
# 6114
# https://ic.tpex.org.tw/company_chain.php?stk_code=6114
# ** 電腦及週邊設備 - 其他電腦及週邊設備之零組件
# 6113
# https://ic.tpex.org.tw/company_chain.php?stk_code=6113
# ** 半導體 - IC通路
# 6111
# https://ic.tpex.org.tw/company_chain.php?stk_code=6111
# ** 文化創意業 - 數位內容產業
# ** 休閒娛樂 - 設計開發、營運發行
# 6109
# https://ic.tpex.org.tw/company_chain.php?stk_code=6109
# ** 電腦及週邊設備 - 電源供應器
# ** 通信網路 - 無線通訊設備(如行動電話、衛星定位系統、衛星通訊設備、微波通訊設備、數位機上盒)
# 6104
# https://ic.tpex.org.tw/company_chain.php?stk_code=6104
# ** 半導體 - 輸出入介面IC
# 6103
# https://ic.tpex.org.tw/company_chain.php?stk_code=6103
# ** 半導體 - 消費性IC
# 6101
# https://ic.tpex.org.tw/company_chain.php?stk_code=6101
# ** 文化創意業 - 流行音樂及文化內容產業
# 6026
# https://ic.tpex.org.tw/company_chain.php?stk_code=6026
# ** 金融 - 證券業
# 6023
# https://ic.tpex.org.tw/company_chain.php?stk_code=6023
# ** 金融 - 期貨業
# 6021
# https://ic.tpex.org.tw/company_chain.php?stk_code=6021
# ** 金融 - 證券業
# 6020
# https://ic.tpex.org.tw/company_chain.php?stk_code=6020
# ** 金融 - 證券業
# 6016
# https://ic.tpex.org.tw/company_chain.php?stk_code=6016
# ** 金融 - 證券業
# 6015
# https://ic.tpex.org.tw/company_chain.php?stk_code=6015
# ** 金融 - 證券業
# 5905
# https://ic.tpex.org.tw/company_chain.php?stk_code=5905
# ** 休閒娛樂 - 旅館服務業
# ** 貿易百貨 - 零售通路
# 5904
# https://ic.tpex.org.tw/company_chain.php?stk_code=5904
# ** 貿易百貨 - 零售通路
# 5903
# https://ic.tpex.org.tw/company_chain.php?stk_code=5903
# ** 貿易百貨 - 零售通路
# 5902
# https://ic.tpex.org.tw/company_chain.php?stk_code=5902
# ** 貿易百貨 - 貿易商、代理商、經銷商
# 5878
# https://ic.tpex.org.tw/company_chain.php?stk_code=5878
# ** 金融 - 金控業/銀行業/保險業
# 5864
# https://ic.tpex.org.tw/company_chain.php?stk_code=5864
# ** 金融 - 證券業
# 5704
# https://ic.tpex.org.tw/company_chain.php?stk_code=5704
# ** 休閒娛樂 - 旅館服務業
# 5703
# https://ic.tpex.org.tw/company_chain.php?stk_code=5703
# ** 休閒娛樂 - 旅館服務業
# 5701
# https://ic.tpex.org.tw/company_chain.php?stk_code=5701
# ** 休閒娛樂 - 娛樂服務業、旅館服務業
# 5609
# https://ic.tpex.org.tw/company_chain.php?stk_code=5609
# ** 交通運輸及航運 - 海陸空貨運承攬
# 5604
# https://ic.tpex.org.tw/company_chain.php?stk_code=5604
# ** 其他 - 其他
# 5603
# https://ic.tpex.org.tw/company_chain.php?stk_code=5603
# ** 交通運輸及航運 - 貨櫃運輸集散及倉儲
# 5601
# https://ic.tpex.org.tw/company_chain.php?stk_code=5601
# ** 交通運輸及航運 - 貨櫃運輸集散及倉儲
# 5548
# https://ic.tpex.org.tw/company_chain.php?stk_code=5548
# ** 建材營造 - 營造業
# 5543
# https://ic.tpex.org.tw/company_chain.php?stk_code=5543
# ** 建材營造 - 建材原料
# ** 能源元件 - 電池模組
# 5536
# https://ic.tpex.org.tw/company_chain.php?stk_code=5536
# ** 半導體 - 生產製程及檢測設備、生產製程及檢測設備
# ** 平面顯示器 - 生產製程及檢測設備
# ** 印刷電路板 - 生產製程及檢測設備
# ** 電機機械 - 冷凍空調設備及零件、機電系統工程
# ** 建材營造 - 機電工程、工程設計、工程承攬
# ** 其他 - 其他電子產品及電子服務產業
# ** 雲端運算 - 電力設備、冷卻設備、系統整合、顧問諮詢、設備安裝服務
# ** LED照明產業 - 生產製程、檢測設備及原物料
# ** 太陽能產業 - 太陽能發電設備/系統及系統工程
# 5530
# https://ic.tpex.org.tw/company_chain.php?stk_code=5530
# ** 建材營造 - 建設業
# ** 其他 - 其他
# 5529
# https://ic.tpex.org.tw/company_chain.php?stk_code=5529
# ** 建材營造 - 建設業
# 5523
# https://ic.tpex.org.tw/company_chain.php?stk_code=5523
# ** 建材營造 - 建設業
# 5520
# https://ic.tpex.org.tw/company_chain.php?stk_code=5520
# ** 水泥 - 預拌混凝土
# 5516
# https://ic.tpex.org.tw/company_chain.php?stk_code=5516
# ** 建材營造 - 營造業
# 5514
# https://ic.tpex.org.tw/company_chain.php?stk_code=5514
# ** 建材營造 - 建設業
# 5512
# https://ic.tpex.org.tw/company_chain.php?stk_code=5512
# ** 建材營造 - 建設業
# 5511
# https://ic.tpex.org.tw/company_chain.php?stk_code=5511
# ** 建材營造 - 營造業
# 5508
# https://ic.tpex.org.tw/company_chain.php?stk_code=5508
# ** 建材營造 - 建設業
# 5498
# https://ic.tpex.org.tw/company_chain.php?stk_code=5498
# ** 印刷電路板 - 基板組裝加工及相關製造、銅箔基板
# 5493
# https://ic.tpex.org.tw/company_chain.php?stk_code=5493
# ** 半導體 - 生產製程及檢測設備、生產製程及檢測設備
# ** 平面顯示器 - 監視器/顯示器
# ** 觸控面板 - 工業用設備
# ** 軟體服務 - 應用/系統軟體設計開發、系統整合服務、資料處理服務、通路經銷
# ** 運動科技 - 感測裝置
# 5490
# https://ic.tpex.org.tw/company_chain.php?stk_code=5490
# ** 電腦及週邊設備 - 工業電腦
# ** 觸控面板 - 工業用設備
# 5489
# https://ic.tpex.org.tw/company_chain.php?stk_code=5489
# ** 電腦及週邊設備 - 安全監控系統
# ** 平面顯示器 - 生產製程及檢測設備
# 5488
# https://ic.tpex.org.tw/company_chain.php?stk_code=5488
# ** 電腦及週邊設備 - 連接線
# 5487
# https://ic.tpex.org.tw/company_chain.php?stk_code=5487
# ** 半導體 - 消費性IC、微控制器IC
# 5483
# https://ic.tpex.org.tw/company_chain.php?stk_code=5483
# ** 半導體 - 晶圓製造
# ** 太陽能產業 - 矽晶圓/矽晶片、太陽能電池、太陽能電池模組
# 5481
# https://ic.tpex.org.tw/company_chain.php?stk_code=5481
# ** 文化創意業 - 其他
# 5478
# https://ic.tpex.org.tw/company_chain.php?stk_code=5478
# ** 休閒娛樂 - 線上遊戲業、設計開發、營運發行
# ** 電子商務 - 資訊系統建置服務、金流串接處理服務、自有產品(服務)銷售
# ** 文化創意業 - 數位內容產業
# ** 金融科技 - 支付
# 5475
# https://ic.tpex.org.tw/company_chain.php?stk_code=5475
# ** 印刷電路板 - 玻璃纖維/玻纖布
# 5474
# https://ic.tpex.org.tw/company_chain.php?stk_code=5474
# ** 電腦及週邊設備 - 多功能視訊卡、安全監控系統、其他電腦及週邊設備之零組件
# ** 人工智慧 - 系統整合、機器學習
# 5468
# https://ic.tpex.org.tw/company_chain.php?stk_code=5468
# ** 半導體 - 光通訊IC
# 5465
# https://ic.tpex.org.tw/company_chain.php?stk_code=5465
# ** 電腦及週邊設備 - 機殼
# 5464
# https://ic.tpex.org.tw/company_chain.php?stk_code=5464
# ** 休閒娛樂 - 旅館服務業
# ** 印刷電路板 - 硬板、軟板、IC載板製造
# 5460
# https://ic.tpex.org.tw/company_chain.php?stk_code=5460
# ** 電腦及週邊設備 - 金屬、塑膠模具
# ** 平面顯示器 - 其他零組件
# ** 通信網路 - 塑膠/金屬機殼、其他零組件
# ** 連接器 - 連接器設計、組裝及製造
# ** LED照明產業 - 燈具/應用
# ** 醫療器材 - 金屬零件
# 5457
# https://ic.tpex.org.tw/company_chain.php?stk_code=5457
# ** 電腦及週邊設備 - 機殼、散熱片、風扇馬達、散熱模組、連接線、金屬、塑膠模具、其他電腦及週邊設備之零組件
# ** 通信網路 - 塑膠/金屬機殼、線材、網路設備(如數據機、網路卡、閘道器、路由器、網路電話)
# ** 連接器 - 連接器設計、組裝及製造
# ** 太空衛星科技 - 零組件/材料、天線/射頻基頻、太陽能板/電池、感測器、微電子、金屬/燃料
# ** 運動科技 - 穿戴式裝置
# ** 醫療器材 - 醫療器材研發、設計、製造、體溫計、血壓計、人工關節、隱型眼鏡、光學鏡片、衛生用品、醫療耗材、生物檢測、顯示器、其他
# ** 電動車輛產業 - 大功率鋰電池芯/模組、電池管理系統、動力馬達等零組件、電動汽車、電動機車、電動自行車
# ** 智慧電網 - 高壓AMI、低壓AMI
# 5455
# https://ic.tpex.org.tw/company_chain.php?stk_code=5455
# ** 建材營造 - 建設業
# 5452
# https://ic.tpex.org.tw/company_chain.php?stk_code=5452
# ** 其他 - 其他電子產品及電子服務產業
# 5450
# https://ic.tpex.org.tw/company_chain.php?stk_code=5450
# ** 紡織 - 成衣及其它家居紡織類品
# 5443
# https://ic.tpex.org.tw/company_chain.php?stk_code=5443
# ** 半導體 - 生產製程及檢測設備
# ** 平面顯示器 - 生產製程及檢測設備
# 5439
# https://ic.tpex.org.tw/company_chain.php?stk_code=5439
# ** 通信網路 - 印刷電路板
# ** 印刷電路板 - 硬板、軟板、IC載板製造
# ** 電動車輛產業 - 大功率鋰電池芯/模組、電池管理系統、動力馬達等零組件
# 5438
# https://ic.tpex.org.tw/company_chain.php?stk_code=5438
# ** 電腦及週邊設備 - 印表機、傳真機、掃瞄器、多功能事務機、投影機
# 5432
# https://ic.tpex.org.tw/company_chain.php?stk_code=5432
# ** 平面顯示器 - 顯示器模組
# ** 太陽能產業 - 太陽能發電設備/系統及系統工程
# 5426
# https://ic.tpex.org.tw/company_chain.php?stk_code=5426
# ** 電腦及週邊設備 - 其他電腦及週邊設備之零組件
# 5425
# https://ic.tpex.org.tw/company_chain.php?stk_code=5425
# ** 半導體 - 其他IC/二極體製造
# 5410
# https://ic.tpex.org.tw/company_chain.php?stk_code=5410
# ** 軟體服務 - 應用/系統軟體設計開發、系統整合服務
# 5403
# https://ic.tpex.org.tw/company_chain.php?stk_code=5403
# ** 軟體服務 - 應用/系統軟體設計開發、系統整合服務
# 5398
# https://ic.tpex.org.tw/company_chain.php?stk_code=5398
# ** 連接器 - 連接器設計、組裝及製造
# ** 製藥 - 藥品代理銷售及通路
# ** 醫療器材 - 醫療器材代理銷售及通路、醫療耗材、醫療器材代理、醫療院所、醫療器材專賣店、藥局等通路
# ** 食品生技 - 保健食品代理銷售及通路
# 5392
# https://ic.tpex.org.tw/company_chain.php?stk_code=5392
# ** 電腦及週邊設備 - 機殼
# 5386
# https://ic.tpex.org.tw/company_chain.php?stk_code=5386
# ** 電腦及週邊設備 - 顯示器模組、記憶體、主機板、顯示卡
# ** 平面顯示器 - 顯示器模組
# ** 觸控面板 - 電子觸控白板、工業用設備
# 5381
# https://ic.tpex.org.tw/company_chain.php?stk_code=5381
# ** 印刷電路板 - 印刷電路板、硬板、軟板、IC載板製造、基板組裝加工及相關製造、銅箔基板
# ** 電機機械 - 電控元件
# ** 智慧電網 - 高/低壓輸電設施
# 5371
# https://ic.tpex.org.tw/company_chain.php?stk_code=5371
# ** 自動化 - 整體解決方案
# ** 電腦及週邊設備 - 印表機、傳真機、掃瞄器、多功能事務機、投影機
# ** 平面顯示器 - 背光模組
# ** 人工智慧 - 系統整合、領域解決方案
# ** 體驗科技 - 近眼顯示(Dear-Eye Display)、垂直應用方案、顯示技術、光學元件/模組、LCoS、OLED、Micro LED、微型顯示器/光機引擎(Light Engine)、ODM/OEM、製造、重工業、物流、安防、醫療、其他
# 5364
# https://ic.tpex.org.tw/company_chain.php?stk_code=5364
# ** 休閒娛樂 - 旅館服務業
# 5356
# https://ic.tpex.org.tw/company_chain.php?stk_code=5356
# ** 電腦及週邊設備 - 印表機、傳真機、掃瞄器、多功能事務機、投影機、安全監控系統
# ** 平面顯示器 - 電視
# ** 通信網路 - 無線通訊設備(如行動電話、衛星定位系統、衛星通訊設備、微波通訊設備、數位機上盒)
# ** 石化及塑橡膠 - 塑膠製品
# ** 汽車 - 其他
# ** 醫療器材 - 電子零組件、塑膠零件、五金零件、塑化材料、金屬零件
# 5355
# https://ic.tpex.org.tw/company_chain.php?stk_code=5355
# ** 印刷電路板 - 硬板、軟板、IC載板製造、基板組裝加工及相關製造
# 5353
# https://ic.tpex.org.tw/company_chain.php?stk_code=5353
# ** 電腦及週邊設備 - 工業電腦
# ** 通信網路 - 網路設備(如數據機、網路卡、閘道器、路由器、網路電話)、無線通訊設備(如行動電話、衛星定位系統、衛星通訊設備、微波通訊設備、數位機上盒)、有線通訊設備(如電話機、傳真機)
# 5351
# https://ic.tpex.org.tw/company_chain.php?stk_code=5351
# ** 人工智慧 - 系統整合、領域解決方案、電腦視覺
# ** 體驗科技 - 處理器/IC、感測器/模組、頭顯裝置品牌廠、CPU、GPU、HPU、SoC、IC、環境感知、深度感測、SLAM、其他、使用者感知、視覺、語音、手勢/動作、觸覺、VR Headset、AR Smart Glasses、MR Headset & SG
# ** 半導體 - 記憶體IC
# 5348
# https://ic.tpex.org.tw/company_chain.php?stk_code=5348
# ** 通信網路 - 無線通訊設備(如行動電話、衛星定位系統、衛星通訊設備、微波通訊設備、數位機上盒)
# ** 運動科技 - 裝置/器材零組件、軟體開發、運動用品、穿戴式裝置、通訊服務、數位內容、運動服務/顧問、運動行銷/媒體
# 5347
# https://ic.tpex.org.tw/company_chain.php?stk_code=5347
# ** 半導體 - 晶圓製造
# 5345
# https://ic.tpex.org.tw/company_chain.php?stk_code=5345
# ** 其他 - 其他電子產品及電子服務產業
# 5344
# https://ic.tpex.org.tw/company_chain.php?stk_code=5344
# ** 半導體 - IC封裝測試
# ** LED照明產業 - 燈具/應用
# 5340
# https://ic.tpex.org.tw/company_chain.php?stk_code=5340
# ** 印刷電路板 - 玻璃纖維/玻纖布
# 5328
# https://ic.tpex.org.tw/company_chain.php?stk_code=5328
# ** 被動元件 - 電容器
# 5324
# https://ic.tpex.org.tw/company_chain.php?stk_code=5324
# ** 休閒娛樂 - 旅館服務業
# ** 建材營造 - 建設業
# 5321
# https://ic.tpex.org.tw/company_chain.php?stk_code=5321
# ** 電子商務 - 自有產品(服務)銷售
# ** 印刷電路板 - 硬板、軟板、IC載板製造
# 5315
# https://ic.tpex.org.tw/company_chain.php?stk_code=5315
# ** 電腦及週邊設備 - 面板、顯示器模組
# ** 平面顯示器 - 面板、顯示器模組
# 5314
# https://ic.tpex.org.tw/company_chain.php?stk_code=5314
# ** 建材營造 - 裝潢業
# 5312
# https://ic.tpex.org.tw/company_chain.php?stk_code=5312
# ...
# 1720
# https://ic.tpex.org.tw/company_chain.php?stk_code=1720
# ** 製藥 - 中、西藥製劑
# ** 食品生技 - 保健食品代理銷售及通路
# 1718
# https://ic.tpex.org.tw/company_chain.php?stk_code=1718
# ** 其他 - 其他
# 1717
# https://ic.tpex.org.tw/company_chain.php?stk_code=1717
# ** 半導體 - 化學品
# ** 平面顯示器 - 化學品(如光阻劑、靶材等)、擴散膜、增亮膜、導光板
# ** 觸控面板 - 膠材
# ** 印刷電路板 - 環氧樹脂、酚醛樹脂、聚亞醯胺樹脂、銅箔基板
# ** 石化及塑橡膠 - 接著劑(合成樹脂)、工業用合成樹脂
# ** 太陽能產業 - 材料
# 1714
# https://ic.tpex.org.tw/company_chain.php?stk_code=1714
# ** 石化及塑橡膠 - 界面活性劑
# 1713
# https://ic.tpex.org.tw/company_chain.php?stk_code=1713
# ** 紡織 - 化學助劑
# 1712
# https://ic.tpex.org.tw/company_chain.php?stk_code=1712
# ** 石化及塑橡膠 - 塑膠製品、農藥
# 1711
# https://ic.tpex.org.tw/company_chain.php?stk_code=1711
# ** 半導體 - 化學品
# ** 電腦及週邊設備 - 其他電腦及週邊設備之零組件
# ** 平面顯示器 - 化學品(如光阻劑、靶材等)
# ** 石化及塑橡膠 - 顏染料、接著劑(合成樹脂)、橡塑膠添加劑
# ** 製藥 - 中藥材、西藥原料藥
# ** 太陽能產業 - 材料
# 1710
# https://ic.tpex.org.tw/company_chain.php?stk_code=1710
# ** 紡織 - 石化原料(例如純對苯二甲酸、乙二醇、己內醯胺、丙烯腈等)
# ** 其他 - 其他
# 1709
# https://ic.tpex.org.tw/company_chain.php?stk_code=1709
# ** 石化及塑橡膠 - 界面活性劑
# 1708
# https://ic.tpex.org.tw/company_chain.php?stk_code=1708
# ** 其他 - 其他
# 1707
# https://ic.tpex.org.tw/company_chain.php?stk_code=1707
# ** 食品生技 - 加工製成品、保健食品代理銷售及通路
# 1702
# https://ic.tpex.org.tw/company_chain.php?stk_code=1702
# ** 食品 - 原物料、加工食品、餐飲連鎖
# 1626
# https://ic.tpex.org.tw/company_chain.php?stk_code=1626
# ** 其他 - 其他
# 1618
# https://ic.tpex.org.tw/company_chain.php?stk_code=1618
# ** 通信網路 - 線材、光通訊設備(如光纖電纜、光傳輸設備)
# ** 其他 - 其他
# ** 汽電共生 - 電纜
# ** 風力發電 - 電纜
# ** 智慧電網 - 高/低壓輸電設施
# 1617
# https://ic.tpex.org.tw/company_chain.php?stk_code=1617
# ** 通信網路 - 線材
# ** 連接器 - 金屬材料
# ** 電機機械 - 金屬加工處理
# ** 其他 - 其他
# 1616
# https://ic.tpex.org.tw/company_chain.php?stk_code=1616
# ** 其他 - 其他
# 1615
# https://ic.tpex.org.tw/company_chain.php?stk_code=1615
# ** 通信網路 - 線材
# ** 其他 - 其他
# ** 汽電共生 - 電纜
# ** 智慧電網 - 高/低壓輸電設施
# 1614
# https://ic.tpex.org.tw/company_chain.php?stk_code=1614
# ** 平面顯示器 - 監視器/顯示器、電視
# ** 通信網路 - 有線通訊設備(如電話機、傳真機)
# ** 電機機械 - 冷凍空調設備及零件
# ** 貿易百貨 - 製造商、貿易商、代理商、經銷商、零售通路
# ** 其他 - 其他電子產品及電子服務產業
# 1612
# https://ic.tpex.org.tw/company_chain.php?stk_code=1612
# ** 建材營造 - 建材原料
# ** 其他 - 其他
# ** 汽電共生 - 電纜
# ** 風力發電 - 電纜
# ** 智慧電網 - 高/低壓輸電設施
# 1611
# https://ic.tpex.org.tw/company_chain.php?stk_code=1611
# ** 其他 - 其他、特殊照明業
# ** LED照明產業 - 燈具/應用
# ** 電動車輛產業 - 鋰電池材料
# ** 太陽能產業 - 太陽能發電設備/系統及系統工程
# 1609
# https://ic.tpex.org.tw/company_chain.php?stk_code=1609
# ** 其他 - 其他
# ** 太陽能產業 - 太陽能電廠
# ** 風力發電 - 電纜
# ** 智慧電網 - 高/低壓輸電設施
# 1608
# https://ic.tpex.org.tw/company_chain.php?stk_code=1608
# ** 通信網路 - 光通訊設備(如光纖電纜、光傳輸設備)
# ** 其他 - 其他
# 1605
# https://ic.tpex.org.tw/company_chain.php?stk_code=1605
# ** 鋼鐵 - 煤、鐵礦砂、鎳鐵、鉻鐵、廢鋼、不鏽鋼胚、冷熱軋不鏽鋼板捲、不鏽鋼棒線、製管、鋼線鋼纜
# ** 建材營造 - 建設業
# ** 電動車輛產業 - 鋰電池材料、大功率鋰電池芯/模組、電池管理系統、動力馬達等零組件
# ** 太陽能產業 - 太陽能發電設備/系統及系統工程
# ** 風力發電 - 電纜
# ** 智慧電網 - 高/低壓輸電設施
# 1604
# https://ic.tpex.org.tw/company_chain.php?stk_code=1604
# ** 平面顯示器 - 電視
# ** 其他 - 其他
# 1603
# https://ic.tpex.org.tw/company_chain.php?stk_code=1603
# ** 建材營造 - 建材原料、工程承攬
# ** 其他 - 其他
# ** 智慧電網 - 高/低壓輸電設施
# 1598
# https://ic.tpex.org.tw/company_chain.php?stk_code=1598
# ** 其他 - 其他
# ** 運動科技 - 健身器材
# 1597
# https://ic.tpex.org.tw/company_chain.php?stk_code=1597
# ** 電機機械 - 傳動元件、電控元件
# 1590
# https://ic.tpex.org.tw/company_chain.php?stk_code=1590
# ** 電機機械 - 傳動元件、金屬加工用機械
# 1589
# https://ic.tpex.org.tw/company_chain.php?stk_code=1589
# ** 電機機械 - 鋼鑄鐵元件
# ** 風力發電 - 齒輪箱、其他配件、風場開發
# ** 能源元件 - 原材料
# 1587
# https://ic.tpex.org.tw/company_chain.php?stk_code=1587
# ** 汽車 - 其他
# 1583
# https://ic.tpex.org.tw/company_chain.php?stk_code=1583
# ** 電機機械 - 金屬加工用機械
# 1582
# https://ic.tpex.org.tw/company_chain.php?stk_code=1582
# ** 電腦及週邊設備 - 機構樞紐、金屬、塑膠模具
# 1568
# https://ic.tpex.org.tw/company_chain.php?stk_code=1568
# ** 電機機械 - 車用機械傳動設備及零配件
# ** 汽車 - 其他
# 1563
# https://ic.tpex.org.tw/company_chain.php?stk_code=1563
# ** 電機機械 - 車用機械傳動設備及零配件
# ** 汽車 - 鋁合金鋼圈
# 1560
# https://ic.tpex.org.tw/company_chain.php?stk_code=1560
# ** 電機機械 - 五金元件及零配件
# 1558
# https://ic.tpex.org.tw/company_chain.php?stk_code=1558
# ** 電機機械 - 專用機械(如紡織成衣生產用機械、食品飲料生產用機械、農林用機械等)、手工具機
# 1541
# https://ic.tpex.org.tw/company_chain.php?stk_code=1541
# ** 電機機械 - 手工具機
# 1540
# https://ic.tpex.org.tw/company_chain.php?stk_code=1540
# ** 電機機械 - 金屬加工用機械
# 1539
# https://ic.tpex.org.tw/company_chain.php?stk_code=1539
# ** 電機機械 - 手工具機
# 1538
# https://ic.tpex.org.tw/company_chain.php?stk_code=1538
# ** 電機機械 - 手工具機
# ** 汽車 - 車燈
# ** LED照明產業 - 燈具/應用
# 1537
# https://ic.tpex.org.tw/company_chain.php?stk_code=1537
# ** 電腦及週邊設備 - 其他電腦及週邊設備之零組件
# ** 電機機械 - 五金元件及零配件、車用機械傳動設備及零配件、機電系統工程
# ** 電動車輛產業 - 大功率鋰電池芯/模組、電池管理系統、動力馬達等零組件
# 1536
# https://ic.tpex.org.tw/company_chain.php?stk_code=1536
# ** 電機機械 - 傳動元件
# ** 汽車 - 其他
# ** 電動車輛產業 - 大功率鋰電池芯/模組、電池管理系統、動力馬達等零組件
# 1535
# https://ic.tpex.org.tw/company_chain.php?stk_code=1535
# ** 電機機械 - 機電系統工程
# 1533
# https://ic.tpex.org.tw/company_chain.php?stk_code=1533
# ** 電機機械 - 電控元件、手工具機、車用機械傳動設備及零配件
# ** 汽車 - 其他
# ** 電動車輛產業 - 大功率鋰電池芯/模組、電池管理系統、動力馬達等零組件
# 1532
# https://ic.tpex.org.tw/company_chain.php?stk_code=1532
# ** 休閒娛樂 - 娛樂服務業、旅館服務業
# ** 電機機械 - 鋼鑄鐵元件
# ** 建材營造 - 建設業
# ** 貿易百貨 - 零售通路
# 1531
# https://ic.tpex.org.tw/company_chain.php?stk_code=1531
# ** 電機機械 - 專用機械(如紡織成衣生產用機械、食品飲料生產用機械、農林用機械等)
# 1530
# https://ic.tpex.org.tw/company_chain.php?stk_code=1530
# ** 電機機械 - 金屬加工用機械
# 1529
# https://ic.tpex.org.tw/company_chain.php?stk_code=1529
# ** 電機機械 - 機電系統工程
# ** 太陽能產業 - 太陽能發電設備/系統及系統工程、太陽能電廠
# 1528
# https://ic.tpex.org.tw/company_chain.php?stk_code=1528
# ** 印刷電路板 - 生產製程及檢測設備
# ** 電機機械 - 專用機械(如紡織成衣生產用機械、食品飲料生產用機械、農林用機械等)
# ** 貿易百貨 - 貿易商、代理商、經銷商
# 1527
# https://ic.tpex.org.tw/company_chain.php?stk_code=1527
# ** 電機機械 - 手工具機
# 1526
# https://ic.tpex.org.tw/company_chain.php?stk_code=1526
# ** 電機機械 - 傳動元件
# 1525
# https://ic.tpex.org.tw/company_chain.php?stk_code=1525
# ** 汽車 - 其他
# 1524
# https://ic.tpex.org.tw/company_chain.php?stk_code=1524
# ** 汽車 - 鈑金
# 1522
# https://ic.tpex.org.tw/company_chain.php?stk_code=1522
# ** 汽車 - 車燈
# 1521
# https://ic.tpex.org.tw/company_chain.php?stk_code=1521
# ** 汽車 - 車燈
# 1519
# https://ic.tpex.org.tw/company_chain.php?stk_code=1519
# ** 電機機械 - 機電系統工程
# ** 電動車輛產業 - 大功率鋰電池芯/模組、電池管理系統、動力馬達等零組件
# ** 汽電共生 - 配電系統、變壓器
# ** 風力發電 - 電力系統
# ** 智慧電網 - 高/低壓輸電設施、配電管理設施、電網營造
# 1517
# https://ic.tpex.org.tw/company_chain.php?stk_code=1517
# ** 電機機械 - 車用機械傳動設備及零配件
# 1516
# https://ic.tpex.org.tw/company_chain.php?stk_code=1516
# ** 其他 - 其他
# 1515
# https://ic.tpex.org.tw/company_chain.php?stk_code=1515
# ** 電機機械 - 手工具機
# 1514
# https://ic.tpex.org.tw/company_chain.php?stk_code=1514
# ** 電機機械 - 機電系統工程
# ** 汽電共生 - 配電系統
# ** 風力發電 - 電力系統
# 1513
# https://ic.tpex.org.tw/company_chain.php?stk_code=1513
# ** 電機機械 - 金屬加工用機械、冷凍空調設備及零件、機電系統工程、金屬加工處理
# ** 建材營造 - 建設業、物業管理
# ** 太陽能產業 - 太陽能發電設備/系統及系統工程、太陽能電廠
# ** 風力發電 - 風場規劃、風場營造
# ** 智慧電網 - 高/低壓輸電設施、配電管理設施、高壓AMI、低壓AMI、能源管理服務、系統整合服務
# 1512
# https://ic.tpex.org.tw/company_chain.php?stk_code=1512
# ** 電機機械 - 車用機械傳動設備及零配件
# ** 汽車 - 其他
# 1506
# https://ic.tpex.org.tw/company_chain.php?stk_code=1506
# ** 電機機械 - 車用機械傳動設備及零配件、冷凍空調設備及零件、金屬加工處理
# ** 汽車 - 其他
# 1504
# https://ic.tpex.org.tw/company_chain.php?stk_code=1504
# ** 電機機械 - 傳動元件、電控元件、冷凍空調設備及零件、機電系統工程
# ** 建材營造 - 機電工程
# ** 人工智慧 - 移動控制
# ** 電動車輛產業 - 大功率鋰電池芯/模組、電池管理系統、動力馬達等零組件
# ** 風力發電 - 監控系統、電力系統
# 1503
# https://ic.tpex.org.tw/company_chain.php?stk_code=1503
# ** 電腦及週邊設備 - 安全監控系統
# ** 電機機械 - 輸送機械及零配件、車用機械傳動設備及零配件、冷凍空調設備及零件、機電系統工程
# ** 建材營造 - 機電工程
# ** 汽車 - 其他
# ** 電動車輛產業 - 大功率鋰電池芯/模組、電池管理系統、動力馬達等零組件
# ** 風力發電 - 電力系統
# 1477
# https://ic.tpex.org.tw/company_chain.php?stk_code=1477
# ** 紡織 - 成衣及其它家居紡織類品
# 1476
# https://ic.tpex.org.tw/company_chain.php?stk_code=1476
# ** 紡織 - 織布、成衣及其它家居紡織類品
# 1475
# https://ic.tpex.org.tw/company_chain.php?stk_code=1475
# ** 紡織 - 染整
# 1474
# https://ic.tpex.org.tw/company_chain.php?stk_code=1474
# ** 紡織 - 織布
# 1473
# https://ic.tpex.org.tw/company_chain.php?stk_code=1473
# ** 紡織 - 成衣及其它家居紡織類品
# 1472
# https://ic.tpex.org.tw/company_chain.php?stk_code=1472
# ** 建材營造 - 結構工程、機電工程、營造業、工程承攬
# 1471
# https://ic.tpex.org.tw/company_chain.php?stk_code=1471
# ** 電腦及週邊設備 - 機殼、電源供應器
# 1470
# https://ic.tpex.org.tw/company_chain.php?stk_code=1470
# ** 紡織 - 染整
# 1468
# https://ic.tpex.org.tw/company_chain.php?stk_code=1468
# ** 紡織 - 人造纖維產品(例如尼龍纖維、聚酯纖維、嫘縈纖維等)、化學助劑、織布、染整、成衣及其它家居紡織類品
# 1467
# https://ic.tpex.org.tw/company_chain.php?stk_code=1467
# ** 紡織 - 染整、成衣及其它家居紡織類品
# 1466
# https://ic.tpex.org.tw/company_chain.php?stk_code=1466
# ** 紡織 - 人造纖維產品(例如尼龍纖維、聚酯纖維、嫘縈纖維等)
# 1465
# https://ic.tpex.org.tw/company_chain.php?stk_code=1465
# ** 紡織 - 人造纖維產品(例如尼龍纖維、聚酯纖維、嫘縈纖維等)、織布
# 1464
# https://ic.tpex.org.tw/company_chain.php?stk_code=1464
# ** 紡織 - 人造纖維產品(例如尼龍纖維、聚酯纖維、嫘縈纖維等)、紡紗、織布、染整
# 1463
# https://ic.tpex.org.tw/company_chain.php?stk_code=1463
# ** 紡織 - 染整
# 1460
# https://ic.tpex.org.tw/company_chain.php?stk_code=1460
# ** 紡織 - 紡紗、織布、染整、成衣及其它家居紡織類品
# 1459
# https://ic.tpex.org.tw/company_chain.php?stk_code=1459
# ** 紡織 - 人造纖維產品(例如尼龍纖維、聚酯纖維、嫘縈纖維等)
# 1457
# https://ic.tpex.org.tw/company_chain.php?stk_code=1457
# ** 紡織 - 人造纖維產品(例如尼龍纖維、聚酯纖維、嫘縈纖維等)、紡紗、染整
# 1456
# https://ic.tpex.org.tw/company_chain.php?stk_code=1456
# ** 紡織 - 人造纖維產品(例如尼龍纖維、聚酯纖維、嫘縈纖維等)、天然纖維產品(例如純棉、純羊毛等)、紡紗、織布
# ** 建材營造 - 建設業
# 1455
# https://ic.tpex.org.tw/company_chain.php?stk_code=1455
# ** 紡織 - 人造纖維產品(例如尼龍纖維、聚酯纖維、嫘縈纖維等)
# 1454
# https://ic.tpex.org.tw/company_chain.php?stk_code=1454
# ** 紡織 - 紡紗、織布、成衣及其它家居紡織類品
# 1453
# https://ic.tpex.org.tw/company_chain.php?stk_code=1453
# ** 紡織 - 紡紗
# ** 建材營造 - 建設業
# 1452
# https://ic.tpex.org.tw/company_chain.php?stk_code=1452
# ** 紡織 - 人造纖維產品(例如尼龍纖維、聚酯纖維、嫘縈纖維等)
# 1451
# https://ic.tpex.org.tw/company_chain.php?stk_code=1451
# ** 紡織 - 紡紗、織布、染整、成衣及其它家居紡織類品
# 1449
# https://ic.tpex.org.tw/company_chain.php?stk_code=1449
# ** 紡織 - 紡紗、織布、染整
# 1447
# https://ic.tpex.org.tw/company_chain.php?stk_code=1447
# ** 紡織 - 人造纖維產品(例如尼龍纖維、聚酯纖維、嫘縈纖維等)、紡紗、織布、染整
# 1446
# https://ic.tpex.org.tw/company_chain.php?stk_code=1446
# ** 紡織 - 織布、成衣及其它家居紡織類品
# 1445
# https://ic.tpex.org.tw/company_chain.php?stk_code=1445
# ** 紡織 - 紡紗、織布
# 1444
# https://ic.tpex.org.tw/company_chain.php?stk_code=1444
# ** 紡織 - 人造纖維產品(例如尼龍纖維、聚酯纖維、嫘縈纖維等)
# 1443
# https://ic.tpex.org.tw/company_chain.php?stk_code=1443
# ** 其他 - 其他
# 1442
# https://ic.tpex.org.tw/company_chain.php?stk_code=1442
# ** 建材營造 - 建設業
# 1441
# https://ic.tpex.org.tw/company_chain.php?stk_code=1441
# ** 紡織 - 紡紗
# 1440
# https://ic.tpex.org.tw/company_chain.php?stk_code=1440
# ** 紡織 - 人造纖維產品(例如尼龍纖維、聚酯纖維、嫘縈纖維等)、紡紗
# 1439
# https://ic.tpex.org.tw/company_chain.php?stk_code=1439
# ** 建材營造 - 建設業
# 1438
# https://ic.tpex.org.tw/company_chain.php?stk_code=1438
# ** 建材營造 - 建設業
# 1437
# https://ic.tpex.org.tw/company_chain.php?stk_code=1437
# ** 其他 - 其他
# 1436
# https://ic.tpex.org.tw/company_chain.php?stk_code=1436
# ** 建材營造 - 建設業
# 1435
# https://ic.tpex.org.tw/company_chain.php?stk_code=1435
# ** 其他 - 其他
# 1434
# https://ic.tpex.org.tw/company_chain.php?stk_code=1434
# ** 半導體 - IC封裝測試、IC模組
# ** 石化及塑橡膠 - 塑膠製品
# ** 紡織 - 紡紗、織布、染整
# ** 油電燃氣 - 加油站
# 1432
# https://ic.tpex.org.tw/company_chain.php?stk_code=1432
# ** 休閒娛樂 - 娛樂服務業
# ** 紡織 - 染整
# 1423
# https://ic.tpex.org.tw/company_chain.php?stk_code=1423
# ** 紡織 - 天然纖維產品(例如純棉、純羊毛等)
# 1419
# https://ic.tpex.org.tw/company_chain.php?stk_code=1419
# ** 紡織 - 織布、染整
# ** 貿易百貨 - 貿易商、代理商、經銷商、零售通路
# 1418
# https://ic.tpex.org.tw/company_chain.php?stk_code=1418
# ** 紡織 - 人造纖維產品(例如尼龍纖維、聚酯纖維、嫘縈纖維等)
# 1417
# https://ic.tpex.org.tw/company_chain.php?stk_code=1417
# ** 紡織 - 成衣及其它家居紡織類品
# 1416
# https://ic.tpex.org.tw/company_chain.php?stk_code=1416
# ** 軟體服務 - 應用/系統軟體設計開發
# ** 建材營造 - 建設業
# ** 其他 - 其他
# 1414
# https://ic.tpex.org.tw/company_chain.php?stk_code=1414
# ** 紡織 - 紡紗
# 1413
# https://ic.tpex.org.tw/company_chain.php?stk_code=1413
# ** 紡織 - 人造纖維產品(例如尼龍纖維、聚酯纖維、嫘縈纖維等)、紡紗
# 1410
# https://ic.tpex.org.tw/company_chain.php?stk_code=1410
# ** 半導體 - IC封裝測試
# ** 石化及塑橡膠 - 塑膠製品
# ** 紡織 - 染整
# 1409
# https://ic.tpex.org.tw/company_chain.php?stk_code=1409
# ** 石化及塑橡膠 - 人造纖維
# ** 紡織 - 人造纖維產品(例如尼龍纖維、聚酯纖維、嫘縈纖維等)
# 1402
# https://ic.tpex.org.tw/company_chain.php?stk_code=1402
# ** 石化及塑橡膠 - 塑膠製品、PTA(對苯二甲酸)觸媒
# ** 紡織 - 石化原料(例如純對苯二甲酸、乙二醇、己內醯胺、丙烯腈等)、人造纖維產品(例如尼龍纖維、聚酯纖維、嫘縈纖維等)、染整、成衣及其它家居紡織類品
# ** 建材營造 - 建設業、工程承攬
# 1342
# https://ic.tpex.org.tw/company_chain.php?stk_code=1342
# ** 其他 - 其他
# 1341
# https://ic.tpex.org.tw/company_chain.php?stk_code=1341
# 1340
# https://ic.tpex.org.tw/company_chain.php?stk_code=1340
# ** 石化及塑橡膠 - 塑膠製品
# 1339
# https://ic.tpex.org.tw/company_chain.php?stk_code=1339
# ** 石化及塑橡膠 - 塑膠製品
# ** 汽車 - 保險桿
# 1338
# https://ic.tpex.org.tw/company_chain.php?stk_code=1338
# ** 汽車 - 其他
# 1337
# https://ic.tpex.org.tw/company_chain.php?stk_code=1337
# ** 石化及塑橡膠 - 塑膠製品
# 1326
# https://ic.tpex.org.tw/company_chain.php?stk_code=1326
# ** 石化及塑橡膠 - 塑膠製品、人造纖維、PTA(對苯二甲酸)觸媒
# ** 紡織 - 石化原料(例如純對苯二甲酸、乙二醇、己內醯胺、丙烯腈等)、人造纖維產品(例如尼龍纖維、聚酯纖維、嫘縈纖維等)、紡紗、織布、染整
# 1325
# https://ic.tpex.org.tw/company_chain.php?stk_code=1325
# ** 石化及塑橡膠 - 塑膠製品
# 1324
# https://ic.tpex.org.tw/company_chain.php?stk_code=1324
# ** 石化及塑橡膠 - 塑膠製品
# 1323
# https://ic.tpex.org.tw/company_chain.php?stk_code=1323
# ** 石化及塑橡膠 - 塑膠製品
# 1321
# https://ic.tpex.org.tw/company_chain.php?stk_code=1321
# ** 石化及塑橡膠 - 塑膠製品
# 1319
# https://ic.tpex.org.tw/company_chain.php?stk_code=1319
# ** 石化及塑橡膠 - 塑膠製品
# ** 汽車 - 鈑金、引擎蓋、保險桿
# 1316
# https://ic.tpex.org.tw/company_chain.php?stk_code=1316
# ** 石化及塑橡膠 - 塑膠製品
# 1315
# https://ic.tpex.org.tw/company_chain.php?stk_code=1315
# ** 石化及塑橡膠 - 塑膠製品
# ** 紡織 - 成衣及其它家居紡織類品
# ** 電機機械 - 手工具機
# 1314
# https://ic.tpex.org.tw/company_chain.php?stk_code=1314
# ** 紡織 - 石化原料(例如純對苯二甲酸、乙二醇、己內醯胺、丙烯腈等)
# ** 石化及塑橡膠 - PTA(對苯二甲酸)觸媒、工業用合成樹脂
# 1313
# https://ic.tpex.org.tw/company_chain.php?stk_code=1313
# ** 石化及塑橡膠 - 塑化劑(可塑劑)
# 1312
# https://ic.tpex.org.tw/company_chain.php?stk_code=1312
# ** 石化及塑橡膠 - 塑膠製品
# 1310
# https://ic.tpex.org.tw/company_chain.php?stk_code=1310
# ** 石化及塑橡膠 - 塑膠製品
# 1309
# https://ic.tpex.org.tw/company_chain.php?stk_code=1309
# ** 石化及塑橡膠 - 塑膠製品
# 1308
# https://ic.tpex.org.tw/company_chain.php?stk_code=1308
# ** 石化及塑橡膠 - 工業用合成樹脂
# 1307
# https://ic.tpex.org.tw/company_chain.php?stk_code=1307
# ** 石化及塑橡膠 - 塑膠製品
# 1305
# https://ic.tpex.org.tw/company_chain.php?stk_code=1305
# ** 石化及塑橡膠 - 塑膠製品
# 1304
# https://ic.tpex.org.tw/company_chain.php?stk_code=1304
# ** 石化及塑橡膠 - 工業用合成樹脂
# 1303
# https://ic.tpex.org.tw/company_chain.php?stk_code=1303
# ** 印刷電路板 - 玻璃纖維/玻纖布、環氧樹脂、酚醛樹脂、銅箔、銅箔基板
# ** 石化及塑橡膠 - 石化上游原料及相關鑽探設備、人造纖維
# ** 紡織 - 石化原料(例如純對苯二甲酸、乙二醇、己內醯胺、丙烯腈等)、人造纖維產品(例如尼龍纖維、聚酯纖維、嫘縈纖維等)、染整
# ** 電機機械 - 電控元件、機械設備之沖壓零組件
# 1301
# https://ic.tpex.org.tw/company_chain.php?stk_code=1301
# ** 石化及塑橡膠 - 塑膠製品、人造纖維
# ** 紡織 - 石化原料(例如純對苯二甲酸、乙二醇、己內醯胺、丙烯腈等)
# 1256
# https://ic.tpex.org.tw/company_chain.php?stk_code=1256
# ** 食品 - 加工食品
# 1236
# https://ic.tpex.org.tw/company_chain.php?stk_code=1236
# ** 食品 - 乳製品
# 1235
# https://ic.tpex.org.tw/company_chain.php?stk_code=1235
# ** 食品 - 原物料
# 1234
# https://ic.tpex.org.tw/company_chain.php?stk_code=1234
# ** 食品 - 冷凍、罐頭、脫水、醃漬食品
# 1233
# https://ic.tpex.org.tw/company_chain.php?stk_code=1233
# ** 食品 - 原物料、餐飲連鎖
# 1232
# https://ic.tpex.org.tw/company_chain.php?stk_code=1232
# ** 食品 - 原物料、加工食品
# 1231
# https://ic.tpex.org.tw/company_chain.php?stk_code=1231
# ** 食品 - 冷凍、罐頭、脫水、醃漬食品
# 1229
# https://ic.tpex.org.tw/company_chain.php?stk_code=1229
# ** 食品 - 加工食品
# ** 雲端運算 - 系統整合
# 1227
# https://ic.tpex.org.tw/company_chain.php?stk_code=1227
# ** 食品 - 營養食品
# 1225
# https://ic.tpex.org.tw/company_chain.php?stk_code=1225
# ** 食品 - 原物料、加工食品
# 1220
# https://ic.tpex.org.tw/company_chain.php?stk_code=1220
# ** 食品 - 原物料、加工食品
# ** 貿易百貨 - 貿易商、代理商、經銷商
# 1219
# https://ic.tpex.org.tw/company_chain.php?stk_code=1219
# ** 食品 - 加工食品
# 1218
# https://ic.tpex.org.tw/company_chain.php?stk_code=1218
# ** 食品 - 加工食品、冷凍、罐頭、脫水、醃漬食品
# 1217
# https://ic.tpex.org.tw/company_chain.php?stk_code=1217
# ** 食品 - 冷凍、罐頭、脫水、醃漬食品
# 1216
# https://ic.tpex.org.tw/company_chain.php?stk_code=1216
# ** 食品 - 原物料、加工食品、冷凍、罐頭、脫水、醃漬食品、乳製品
# 1215
# https://ic.tpex.org.tw/company_chain.php?stk_code=1215
# ** 食品 - 原物料、加工食品、冷凍、罐頭、脫水、醃漬食品
# 1213
# https://ic.tpex.org.tw/company_chain.php?stk_code=1213
# ** 其他 - 其他
# 1210
# https://ic.tpex.org.tw/company_chain.php?stk_code=1210
# ** 食品 - 原物料、加工食品、冷凍、罐頭、脫水、醃漬食品
# 1203
# https://ic.tpex.org.tw/company_chain.php?stk_code=1203
# ** 食品 - 冷凍、罐頭、脫水、醃漬食品
# 1201
# https://ic.tpex.org.tw/company_chain.php?stk_code=1201
# ** 食品 - 冷凍、罐頭、脫水、醃漬食品、乳製品
# 1110
# https://ic.tpex.org.tw/company_chain.php?stk_code=1110
# ** 水泥 - 水泥成品
# 1109
# https://ic.tpex.org.tw/company_chain.php?stk_code=1109
# ** 水泥 - 石灰石、水泥生料、水泥熟料、水泥成品、預拌混凝土
# 1108
# https://ic.tpex.org.tw/company_chain.php?stk_code=1108
# ** 水泥 - 石灰石、水泥生料、水泥熟料、水泥成品、預拌混凝土
# 1104
# https://ic.tpex.org.tw/company_chain.php?stk_code=1104
# ** 水泥 - 水泥成品、預拌混凝土
# 1103
# https://ic.tpex.org.tw/company_chain.php?stk_code=1103
# ** 水泥 - 水泥成品
# ** 建材營造 - 建設業
# ** 交通運輸及航運 - 貨櫃運輸集散及倉儲
# ** 金融 - 租賃業
# 1102
# https://ic.tpex.org.tw/company_chain.php?stk_code=1102
# ** 水泥 - 水泥熟料
# ** 風力發電 - 風場開發、發電營運
# 1101
# https://ic.tpex.org.tw/company_chain.php?stk_code=1101
# ** 水泥 - 石灰石、水泥生料、水泥熟料、水泥成品、預拌混凝土

# %% [markdown]
# df_data_all

# %%
file_name='Result/StockType.xlsx'
#save_excel(file_name,df_data_all)
df_data_all.to_excel(file_name, index=False)
df_data_all.drop_duplicates().to_excel(file_name, index=False)

# %% [markdown]
# ###############################################

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import warnings
import json
warnings.filterwarnings("ignore")


def abs_url(url, base):
    # 取得完整 URL
    if url is None:
        return None
    return url if url.startswith('http') else base + '/' + url.lstrip('/')

def clean(txt):
    return txt.strip().replace('\n', ' ').replace('\r', '').replace('\t', ' ') if txt else ''



origin='https://ic.tpex.org.tw/'
url = 'https://ic.tpex.org.tw/index.php'
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36'    
}
"""
proxies = {
    "http": "http://itchang:B$0000000000@auhqwsg.corpnet.auo.com:8080",
    "https": "http://itchang:B$0000000000@auhqwsg.corpnet.auo.com:8080"
}
"""
def abs_url(url, base):
    # 取得完整 URL
    if url is None:
        return None
    return url if url.startswith('http') else base + '/' + url.lstrip('/')

def clean(txt):
    return txt.strip().replace('\n', ' ').replace('\r', '').replace('\t', ' ') if txt else ''

# %%
url = "https://ic.tpex.org.tw/index.php"   # 這裡請換成你要抓取的實際 URL
#response = requests.get(url,  headers=headers,verify=False, proxies=proxies, timeout=15)
response = requests.get(url,  headers=headers,verify=False, timeout=15)
response.encoding = 'utf-8'
soup = BeautifulSoup(response.text, 'html.parser')


data = []
base_url = url.split('/')[0] + "//" + url.split('/')[2]

main = soup.select('.Content_2 .item')
for a in main:
    a_tag = a.find('a')
    
    href = a_tag['href'] if a_tag else ''
    abs_href = abs_url(href, base_url)
    title = clean(a.find(class_='txt').get_text())

    subtitle = ''
    item = ''
    
    ul = a.find('ul')

    if ul:
        sub1 = ul.select('.listItem a')
        for b in sub1:
            href2 = b['href'] if b.has_attr('href') else ''
            url2 = abs_url(href2, base_url)
            spans = b.select('span')
            subtitle = clean(spans[1].get_text()) if len(spans) > 1 else ''
            third_menu = b.find(class_='thirdMenu')
            if third_menu:
                sub2 = third_menu.select('.itemLink')
                for c in sub2:
                    onclick = c.get('onclick')
                    if onclick:
                        # 取出 URL
                        url3 = onclick.replace("location.href=", "").replace("'", "")
                        url3 = abs_url(url3, base_url)
                    else:
                        url3 = ''
                    item = clean(c.get_text())
                    data.append({'type': title, 'subtype': subtitle, 'item': item, 'url': url3})
            else:
                data.append({'type': title, 'subtype': subtitle, 'item': item, 'url': url2})
    else:
        data.append({'type': title, 'subtype': subtitle, 'item': item, 'url': abs_href})

# %%
data
# Out:
# [{'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'url': 'https://ic.tpex.org.tw/introduce.php?ic=D000'},
#  {'type': '生技醫療',
#   'subtype': '製藥',
#   'item': '',
#   'url': 'https://ic.tpex.org.tw/introduce.php?ic=C100'},
#  {'type': '生技醫療',
#   'subtype': '醫療器材',
#   'item': '',
#   'url': 'https://ic.tpex.org.tw/introduce.php?ic=C200'},
#  {'type': '生技醫療',
#   'subtype': '食品生技',
#   'item': '',
#   'url': 'https://ic.tpex.org.tw/introduce.php?ic=C300'},
#  {'type': '生技醫療',
#   'subtype': '再生醫療',
#   'item': '',
#   'url': 'https://ic.tpex.org.tw/introduce.php?ic=C400'},
#  {'type': '綠色能源',
#   'subtype': '節能',
#   'item': '◈ 電動車',
#   'url': 'https://ic.tpex.org.tw/introduce.php?ic=A300'},
#  {'type': '綠色能源',
#   'subtype': '節能',
#   'item': '◈ LED 照明',
#   'url': 'https://ic.tpex.org.tw/introduce.php?ic=A200'},
#  {'type': '綠色能源',
#   'subtype': '創能',
#   'item': '◈ 太陽能',
#   'url': 'https://ic.tpex.org.tw/introduce.php?ic=A100'},
#  {'type': '綠色能源',
#   'subtype': '創能',
#   'item': '◈ 汽電共生',
#   'url': 'https://ic.tpex.org.tw/introduce.php?ic=AB10'},
#  {'type': '綠色能源',
#   'subtype': '創能',
#   'item': '◈ 風力發電',
#   'url': 'https://ic.tpex.org.tw/introduce.php?ic=AB20'},
#  {'type': '綠色能源',
#   'subtype': '儲能',
#   'item': '◈ 能源元件',
#   'url': 'https://ic.tpex.org.tw/introduce.php?ic=E000'},
#  {'type': '綠色能源',
#   'subtype': '智慧系統整合',
#   'item': '◈ 智慧電網',
#   'url': 'https://ic.tpex.org.tw/introduce.php?ic=AD10'},
#  {'type': '數位科技',
#   'subtype': '區塊鏈',
#   'item': '',
#   'url': 'https://ic.tpex.org.tw/introduce.php?ic=5100'},
#  {'type': '數位科技',
#   'subtype': '金融科技',
#   'item': '',
#   'url': 'https://ic.tpex.org.tw/introduce.php?ic=5200'},
#  {'type': '數位科技',
#   'subtype': '人工智慧',
#   'item': '',
#   'url': 'https://ic.tpex.org.tw/introduce.php?ic=5300'},
#  {'type': '數位科技',
#   'subtype': '雲端運算',
#   'item': '',
#   'url': 'https://ic.tpex.org.tw/introduce.php?ic=5400'},
#  {'type': '數位科技',
#   'subtype': '資通訊安全',
#   'item': '',
#   'url': 'https://ic.tpex.org.tw/introduce.php?ic=5500'},
#  {'type': '數位科技',
#   'subtype': '大數據',
#   'item': '',
#   'url': 'https://ic.tpex.org.tw/introduce.php?ic=5600'},
#  {'type': '數位科技',
#   'subtype': '體驗科技',
#   'item': '',
#   'url': 'https://ic.tpex.org.tw/introduce.php?ic=5700'},
#  {'type': '數位科技',
#   'subtype': '運動科技',
#   'item': '',
#   'url': 'https://ic.tpex.org.tw/introduce.php?ic=5800'},
#  {'type': '前瞻科技',
#   'subtype': '太空衛星科技',
#   'item': '',
#   'url': 'https://ic.tpex.org.tw/introduce.php?ic=4100'},
#  {'type': '自動化',
#   'subtype': '',
#   'item': '',
#   'url': 'https://ic.tpex.org.tw/introduce.php?ic=6000'},
#  {'type': '電子商務',
#   'subtype': '',
#   'item': '',
#   'url': 'https://ic.tpex.org.tw/introduce.php?ic=R300'},
#  {'type': '被動元件',
#   'subtype': '',
#   'item': '',
#   'url': 'https://ic.tpex.org.tw/introduce.php?ic=J000'},
#  {'type': '通信網路',
#   'subtype': '',
#   'item': '',
#   'url': 'https://ic.tpex.org.tw/introduce.php?ic=I000'},
#  {'type': '連接器',
#   'subtype': '',
#   'item': '',
#   'url': 'https://ic.tpex.org.tw/introduce.php?ic=K000'},
#  {'type': '電腦週邊',
#   'subtype': '',
#   'item': '',
#   'url': 'https://ic.tpex.org.tw/introduce.php?ic=F000'},
#  {'type': '平面顯示器',
#   'subtype': '',
#   'item': '',
#   'url': 'https://ic.tpex.org.tw/introduce.php?ic=G000'},
#  {'type': '觸控面板',
#   'subtype': '',
#   'item': '',
#   'url': 'https://ic.tpex.org.tw/introduce.php?ic=H000'},
#  {'type': '印刷電路板',
#   'subtype': '',
#   'item': '',
#   'url': 'https://ic.tpex.org.tw/introduce.php?ic=L000'},
#  {'type': '休閒娛樂',
#   'subtype': '',
#   'item': '',
#   'url': 'https://ic.tpex.org.tw/introduce.php?ic=B000'},
#  {'type': '水泥',
#   'subtype': '',
#   'item': '',
#   'url': 'https://ic.tpex.org.tw/introduce.php?ic=1000'},
#  {'type': '食品',
#   'subtype': '',
#   'item': '',
#   'url': 'https://ic.tpex.org.tw/introduce.php?ic=M000'},
#  {'type': '石化及塑橡膠',
#   'subtype': '',
#   'item': '',
#   'url': 'https://ic.tpex.org.tw/introduce.php?ic=N000'},
#  {'type': '紡織',
#   'subtype': '',
#   'item': '',
#   'url': 'https://ic.tpex.org.tw/introduce.php?ic=O000'},
#  {'type': '電機機械',
#   'subtype': '',
#   'item': '',
#   'url': 'https://ic.tpex.org.tw/introduce.php?ic=P000'},
#  {'type': '造紙',
#   'subtype': '',
#   'item': '',
#   'url': 'https://ic.tpex.org.tw/introduce.php?ic=2000'},
#  {'type': '鋼鐵',
#   'subtype': '',
#   'item': '',
#   'url': 'https://ic.tpex.org.tw/introduce.php?ic=Q000'},
#  {'type': '汽車',
#   'subtype': '',
#   'item': '',
#   'url': 'https://ic.tpex.org.tw/introduce.php?ic=3000'},
#  {'type': '軟體服務',
#   'subtype': '',
#   'item': '',
#   'url': 'https://ic.tpex.org.tw/introduce.php?ic=R000'},
#  {'type': '建材營造',
#   'subtype': '',
#   'item': '',
#   'url': 'https://ic.tpex.org.tw/introduce.php?ic=S000'},
#  {'type': '交通運輸及航運',
#   'subtype': '',
#   'item': '',
#   'url': 'https://ic.tpex.org.tw/introduce.php?ic=T000'},
#  {'type': '金融',
#   'subtype': '',
#   'item': '',
#   'url': 'https://ic.tpex.org.tw/introduce.php?ic=U000'},
#  {'type': '貿易百貨',
#   'subtype': '',
#   'item': '',
#   'url': 'https://ic.tpex.org.tw/introduce.php?ic=V000'},
#  {'type': '油電燃氣',
#   'subtype': '',
#   'item': '',
#   'url': 'https://ic.tpex.org.tw/introduce.php?ic=W000'},
#  {'type': '文化創意',
#   'subtype': '',
#   'item': '',
#   'url': 'https://ic.tpex.org.tw/introduce.php?ic=Y000'},
#  {'type': '其他',
#   'subtype': '',
#   'item': '',
#   'url': 'https://ic.tpex.org.tw/introduce.php?ic=X000'}]

# %%
########################################

# %%
areadata=[]
detaildata=[]

for a in data:
    time.sleep(3)
    print(a)
    url=a['url']
    type=a['type']
    item=a['item']
    subtype=a['subtype']
    #url='https://ic.tpex.org.tw/introduce.php?ic=D000'
    response = requests.get(url,verify = False)
    response.encoding = 'utf-8'

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, "html.parser")

    for chain in soup.select('.chain'):

        title_panel = chain.select_one('.chain-title-panel')
        if not title_panel:
            # 這裡你可以 print 看是哪個 URL 有問題
            print("no .chain-title-panel in", url)
            continue  # 跳過這一個 chain

        area = title_panel.get_text(strip=True)

        
        
        area = chain.select_one('.chain-title-panel').get_text(strip=True)
        for b in chain.select('.company-chain-panel'):
            title = clean(b.get_text())
            areadata.append({'area': area, 'title': title})

    for a in soup.select('div[id^="companyList"] '):
        title = a["title"]
        for b in a.select('.company-text-over'):
            name = b.get_text(strip=True)
            href = b.get('href') or ''
            url = abs_url(href, origin)
            try:
                number = href.split('stk_code=')[1]
            except Exception:
                number = ''
            area = next((x['area'] for x in areadata if x['title'] == title), '')
            detaildata.append({'area': area, 'type':type,'subtype':subtype,'item':item,'title': title, 'number': number, 'name': name, 'url': url})
# Out:
# {'type': '半導體', 'subtype': '', 'item': '', 'url': 'https://ic.tpex.org.tw/introduce.php?ic=D000'}
# {'type': '生技醫療', 'subtype': '製藥', 'item': '', 'url': 'https://ic.tpex.org.tw/introduce.php?ic=C100'}
# {'type': '生技醫療', 'subtype': '醫療器材', 'item': '', 'url': 'https://ic.tpex.org.tw/introduce.php?ic=C200'}
# {'type': '生技醫療', 'subtype': '食品生技', 'item': '', 'url': 'https://ic.tpex.org.tw/introduce.php?ic=C300'}
# {'type': '生技醫療', 'subtype': '再生醫療', 'item': '', 'url': 'https://ic.tpex.org.tw/introduce.php?ic=C400'}
# {'type': '綠色能源', 'subtype': '節能', 'item': '◈ 電動車', 'url': 'https://ic.tpex.org.tw/introduce.php?ic=A300'}
# {'type': '綠色能源', 'subtype': '節能', 'item': '◈ LED 照明', 'url': 'https://ic.tpex.org.tw/introduce.php?ic=A200'}
# {'type': '綠色能源', 'subtype': '創能', 'item': '◈ 太陽能', 'url': 'https://ic.tpex.org.tw/introduce.php?ic=A100'}
# {'type': '綠色能源', 'subtype': '創能', 'item': '◈ 汽電共生', 'url': 'https://ic.tpex.org.tw/introduce.php?ic=AB10'}
# {'type': '綠色能源', 'subtype': '創能', 'item': '◈ 風力發電', 'url': 'https://ic.tpex.org.tw/introduce.php?ic=AB20'}
# {'type': '綠色能源', 'subtype': '儲能', 'item': '◈ 能源元件', 'url': 'https://ic.tpex.org.tw/introduce.php?ic=E000'}
# {'type': '綠色能源', 'subtype': '智慧系統整合', 'item': '◈ 智慧電網', 'url': 'https://ic.tpex.org.tw/introduce.php?ic=AD10'}
# {'type': '數位科技', 'subtype': '區塊鏈', 'item': '', 'url': 'https://ic.tpex.org.tw/introduce.php?ic=5100'}
# {'type': '數位科技', 'subtype': '金融科技', 'item': '', 'url': 'https://ic.tpex.org.tw/introduce.php?ic=5200'}
# {'type': '數位科技', 'subtype': '人工智慧', 'item': '', 'url': 'https://ic.tpex.org.tw/introduce.php?ic=5300'}
# {'type': '數位科技', 'subtype': '雲端運算', 'item': '', 'url': 'https://ic.tpex.org.tw/introduce.php?ic=5400'}
# {'type': '數位科技', 'subtype': '資通訊安全', 'item': '', 'url': 'https://ic.tpex.org.tw/introduce.php?ic=5500'}
# {'type': '數位科技', 'subtype': '大數據', 'item': '', 'url': 'https://ic.tpex.org.tw/introduce.php?ic=5600'}
# {'type': '數位科技', 'subtype': '體驗科技', 'item': '', 'url': 'https://ic.tpex.org.tw/introduce.php?ic=5700'}
# no .chain-title-panel in https://ic.tpex.org.tw/introduce.php?ic=5700
# no .chain-title-panel in https://ic.tpex.org.tw/introduce.php?ic=5700
# no .chain-title-panel in https://ic.tpex.org.tw/introduce.php?ic=5700
# {'type': '數位科技', 'subtype': '運動科技', 'item': '', 'url': 'https://ic.tpex.org.tw/introduce.php?ic=5800'}
# {'type': '前瞻科技', 'subtype': '太空衛星科技', 'item': '', 'url': 'https://ic.tpex.org.tw/introduce.php?ic=4100'}
# {'type': '自動化', 'subtype': '', 'item': '', 'url': 'https://ic.tpex.org.tw/introduce.php?ic=6000'}
# {'type': '電子商務', 'subtype': '', 'item': '', 'url': 'https://ic.tpex.org.tw/introduce.php?ic=R300'}
# {'type': '被動元件', 'subtype': '', 'item': '', 'url': 'https://ic.tpex.org.tw/introduce.php?ic=J000'}
# {'type': '通信網路', 'subtype': '', 'item': '', 'url': 'https://ic.tpex.org.tw/introduce.php?ic=I000'}
# {'type': '連接器', 'subtype': '', 'item': '', 'url': 'https://ic.tpex.org.tw/introduce.php?ic=K000'}
# {'type': '電腦週邊', 'subtype': '', 'item': '', 'url': 'https://ic.tpex.org.tw/introduce.php?ic=F000'}
# {'type': '平面顯示器', 'subtype': '', 'item': '', 'url': 'https://ic.tpex.org.tw/introduce.php?ic=G000'}
# {'type': '觸控面板', 'subtype': '', 'item': '', 'url': 'https://ic.tpex.org.tw/introduce.php?ic=H000'}
# {'type': '印刷電路板', 'subtype': '', 'item': '', 'url': 'https://ic.tpex.org.tw/introduce.php?ic=L000'}
# {'type': '休閒娛樂', 'subtype': '', 'item': '', 'url': 'https://ic.tpex.org.tw/introduce.php?ic=B000'}
# {'type': '水泥', 'subtype': '', 'item': '', 'url': 'https://ic.tpex.org.tw/introduce.php?ic=1000'}
# {'type': '食品', 'subtype': '', 'item': '', 'url': 'https://ic.tpex.org.tw/introduce.php?ic=M000'}
# {'type': '石化及塑橡膠', 'subtype': '', 'item': '', 'url': 'https://ic.tpex.org.tw/introduce.php?ic=N000'}
# {'type': '紡織', 'subtype': '', 'item': '', 'url': 'https://ic.tpex.org.tw/introduce.php?ic=O000'}
# {'type': '電機機械', 'subtype': '', 'item': '', 'url': 'https://ic.tpex.org.tw/introduce.php?ic=P000'}
# {'type': '造紙', 'subtype': '', 'item': '', 'url': 'https://ic.tpex.org.tw/introduce.php?ic=2000'}
# {'type': '鋼鐵', 'subtype': '', 'item': '', 'url': 'https://ic.tpex.org.tw/introduce.php?ic=Q000'}
# {'type': '汽車', 'subtype': '', 'item': '', 'url': 'https://ic.tpex.org.tw/introduce.php?ic=3000'}
# {'type': '軟體服務', 'subtype': '', 'item': '', 'url': 'https://ic.tpex.org.tw/introduce.php?ic=R000'}
# {'type': '建材營造', 'subtype': '', 'item': '', 'url': 'https://ic.tpex.org.tw/introduce.php?ic=S000'}
# {'type': '交通運輸及航運', 'subtype': '', 'item': '', 'url': 'https://ic.tpex.org.tw/introduce.php?ic=T000'}
# {'type': '金融', 'subtype': '', 'item': '', 'url': 'https://ic.tpex.org.tw/introduce.php?ic=U000'}
# {'type': '貿易百貨', 'subtype': '', 'item': '', 'url': 'https://ic.tpex.org.tw/introduce.php?ic=V000'}
# {'type': '油電燃氣', 'subtype': '', 'item': '', 'url': 'https://ic.tpex.org.tw/introduce.php?ic=W000'}
# {'type': '文化創意', 'subtype': '', 'item': '', 'url': 'https://ic.tpex.org.tw/introduce.php?ic=Y000'}
# {'type': '其他', 'subtype': '', 'item': '', 'url': 'https://ic.tpex.org.tw/introduce.php?ic=X000'}

# %%
detaildata
# Out:
# [{'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IP設計/IC設計代工服務',
#   'number': '2401',
#   'name': '凌陽',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=2401'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IP設計/IC設計代工服務',
#   'number': '3035',
#   'name': '智原',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3035'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IP設計/IC設計代工服務',
#   'number': '3443',
#   'name': '創意',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3443'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IP設計/IC設計代工服務',
#   'number': '5222',
#   'name': '全訊',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=5222'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IP設計/IC設計代工服務',
#   'number': '6423',
#   'name': '億而得-創',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6423'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IP設計/IC設計代工服務',
#   'number': '6533',
#   'name': '晶心科',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6533'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IP設計/IC設計代工服務',
#   'number': '6695',
#   'name': '芯鼎',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6695'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IP設計/IC設計代工服務',
#   'number': '3661',
#   'name': '世芯-KY',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3661'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IP設計/IC設計代工服務',
#   'number': '3339',
#   'name': '泰谷',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3339'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IP設計/IC設計代工服務',
#   'number': '3529',
#   'name': '力旺',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3529'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IP設計/IC設計代工服務',
#   'number': '6643',
#   'name': 'M31',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6643'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IP設計/IC設計代工服務',
#   'number': '8054',
#   'name': '安國',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=8054'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IP設計/IC設計代工服務',
#   'number': '8227',
#   'name': '巨有科技',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=8227'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IP設計/IC設計代工服務',
#   'number': '8299',
#   'name': '群聯',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=8299'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IP設計/IC設計代工服務',
#   'number': '6786',
#   'name': '芯測',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6786'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IP設計/IC設計代工服務',
#   'number': '6842',
#   'name': '一元素',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6842'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IP設計/IC設計代工服務',
#   'number': '7707',
#   'name': '益芯科',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=7707'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IP設計/IC設計代工服務',
#   'number': '7796',
#   'name': '擷發科',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=7796'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IP設計/IC設計代工服務',
#   'number': '',
#   'name': '安謀',
#   'url': 'http://www.arm.com/'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IP設計/IC設計代工服務',
#   'number': '',
#   'name': '益華',
#   'url': 'http://www.cadence.com/'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IP設計/IC設計代工服務',
#   'number': '',
#   'name': 'Imagination',
#   'url': 'http://imgtec.com/'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IP設計/IC設計代工服務',
#   'number': '',
#   'name': '新思科技',
#   'url': 'http://www.synopsys.com/home.aspx'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '2308',
#   'name': '台達電',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=2308'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '3014',
#   'name': '聯陽',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3014'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '4961',
#   'name': '天鈺',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=4961'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6415',
#   'name': '矽力*-KY',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6415'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '3288',
#   'name': '點晶',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3288'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '3527',
#   'name': '聚積',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3527'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6129',
#   'name': '普誠',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6129'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6138',
#   'name': '茂達',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6138'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': '安華高科技',
#   'url': 'http://www.avagotech.com/'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': '博通',
#   'url': 'http://www.broadcom.com/'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': '美信',
#   'url': 'https://www.analog.com/en/index.html'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': '德州儀器',
#   'url': 'http://www.ti.com/'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '5468',
#   'name': '凱鈺',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=5468'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6568',
#   'name': '宏觀',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6568'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': '海思半導體',
#   'url': 'http://www.hisilicon.com/'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': '邁威爾',
#   'url': 'http://www.marvell.com/'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': 'PMC-Sierra',
#   'url': 'http://pmcs.com/'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '8016',
#   'name': '矽創',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=8016'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6415',
#   'name': '矽力*-KY',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6415'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6732',
#   'name': '昇佳電子',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6732'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '2308',
#   'name': '台達電',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=2308'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '2401',
#   'name': '凌陽',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=2401'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '2436',
#   'name': '偉詮電',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=2436'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '2454',
#   'name': '聯發科',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=2454'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '2458',
#   'name': '義隆',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=2458'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '3014',
#   'name': '聯陽',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3014'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '3034',
#   'name': '聯詠',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3034'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '3041',
#   'name': '揚智',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3041'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '3150',
#   'name': '鈺寶-創',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3150'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '3530',
#   'name': '晶相光',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3530'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '4919',
#   'name': '新唐',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=4919'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '4952',
#   'name': '凌通',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=4952'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6695',
#   'name': '芯鼎',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6695'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6756',
#   'name': '威鋒電子',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6756'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '8016',
#   'name': '矽創',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=8016'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '3073',
#   'name': '天方能源',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3073'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '3122',
#   'name': '笙泉',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3122'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '3268',
#   'name': '海德威',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3268'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '3288',
#   'name': '點晶',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3288'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '3527',
#   'name': '聚積',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3527'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '3556',
#   'name': '禾瑞亞',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3556'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '5236',
#   'name': '凌陽創新',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=5236'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '5272',
#   'name': '笙科',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=5272'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '5302',
#   'name': '太欣',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=5302'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '5487',
#   'name': '通泰',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=5487'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6103',
#   'name': '合邦',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6103'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6129',
#   'name': '普誠',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6129'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6237',
#   'name': '驊訊',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6237'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6462',
#   'name': '神盾',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6462'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6494',
#   'name': '九齊',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6494'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6568',
#   'name': '宏觀',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6568'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6684',
#   'name': '安格',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6684'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6720',
#   'name': '久昌',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6720'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '8024',
#   'name': '佑華',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=8024'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '8054',
#   'name': '安國',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=8054'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6563',
#   'name': '映智',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6563'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '7770',
#   'name': '君曜',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=7770'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '8102',
#   'name': '傑霖科技',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=8102'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '2337',
#   'name': '旺宏',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=2337'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '2344',
#   'name': '華邦電',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=2344'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '2408',
#   'name': '南亞科',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=2408'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '3006',
#   'name': '晶豪科',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3006'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6531',
#   'name': '愛普*',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6531'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '5351',
#   'name': '鈺創',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=5351'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': '美光',
#   'url': 'http://www.micron.com'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': '三星電子',
#   'url': 'http://www.samsung.com/'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': '三星電子',
#   'url': 'http://www.samsung.com/tw/home/'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': '新帝公司',
#   'url': 'http://www.sandisk.com/'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '3259',
#   'name': '鑫創',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3259'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6485',
#   'name': '點序',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6485'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '8299',
#   'name': '群聯',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=8299'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '4925',
#   'name': '智微',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=4925'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '7843',
#   'name': '英柏得',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=7843'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': '安華高科技',
#   'url': 'http://www.avagotech.com/'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': '博通',
#   'url': 'http://www.broadcom.com/'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': '邁威爾',
#   'url': 'http://www.marvell.com/'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': '邁威爾',
#   'url': 'http://www.marvell.com/'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': '慧榮科技股份有限公司',
#   'url': 'http://www.siliconmotion.com/'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '2308',
#   'name': '台達電',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=2308'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '2436',
#   'name': '偉詮電',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=2436'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '2458',
#   'name': '義隆',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=2458'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '3014',
#   'name': '聯陽',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3014'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '3034',
#   'name': '聯詠',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3034'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '4952',
#   'name': '凌通',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=4952'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '5471',
#   'name': '松翰',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=5471'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6202',
#   'name': '盛群',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6202'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '3122',
#   'name': '笙泉',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3122'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '3228',
#   'name': '金麗科',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3228'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '4945',
#   'name': '陞達科技',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=4945'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '5236',
#   'name': '凌陽創新',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=5236'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '5487',
#   'name': '通泰',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=5487'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6129',
#   'name': '普誠',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6129'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6229',
#   'name': '研通',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6229'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6679',
#   'name': '鈺太',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6679'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6716',
#   'name': '應廣',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6716'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '8024',
#   'name': '佑華',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=8024'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': 'Atmel',
#   'url': 'https://ic.tpex.org.tw//www.atmel.com/'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': '愛特梅爾',
#   'url': 'http://www.atmel.com/'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': '恩智浦半導體',
#   'url': 'http://www.nxp.com/'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': '瑞薩電子',
#   'url': 'http://www.renesas.com/'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '2308',
#   'name': '台達電',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=2308'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '2436',
#   'name': '偉詮電',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=2436'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '2454',
#   'name': '聯發科',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=2454'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '3034',
#   'name': '聯詠',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3034'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '3257',
#   'name': '虹冠電',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3257'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '3588',
#   'name': '通嘉',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3588'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '3592',
#   'name': '瑞鼎',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3592'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '4952',
#   'name': '凌通',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=4952'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '4961',
#   'name': '天鈺',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=4961'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6719',
#   'name': '力智',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6719'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6756',
#   'name': '威鋒電子',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6756'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6799',
#   'name': '來頡',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6799'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '8016',
#   'name': '矽創',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=8016'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '8081',
#   'name': '致新',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=8081'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '8261',
#   'name': '富鼎',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=8261'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6415',
#   'name': '矽力*-KY',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6415'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '3122',
#   'name': '笙泉',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3122'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '3288',
#   'name': '點晶',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3288'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '3317',
#   'name': '尼克森',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3317'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '3438',
#   'name': '類比科',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3438'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '3527',
#   'name': '聚積',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3527'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '4923',
#   'name': '力士',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=4923'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '5299',
#   'name': '杰力',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=5299'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6129',
#   'name': '普誠',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6129'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6130',
#   'name': '上亞科技',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6130'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6138',
#   'name': '茂達',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6138'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6291',
#   'name': '沛亨',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6291'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6435',
#   'name': '大中',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6435'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6651',
#   'name': '全宇昕',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6651'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6679',
#   'name': '鈺太',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6679'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6693',
#   'name': '廣閎科',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6693'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '7712',
#   'name': '博盛半導體',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=7712'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': '亞德諾半導體',
#   'url': 'http://www.analog.com/'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': '意法半導體',
#   'url': 'http://www.st.com/'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': '德州儀器',
#   'url': 'http://www.ti.com/'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '2401',
#   'name': '凌陽',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=2401'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '7843',
#   'name': '英柏得',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=7843'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': '安華高科技',
#   'url': 'http://www.avagotech.com/'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': '博通',
#   'url': 'http://www.broadcom.com/'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': '邁威爾',
#   'url': 'http://www.marvell.com/'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': '邁威爾',
#   'url': 'http://www.marvell.com/'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': '三星電子',
#   'url': 'http://www.samsung.com/'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': '三星電子',
#   'url': 'http://www.samsung.com/tw/home/'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '2379',
#   'name': '瑞昱',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=2379'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '2454',
#   'name': '聯發科',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=2454'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '3094',
#   'name': '聯傑',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3094'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '4968',
#   'name': '立積',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=4968'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6526',
#   'name': '達發',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6526'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '3169',
#   'name': '亞信',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3169'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '5274',
#   'name': '信驊',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=5274'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6138',
#   'name': '茂達',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6138'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6568',
#   'name': '宏觀',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6568'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6708',
#   'name': '天擎',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6708'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '8040',
#   'name': '九暘',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=8040'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6699',
#   'name': '奇邑',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6699'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': '博通',
#   'url': 'http://www.broadcom.com/'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': '高通',
#   'url': 'https://www.qualcomm.com/'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': '紫光',
#   'url': 'http://www.thunis.com/drupal/unis_about/intro'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '2401',
#   'name': '凌陽',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=2401'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '3014',
#   'name': '聯陽',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3014'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '5269',
#   'name': '祥碩',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=5269'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6243',
#   'name': '迅杰',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6243'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6756',
#   'name': '威鋒電子',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6756'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '4951',
#   'name': '精拓科',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=4951'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6104',
#   'name': '創惟',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6104'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6233',
#   'name': '旺玖',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6233'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6411',
#   'name': '晶焱',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6411'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6568',
#   'name': '宏觀',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6568'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6679',
#   'name': '鈺太',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6679'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6684',
#   'name': '安格',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6684'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '8054',
#   'name': '安國',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=8054'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '4925',
#   'name': '智微',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=4925'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6563',
#   'name': '映智',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6563'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': '博通',
#   'url': 'http://www.broadcom.com/'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': '英特爾',
#   'url': 'http://www.intel.com.tw/content/www/tw/zh/homepage.html'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': '邁威爾',
#   'url': 'http://www.marvell.com/'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': '邁威爾',
#   'url': 'http://www.marvell.com/'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '2454',
#   'name': '聯發科',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=2454'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '3034',
#   'name': '聯詠',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3034'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '4952',
#   'name': '凌通',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=4952'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '3527',
#   'name': '聚積',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3527'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6129',
#   'name': '普誠',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6129'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': 'Atmel',
#   'url': 'https://ic.tpex.org.tw//www.atmel.com/'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': '愛特梅爾',
#   'url': 'http://www.atmel.com/'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': '匯頂科技',
#   'url': 'http://www.goodix.com/'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': 'Synaptics',
#   'url': 'http://www.synaptics.com/'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '3034',
#   'name': '聯詠',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3034'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '3545',
#   'name': '敦泰',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3545'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '3592',
#   'name': '瑞鼎',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3592'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '4961',
#   'name': '天鈺',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=4961'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '8016',
#   'name': '矽創',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=8016'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '3141',
#   'name': '晶宏',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3141'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '3527',
#   'name': '聚積',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3527'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6129',
#   'name': '普誠',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6129'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6996',
#   'name': '力領科技',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6996'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '4966',
#   'name': '譜瑞-KY',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=4966'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6927',
#   'name': '聯合聚晶',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6927'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': '格科微電子',
#   'url': 'http://www.gcoreinc.com/index.php?lang=en'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': '瑞薩電子',
#   'url': 'http://tw.renesas.com/'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': '瑞薩電子',
#   'url': 'http://www.renesas.com/'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': '三星電子',
#   'url': 'http://www.samsung.com/'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': '三星電子',
#   'url': 'http://www.samsung.com/tw/home/'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '2401',
#   'name': '凌陽',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=2401'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '2454',
#   'name': '聯發科',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=2454'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '2401',
#   'name': '凌陽',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=2401'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '3034',
#   'name': '聯詠',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3034'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '8016',
#   'name': '矽創',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=8016'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '3227',
#   'name': '原相',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3227'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '6563',
#   'name': '映智',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6563'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': '豪威科技',
#   'url': 'http://www.ovt.com/'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': '三星電子',
#   'url': 'http://www.samsung.com/'},
#  {'area': '上游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC設計',
#   'number': '',
#   'name': '索尼',
#   'url': 'http://www.sony.net/'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '光罩',
#   'number': '2338',
#   'name': '光罩',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=2338'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '光罩',
#   'number': '2438',
#   'name': '翔耀',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=2438'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '光罩',
#   'number': '',
#   'name': '大日本印刷',
#   'url': 'https://www.dnp.co.jp/'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '光罩',
#   'number': '',
#   'name': '豐創',
#   'url': 'http://www.photronics.com/plab/photronics/'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '光罩',
#   'number': '',
#   'name': '凸版印刷',
#   'url': 'http://www.toppan.co.jp/english/'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC/晶圓製造',
#   'number': '2303',
#   'name': '聯電',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=2303'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC/晶圓製造',
#   'number': '2330',
#   'name': '台積電',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=2330'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC/晶圓製造',
#   'number': '2337',
#   'name': '旺宏',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=2337'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC/晶圓製造',
#   'number': '2340',
#   'name': '台亞',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=2340'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC/晶圓製造',
#   'number': '2344',
#   'name': '華邦電',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=2344'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC/晶圓製造',
#   'number': '2371',
#   'name': '大同',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=2371'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC/晶圓製造',
#   'number': '2408',
#   'name': '南亞科',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=2408'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC/晶圓製造',
#   'number': '2434',
#   'name': '統懋',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=2434'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC/晶圓製造',
#   'number': '2455',
#   'name': '全新',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=2455'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC/晶圓製造',
#   'number': '3016',
#   'name': '嘉晶',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3016'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC/晶圓製造',
#   'number': '3532',
#   'name': '台勝科',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3532'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC/晶圓製造',
#   'number': '4919',
#   'name': '新唐',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=4919'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC/晶圓製造',
#   'number': '5222',
#   'name': '全訊',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=5222'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC/晶圓製造',
#   'number': '6770',
#   'name': '力積電',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6770'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC/晶圓製造',
#   'number': '8028',
#   'name': '昇陽半導體',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=8028'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC/晶圓製造',
#   'number': '3105',
#   'name': '穩懋',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3105'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC/晶圓製造',
#   'number': '3707',
#   'name': '漢磊',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3707'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC/晶圓製造',
#   'number': '5347',
#   'name': '世界',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=5347'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC/晶圓製造',
#   'number': '5483',
#   'name': '中美晶',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=5483'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC/晶圓製造',
#   'number': '6182',
#   'name': '合晶',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6182'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC/晶圓製造',
#   'number': '6488',
#   'name': '環球晶',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6488'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC/晶圓製造',
#   'number': '8086',
#   'name': '宏捷科',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=8086'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC/晶圓製造',
#   'number': '4991',
#   'name': '環宇-KY',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=4991'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': 'IC/晶圓製造',
#   'number': '',
# ...
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '6667',
#   'name': '信紘科',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6667'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '6683',
#   'name': '雍智科技',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6683'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '6735',
#   'name': '美達科技',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6735'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '6788',
#   'name': '華景電',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6788'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '6823',
#   'name': '濾能',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6823'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '6829',
#   'name': '千附精密',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6829'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '6877',
#   'name': '鏵友益',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6877'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '6895',
#   'name': '宏碩系統',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6895'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '6953',
#   'name': '家碩',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6953'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '7556',
#   'name': '意德士科技',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=7556'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '7704',
#   'name': '明遠精密',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=7704'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '7728',
#   'name': '光焱科技',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=7728'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '7751',
#   'name': '竑騰',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=7751'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '8027',
#   'name': '鈦昇',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=8027'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '8091',
#   'name': '翔名',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=8091'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '8383',
#   'name': '千附',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=8383'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '3485',
#   'name': '敘豐',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3485'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '3595',
#   'name': '山太士',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3595'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '4537',
#   'name': '旭東',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=4537'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '5246',
#   'name': '勵威',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=5246'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '5297',
#   'name': '廣化',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=5297'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '6725',
#   'name': '矽科宏晟',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6725'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '6812',
#   'name': '梭特',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6812'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '6983',
#   'name': '華洋精機',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6983'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '7530',
#   'name': '鋒魁科技',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=7530'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '7769',
#   'name': '鴻勁',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=7769'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '7772',
#   'name': '耀穎',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=7772'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '7795',
#   'name': '長廣',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=7795'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '7810',
#   'name': '捷創科技',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=7810'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '7813',
#   'name': '宇辰系統',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=7813'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '7822',
#   'name': '倍利科',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=7822'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '7828',
#   'name': '創新服務',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=7828'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '7846',
#   'name': '德揚',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=7846'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '7848',
#   'name': '騏億鑫',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=7848'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '7853',
#   'name': '政美應用',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=7853'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '7856',
#   'name': '漢測',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=7856'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '8098',
#   'name': '慶康科技',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=8098'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '7505',
#   'name': '立達軟體',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=7505'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '7514',
#   'name': '頂程國際',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=7514'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '7611',
#   'name': '京碼',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=7611'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '7677',
#   'name': '埃爾思',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=7677'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '',
#   'name': '安捷倫科技',
#   'url': 'http://www.agilent.com/'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '',
#   'name': '應用材料',
#   'url': 'http://www.appliedmaterials.com/zh-hant/company/about'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '',
#   'name': '艾司摩爾',
#   'url': 'http://www.asml.com/asml/show.do?ctx=427'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '',
#   'name': 'Canon',
#   'url': 'http://www.canon.com/'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '',
#   'name': '科磊',
#   'url': 'http://www.kla-tencor.com/'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '',
#   'name': '科林研發',
#   'url': 'http://www.lamresearch.com/'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '',
#   'name': '尼康株式會社',
#   'url': 'http://www.nikon.com/'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '',
#   'name': '奧寶科技',
#   'url': 'http://www.orbotech.com/'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '',
#   'name': '東京電力',
#   'url': 'http://www.tepco.co.jp/index-j.html'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '',
#   'name': '優貝克集團',
#   'url': 'https://www.ulvac.co.jp/'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '化學品',
#   'number': '1711',
#   'name': '永光',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=1711'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '化學品',
#   'number': '1717',
#   'name': '長興',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=1717'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '化學品',
#   'number': '1727',
#   'name': '中華化',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=1727'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '化學品',
#   'number': '2493',
#   'name': '揚博',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=2493'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '化學品',
#   'number': '3010',
#   'name': '華立',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3010'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '化學品',
#   'number': '3305',
#   'name': '昇貿',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3305'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '化學品',
#   'number': '4720',
#   'name': '德淵',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=4720'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '化學品',
#   'number': '4722',
#   'name': '國精化',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=4722'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '化學品',
#   'number': '4755',
#   'name': '三福化',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=4755'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '化學品',
#   'number': '4764',
#   'name': '雙鍵',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=4764'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '化學品',
#   'number': '5234',
#   'name': '達興材料',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=5234'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '化學品',
#   'number': '5434',
#   'name': '崇越',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=5434'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '化學品',
#   'number': '1742',
#   'name': '台蠟',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=1742'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '化學品',
#   'number': '1785',
#   'name': '光洋科',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=1785'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '化學品',
#   'number': '3663',
#   'name': '鑫科',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=3663'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '化學品',
#   'number': '4749',
#   'name': '新應材',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=4749'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '化學品',
#   'number': '4768',
#   'name': '晶呈科技',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=4768'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '化學品',
#   'number': '4772',
#   'name': '台特化',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=4772'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '化學品',
#   'number': '6959',
#   'name': '兆捷科技',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6959'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '化學品',
#   'number': '6990',
#   'name': '華鉬',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=6990'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '化學品',
#   'number': '7763',
#   'name': '崇舜',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=7763'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '化學品',
#   'number': '7858',
#   'name': '芝普',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=7858'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '化學品',
#   'number': '7669',
#   'name': '碩正科技',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=7669'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '化學品',
#   'number': '',
#   'name': '液化空氣集團',
#   'url': 'http://www.airliquide.com/'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '化學品',
#   'number': '',
#   'name': '荷商嘉柏微電子材料',
#   'url': 'https://www.cmcmaterials.com/home/default.aspx'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '化學品',
#   'number': '',
#   'name': 'JSR株式會社',
#   'url': 'http://www.jsr.co.jp/'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '化學品',
#   'number': '',
#   'name': '林德集团',
#   'url': 'https://www.linde.com/'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '化學品',
#   'number': '',
#   'name': '普萊克斯',
#   'url': 'http://www.praxair.com/'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '化學品',
#   'number': '',
#   'name': 'Resonac',
#   'url': 'https://www.resonac.com/'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '化學品',
#   'number': '',
#   'name': '信越化學',
#   'url': 'https://www.shinetsu.co.jp/'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '化學品',
#   'number': '',
#   'name': '昭和電工材料',
#   'url': 'https://www.resonac.com/jp'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '化學品',
#   'number': '',
#   'name': '東京応化工業株式会社',
#   'url': 'http://www.tok.co.jp/'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '2308',
#   'name': '台達電',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=2308'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '2360',
#   'name': '致茂',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=2360'},
#  {'area': '中游',
#   'type': '半導體',
#   'subtype': '',
#   'item': '',
#   'title': '生產製程及檢測設備',
#   'number': '2467',
#   'name': '志聖',
#   'url': 'https://ic.tpex.org.tw//company_basic.php?stk_code=2467'},
#  ...]

# %%
outputdata=list({tuple(sorted(d.items())): d for d in detaildata}.values())
json_str = json.dumps(outputdata, ensure_ascii=False, indent=2)
print('✅ 產出結果 ↓')
print(len(outputdata))
# print(json_str)
# 這裡沒有 copy(json) 等功能，請自行複製輸出結果
with open('output.json', 'w', encoding='utf-8') as f:
    f.write(json_str)
# Out:
# ✅ 產出結果 ↓
# 8335
