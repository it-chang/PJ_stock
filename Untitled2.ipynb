# %%
import os
from os.path import join, getmtime
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
today = datetime.today()
weekday = today.weekday()  # 0 = Monday, 6 = Sunday

# 轉換成中文星期
week_map = ['星期一', '星期二', '星期三', '星期四', '星期五', '星期六', '星期日']
print("今天是：", week_map[weekday])
# Out:
# 今天是： 星期五

# %%
diffdays=1
    
if weekday==5:   
    diffdays=1
if weekday==6:
    diffdays=2

today=(datetime.now()-timedelta(days=diffdays)).date()
adate=(datetime.now()-timedelta(days=diffdays)).strftime("%Y-%m-%d")
    
print(today)
print(adate)
# Out:
# 2025-06-12
# 2025-06-12

# %% [markdown]
# today = datetime.today().date()
# adate=datetime.now().strftime('%Y-%m-%d')

# %% [markdown]
# today=(datetime.now()-timedelta(days=2)).date()
# adate=(datetime.now()).strftime("%Y-%m-%d")
# #adate=today.strftime("%Y-%m-%d")
# adate='2025-05-09'

# %%
print(today)
print(adate)
# Out:
# 2025-06-12
# 2025-06-12

# %%
start_month = '2023-01-01'
start_date = datetime.strptime(start_month, "%Y-%m-%d").date()
dateList = []
current_date = start_date
while current_date <= today:
    dateList.append(f"{current_date.year}-{current_date.month:02d}-{current_date.day:02d}")
    current_date += timedelta(days=1)
    
dateList=dateList[-15:]
print('Base 資料',dateList)
print('============================')
print('join 新資料日',adate)
# Out:
# Base 資料 ['2025-05-29', '2025-05-30', '2025-05-31', '2025-06-01', '2025-06-02', '2025-06-03', '2025-06-04', '2025-06-05', '2025-06-06', '2025-06-07', '2025-06-08', '2025-06-09', '2025-06-10', '2025-06-11', '2025-06-12']
# ...
# join 新資料日 2025-06-12

# %%
new_DailyResult_path_List=[]
new_RunRealTimeStock_path_List = [f'D:\\Project\\Jupyter\\Stock\\Main\\Result\\DailyRunRealTimeStock\\{adate}.xlsx']
new_DailyResult_path_List = [ f"D:\Project\Jupyter\Stock\Main\Result\DailyFiles\\{date}.xlsx" for date in dateList] 

new_RunRealTimeStock_path_List = [f'\\\\auohqeshtt02\\d$\\Production\\CMMM\\Result\\DailyRunRealTimeStock\\{adate}.xlsx']
new_DailyResult_path_List = [ f"\\\\auohqeshtt02\\d$\\Production\\CMMM\\Result\\DailyFiles\\{date}.xlsx" for date in dateList] 

data=StockBaseData=pd.read_csv('BaseInfo/StockBaseData.csv', converters={'公司代號': str})

_df =  pd.DataFrame()
for path in new_RunRealTimeStock_path_List:
    try:
        _df=pd.concat([pd.read_excel(path), _df])
    except:
        print('error----->'+path)
    
_df2 = pd.DataFrame()
for path in new_DailyResult_path_List:
    try:
        _df2=pd.concat([pd.read_excel(path), _df2])
    except:
        print('error----->'+path)
        
df=pd.merge( _df2,_df[pd.notna(_df['now_price'])], left_on='stock_number', right_on='stock_number', how='outer')

#print(_df2.dtypes)
#print(_df.dtypes)
# Out:
# error----->\\auohqeshtt02\d$\Production\CMMM\Result\DailyFiles\2025-05-30.xlsx
# error----->\\auohqeshtt02\d$\Production\CMMM\Result\DailyFiles\2025-05-31.xlsx
# error----->\\auohqeshtt02\d$\Production\CMMM\Result\DailyFiles\2025-06-01.xlsx
# error----->\\auohqeshtt02\d$\Production\CMMM\Result\DailyFiles\2025-06-07.xlsx
# error----->\\auohqeshtt02\d$\Production\CMMM\Result\DailyFiles\2025-06-08.xlsx

# %%
def  GetStockInfoByID(StocKID,strtype):
    try :
        result=data[data['公司代號']==StocKID]
        if strtype=='name':
            return result.iloc[0]['公司簡稱']
        if strtype=='category':
            if result.iloc[0]['Type']=="上櫃" :
                return result.iloc[0]['上櫃公司產業類別']
            else:
                return result.iloc[0]['上市公司產業類別']
        if strtype=='type':
            return result.iloc[0]['Type']
    except :
        print(StocKID)

# %%
def stock_recommend(row):
    _str='--'
    _quote=float( row['_quote'])
    _level=float( row['level'])

    if int(row['遠交易量'])>0 and _quote > -2:   
        _str+='遠期量推'
    if row['短增'] and int(row['短交易量'])>0 and int(row['遠交易量'])>0 and _quote > -1:   
        _str+='近期量推'
        if int(row['成交股數'])>50000:
            _str+='量大'
   
        
    if row['interval_type']=='負區間':
        if  _level >= 40:
            _str+='探底'
            if row['Signal_Balance_uptrend_3days'] and  row['Signal_Balance_uptrend']  :
                _str+='有撐'  
            else:
                _str='--'
    if row['短增'] and int(row['短交易量'])>0 and int(row['遠交易量'])>0 and _quote > 4:
        _str+='ShowTime'
    return _str
def stock_recommend2(row):
    _str='--'
    _quote=float( row['_quote'])
    _level=float( row['level'])
    if len(row['recommend'] )>0:
        
        if row['interval_type']=='正區間':
            if  _level >= 90:
                _str+='追高' 

        if row['interval_type']=='負區間':
            if  _level >= 40:
                _str+='探底'       

            if row['Signal_Balance_uptrend_3days'] and  row['Signal_Balance_uptrend']  :
                _str+='有撐'  
            
    return _str

def stock_LevelArea(row):
    _level=float( row['level'])

    if row['interval_type']=='正區間': 
        _level=_level*1

    if row['interval_type']=='負區間':
        _level=_level*-1
            
    return _level

def  stock_quote(row):
      return str(format(float(row['漲跌價差'])/float(row['開盤價'])*100, '.2f'))    

def  diff_quote(row):
    try :
        if float(row['收盤價_y'])!=0:
            return format((  float(row['收盤價_y']) - float(row['now_price']) ) /float(row['收盤價_y'])*100, '.2f')

    except FileNotFoundError:
        print(row['_quote'])

def trading_volume(row):
    data=row['成交股數']
    try :
         if row['Type2']=='上市': 
                data=data/1000
    except FileNotFoundError:
          print(data)
        
    return data

# %%
df.columns.values
# Out:
# array(['日期_x', '成交股數', '成交金額', '開盤價', '最高價', '最低價', '收盤價', '漲跌價差', '成交筆數',
#        '年月日', 'EMA_12', 'EMA_26', 'MACD', 'MACD-SL', 'DIF',
#        'MACD_golden_cross', 'Lowest_Low', 'Highest_High', '%K', '%D',
#        'KD_golden_cross', 'Volume_MA_short', 'Volume_MA_long',
#        'Volume_Oscillator', 'MA_short', 'MA_long', 'MA_longlong',
#        'MA_break', 'MA_short_volatility', 'MA_long_volatility',
#        'Is_Entangled', 'MA_short_change', 'MA_long_change',
#        'Bollinger_MA', 'Bollinger_STD', 'Bollinger_upper',
#        'Bollinger_lower', 'Bollinger_breakout', 'RSI', 'RSI_rebound',
#        'Price_Change', 'Volume_Price_Change', 'Volume_Price_Change_sum',
#        'Volume_Price_Change_sum_12', 'Volume_Price_Change_break',
#        'Volume_Change', 'Volume_Change_sum', 'Bar_Color',
#        'Close_above_MA', 'Close_above_MA_5days', 'Analysis',
#        'Signal_Balance', 'Signal_Balance_roll',
#        'Signal_Balance_roll_diff', 'Signal_Balance_uptrend',
# ...

# %%
# Rename columns in one go to avoid repeating `df.rename()`
rename_dict = {
    '日期_x': '日期',
    'now_price_x': 'now_price',
    'change_price_x': 'change_price',
    'change_quote_x': 'change_quote'
}
df.rename(columns=rename_dict, inplace=True)

# Convert date columns
date_columns = ['日期', 'highlight_date', 'highlight_enddate']
for col in date_columns:
    df[col] = pd.to_datetime(df[col], errors='coerce')  # 先轉換成 datetime，無法轉換的設為 NaT
    df[col] = df[col].dt.strftime('%Y-%m-%d')

# Apply stock information based on 'stock_number' and add new columns
stock_columns = ['Type0', 'Type1', 'Type2']
stock_info_types = ['name', 'category', 'type']
for i, col in enumerate(stock_columns):
    df[col] = df.apply(lambda x: f"{GetStockInfoByID(str(x['stock_number']), stock_info_types[i])}", axis=1)

df['Type'] = df['Type0'] + '-' + df['Type1'] + '-' + df['Type2']

# %%
df['MA5_%']=(df['收盤價']-df['MA_short'])/ abs(df['MA_short'])
df['均價_%']=(df['MA_short']-df['MA_long'])/ abs(df['MA_long'])
df['均價long_%']=(df['MA_long']-df['MA_longlong'])/ abs(df['MA_longlong'])
df['MACD_%']=(df['MACD']-df['MACD-SL'])/ abs(df['MACD-SL'])
            

df['MA5_%'] =( 100*df['MA5_%']).astype(float).apply(lambda x: f"{x:.2f}").astype(str)
df['均價_%'] = (100*df['均價_%']).astype(float).apply(lambda x: f"{x:.2f}").astype(str)
df['均價long_%'] = (100*df['均價long_%']).astype(float).apply(lambda x: f"{x:.2f}").astype(str)
df['MACD_%'] = (100*df['MACD_%']).astype(float).apply(lambda x: f"{x:.2f}").astype(str)

#處理數值 NA ,浮點與轉str
df['change_quote'] = df['change_quote'].astype(str).str.replace("+", "", regex=False).str.replace("%", "", regex=False)
df['change_quote'] = pd.to_numeric(df['change_quote'], errors='coerce').fillna('0.00').astype(str)
df['MACD'] = df['MACD'] .astype(float).apply(lambda x: f"{x:.2f}").astype(str)
df['MACD-SL'] = df['MACD-SL'].astype(float).apply(lambda x: f"{x:.2f}").astype(str)
df['now_price'] = pd.to_numeric(df['now_price'], errors='coerce').fillna('0.00').astype(str)
df['收盤價'] = pd.to_numeric(df['收盤價'], errors='coerce').fillna('0.00').astype(str)
df['Signal_Balance_roll'] = pd.to_numeric(df['Signal_Balance_roll'], errors='coerce').fillna(0)
df['MA_break'] = df['MA_break'].fillna(False)
df['MACD_golden_cross'] = df['MACD_golden_cross'].fillna(False)
df['stock_number'] = df['stock_number'].astype(str)
df['Trend'] = df['Trend'].fillna("--").astype(str).replace("0", "-")
df['Signal_Balance_uptrend_3days'] = df['Signal_Balance_uptrend_3days'].astype(str)

df['Signal_Balance_roll'] = (df['Signal_Balance_roll'] * 10).astype(str)
df['Volume_Oscillator'] = df['Volume_Oscillator'].fillna('0').astype(int).astype(str)
df['level'] = (df['level'] * 100).astype(str)
df['now_price'] = df['now_price'].astype(str)



df['短交易量'] = pd.to_numeric(df['短交易量'], errors='coerce').fillna('0.00').astype(float).apply(lambda x: f"{x:.2f}").astype(float)
df['遠交易量'] = pd.to_numeric(df['遠交易量'], errors='coerce').fillna('0.00').astype(float).apply(lambda x: f"{x:.2f}").astype(float)

df['短增'] = df['短交易量'] > df['遠交易量']
df['漲跌價差'] = pd.to_numeric(df['漲跌價差'], errors='coerce').fillna(0)
df['量增與漲幅倍率'] = (df['漲跌價差'] / df['開盤價']) * 100 / df['短交易量']
df['量增'] = (df['短交易量'] > df['遠交易量']) & (df['短交易量'] > 0) & (df['遠交易量'] > 0) & (df['量增與漲幅倍率'] > 0)

df['Volume_Price_Change_sum'] = df['Volume_Price_Change_sum'].fillna('0').astype(float).apply(lambda x: f"{x:.2f}").astype(float)
df['Volume_Price_Change_sum_12'] = df['Volume_Price_Change_sum_12'].fillna('0').astype(float).apply(lambda x: f"{x:.2f}").astype(float)
df['Volume_%'] = (df['Volume_Price_Change_sum'] - df['Volume_Price_Change_sum_12']) / abs(df['Volume_Price_Change_sum_12'])
df['Volume_%'] = df['Volume_%'].round(2)

# Apply custom functions for additional calculations
df['_quote'] = df.apply(stock_quote, axis=1)
df['recommend'] = df.apply(stock_recommend, axis=1)
df['recommend2'] = df.apply(stock_recommend2, axis=1)
df['LevelArea'] = df.apply(stock_LevelArea, axis=1)
df['成交股數'] = df.apply(trading_volume, axis=1)


# Handle 'Typelevel' logic more efficiently
df['Typelevel'] = df.apply(lambda x: f"{x['Type1']}右上" if x['LevelArea'] >= 50 else (
    f"{x['Type1']}平" if -40 <= x['LevelArea'] < 50 else f"{x['Type1']}右下"), axis=1)

# Replace all '-' values with 0
df.replace('-', 0, inplace=True)

# %%
aa=df
aa['Volume_Price_Change_sum'] = pd.to_numeric(aa['Volume_Price_Change_sum'], errors='coerce')


aa['遠交易量'] = pd.to_numeric(aa['遠交易量'], errors='coerce')
aa['短交易量'] = pd.to_numeric(aa['短交易量'], errors='coerce')
aa['_quote'] = pd.to_numeric(aa['_quote'], errors='coerce')
aa['Highest_High'] = pd.to_numeric(aa['Highest_High'], errors='coerce')
aa['now_price'] = pd.to_numeric(aa['now_price'], errors='coerce')
aa['收盤價'] = pd.to_numeric(aa['收盤價'], errors='coerce')
aa['過壓力區']= aa['收盤價']/aa['Lowest_Low'] 

aa['收盤價'] =pd.to_numeric(aa['收盤價'], errors='coerce').apply(lambda x: f"{x:.2f}" if pd.notna(x) else "0").astype(float)
aa['最低價'] =pd.to_numeric(aa['最低價'], errors='coerce').apply(lambda x: f"{x:.2f}" if pd.notna(x) else "0").astype(float)
aa['最高價'] =pd.to_numeric(aa['最高價'], errors='coerce').apply(lambda x: f"{x:.2f}" if pd.notna(x) else "0").astype(float)

aa['短增量'] =pd.to_numeric(aa['短增量'], errors='coerce').apply(lambda x: f"{x:.2f}" if pd.notna(x) else "0").astype(float)
aa['短增量_'] =pd.to_numeric(aa['短增量_'], errors='coerce').apply(lambda x: f"{x:.2f}" if pd.notna(x) else "0").astype(float)

# %%
## 取得其他資訊
stock_info = pd.read_excel('Result/StockInfo.xlsx', engine='openpyxl')
stock_type = pd.read_excel('Result/StockType.xlsx', engine='openpyxl')

stock_info=pd.merge(left=stock_info, right=stock_type, on="stock_number",how='left')

# 确保两个 DataFrame 的 `stock_number` 列为字符串类型
aa['stock_number'] = aa['stock_number'].astype(str)

stock_info['stock_number'] = stock_info['stock_number'].astype(str)
stock_info['desc'] = stock_info['desc'].fillna("-")
stock_info['成交量'] = (stock_info['成交量'] .str.replace(",", ""))
stock_info['殖利率']=stock_info['殖利率'].str.replace("%", "")
stock_info['總市值'] = (stock_info['總市值'] .str.replace(",", ""))
stock_info['一年內最大量'] = (stock_info['一年內最大量'] .str.replace(",", ""))
stock_info['一年內最低量'] = (stock_info['一年內最低量'] .str.replace(",", ""))

stock_info['營業毛利率']=stock_info['營業毛利率'].replace("%", "")
stock_info['營業利益率']=stock_info['營業利益率'].replace("%", "")


# 合并两个 DataFrame
aa = pd.merge(left=aa, right=stock_info, on="stock_number",how='left')

aa['營收比重'] = aa['營收比重'].fillna("-")
aa['量能'] = aa['成交股數'].astype(float)/ aa['一年內最大量'].fillna(0).astype(int) 
aa['量能'] = (aa['量能'] *100) .apply(lambda x: f"{x:.2f}").astype(str)

aa['now_price']=aa['now_price'].replace(",", "").astype(float)

aa['每股淨值(元)'] = aa['每股淨值(元)'].str.strip()  # 去掉前後空白
aa['每股淨值(元)'] = aa['每股淨值(元)'].str.replace(",", "", regex=True).astype(float)
aa['淨值倍率']=(aa['now_price']/aa['每股淨值(元)']).astype(float).apply(lambda x: f"{x:.2f}")
aa['diff_quote'] = aa.apply(diff_quote, axis=1)


aa['_quote'] = pd.to_numeric(aa['_quote'], errors='coerce')
aa['短交易量'] = pd.to_numeric(aa['短交易量'], errors='coerce')
aa['本益比'] = pd.to_numeric(aa['本益比'], errors='coerce')
aa['diff_quote'] = pd.to_numeric(aa['diff_quote'], errors='coerce')

aa['成交量']=aa['成交量'].fillna('0').astype(int).astype(str)


rename_dict = {
    '收盤價_x': '收盤價',
    '最低價_x': '最低價',
    '最高價_x': '最高價',
    '開盤價_x': '開盤價'
}
aa.rename(columns=rename_dict, inplace=True)

#偏多程度 - 偏空程度
#正數 → 偏多（收盤價偏向高點）
#負數 → 偏空（收盤價偏向低點）
#接近 0 → 收盤在高低之間，盤整或不明顯

aa['價能'] =((aa['收盤價']-aa['最低價'])/aa['最低價'])-((aa['最高價']-aa['收盤價'])/aa['收盤價']) 
aa['價能'] = (aa['價能']*100 ) .apply(lambda x: f"{x:.2f}").astype(str)

aa['rt_price']  =''
aa['rt_量']=''

# %% [markdown]
# ### COL
#
# aa.columns.values

# %%
bb=aa[ 
    (aa['stock_number']!='')
    & (aa['MA5_%']>=str(0) )
    & (aa['成交量'].astype(int) > 500) 
    & (aa['短增量_']!=str(0.0) )
    & (aa['遠交易量']>-15 )
    & (aa['短交易量']>-15 )
    ].drop_duplicates()
bb['flag'] = 'N' 
aa['flag'] = 'N'  # 先設置所有行為 'N'
aa.loc[bb.index, 'flag'] = 'Y'  # 符合條件的行標記 'Y'
bb.loc[bb.index, 'flag'] = 'Y'
len(list(set(bb['stock_number'])))
# Out:
# C:\Users\itchang\AppData\Local\Temp\ipykernel_20380\1285675196.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   aa['flag'] = 'N'  # 先設置所有行為 'N'
# 575

# %%
targetday=today.strftime('%Y-%m-%d')
print(targetday)
#--------------------------------------------------------
# Out:
# 2025-06-12

# %% [markdown]
# # 【分析確認用】
# col_n='成交筆數'
# aa[col_n] = aa[col_n].replace([np.inf, -np.inf], np.nan)
# aa[col_n] = aa[col_n].astype(float).round()
# aa[col_n] =( aa[col_n]/10).fillna(0).astype(int)
#
#
# targetday='2025-06-11'
# #(aa['日期']==targetday) &
# xx=aa#[((aa['flag'] == 'Y') ) ]
#
# #,'highlight','Volume_Price_Change_break' ,'遠交易量' 'flag'
# count_quote_df = xx[xx['diff_quote'] > 6 ].groupby(['成交筆數'])['stock_number'].count().reset_index(name='count_quote_gt_6')
# count_quote_df.to_excel('checkcheck.xlsx', index=False)
# # 合併三個結果
# #merged_df = sum_df.merge(count_all_df, on=['日期', 'Typelevel'], how='left') \
# #                  .merge(count_quote_df, on=['日期', 'Typelevel'], how='left')
# print(count_quote_df)

# %% [markdown]
# ### Distinct Type
# sorted(bb['Type1'].astype(str).unique())

# %%
output_col=['日期','stock_number','_quote' ,#'change_quote',
            
            '成交股數','rt_量', '量能',  '短增量',
            'now_price', 'rt_price','diff_quote',
            
            '盤後量','成交量','價能', 
            
            'MA5_%','均價_%','均價long_%' ,'MACD_%', 'MACD','MACD-SL',
            
            '短交易量','遠交易量','MA_break','MACD_golden_cross',#'LevelArea',
            
            'highlight_date','highlight_enddate',
            
            'Volume_Oscillator','Volume_Price_Change_sum',  'Volume_Price_Change_sum_12', 'Volume_Price_Change_break','Volume_%',
            
            'Type0', 'Type1', 'Type2',
            '淨值倍率','殖利率','每股營收(元)','本益比','營業毛利率','營業利益率',
            '同業平均本益比','總市值','營收比重','Type','Typelevel',
            
            '每股淨值(元)','flag', 'desc'
           ]
#--------------------------------------------------------
bb[output_col] = bb[output_col].fillna("0")
bb[output_col] = bb[output_col].astype(str)
bb[output_col] = bb[output_col].replace(["NaN","nan","None", ""], "0")

########################################################################################################
###【太陽圖】當日 表現好  -----------------------------------------------------------------------------------
#----------------------------------------------------------------------------------------------------------
to_excel='Result/checksun.xlsx' 
datalist=aa[ (aa['日期']==targetday) &  (aa['flag'] == 'Y' )]['stock_number'].drop_duplicates().tolist()
maskfilter=(aa['stock_number'].isin(datalist))
aa[output_col][maskfilter].drop_duplicates().sort_values(by=['stock_number','日期',], ascending=False).to_excel(to_excel, index=False)

###【太陽圖】當日 highlight -------------------------------------------------------------------------------------
#---------------------------------------------------------------------------------------------------------------
to_excel='Result/checkH.xlsx' 
datalist=aa[(aa['日期']==targetday) & (aa['highlight'] == True) ]['stock_number'].drop_duplicates().tolist()
maskfilter=(aa['stock_number'].isin(datalist))
aa[output_col][maskfilter].drop_duplicates().sort_values(by=['stock_number','日期',], ascending=False).to_excel(to_excel, index=False)

###【太陽圖】當日 Volume_Price_Change_break ---------------------------------------------------------------------
#---------------------------------------------------------------------------------------------------------------
to_excel='Result/checkVolume.xlsx' 
datalist=aa[(aa['日期']==targetday) & (aa['Volume_Price_Change_break'] == True) ]['stock_number'].drop_duplicates().tolist()
maskfilter=(aa['stock_number'].isin(datalist))
aa[output_col][maskfilter].drop_duplicates().sort_values(by=['stock_number','日期',], ascending=False).to_excel(to_excel, index=False)

###【太陽圖】當日 表現好 + highlight -----------------------------------------------------------------------------
#---------------------------------------------------------------------------------------------------------------
to_excel='Result/checkHS.xlsx' 
#datalist=aa[  (aa['highlight_enddate']>=targetday)  ]['stock_number'].drop_duplicates().tolist()
datalist=aa[ (aa['日期']==targetday) & (aa['flag'] == 'Y' ) &(aa['highlight'] == True) ]['stock_number'].drop_duplicates().tolist()
maskfilter=(aa['stock_number'].isin(datalist))
aa[output_col][maskfilter].drop_duplicates().sort_values(by=['stock_number','日期',], ascending=False).to_excel(to_excel, index=False)







###########################################################################################################
#【太陽圖】自定 持有 --------------------------------------------------------------------------------------
#-----------------------------------------------------------------------------------------------
to_excel='Result/checksunmy.xlsx' 
datalist=[ '1101', '1599','2062', '2301', '2349', '2376', '2542','3066','4966','6789']
maskfilter=(aa['stock_number'].isin(datalist))
aa[output_col][maskfilter].drop_duplicates().sort_values(by=['stock_number','日期',], ascending=False).to_excel(to_excel, index=False)

#【】自定 (By 簡稱)--------------------------------------------------------------------------------------
#-----------------------------------------------------------------------------------------------
#to_excel1='Result/checksundangchong.xlsx'   
#myList=['陽明','長榮','華經','華星光']
#maskfilter=(aa['Type0'].isin(myList))
#aa[output_col][maskfilter].drop_duplicates().sort_values(by=['stock_number','日期',], ascending=False).to_excel(to_excel1, index=False)

###########################################################################################################
########################################################################################################

###【太陽圖】分類別 BY日  -----------------------------------------------------------------------------------
#----------------------------------------------------------------------------------------------------------
for Type1 in sorted(bb['Type1'].astype(str).unique()): 
    to_excel1='Result/checksun/'+Type1+'.xlsx'
    datalist=aa[ (aa['Type1']==Type1)]['stock_number'].drop_duplicates().tolist()
    maskfilter=(aa['stock_number'].isin(datalist))# & (aa['highlight']==True) 
    aa[output_col][maskfilter].drop_duplicates().sort_values(by=['stock_number','日期',], ascending=False).to_excel(to_excel1, index=False)

###【RowData】表現好 BY日 --------------------------------------------------------------------------------
#-----------------------------------------------------------------------------------------------
for _date in dateList: 
    maskfilter=(aa['日期']==_date) 
    to_excel1='Result/check1/'+_date+'.xlsx'
    bb[output_col][maskfilter].drop_duplicates().sort_values(by=['stock_number','日期',], ascending=False).to_excel(to_excel1, index=False)

##############################################################################################
##############################################################################################
cc=aa.copy()
cc[output_col] = cc[output_col].astype(str)
cc[output_col] = cc[output_col].replace(["NaN","nan","None", ""], "0")

###【RowData】所有股票 當日 --------------------------------------------------------------------------------
#-----------------------------------------------------------------------------------------------
to_excel='Result/checkall.xlsx' 
maskfilter=(aa['日期']==targetday)
cc[output_col][maskfilter].drop_duplicates().sort_values(by=['stock_number','日期',], ascending=False).to_excel(to_excel, index=False)

###【RowData】所有股票 BY日 --------------------------------------------------------------------------------
#-----------------------------------------------------------------------------------------------
for _date in dateList: 
    maskfilter=(aa['日期']==_date) 
    to_excel1='Result/checkall/'+_date+'.xlsx'
    cc[output_col][ maskfilter].drop_duplicates().sort_values(by=['stock_number','日期',], ascending=False).to_excel(to_excel1, index=False) 
    
###【RowData】自定 持有---------------------------------------------------------------------------------------
#-----------------------------------------------------------------------------------------------    
to_excel1='Result/checkmy.xlsx'   
myList=[ '1101', '1599','2062', '2301', '2349', '2376', '2542','3066','4966','6789']
maskfilter= (aa['日期']==targetday) & (aa['stock_number'].isin(myList))
cc[output_col][maskfilter].drop_duplicates().sort_values(by=['stock_number','日期',], ascending=False).to_excel(to_excel1, index=False)

###【RowData】自定 -----------------------------------------------------------------------------------
#-----------------------------------------------------------------------------------------------   
#to_excel1='Result/checkdangchong.xlsx'   
#myList=['陽明','長榮','華經','華星光']
#maskfilter= (aa['日期']==targetday) & (aa['Type0'].isin(myList))
#cc[output_col][maskfilter].drop_duplicates().sort_values(by=['stock_number','日期',], ascending=False).to_excel(to_excel1, index=False)

###【RowData】當日 highlight ------------------------------------------------------------------------------------------
#-----------------------------------------------------------------------------------------------
to_excel1='Result/check4.xlsx'   
maskfilter= (aa['日期']==targetday) & (aa['highlight'] == True)
cc[output_col][maskfilter].drop_duplicates().sort_values(by=['stock_number','日期',], ascending=False).to_excel(to_excel1, index=False)

##################################################################################################################
##################################################################################################################
###【RowData】指定日-關注--------------------------------------------------------------------------------------
#-----------------------------------------------------------------------------------------------
dd=cc.copy()
dd['波動幅度'] = abs(dd['change_quote'].astype(float) / dd['now_price'].astype(float) * 100)

for _date in dateList: 
    day_trade_stocks = dd[   
    (dd['日期']==_date)
    & (dd['成交量'].astype(int) > 500) 
    &  (dd['highlight_enddate']>=targetday) 
    & (dd['短增量_']!=str(0.0) )
    & (aa['遠交易量']>-15 )
    & (aa['短交易量']>-15 )
    ]
    myList=sorted(day_trade_stocks['stock_number'].astype(str).unique())
    maskfilter= (aa['日期']==_date) & (aa['stock_number'].isin(myList))
    to_excel1='Result/check3/'+_date+'.xlsx'
    cc[output_col][ maskfilter].drop_duplicates().sort_values(by=['stock_number','日期',], ascending=False).to_excel( to_excel1, index=False) 

#-----------------------------------------------------------------------------------------------
#print("http://localhost/IT/menu.html")
# Out:
# C:\Users\itchang\AppData\Local\Temp\ipykernel_20380\3401044927.py:94: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   bb[output_col][maskfilter].drop_duplicates().sort_values(by=['stock_number','日期',], ascending=False).to_excel(to_excel1, index=False)
# C:\Users\itchang\AppData\Local\Temp\ipykernel_20380\3401044927.py:94: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   bb[output_col][maskfilter].drop_duplicates().sort_values(by=['stock_number','日期',], ascending=False).to_excel(to_excel1, index=False)
# C:\Users\itchang\AppData\Local\Temp\ipykernel_20380\3401044927.py:94: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   bb[output_col][maskfilter].drop_duplicates().sort_values(by=['stock_number','日期',], ascending=False).to_excel(to_excel1, index=False)
# ...

# %% [markdown]
# analyze_ = aa.copy()
# analyze_['Volume_Price_Change_sum'] = analyze_['Volume_Price_Change_sum'].fillna('0').astype(float)
# analyze_.groupby(['日期', 'Typelevel'])['Volume_Price_Change_sum'].sum().reset_index()
# analyze_.groupby(['日期', 'Typelevel'])['stock_number'].count().reset_index(name='count')
# analyze_[analyze_['_quote'] > 6] .groupby(['日期', 'Typelevel'])['stock_number'].count() .reset_index(name='count')

# %%
#【分析表】

analyze_ = aa.copy() 

# 1. Volume_Price_Change_sum 總和
sum_df = analyze_.groupby(['日期', 'Typelevel'])['Volume_Price_Change_sum'].sum().reset_index()

# 2. 全部 stock_number 計數
count_all_df = analyze_.groupby(['日期', 'Typelevel'])['stock_number'].count().reset_index(name='count_total')

# 3. _quote > 6 條件下的 stock_number 計數
count_quote_df = analyze_[analyze_['_quote'] > 6].groupby(['日期', 'Typelevel'])['stock_number'].count().reset_index(name='count_quote_gt_6')

# 合併三個結果
merged_df = sum_df.merge(count_all_df, on=['日期', 'Typelevel'], how='left') \
                  .merge(count_quote_df, on=['日期', 'Typelevel'], how='left')

# 若 count_quote_gt_6 有缺值，補 0
merged_df['count_quote_gt_6'] = merged_df['count_quote_gt_6'].fillna(0).astype(int)

# 若 count_quote_gt_6 有缺值，補 0
merged_df['count_total'] = merged_df['count_total'].fillna(0).astype(int)

merged_df['quote_ratio_str'] = merged_df['count_quote_gt_6'].astype(str) + '　/　' + merged_df['count_total'].astype(str)

#ivot_df = 
#merged_df[merged_df['Typelevel']=='通信網路業右上']
merged_df.pivot(index='Typelevel', columns='日期',values='count_total').to_excel( 'Result/analyze.xlsx') 
merged_df.pivot(index='Typelevel', columns='日期',values='count_quote_gt_6').to_excel( 'Result/analyze_1.xlsx') 
merged_df.pivot(index='Typelevel', columns='日期',values='Volume_Price_Change_sum').to_excel( 'Result/analyze_2.xlsx')

# %%
#----------------------------------------------------------

# %% [markdown]
# datalist=[ '6240']#[ '3570']
# maskfilter=(aa['stock_number'].isin(datalist))
# aa[output_col][maskfilter].drop_duplicates().sort_values(by=['stock_number','日期',], ascending=False)

# %%
# JS CHECK DATA

# %% [markdown]
# function getMissingElements(array1, array2) {
#     return array1.filter(element => !array2.includes(element));
#
# }
# array1=app.jsonData.map(x=>x.stock_number)
# array2=app.filteredData.map(x=>x.stock_number)
# getMissingElements(array1, array2);

# %%
aa.head(1)
# Out:
#            日期      成交股數         成交金額   開盤價   最高價    最低價    收盤價  漲跌價差    成交筆數  \
# 0  2025-06-12  9954.901  269487242.0  27.3  27.3  26.95  27.05 -0.25  5334.0
#
#           年月日     EMA_12     EMA_26   MACD MACD-SL       DIF  \
# 0  2025-06-12  27.796167  28.672288  -0.88   -0.75 -0.124867
#
#    MACD_golden_cross  Lowest_Low  Highest_High         %K         %D  \
# 0              False       26.85          27.7  23.529412  17.843137
#
#   KD_golden_cross  Volume_MA_short  Volume_MA_long Volume_Oscillator  \
# 0           False      391515378.6    1.592315e+09               -75
#
#    MA_short  MA_long  MA_longlong  MA_break  MA_short_volatility  \
# 0     27.25  28.6575       29.656     False             0.827761
#
#    MA_long_volatility Is_Entangled  MA_short_change  MA_long_change  \
# 0            0.524282         True            -0.09          -0.165
#
#    Bollinger_MA  Bollinger_STD  Bollinger_upper  Bollinger_lower  \
# ...

# %%
# Out:
#    stock_number  短交易量  遠交易量
# 0          1101  10.0 -75.0
# 10         1240 -51.0 -28.0
# 20         1259 -12.0  11.0
# 30         1102 -20.0 -16.0
# 40         1264 -35.0  -6.0
# 50         1103  -8.0 -10.0
# 60         1268 -23.0   7.0
# 70         1104  21.0 -60.0
# 80         1294  -6.0 -48.0
# 90         1108   6.0 -25.0

# %%
xx=aa.copy()
# 【分析確認用】
col_n='均價_%'
xx[col_n] = xx[col_n].replace([np.inf, -np.inf], np.nan)
xx[col_n] = xx[col_n].astype(float).round()
xx[col_n] =( xx[col_n]).fillna(0).astype(int)

col_n='MA5_%'
xx[col_n] = xx[col_n].replace([np.inf, -np.inf], np.nan)
xx[col_n] = xx[col_n].astype(float).round()
xx[col_n] =( xx[col_n]).fillna(0).astype(int)

col_n='MACD_%'
xx[col_n] = xx[col_n].replace([np.inf, -np.inf], np.nan)
xx[col_n] = xx[col_n].astype(float).round()
xx[col_n] =( xx[col_n]).fillna(0).astype(int)

col_n='均價long_%'
xx[col_n] = xx[col_n].replace([np.inf, -np.inf], np.nan)
xx[col_n] = xx[col_n].astype(float).round()
xx[col_n] =( xx[col_n]).fillna(0).astype(int)

#xx=xx[((xx['stock_number'] == '1101') ) ]
sum_df = xx.groupby(['stock_number'])['stock_number'].count().reset_index(name='count_quote_gt_6')

count_MA_df = xx[xx['MA5_%'].fillna(0).astype(int) > 0 ].groupby(['stock_number'])['stock_number'].count().reset_index(name='MA_pi_bigger_0')
count_avg_df = xx[xx['均價_%'].fillna(0).astype(int) > 0 ].groupby(['stock_number'])['stock_number'].count().reset_index(name='均價_bigger_0')
count_avgLong_df = xx[xx['均價long_%'].fillna(0).astype(int) > 0 ].groupby(['stock_number'])['stock_number'].count().reset_index(name='均價Long_bigger_0')
count_MACD_df = xx[xx['MACD_%'].fillna(0).astype(int) > 0 ].groupby(['stock_number'])['stock_number'].count().reset_index(name='MACD_pi_bigger_0')

## MACD_%' 均價long_%

qq=xx[(xx['日期']==targetday)][['stock_number','短交易量','遠交易量','收盤價']]
qq1=xx[(xx['日期']==dateList[0])][['stock_number','收盤價']]

merged_df = sum_df.merge(count_MA_df, on=['stock_number'], how='left') \
                  .merge(count_avg_df, on=['stock_number'], how='left') \
                  .merge(count_avgLong_df, on=['stock_number'], how='left') \
                  .merge(count_MACD_df, on=['stock_number'], how='left') \
                  .merge(qq, on=['stock_number'], how='left') \
                  .merge(qq1, on=['stock_number'], how='left') 
                  
                  
merged_df['MA_pi_bigger_0'] =merged_df['MA_pi_bigger_0'].fillna(0)
merged_df['均價_bigger_0'] =merged_df['均價_bigger_0'].fillna(0)
merged_df['均價Long_bigger_0'] =merged_df['均價Long_bigger_0'].fillna(0)
merged_df['MACD_pi_bigger_0'] =merged_df['MACD_pi_bigger_0'].fillna(0)

merged_df['radoo']=(merged_df['MACD_pi_bigger_0']/merged_df['均價_bigger_0'].replace([np.inf, -np.inf], np.nan)).apply(lambda x: f"{x:.2f}").astype(str)
merged_df['price_radioo']=(1-(merged_df['收盤價_y']/merged_df['收盤價_x']))*100


n=len(dateList)/3
#merged_df=merged_df[(merged_df['MA_pi_smaller_0']< 7) & (merged_df['count_quote_gt_6']>5) ]
merged_df=merged_df[~(
                    #(merged_df['count_quote_gt_6']>n) &
                    #(merged_df['均價_bigger_0']> 3) &
                    #(merged_df['均價Long_bigger_0']>3) & (merged_df['均價Long_bigger_0']< 7) &
                    (merged_df['MACD_pi_bigger_0']>1) 
                    )]

merged_df.to_excel('checkcheck.xlsx', index=False)
print(merged_df)
# Out:
#      stock_number  count_quote_gt_6  MA_pi_bigger_0  均價_bigger_0  \
# 0            1101                10             1.0          0.0
# 2            1103                10             3.0          0.0
# 4            1108                10             0.0          1.0
# 5            1109                10             0.0          0.0
# 6            1110                10             3.0          3.0
# 7            1201                10             1.0          0.0
# 8            1203                10             3.0          0.0
# 9            1210                10             1.0          3.0
# 10           1213                10             4.0          0.0
# 11           1215                10             3.0          2.0
# 12           1216                 1             0.0          0.0
# 13           1217                10             0.0          0.0
# 14           1218                10             5.0          1.0
# ...
