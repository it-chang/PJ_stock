# %%
import pandas as pd
import numpy as np

# %%
to_excel='check.xlsx' 
file2_path = 'D:\\Project\\Jupyter\\Stock\\Main\\log\\DailyResult\\DailyResult_2024-08-29.xlsx' 
file1_path = 'D:\\Project\\Jupyter\\Stock\\Main\\log\\RunRealTimeStock\\2024-08-30DailyResultWeb.xlsx'   
data=StockBaseData=pd.read_csv('BaseInfo/StockBaseData.csv', converters={'公司代號': str})

# %%
_df = pd.read_excel(file1_path)
df= _df[pd.notna(_df['now_price'])]
_df2 = pd.read_excel(file2_path)
df=pd.merge(df, _df2, left_on='stock_number', right_on='stock_number', how='left')#.drop('stock_number', axis=1)

# %%
_data=df['日期'][0].replace("/", "_")

to_excel_= file_name = f"log/check/check_{_data}.xlsx"

# %% [markdown]
# print(_df2.dtypes)
# print(df.dtypes)
# df

# %%
def  GetStockInfoByID(StocKID,strtype):
    result=data[data['公司代號']==StocKID]
    if strtype=='name':
        return result.iloc[0]['公司簡稱']
    if strtype=='category':
        if result.iloc[0]['Type']=="上櫃" :
            return result.iloc[0]['上櫃公司產業類別']
        else:
            return result.iloc[0]['上市公司產業類別']
    if strtype=='type':
        return result.iloc[0]['Type']

# %%
def stock_recommend(row):

    _str=''
    _quote=float( row['_quote'])
    _level=float( row['level'])

    if int(row['遠交易量'])>0 and _quote > -2:   
        _str+='遠期量推'
    if row['短增'] and int(row['短交易量'])>0 and int(row['遠交易量'])>0 and _quote > -1:   
        _str+='近期量推'
        if int(row['成交股數'])>50000:
            _str+='量大'
   
        
    if row['interval_type']=='負區間':
        if  _level >= 40:
            _str+='探底'
            if row['Signal_Balance_uptrend_3days'] and  row['Signal_Balance_uptrend']  :
                _str+='有撐'  
            else:
                _str=''
    if row['短增'] and int(row['短交易量'])>0 and int(row['遠交易量'])>0 and _quote > 4:
        _str+='ShowTime'
    return _str
def stock_recommend2(row):
    _str=''
    _quote=float( row['_quote'])
    _level=float( row['level'])
    if len(row['recommend'] )>0:
        
        if row['interval_type']=='正區間':
            if  _level >= 90:
                _str+='追高' 

        if row['interval_type']=='負區間':
            if  _level >= 40:
                _str+='探底'       

            if row['Signal_Balance_uptrend_3days'] and  row['Signal_Balance_uptrend']  :
                _str+='有撐'  
            
    return _str

def stock_LevelArea(row):
    _level=float( row['level'])


    if row['interval_type']=='正區間': 
        _level=_level*1

    if row['interval_type']=='負區間':
        _level=_level*-1
            
    return _level


def  stock_quote(row):

      return str(format(float(row['漲跌價差'])/float(row['開盤價'])*100, '.2f')   )

# %%
df['Type0']  =df.apply(lambda x: f"{GetStockInfoByID(str(x['stock_number']),'name')}", axis=1)
df['Type1']  =df.apply(lambda x: f"{GetStockInfoByID(str(x['stock_number']),'category')}", axis=1)
df['Type2']  =df.apply(lambda x: f"{GetStockInfoByID(str(x['stock_number']),'type')}", axis=1)
df['Type']=df['Type0']+'-'+df['Type1']+'-'+df['Type2']

df['change_quote'] = (df['change_quote']
                   .str.replace("+", "", regex=False)
                   .str.replace("%", "", regex=False))

# 将无效的值转换为 NaN，并替换 NaN 值为 0
df['change_quote'] = pd.to_numeric(df['change_quote'], errors='coerce').fillna('0.00').astype(str)
df['change_price'] = pd.to_numeric(df['change_price'], errors='coerce').fillna('0.00').astype(str)
df['now_price'] = pd.to_numeric(df['now_price'], errors='coerce').fillna('0.00').astype(str)
df['收盤價'] = pd.to_numeric(df['收盤價'], errors='coerce').fillna('0.00').astype(str)
df['Signal_Balance_roll'] = pd.to_numeric(df['Signal_Balance_roll'], errors='coerce').fillna(0)
df['MA_break'] = df['MA_break'].fillna(False)

df['stock_number'] = df['stock_number'].astype(str)
df['Signal_Balance_uptrend_3days'] = df['Signal_Balance_uptrend_3days'].astype(str)
df['Weighted_Signa_over_threshold'] = df['Weighted_Signa_over_threshold'].astype(str)
df['Signal_Balance_roll'] =( df['Signal_Balance_roll']*10).astype(str)
df['Volume_Oscillator'] =( df['Volume_Oscillator']).fillna('0').astype(int)
df['Volume_Oscillator'] =( df['Volume_Oscillator']).astype(str)

df['level'] =( df['level']*100).astype(str)
df['now_price'] = df['now_price'].astype(str)
df.replace('-', 0, inplace=True)

# %%
df['短交易量']=(df['成交金額']-df['Volume_MA_short'])/df['Volume_MA_short']
df['遠交易量']=(df['Volume_MA_short']-df['Volume_MA_long'])/df['Volume_MA_long']
df['短增'] = df['短交易量']>df['遠交易量']
df['漲跌價差']=pd.to_numeric(df['漲跌價差'], errors='coerce').fillna(0)
df['量增與漲幅倍率']=(df['漲跌價差']/df['開盤價']) *100    /df['短交易量']
df['量增']=(df['短交易量']>   df['遠交易量'])& (df['短交易量']> 0) & (df['遠交易量']> 0)& (df['量增與漲幅倍率']> 0)

df['短交易量'] =( df['短交易量']*100).fillna('0').astype(int)
df['遠交易量'] =( df['遠交易量']*100).fillna('0').astype(int)
df['短遠交易比'] = (df['短交易量'] / df['遠交易量']).replace([np.inf, -np.inf], 0).fillna(0).astype(int)
df['短遠交易比'] = df['短遠交易比'].astype(str)
df['短交易量'] =df['短交易量'].astype(str)
df['遠交易量'] =df['遠交易量'].astype(str)

#df['量增與漲幅倍率'] =( df['量增與漲幅倍率']).fillna('0').astype(int)

df['Volume_Price_Change_sum'] =df['Volume_Price_Change_sum'].fillna('0').astype(str)

df['量增與漲幅倍率'] =df['量增與漲幅倍率'].fillna('0').astype(str)

df['_quote']  =df.apply(stock_quote, axis=1)
df['recommend']  =df.apply(stock_recommend, axis=1)
df['recommend2']  =df.apply(stock_recommend2, axis=1)
df['LevelArea']  =df.apply(stock_LevelArea, axis=1)

# %%
df.columns
# Out:
# Index(['stock_number', 'now_price', 'change_price', 'change_quote', '日期',
#        '成交股數', '成交金額', '開盤價', '最高價', '最低價', '收盤價', '漲跌價差', '成交筆數', 'Year',
#        'Date', 'Date_', '年月日', 'EMA_12', 'EMA_26', 'MACD', 'MACD-SL',
#        'Signal_Line', 'DIF', 'MACD_golden_cross', 'Lowest_Low', 'Highest_High',
#        '%K', '%D', 'KD_golden_cross', 'Volume_MA_short', 'Volume_MA_long',
#        'Volume_Oscillator', 'Volume_breakout', 'MA_short', 'MA_long',
#        'MA_break', 'MA_short_volatility', 'MA_long_volatility', 'Is_Entangled',
#        'MA_short_change', 'MA_long_change', 'Bollinger_MA', 'Bollinger_STD',
#        'Bollinger_upper', 'Bollinger_lower', 'Bollinger_breakout', 'RSI',
#        'RSI_rebound', 'Price_Change', 'Volume_Price_Change',
#        'Volume_Price_Change_sum', 'Bar_Color', 'Close_above_MA',
#        'Close_above_MA_5days', 'Analysis', 'Signal_Balance',
#        'Signal_Balance_roll', 'Signal_Balance_roll_diff',
#        'Signal_Balance_uptrend', 'Signal_Balance_uptrend_3days', 'Trend',
#        'Weighted_Signal', 'Weighted_Signa_over_threshold',
#        'Weighted_Signal_roll', 'Weighted_Signal_roll_',
#        'Weighted_Signal_golden_cross', 'level', 'interval_type', 'lower_bound',
#        'upper_bound', 'Type0', 'Type1', 'Type2', 'Type', '短交易量', '遠交易量', '短增',
#        '量增與漲幅倍率', '量增', '短遠交易比', '_quote', 'recommend', 'recommend2',
#        'LevelArea'],
#       dtype='object')

# %% [markdown]
# pd.set_option('display.max_columns', None)
# df.head(5)

# %%
aa=df

# %% [markdown]
# pd.set_option("display.max_rows", None)
# aa.sort_values(by=['change_quote'], inplace=True)
# aa.head(5)

# %%
def jug (row,logic_type,predict):
  
    _str='N'
    if logic_type=='多頭排列':
        
        # 【邏輯一】
        if( float(row['EMA_12'])>float(row['EMA_26']) 
           and  float(row['now_price']) >float(row['EMA_12']) 
           and  float(row['Volume_Price_Change_sum']) >0
           and  float(row['遠交易量']) >0
           and  float( row['change_quote'])>-7.5
           and  (float( row['change_quote'])>-3 and  float( row['成交股數'])>5000)
           and   row['recommend'] !=''
           and   row['Is_Entangled']   # 當短期移動平均線的波動率大於長期移動平均線的波動率時，標記為糾纏狀態
           #and   row['Close_above_MA_5days']  # 計算連續 5 日收盤價都高於短期移動平均線的天數
          ) :
            _str='T'
            
            
            
        if( float(row['成交股數']) <100
           and row['interval_type'] =='負區間'
           and  float(row['level'] )>50
           and  float(row['Volume_Price_Change_sum']) <0
          ):
            _str='F'
            
        if( float(row['遠交易量']) <-20
           and  float(row['遠交易量'])<-20
           and  float(row['Volume_Price_Change_sum']) <-500
          ):
            _str='F'
        if( float(row['EMA_12'])<float(row['EMA_26']) ):
             _str='F'
            
            
    elif logic_type=='':
        # 【邏輯二】
        if row['']>1:
            _str='T'
        else:
            _str='F'
            
            
            
    if predict!=True:
        #事實判定
        _quote=float( row['change_quote'])
        if _quote>0:
            _str+='T'
        else:
            _str+='F'
       
    return _str

# %%
aa['預測']  =df.apply(lambda x: jug(x,'多頭排列',True), axis=1)
aa['判定']  =df.apply(lambda x: jug(x,'多頭排列',False), axis=1)
pd.pivot_table(data=aa, index='判定', aggfunc=pd.Series.nunique).sort_values(by=['判定'], ascending=False)
# Out:
#      %D   %K  Analysis  Bar_Color  Bollinger_MA  Bollinger_STD  \
# 判定
# TT   31   18         8          2            40             40
# TF   25   12         6          2            33             33
# NT  218  132        25          2           246            248
# NF  250  181        30          2           294            294
# FT  659  371        40          2           735            739
# FF  359  227        32          2           390            390
#
#     Bollinger_breakout  Bollinger_lower  Bollinger_upper  Close_above_MA  ...  \
# 判定                                                                        ...
# TT                   2               40               40               2  ...
# TF                   2               33               33               2  ...
# NT                   2              248              248               2  ...
# NF                   2              294              294               2  ...
# FT                   2              739              739               2  ...
# FF                   2              390              390               2  ...
#
#     最高價  漲跌價差  短交易量  短增  短遠交易比  遠交易量  量增  量增與漲幅倍率  開盤價  預測
# 判定
# TT   40    29    39   2     18    31   2       39   40   1
# TF   33    27    29   2     20    27   2       33   32   1
# NT  234    81   127   2     42   114   2      233  234   1
# NF  282   100   174   2     46   150   2      296  276   1
# FT  617    98   151   2     51   120   2      669  593   1
# FF  380    93   145   2     42   104   2      369  363   1
#
# [6 rows x 85 columns]

# %%
aa['Volume_Price_Change_sum'] = pd.to_numeric(aa['Volume_Price_Change_sum'], errors='coerce')
aa['遠交易量'] = pd.to_numeric(aa['遠交易量'], errors='coerce')
aa['短交易量'] = pd.to_numeric(aa['短交易量'], errors='coerce')
aa['_quote'] = pd.to_numeric(aa['_quote'], errors='coerce')
aa['Highest_High'] = pd.to_numeric(aa['Highest_High'], errors='coerce')
aa['now_price'] = pd.to_numeric(aa['now_price'], errors='coerce')
aa['過壓力區']= aa['now_price']/aa['Lowest_Low']

# %%
aa['TTYPE']=''
aa['TJug']=''

# 低量，若過壓力區越大==> 有撐  ( 可以找過壓力區>1.08)
#aa[((aa['遠交易量']<0) & (aa['短交易量'] < 0)& (aa['LevelArea'] >-200))  ].sort_values(by=['過壓力區'], ascending=False)
x_type='TYPE(--)'
aa['TTYPE']=np.where((aa['遠交易量']<0) & (aa['短交易量'] < 0)& (aa['LevelArea'] >-200),x_type , aa['TTYPE'])
aa['TJug']=np.where((aa['TTYPE']==x_type) & (aa['過壓力區'] > 1.08) , 'T', aa['TJug'])

 

# 近期已沖量一段時間，  ( 可以找過壓力區>1.1)
#aa[((aa['遠交易量']>0) & (aa['短交易量'] < 0)& (aa['LevelArea'] >-200))].sort_values(by=['過壓力區'], ascending=False)
x_type='TYPE(-+)'
aa['TTYPE']=np.where((aa['遠交易量']>0) & (aa['短交易量'] < 0)& (aa['LevelArea'] >-200) ,x_type , aa['TTYPE'])
aa['TJug']=np.where((aa['TTYPE']==x_type) & (aa['過壓力區'] > 1.1) , 'T', aa['TJug'])

 

#++ 沒特別發現規則
#bb=aa[((aa['遠交易量']<0) & (aa['短交易量'] > 0)& (aa['LevelArea'] >-200))].sort_values(by=['過壓力區'], ascending=False)
x_type='TYPE(+-)'
aa['TTYPE']=np.where((aa['遠交易量']<0) & (aa['短交易量'] > 0)& (aa['LevelArea'] >-200),x_type , aa['TTYPE'])
aa['TJug']=np.where((aa['TTYPE']==x_type) & (aa['過壓力區'] > 1.2) , 'T', aa['TJug'])

 

# 火熱狀態 ( 可以找過壓力區>1.25)
#aa[((aa['遠交易量']>0) & (aa['短交易量'] > 0)& (aa['LevelArea'] >-200))].sort_values(by=['過壓力區'], ascending=False)
x_type='TYPE(++)'
aa['TTYPE']=np.where((aa['遠交易量']>0) & (aa['短交易量'] > 0)& (aa['LevelArea'] >-200) ,x_type , aa['TTYPE'])
aa['TJug']=np.where((aa['TTYPE']==x_type) & (aa['過壓力區'] > 1.25) , 'T', aa['TJug'])

# %%
#aa.to_excel(to_excel, index=False)
#aa[(aa['判定']=='TF' )|( aa['判定']=='TT') ].drop_duplicates().to_excel(to_excel, index=False)

#aa[(aa['Type1']=='電機機械')].drop_duplicates().to_excel(to_excel, index=False)
#aa[(aa['MA_break'])].drop_duplicates().to_excel(to_excel, index=False)

aa[(aa['MA_break']) & (aa['Volume_Price_Change_sum'] > 0)& (aa['遠交易量'] > 0)]
aa[(aa['MA_break']) & (aa['Volume_Price_Change_sum'] > 0)]
aa[~((aa['遠交易量']<0) & (aa['Volume_Price_Change_sum'] < 0))]

bb=aa[((aa['MA_break']) & (aa['Volume_Price_Change_sum'] > 0)) | (aa['TJug']=='T')  ]

# %%
 
bb[['stock_number','日期','_quote','成交股數','收盤價', 'LevelArea'
        ,  'MA_break' ,'MACD_golden_cross','Signal_Balance_roll'
        ,'Highest_High'
        ,'短交易量','遠交易量','短遠交易比','量增','Volume_Price_Change_sum'
       ,'now_price', 'change_quote', 'Type0', 'Type1', 'Type2',
       '過壓力區','預測','TTYPE','TJug', 'Type']].drop_duplicates().sort_values(by=['過壓力區'], ascending=False).to_excel(to_excel, index=False)
# Weighted_Signal
#bb.drop_duplicates().sort_values(by=['Signal_Balance_roll'], ascending=False).to_excel(to_excel, index=False)

# %%
bb
# Out:
#      stock_number  now_price change_price change_quote          日期      成交股數  \
# 43           1324      13.25        -0.05        -0.38  2024/08/29   32000.0
# 51           1342      95.50          1.2         1.27  2024/08/29   39000.0
# 95           1472      60.70          3.2         5.57  2024/08/29   23000.0
# 104          1512       7.78         0.18         2.37  2024/08/29   50000.0
# 119          1530      36.30          3.3         10.0  2024/08/29  723000.0
# ...           ...        ...          ...          ...         ...       ...
# 1794         8409      22.60         0.25         1.12  2024/08/29      33.0
# 1804         8432      59.80          0.6         1.01  2024/08/29     114.0
# 1808         8437      30.05        -0.15         -0.5  2024/08/29      34.0
# 1827         8929      21.20          0.0          0.0  2024/08/29      10.0
# 1834         8937      65.60         -0.2         -0.3  2024/08/29    2562.0
#
#             成交金額    開盤價    最高價    最低價  ... 短遠交易比  _quote           recommend  \
# 43      425950.0  13.30   13.5  13.25  ...     8    0.00                探底有撐
# 51     3666500.0  93.60   94.4   93.6  ...     1    0.21                探底有撐
# 95     1316300.0  57.00  57.60  56.50  ...   -74    0.88                遠期量推
# 104     383670.0   7.74   7.79   7.55  ...    -1   -2.58
# 119   23506800.0  31.05  33.30  31.05  ...     6    5.64  遠期量推近期量推量大ShowTime
# ...          ...    ...    ...    ...  ...   ...     ...                 ...
# 1794       736.0  22.25  22.50  22.20  ...     1   -0.90
# 1804      6712.0  58.80  59.40  58.50  ...     1   -0.17
# 1808      1040.0  30.60  30.60  30.00  ...     0   -0.82                探底有撐
# 1827       213.0  20.95  21.20  20.90  ...     1    0.24
# 1834    165979.0  63.00  68.00  60.50  ...     1    6.03    遠期量推近期量推ShowTime
#
#       recommend2 LevelArea 預測  判定      過壓力區     TTYPE  TJug
# 43          探底有撐     -40.0  F  FF  1.019231  TYPE(--)
# 51          探底有撐     -95.0  F  FT  1.035792  TYPE(--)
# 95                    40.0  F  FT  1.076241  TYPE(-+)
# 104                  -90.0  F  FT  1.125904  TYPE(-+)     T
# 119           追高      90.0  T  TT  1.212020  TYPE(++)
# ...          ...       ... ..  ..       ...       ...   ...
# 1794                 -40.0  N  NT  1.113300  TYPE(--)     T
# 1804                  90.0  F  FT  1.049123  TYPE(--)
# 1808        探底有撐     -90.0  F  FF  1.023850  TYPE(--)
# 1827                  40.0  F  FF  1.031630  TYPE(--)
# 1834          追高     100.0  N  NF  1.381053  TYPE(++)     T
#
# [221 rows x 89 columns]

# %% [markdown]
# bb=aa[['stock_number','過壓力區']].drop_duplicates().sort_values(by=['過壓力區'], ascending=False)
# bb['SN'] = range(len(bb))
# bb.to_excel(to_excel_, index=False)
# bb

# %% [markdown]
# function getMissingElements(array1, array2) {
#     return array1.filter(element => !array2.includes(element));
#
# }
# array1=app.jsonData.map(x=>x.stock_number)
# array2=app.filteredData.map(x=>x.stock_number)
# getMissingElements(array1, array2);
