# %% [markdown]
# # 目的

# %% [markdown]
# #每日收盤後開始爬股價
#
# #可以視情況條種是否抓營收，大概都隔月的10 後營收才會公布

# %% [markdown]
# ## 【資料源】
# 來自 _BaseInfo  _CrawBase 會先去取基本相關資料 (股票號碼...等)
#
# ## 【輸出】
# 股票相關推薦圖表/數據

# %%
import pandas as pd

# %% [markdown]
# #  Update Base Info

# %%
 
#%run _BaseInfoETF.ipynb
# %run _CrawBase.ipynb
#%run _LineMsg.ipynb
# %run _genHtml.ipynb
# Out:
# C:\Users\user\anaconda3\lib\site-packages\mpl_finance.py:16: DeprecationWarning:
#
#   =================================================================
#
#    WARNING: `mpl_finance` is deprecated:
#
#     Please use `mplfinance` instead (no hyphen, no underscore).
#
#     To install: `pip install --upgrade mplfinance`
#
#    For more information, see: https://pypi.org/project/mplfinance/
#
#   =================================================================
#
#   __warnings.warn('\n\n  ================================================================='+
# 43.9
# 32.89403553299493
# 3.263823803072933
# 32.89403553299493
# 4.197966341128128
# 32.89403553299493
# 5.816803569757285
# 32.89403553299493
# 10.237427863088254
# 32.89403553299493
# 12.19864769558112
# 数据点 43.9 落在置信水平 95.0% 的正區間: [20.70, 45.09]

# %% [markdown]
# %run RunRealTimeStock.ipynb

# %%
def MainStock(stock_number, start_month,end_time=datetime.now().strftime("%Y-%m-%d"),updateRevenue=False):  
    strmsg ='【stock_number】'+stock_number+'\n' +'【start_month】'+start_month+'\n'+'【end_time】'+end_time+'\n' 
    try:
        #處理 Stock
        RowData_df_craw_stock,His_Stock ,isSuccess= craw_stock(stock_number,start_month,end_time)
        #data_final,df_final=DataCleaning(RowData_df_craw_stock)
        print("【craw_stock】 success")
        
        #處理 Revenue
        if(updateRevenue):
            RowData_df_craw_revenue,His_Stock=craw_revenue(stock_number)
            df_Revenue=RevenueDataCleaning(RowData_df_craw_revenue)
            print("【craw_revenue】 success")
            
        #處理相關指標轉成html 
        stock_data=data_process(RowData_df_craw_stock)
        
        level,interval_type, lower_bound, upper_bound=get_interval(stock_data.iloc[-1]['收盤價'],np.array(stock_data['收盤價']))
        stock_data['stock_number']=stock_number
        stock_data['level']=level
        stock_data['interval_type']=interval_type
        stock_data['lower_bound']=lower_bound
        stock_data['upper_bound']=upper_bound

        gen_html(stock_number,stock_data)

        #sendLineMessage('成功'+'\n'+strmsg )
    except:
        #sendLineMessage('失败'+'\n'+strmsg)
        print('MainStock Fail'+'\n'+strmsg)
        
    #return data_final,df_final,df_Revenue

# %% [markdown]
# # 清資料使用
# type_='Stock_His'
# strMonth = (datetime.now() - timedelta(days=2)).strftime('%Y-%m-01')
# df=get_DB()
# df[~((df['status'] != 'OK')& (df['status'] != '很抱歉，沒有符合條件的資料!'))].to_csv('BaseInfo/His_Stock.csv',index=False)
# DDD=df[((df['status'] != 'OK')& (df['status'] != '很抱歉，沒有符合條件的資料!'))]['stock_number'].unique()

# %%
start_month='2023-01-01'  #起始月份
want_update_Stock=True
want_update_Revenue=False
file_path = 'D:\Project\Jupyter\Stock\Main\DailyResultLast.xlsx'   

for code in _baseInfo.dropna()['公司代號']:#.iloc[::-1]:
#for code in DDD:
    stock_number=str(code)
    if (want_update_Stock):        
        type_='Stock_His'
        strMonth = (datetime.now() - timedelta(days=2)).strftime('%Y-%m-01')
        delete_DB_stock_by_Month_Stock_number(strMonth,stock_number,type_)
    try:
        if(want_update_Revenue):
            MainStock(stock_number,start_month,want_update_Revenue)
        else:
            MainStock(stock_number,start_month)
    except Exception as error:
        print("An exception occurred:", error)
        print('Action Fail'+'\n')
        
    print(stock_number,'=====================>Data Ready')
# Out:
# Stock_His 1203 2024-08-01 ===>外部抓取
# 【craw_stock】 success
# 54.6
# 45.881428571428565
# 3.4267326275668353
# 45.881428571428565
# 4.407501476344148
# 45.881428571428565
# 6.107140514713967
# 45.881428571428565
# 10.748413577895102
# 数据点 54.6 落在置信水平 90.0% 的正區間: [35.13, 56.63]
# 1203 =====================>Data Ready
# Stock_His 1220 2024-08-01 ===>外部抓取
# 【craw_stock】 success
# 16.9
# 15.038959390862946
# 0.5411878206941307
# 15.038959390862946
# 0.6960817717437543
# 15.038959390862946
# 0.9645077177140868
# 15.038959390862946
# 1.6975093047369076
# 15.038959390862946
# 2.022707094534755
# 数据点 16.9 落在置信水平 95.0% 的正區間: [13.02, 17.06]
# 1220 =====================>Data Ready
# Stock_His 2324 2024-07-01 ===>外部抓取
# Stock_His 2324 2024-08-01 ===>外部抓取
# 【craw_stock】 success
# 32.85
# 31.36243654822335
# 2.4847500123186923
# 数据点 32.85 落在置信水平 40.0% 的正區間: [28.88, 33.85]
# 2324 =====================>Data Ready
# Stock_His 2338 2023-12-01 ===>外部抓取
# Stock_His 2338 2024-08-01 ===>外部抓取
# 【craw_stock】 success
# 63.1
# 74.80000000000001
# 4.1507531719771045
# 74.80000000000001
# 5.338744723255309
# 74.80000000000001
# 7.397493653059884
# 74.80000000000001
# 13.019402620813233
# 数据点 63.1 落在置信水平 90.0% 的負區間: [61.78, 87.82]
# 2338 =====================>Data Ready
# Stock_His 2345 2024-07-01 ===>外部抓取
# Stock_His 2345 2024-08-01 ===>外部抓取
# 【craw_stock】 success
# 515.0
# 435.1954314720812
# 51.45563634085121
# 435.1954314720812
# 66.18280962864704
# 435.1954314720812
# 91.70449975571421
# 数据点 515.0 落在置信水平 65.0% 的正區間: [343.49, 526.90]
# 2345 =====================>Data Ready
# Stock_His 2428 2024-07-01 ===>外部抓取
# Stock_His 2428 2024-08-01 ===>外部抓取
# 【craw_stock】 success
# 172.5
# 157.85406091370558
# 6.231985927159165
# 157.85406091370558
# 8.015649354590403
# 157.85406091370558
# 11.1066773744485
# 157.85406091370558
# 19.5474726034552
# 数据点 172.5 落在置信水平 90.0% 的正區間: [138.31, 177.40]
# 2428 =====================>Data Ready
# Stock_His 2535 2023-10-01 ===>外部抓取
# Stock_His 2535 2024-08-01 ===>外部抓取
# 【craw_stock】 success
# 53.7
# 42.02622739018088
# 5.318358683036091
# 42.02622739018088
# 6.840531869524186
# 42.02622739018088
# 9.478406200606628
# 42.02622739018088
# 16.681756324084994
# 数据点 53.7 落在置信水平 90.0% 的正區間: [25.34, 58.71]
# 2535 =====================>Data Ready
# Stock_His 2913 2023-02-01 ===>外部抓取
# Stock_His 2913 2024-08-01 ===>外部抓取
# 【craw_stock】 success
# 20.85
# 21.860152284263958
# 0.7567864711427948
# 21.860152284263958
# 0.9733871449455798
# 21.860152284263958
# 1.348748741504616
# 数据点 20.85 落在置信水平 65.0% 的負區間: [20.51, 23.21]
# 2913 =====================>Data Ready
# Stock_His 3024 2024-07-01 ===>外部抓取
# Stock_His 3024 2024-08-01 ===>外部抓取
# 【craw_stock】 success
# 20.6
# 17.271319796954312
# 1.3771892189984176
# 17.271319796954312
# 1.771356033765252
# 17.271319796954312
# 2.454433709858643
# 17.271319796954312
# 4.3197415467234705
# 数据点 20.6 落在置信水平 90.0% 的正區間: [12.95, 21.59]
# 3024 =====================>Data Ready
# Stock_His 3030 2024-07-01 ===>外部抓取
# Stock_His 3030 2024-08-01 ===>外部抓取
# 【craw_stock】 success
# 159.0
# 83.69289340101523
# 19.584911450588315
# 83.69289340101523
# 25.19033012325494
# 83.69289340101523
# 34.90432992488865
# 83.69289340101523
# 61.430742061381025
# 83.69289340101523
# 73.19924400022546
# 83.69289340101523
# 96.20011346160202
# 数据点 159.0 落在置信水平 99.0% 的正區間: [-12.51, 179.89]
# 3030 =====================>Data Ready
# Stock_His 3052 2024-07-01 ===>外部抓取
# Stock_His 3052 2024-08-01 ===>外部抓取
# 【craw_stock】 success
# 12.55
# 12.140101522842642
# 0.5166787378214897
# 数据点 12.55 落在置信水平 40.0% 的正區間: [11.62, 12.66]
# 3052 =====================>Data Ready
# Stock_His 3055 2024-07-01 ===>外部抓取
# Stock_His 3055 2024-08-01 ===>外部抓取
# 【craw_stock】 success
# 73.0
# 50.12131979695431
# 11.396606725181405
# 50.12131979695431
# 14.658441852878699
# 50.12131979695431
# 20.311091125611764
# 50.12131979695431
# 35.74700911341566
# 数据点 73.0 落在置信水平 90.0% 的正區間: [14.37, 85.87]
# 3055 =====================>Data Ready
# Stock_His 3062 2024-01-01 ===>外部抓取
# Stock_His 3062 2024-08-01 ===>外部抓取
# 【craw_stock】 success
# 33.45
# 23.467005076142133
# 1.6206626552337977
# 23.467005076142133
# 2.084514265319485
# 23.467005076142133
# 2.8883533202560017
# 23.467005076142133
# 5.083429138465145
# 23.467005076142133
# 6.057279423591597
# 23.467005076142133
# 7.96061456340101
# 3062 =====================>Data Ready
# Stock_His 3090 2024-07-01 ===>外部抓取
# Stock_His 3090 2024-08-01 ===>外部抓取
# 【craw_stock】 success
# 62.1
# 58.89314720812183
# 2.1576606927969877
# 58.89314720812183
# 2.7752070915742837
# 58.89314720812183
# 3.8453939849234073
# 数据点 62.1 落在置信水平 65.0% 的正區間: [55.05, 62.74]
# 3090 =====================>Data Ready
# Stock_His 3266 2024-07-01 ===>外部抓取
# Stock_His 3266 2024-08-01 ===>外部抓取
# 【craw_stock】 success
# 23.3
# 16.96522842639594
# 2.396683763120621
# 16.96522842639594
# 3.0826412131794356
# 16.96522842639594
# 4.271382130301789
# 16.96522842639594
# 7.517525030757298
# 数据点 23.3 落在置信水平 90.0% 的正區間: [9.45, 24.48]
# 3266 =====================>Data Ready
# Stock_His 3305 2023-05-01 ===>外部抓取
# Stock_His 3305 2024-08-01 ===>外部抓取
# 【craw_stock】 success
# 64.7
# 62.0493654822335
# 5.287125731878642
# 数据点 64.7 落在置信水平 40.0% 的正區間: [56.76, 67.34]
# 3305 =====================>Data Ready
# Stock_His 3437 2024-07-01 ===>外部抓取
# Stock_His 3437 2024-08-01 ===>外部抓取
# 【craw_stock】 success
# 23.8
# 23.25913705583756
# 2.9224114858442802
# 数据点 23.8 落在置信水平 40.0% 的正區間: [20.34, 26.18]
# 3437 =====================>Data Ready
# Stock_His 3588 2023-03-01 ===>外部抓取
# Stock_His 3588 2024-08-01 ===>外部抓取
# 【craw_stock】 success
# 73.5
# 73.52956852791878
# 8.657067203056814
# 数据点 73.5 落在置信水平 40.0% 的負區間: [64.87, 82.19]
# 3588 =====================>Data Ready
# Stock_His 3592 2023-05-01 ===>外部抓取
# Stock_His 3592 2024-08-01 ===>外部抓取
# 【craw_stock】 success
# 352.5
# 386.4733502538071
# 22.727598567756125
# 386.4733502538071
# 29.232489116686562
# 386.4733502538071
# 40.505243069942836
# 数据点 352.5 落在置信水平 65.0% 的負區間: [345.97, 426.98]
# 3592 =====================>Data Ready
# Stock_His 3661 2023-05-01 ===>外部抓取
# Stock_His 3661 2024-08-01 ===>外部抓取
# 【craw_stock】 success
# 2655.0
# 2418.6522842639592
# 475.3311001633905
# 数据点 2655.0 落在置信水平 40.0% 的正區間: [1943.32, 2893.98]
# 3661 =====================>Data Ready
# Stock_His 3703 2023-07-01 ===>外部抓取
# Stock_His 3703 2024-08-01 ===>外部抓取
# 【craw_stock】 success
# 33.8
# 30.2510152284264
# 1.7711794505365586
# 30.2510152284264
# 2.2781106352768807
# 30.2510152284264
# 3.1566051270481466
# 30.2510152284264
# 5.55554556602611
# 数据点 33.8 落在置信水平 90.0% 的正區間: [24.70, 35.81]
# 3703 =====================>Data Ready
# Stock_His 6414 2023-03-01 ===>外部抓取
# Stock_His 6414 2024-08-01 ===>外部抓取
# 【craw_stock】 success
# 292.0
# 280.78934010152284
# 17.390094263321785
# 数据点 292.0 落在置信水平 40.0% 的正區間: [263.40, 298.18]
# 6414 =====================>Data Ready
# Stock_His 8940 2023-05-01 ===>外部抓取
# Stock_His 8940 2024-08-01 ===>外部抓取
# 【craw_stock】 success
# 22.7
# 26.393654822335026
# 2.0171695635466
# 26.393654822335026
# 2.59450584438535
# 26.393654822335026
# 3.5950099717381754
# 26.393654822335026
# 6.327127057221256
# 数据点 22.7 落在置信水平 90.0% 的負區間: [20.07, 32.72]
# 8940 =====================>Data Ready
# Stock_His 9917 2024-01-01 ===>外部抓取
# Stock_His 9917 2024-08-01 ===>外部抓取
# 【craw_stock】 success
# 145.5
# 116.29593908629441
# 5.540796469667983
# 116.29593908629441
# 7.126633815467638
# 116.29593908629441
# 9.87483596808093
# 116.29593908629441
# 17.379462735970648
# 116.29593908629441
# 20.708907148346142
# 116.29593908629441
# 27.216117386820876
# 9917 =====================>Data Ready
