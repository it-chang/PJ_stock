# %% [markdown]
# # 目的

# %% [markdown]
# #每日收盤後開始爬股價
#
# #可以視情況條種是否抓營收，大概都隔月的10 後營收才會公布

# %% [markdown]
# ## 【資料源】
# 來自 _BaseInfo  _CrawBase 會先去取基本相關資料 (股票號碼...等)
#
# ## 【輸出】
# 股票相關推薦圖表/數據

# %%
import pandas as pd

# %% [markdown]
# #  Update Base Info

# %%
 
#%run _BaseInfoETF.ipynb
# %run _CrawBase.ipynb
#%run _LineMsg.ipynb
# %run _genHtml.ipynb
# Out:
# C:\Users\user\anaconda3\lib\site-packages\mpl_finance.py:16: DeprecationWarning:
#
#   =================================================================
#
#    WARNING: `mpl_finance` is deprecated:
#
#     Please use `mplfinance` instead (no hyphen, no underscore).
#
#     To install: `pip install --upgrade mplfinance`
#
#    For more information, see: https://pypi.org/project/mplfinance/
#
#   =================================================================
#
#   __warnings.warn('\n\n  ================================================================='+

# %% [markdown]
# %run RunRealTimeStock.ipynb

# %%
def MainStock(stock_number, start_month,end_time=datetime.now().strftime("%Y-%m-%d"),updateRevenue=False):  
    strmsg ='【stock_number】'+stock_number+'\n' +'【start_month】'+start_month+'\n'+'【end_time】'+end_time+'\n' 
    try:
        #處理 Stock
        RowData_df_craw_stock,His_Stock ,isSuccess= craw_stock(stock_number,start_month,end_time)
        #data_final,df_final=DataCleaning(RowData_df_craw_stock)
        print("【craw_stock】 success")
        
        #處理 Revenue
        if(updateRevenue):
            RowData_df_craw_revenue,His_Stock=craw_revenue(stock_number)
            df_Revenue=RevenueDataCleaning(RowData_df_craw_revenue)
            print("【craw_revenue】 success")
            
        #處理相關指標轉成html 
        stock_data=data_process(RowData_df_craw_stock)
        
        level,interval_type, lower_bound, upper_bound=get_interval(stock_data.iloc[-1]['收盤價'],np.array(stock_data['收盤價']))
        stock_data['stock_number']=stock_number
        stock_data['level']=level
        stock_data['interval_type']=interval_type
        stock_data['lower_bound']=lower_bound
        stock_data['upper_bound']=upper_bound

        gen_html(stock_number,stock_data)

        #sendLineMessage('成功'+'\n'+strmsg )
    except:
        #sendLineMessage('失败'+'\n'+strmsg)
        print('MainStock Fail'+'\n'+strmsg)
        
    #return data_final,df_final,df_Revenue

# %% [markdown]
# # 清資料使用
# type_='Stock_His'
# strMonth = (datetime.now() - timedelta(days=2)).strftime('%Y-%m-01')
# df=get_DB()
# df[~((df['status'] != 'OK')& (df['status'] != '很抱歉，沒有符合條件的資料!'))].to_csv('BaseInfo/His_Stock.csv',index=False)
# DDD=df[((df['status'] != 'OK')& (df['status'] != '很抱歉，沒有符合條件的資料!'))]['stock_number'].unique()

# %%
start_month='2023-01-01'  #起始月份
want_update_Stock=True
want_update_Revenue=False
file_path = 'D:\Project\Jupyter\Stock\Main\DailyResultLast.xlsx'   

for code in _baseInfo.dropna()['公司代號']:#.iloc[::-1]:
#for code in DDD:
    stock_number=str(code)
    if (want_update_Stock):        
        type_='Stock_His'
        strMonth = (datetime.now() - timedelta(days=2)).strftime('%Y-%m-01')
        delete_DB_stock_by_Month_Stock_number(strMonth,stock_number,type_)
    try:
        if(want_update_Revenue):
            MainStock(stock_number,start_month,want_update_Revenue)
        else:
            MainStock(stock_number,start_month)
    except Exception as error:
        print("An exception occurred:", error)
        print('Action Fail'+'\n')
        
    print(stock_number,'=====================>Data Ready')
# Out:
# Stock_His 1101 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 32.15
# 34.82356608478803
# 1.1782218187455014
# 34.82356608478803
# 1.5154419588519237
# 34.82356608478803
# 2.099832985712068
# 34.82356608478803
# 3.6956531981803735
# 数据点 32.15 落在置信水平 90.0% 的負區間: [31.13, 38.52]
# 1101 =====================>Data Ready
# Stock_His 1102 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 45.1
# 42.135875
# 0.977940330062784
# 42.135875
# 1.2578376888390999
# 42.135875
# 1.7428902864067097
# 42.135875
# 3.0674430323096553
# 数据点 45.1 落在置信水平 90.0% 的正區間: [39.07, 45.20]
# 1102 =====================>Data Ready
# Stock_His 1103 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 18.3
# 18.86084788029925
# 0.6006906080602005
# 数据点 18.3 落在置信水平 40.0% 的負區間: [18.26, 19.46]
# 1103 =====================>Data Ready
# Stock_His 1104 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 30.2
# 29.25511221945137
# 1.7224734953094916
# 数据点 30.2 落在置信水平 40.0% 的正區間: [27.53, 30.98]
# 1104 =====================>Data Ready
# Stock_His 1108 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 15.1
# 15.415336658354116
# 0.7947342017714732
# 数据点 15.1 落在置信水平 40.0% 的負區間: [14.62, 16.21]
# 1108 =====================>Data Ready
# Stock_His 1109 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 18.35
# 18.11059850374065
# 0.5139977481644645
# 数据点 18.35 落在置信水平 40.0% 的正區間: [17.60, 18.62]
# 1109 =====================>Data Ready
# Stock_His 1110 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 22.55
# 19.2926433915212
# 0.8239581199815529
# 19.2926433915212
# 1.0597840639942406
# 19.2926433915212
# 1.4684623995715431
# 19.2926433915212
# 2.5844568593363104
# 19.2926433915212
# 3.0795702917862813
# 19.2926433915212
# 4.047241409787055
# 数据点 22.55 落在置信水平 99.0% 的正區間: [15.25, 23.34]
# 1110 =====================>Data Ready
# Stock_His 1201 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 18.3
# 19.220573566084788
# 0.3828148598552157
# 19.220573566084788
# 0.4923807146215503
# 19.220573566084788
# 0.6822546122941535
# 19.220573566084788
# 1.2007509440295714
# 数据点 18.3 落在置信水平 90.0% 的負區間: [18.02, 20.42]
# 1201 =====================>Data Ready
# Stock_His 1203 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# nan
# 46.00038363171356
# 3.436982015525924
# 46.00038363171356
# 4.420684352708034
# 46.00038363171356
# 6.1254070266537735
# 46.00038363171356
# 10.780562179107331
# 46.00038363171356
# 12.84583215061263
# 46.00038363171356
# 16.88228515575685
# 1203 =====================>Data Ready
# Stock_His 1210 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 52.5
# 54.45897755610973
# 1.8371656821272888
# 54.45897755610973
# 2.3629828575258163
# 数据点 52.5 落在置信水平 50.0% 的負區間: [52.10, 56.82]
# 1210 =====================>Data Ready
# Stock_His 1213 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 12.0
# 7.411536458333333
# 0.7683835733074099
# 7.411536458333333
# 0.9883034662542979
# 7.411536458333333
# 1.369417156633662
# 7.411536458333333
# 2.410139724917257
# 7.411536458333333
# 2.8718586147401077
# 7.411536458333333
# 3.7742619935094766
# 1213 =====================>Data Ready
# Stock_His 1215 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 98.0
# 95.4428927680798
# 4.2058622970701265
# 数据点 98.0 落在置信水平 40.0% 的正區間: [91.24, 99.65]
# 1215 =====================>Data Ready
# Stock_His 1216 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 83.1
# 74.42344139650874
# 2.5273574585801644
# 74.42344139650874
# 3.250715168242056
# 74.42344139650874
# 4.504269462487676
# 74.42344139650874
# 7.9274008732003605
# 74.42344139650874
# 9.446080762384142
# 数据点 83.1 落在置信水平 95.0% 的正區間: [64.98, 83.87]
# 1216 =====================>Data Ready
# Stock_His 1217 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 12.3
# 11.981795511221947
# 0.35048349285938374
# 数据点 12.3 落在置信水平 40.0% 的正區間: [11.63, 12.33]
# 1217 =====================>Data Ready
# Stock_His 1218 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 20.6
# 24.475436408977554
# 2.083081706608782
# 24.475436408977554
# 2.67928277314791
# 24.475436408977554
# 3.71247893213165
# 24.475436408977554
# 6.533869470603173
# 数据点 20.6 落在置信水平 90.0% 的負區間: [17.94, 31.01]
# 1218 =====================>Data Ready
# Stock_His 1219 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 17.35
# 19.59800498753117
# 0.5997846790894488
# 19.59800498753117
# 0.7714497003089531
# 19.59800498753117
# 1.0689393401471166
# 19.59800498753117
# 1.8813063314823064
# 19.59800498753117
# 2.2417147600096325
# 19.59800498753117
# 2.946112589097373
# 数据点 17.35 落在置信水平 99.0% 的負區間: [16.65, 22.54]
# 1219 =====================>Data Ready
# Stock_His 1220 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 16.75
# 15.071072319201996
# 0.5512160594565798
# 15.071072319201996
# 0.7089802035604233
# 15.071072319201996
# 0.9823800964181306
# 15.071072319201996
# 1.7289642413752575
# 数据点 16.75 落在置信水平 90.0% 的正區間: [13.34, 16.80]
# 1220 =====================>Data Ready
# Stock_His 1225 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 161.0
# 69.05807291666667
# 15.031031285057365
# 69.05807291666667
# 19.33307899394123
# 69.05807291666667
# 26.788381270378697
# 69.05807291666667
# 47.14687672285444
# 69.05807291666667
# 56.17896866094259
# 69.05807291666667
# 73.83168000098217
# 1225 =====================>Data Ready
# Stock_His 1227 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 38.85
# 39.60162094763092
# 0.8439107596845469
# 数据点 38.85 落在置信水平 40.0% 的負區間: [38.76, 40.45]
# 1227 =====================>Data Ready
# Stock_His 1229 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 62.0
# 63.251870324189525
# 2.525727734867322
# 数据点 62.0 落在置信水平 40.0% 的負區間: [60.73, 65.78]
# 1229 =====================>Data Ready
# Stock_His 1231 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 107.0
# 92.8152119700748
# 4.7662898767842465
# 92.8152119700748
# 6.1304548535866195
# 92.8152119700748
# 8.494506334463756
# 92.8152119700748
# 14.950117326249602
# 数据点 107.0 落在置信水平 90.0% 的正區間: [77.87, 107.77]
# 1231 =====================>Data Ready
# Stock_His 1232 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 147.0
# 145.21820448877804
# 1.632321816838604
# 145.21820448877804
# 2.099510408167842
# 数据点 147.0 落在置信水平 50.0% 的正區間: [143.12, 147.32]
# 1232 =====================>Data Ready
# Stock_His 1233 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 32.45
# 34.57475
# 0.7237962090242768
# 34.57475
# 0.9309547042518936
# 34.57475
# 1.2899533266671024
# 34.57475
# 2.2702853844274147
# 数据点 32.45 落在置信水平 90.0% 的負區間: [32.30, 36.85]
# 1233 =====================>Data Ready
# Stock_His 1234 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 42.25
# 39.3850374064838
# 1.48471348932654
# 39.3850374064838
# 1.9096549417108453
# 39.3850374064838
# 2.6460640175031003
# 39.3850374064838
# 4.657006064489093
# 数据点 42.25 落在置信水平 90.0% 的正區間: [34.73, 44.04]
# 1234 =====================>Data Ready
# Stock_His 1235 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 131.0
# 84.26849315068493
# 6.899892716055784
# 84.26849315068493
# 8.874718467377408
# 84.26849315068493
# 12.297024289089272
# 84.26849315068493
# 21.642453209993555
# 84.26849315068493
# 25.78857360535954
# 84.26849315068493
# 33.89193072596244
# 1235 =====================>Data Ready
# Stock_His 1236 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 23.85
# 23.69898218829517
# 0.46365618288005855
# 数据点 23.85 落在置信水平 40.0% 的正區間: [23.24, 24.16]
# 1236 =====================>Data Ready
# Stock_His 1256 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 156.5
# 257.1430412371134
# 26.129349608331005
# 257.1430412371134
# 33.60785899902694
# 257.1430412371134
# 46.56786127182356
# 257.1430412371134
# 81.95826363936979
# 257.1430412371134
# 97.65929462448311
# 257.1430412371134
# 128.34606903079978
# 数据点 156.5 落在置信水平 99.0% 的負區間: [128.80, 385.49]
# 1256 =====================>Data Ready
# Stock_His 1301 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 49.8
# 77.44364089775561
# 6.313823892123018
# 77.44364089775561
# 8.120910251952942
# 77.44364089775561
# 11.252529416551758
# 77.44364089775561
# 19.80416852619177
# 77.44364089775561
# 23.598122300424436
# 77.44364089775561
# 31.013189736967764
# 数据点 49.8 落在置信水平 99.0% 的負區間: [46.43, 108.46]
# 1301 =====================>Data Ready
# Stock_His 1303 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 43.4
# 64.77082294264339
# 5.278220671704684
# 64.77082294264339
# 6.78890591459046
# 64.77082294264339
# 9.406872030356485
# 64.77082294264339
# 16.55585798509187
# 64.77082294264339
# 19.72752155708823
# 64.77082294264339
# 25.92635809329181
# 数据点 43.4 落在置信水平 99.0% 的負區間: [38.84, 90.70]
# 1303 =====================>Data Ready
# Stock_His 1304 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 14.55
# 20.120947630922693
# 1.8634976453741923
# 20.120947630922693
# 2.396851320431886
# 20.120947630922693
# 3.3211350887389424
# 20.120947630922693
# 5.845114157079027
# 数据点 14.55 落在置信水平 90.0% 的負區間: [14.28, 25.97]
# 1304 =====================>Data Ready
# Stock_His 1305 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 16.65
# 22.156733167082294
# 1.8269012085063427
# 22.156733167082294
# 2.349780577816489
# 22.156733167082294
# 3.255912730714321
# 22.156733167082294
# 5.730324448722855
# 数据点 16.65 落在置信水平 90.0% 的負區間: [16.43, 27.89]
# 1305 =====================>Data Ready
# Stock_His 1307 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 33.5
# 26.107231920199503
# 2.0087584193483585
# 26.107231920199503
# 2.5836873375157854
# 26.107231920199503
# 3.5800195872842075
# 26.107231920199503
# 6.3007443579179245
# 26.107231920199503
# 7.507799973789045
# 数据点 33.5 落在置信水平 95.0% 的正區間: [18.60, 33.62]
# 1307 =====================>Data Ready
# Stock_His 1308 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 17.2
# 23.497506234413965
# 2.024831613204856
# 23.497506234413965
# 2.6043608575570554
# 23.497506234413965
# 3.6086653160499114
# 23.497506234413965
# 6.351160119479685
# 数据点 17.2 落在置信水平 90.0% 的負區間: [17.15, 29.85]
# 1308 =====================>Data Ready
# Stock_His 1309 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 17.4
# 18.271072319201995
# 1.2204990855216649
# 数据点 17.4 落在置信水平 40.0% 的負區間: [17.05, 19.49]
# 1309 =====================>Data Ready
# Stock_His 1310 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 13.05
# 14.783167082294263
# 0.6779075327739689
# 14.783167082294263
# 0.8719321803777966
# 14.783167082294263
# 1.2081702918191692
# 14.783167082294263
# 2.126349301725024
# 数据点 13.05 落在置信水平 90.0% 的負區間: [12.66, 16.91]
# 1310 =====================>Data Ready
# Stock_His 1312 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 12.95
# 16.45486284289277
# 1.2935665039772861
# 16.45486284289277
# 1.66379957110267
# 16.45486284289277
# 2.305400877023198
# 16.45486284289277
# 4.057447512364628
# 数据点 12.95 落在置信水平 90.0% 的負區間: [12.40, 20.51]
# 1312 =====================>Data Ready
# Stock_His 1313 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 11.65
# 14.350872817955112
# 0.6523636142005381
# 14.350872817955112
# 0.8390773092628733
# 14.350872817955112
# 1.162645788748989
# 14.350872817955112
# 2.0462273222572938
# 14.350872817955112
# 2.4382302413371235
# 14.350872817955112
# 3.2043777099858857
# 数据点 11.65 落在置信水平 99.0% 的負區間: [11.15, 17.56]
# 1313 =====================>Data Ready
# Stock_His 1314 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 9.36
# 9.882443890274315
# 0.2176432787944496
# 9.882443890274315
# 0.27993519683619034
# 9.882443890274315
# 0.38788497094521157
# 9.882443890274315
# 0.6826677850827582
# 数据点 9.36 落在置信水平 90.0% 的負區間: [9.20, 10.57]
# 1314 =====================>Data Ready
# Stock_His 1315 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 70.8
# 71.48952618453865
# 0.3933668117045184
# 71.48952618453865
# 0.5059527520136643
# 71.48952618453865
# 0.7010603551553773
# 数据点 70.8 落在置信水平 65.0% 的負區間: [70.79, 72.19]
# 1315 =====================>Data Ready
# Stock_His 1316 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 19.8
# 14.691396508728179
# 1.9745825569164248
# 14.691396508728179
# 2.5397299645616433
# 14.691396508728179
# 3.5191111894698284
# 14.691396508728179
# 6.193547110941436
# 数据点 19.8 落在置信水平 90.0% 的正區間: [8.50, 20.88]
# 1316 =====================>Data Ready
# Stock_His 1319 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 96.7
# 77.5493765586035
# 13.840397370177868
# 77.5493765586035
# 17.801672459506424
# 77.5493765586035
# 24.666427383093318
# 数据点 96.7 落在置信水平 65.0% 的正區間: [52.88, 102.22]
# 1319 =====================>Data Ready
# Stock_His 1321 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 39.15
# 36.276807980049874
# 1.0177624115176087
# 36.276807980049874
# 1.309057291264826
# 36.276807980049874
# 1.8138614048057788
# 36.276807980049874
# 3.1923504142179433
# 数据点 39.15 落在置信水平 90.0% 的正區間: [33.08, 39.47]
# 1321 =====================>Data Ready
# Stock_His 1323 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 29.7
# 31.611845386533663
# 0.5390280158216854
# 31.611845386533663
# 0.693303806784557
# 31.611845386533663
# 0.960658502361165
# 31.611845386533663
# 1.690734782607622
# 31.611845386533663
# 2.014634753526225
# 数据点 29.7 落在置信水平 95.0% 的負區間: [29.60, 33.63]
# 1323 =====================>Data Ready
# Stock_His 1324 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 13.05
# 13.922693266832917
# 1.3354576165295597
# 数据点 13.05 落在置信水平 40.0% 的負區間: [12.59, 15.26]
# 1324 =====================>Data Ready
# Stock_His 1325 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 28.45
# 27.73017456359102
# 2.956163983456126
# 数据点 28.45 落在置信水平 40.0% 的正區間: [24.77, 30.69]
# 1325 =====================>Data Ready
# Stock_His 1326 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 41.9
# 61.037531172069826
# 4.001844042076926
# 61.037531172069826
# 5.147216150352854
# 61.037531172069826
# 7.132107035817468
# 61.037531172069826
# 12.55232885473768
# 61.037531172069826
# 14.957022360090274
# 61.037531172069826
# 19.656859408055784
# 数据点 41.9 落在置信水平 99.0% 的負區間: [41.38, 80.69]
# 1326 =====================>Data Ready
# Stock_His 1337 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 7.07
# 7.462842892768079
# 0.2620058402692925
# 7.462842892768079
# 0.3369948149755879
# 7.462842892768079
# 0.4669481561905326
# 数据点 7.07 落在置信水平 65.0% 的負區間: [7.00, 7.93]
# 1337 =====================>Data Ready
# Stock_His 1338 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 32.4
# 38.99576059850374
# 2.5770354287297663
# 38.99576059850374
# 3.3146115239176437
# 38.99576059850374
# 4.592805796413678
# 38.99576059850374
# 8.083222592287148
# 数据点 32.4 落在置信水平 90.0% 的負區間: [30.91, 47.08]
# 1338 =====================>Data Ready
# Stock_His 1339 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 57.9
# 57.03541147132169
# 5.908964323221897
# 数据点 57.9 落在置信水平 40.0% 的正區間: [51.13, 62.94]
# 1339 =====================>Data Ready
# Stock_His 1340 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 9.78
# 11.22937655860349
# 0.5727513251615358
# 11.22937655860349
# 0.736679100937034
# 11.22937655860349
# 1.0207603577270652
# 11.22937655860349
# 1.7965125351769493
# 数据点 9.78 落在置信水平 90.0% 的負區間: [9.43, 13.03]
# 1340 =====================>Data Ready
# Stock_His 1341 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 68.4
# 66.83308270676692
# 1.6007274545503385
# 数据点 68.4 落在置信水平 40.0% 的正區間: [65.23, 68.43]
# 1341 =====================>Data Ready
# Stock_His 1342 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 96.0
# 121.47556109725686
# 8.252063197021753
# 121.47556109725686
# 10.613895123058942
# 121.47556109725686
# 14.70686947533921
# 121.47556109725686
# 25.883720077541163
# 数据点 96.0 落在置信水平 90.0% 的負區間: [95.59, 147.36]
# 1342 =====================>Data Ready
# Stock_His 1402 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 35.8
# 32.01508728179551
# 1.1298720541064988
# 32.01508728179551
# 1.4532539558215825
# 32.01508728179551
# 2.0136637864788614
# 32.01508728179551
# 3.543997576567756
# 32.01508728179551
# 4.222933577526752
# 数据点 35.8 落在置信水平 95.0% 的正區間: [27.79, 36.24]
# 1402 =====================>Data Ready
# Stock_His 1409 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 16.05
# 16.55847880299252
# 0.528488778796571
# 数据点 16.05 落在置信水平 40.0% 的負區間: [16.03, 17.09]
# 1409 =====================>Data Ready
# Stock_His 1410 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 37.85
# 37.879375
# 0.6269309621681952
# 数据点 37.85 落在置信水平 40.0% 的負區間: [37.25, 38.51]
# 1410 =====================>Data Ready
# Stock_His 1413 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 9.82
# 9.2204
# 0.40143428074222937
# 9.2204
# 0.516329220083576
# 9.2204
# 0.7154382399705077
# 数据点 9.82 落在置信水平 65.0% 的正區間: [8.50, 9.94]
# 1413 =====================>Data Ready
# Stock_His 1414 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 22.45
# 18.76795511221945
# 1.0126246284214526
# 18.76795511221945
# 1.3024490177160597
# 18.76795511221945
# 1.8047048213449246
# 18.76795511221945
# 3.1762350578149503
# 18.76795511221945
# 3.7847175078360107
# 数据点 22.45 落在置信水平 95.0% 的正區間: [14.98, 22.55]
# 1414 =====================>Data Ready
# Stock_His 1416 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 12.8
# 11.558229426433916
# 0.49848940319306345
# 11.558229426433916
# 0.6411625940233904
# 11.558229426433916
# 0.8884103784185792
# 11.558229426433916
# 1.5635799030873316
# 数据点 12.8 落在置信水平 90.0% 的正區間: [9.99, 13.12]
# 1416 =====================>Data Ready
# Stock_His 1417 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 10.95
# 12.550872817955113
# 0.5751410254761782
# 12.550872817955113
# 0.7397527599613988
# 12.550872817955113
# 1.0250192939195686
# 12.550872817955113
# 1.8040081556704688
# 数据点 10.95 落在置信水平 90.0% 的負區間: [10.75, 14.35]
# 1417 =====================>Data Ready
# Stock_His 1418 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 33.3
# 24.06268844221105
# 3.915803978581105
# 24.06268844221105
# 5.036550467296092
# 24.06268844221105
# 6.978765992096471
# 24.06268844221105
# 12.282452477665887
# 数据点 33.3 落在置信水平 90.0% 的正區間: [11.78, 36.35]
# 1418 =====================>Data Ready
# Stock_His 1419 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 48.25
# 44.64812967581048
# 1.5119036320115784
# 44.64812967581048
# 1.944627204519516
# 44.64812967581048
# 2.694522429652565
# 44.64812967581048
# 4.742291650084455
# 数据点 48.25 落在置信水平 90.0% 的正區間: [39.91, 49.39]
# 1419 =====================>Data Ready
# Stock_His 1423 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 45.05
# 29.072715736040614
# 3.9579720941305503
# 29.072715736040614
# 5.090787564770136
# 29.072715736040614
# 7.053918224526117
# 29.072715736040614
# 12.414718515021631
# 29.072715736040614
# 14.793049526687675
# 29.072715736040614
# 19.441362576177276
# 数据点 45.05 落在置信水平 99.0% 的正區間: [9.63, 48.51]
# 1423 =====================>Data Ready
# Stock_His 1432 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 18.25
# 17.606359102244387
# 0.9509943239270381
# 数据点 18.25 落在置信水平 40.0% 的正區間: [16.66, 18.56]
# 1432 =====================>Data Ready
# Stock_His 1434 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 20.45
# 25.150623441396508
# 1.1408234456742876
# 25.150623441396508
# 1.4673397570057047
# 25.150623441396508
# 2.033181412860943
# 25.150623441396508
# 3.5783481077055312
# 25.150623441396508
# 4.263864759959466
# 25.150623441396508
# 5.603668170285524
# 数据点 20.45 落在置信水平 99.0% 的負區間: [19.55, 30.75]
# 1434 =====================>Data Ready
# Stock_His 1435 2023-01-01 ===>外部抓取
# Stock_His 1435 2023-02-01 ===>外部抓取
# Stock_His 1435 2023-05-01 ===>外部抓取
# Stock_His 1435 2023-06-01 ===>外部抓取
# Stock_His 1435 2023-07-01 ===>外部抓取
# Stock_His 1435 2023-08-01 ===>外部抓取
# Stock_His 1435 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 47.0
# 45.53518518518518
# 3.4262535896572652
# 数据点 47.0 落在置信水平 40.0% 的正區間: [42.11, 48.96]
# 1435 =====================>Data Ready
# Stock_His 1436 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 162.5
# 91.21920199501247
# 21.48785895248261
# 91.21920199501247
# 27.637922286276982
# 91.21920199501247
# 38.29577275083341
# 91.21920199501247
# 67.39959606616675
# 91.21920199501247
# 80.31157222607484
# 数据点 162.5 落在置信水平 95.0% 的正區間: [10.91, 171.53]
# 1436 =====================>Data Ready
# Stock_His 1437 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 35.8
# 30.857356608478803
# 1.745433804002954
# 30.857356608478803
# 2.244996299424285
# 30.857356608478803
# 3.1107211033697295
# 30.857356608478803
# 5.47479083933768
# 数据点 35.8 落在置信水平 90.0% 的正區間: [25.38, 36.33]
# 1437 =====================>Data Ready
# Stock_His 1438 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 78.8
# 41.45548628428928
# 8.36557295427297
# 41.45548628428928
# 10.759892630608704
# 41.45548628428928
# 14.909167148565171
# 41.45548628428928
# 26.239758890212943
# 41.45548628428928
# 31.266601200952557
# 41.45548628428928
# 41.09127934546746
# 数据点 78.8 落在置信水平 99.0% 的正區間: [0.36, 82.55]
# 1438 =====================>Data Ready
# Stock_His 1439 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 33.65
# 24.80889724310777
# 1.6403302970917992
# 24.80889724310777
# 2.1098110042094698
# 24.80889724310777
# 2.9234050927385167
# 24.80889724310777
# 5.145119375716548
# 24.80889724310777
# 6.130787875182254
# 24.80889724310777
# 8.05722104451967
# 1439 =====================>Data Ready
# Stock_His 1440 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 16.05
# 16.24426433915212
# 0.6080710605737287
# 数据点 16.05 落在置信水平 40.0% 的負區間: [15.64, 16.85]
# 1440 =====================>Data Ready
# Stock_His 1441 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 16.4
# 11.757146464646464
# 1.5682919662219672
# 11.757146464646464
# 2.0171545048059545
# 11.757146464646464
# 2.7950180089233703
# 11.757146464646464
# 4.9191613399418115
# 数据点 16.4 落在置信水平 90.0% 的正區間: [6.84, 16.68]
# 1441 =====================>Data Ready
# Stock_His 1442 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 63.4
# 41.63790523690773
# 6.181626361842515
# 41.63790523690773
# 7.95087632365837
# 41.63790523690773
# 11.016926298109906
# 41.63790523690773
# 19.389512968299563
# 41.63790523690773
# 23.104029728209152
# 数据点 63.4 落在置信水平 95.0% 的正區間: [18.53, 64.74]
# 1442 =====================>Data Ready
# Stock_His 1443 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 32.95
# 29.444486215538845
# 0.9095684163938188
# 29.444486215538845
# 1.169896975865992
# 29.444486215538845
# 1.6210375101856622
# 29.444486215538845
# 2.8529852134199483
# 29.444486215538845
# 3.3995415610883355
# 29.444486215538845
# 4.4677549387412006
# 数据点 32.95 落在置信水平 99.0% 的正區間: [24.98, 33.91]
# 1443 =====================>Data Ready
# Stock_His 1444 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 9.27
# 10.236159600997507
# 0.26291520079521774
# 10.236159600997507
# 0.3381644445604296
# 10.236159600997507
# 0.4685688231972558
# 10.236159600997507
# 0.8246693340848399
# 10.236159600997507
# 0.9826541203891583
# 数据点 9.27 落在置信水平 95.0% 的負區間: [9.25, 11.22]
# 1444 =====================>Data Ready
# Stock_His 1445 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 19.25
# 19.92805486284289
# 1.240410049937716
# 数据点 19.25 落在置信水平 40.0% 的負區間: [18.69, 21.17]
# 1445 =====================>Data Ready
# Stock_His 1446 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 47.85
# 38.40822942643391
# 3.7858705265310535
# 38.40822942643391
# 4.869428621509212
# 38.40822942643391
# 6.747197925522523
# 38.40822942643391
# 11.874898509491485
# 数据点 47.85 落在置信水平 90.0% 的正區間: [26.53, 50.28]
# 1446 =====================>Data Ready
# Stock_His 1447 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 8.77
# 8.251720698254363
# 0.4224275713380384
# 8.251720698254363
# 0.5433310230693111
# 数据点 8.77 落在置信水平 50.0% 的正區間: [7.71, 8.80]
# 1447 =====================>Data Ready
# Stock_His 1449 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 19.3
# 18.34588528678304
# 1.3497547920714197
# 数据点 19.3 落在置信水平 40.0% 的正區間: [17.00, 19.70]
# 1449 =====================>Data Ready
# Stock_His 1451 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 20.1
# 20.275311720698255
# 0.726808320801123
# 数据点 20.1 落在置信水平 40.0% 的負區間: [19.55, 21.00]
# 1451 =====================>Data Ready
# Stock_His 1452 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 17.05
# 17.04152119700748
# 0.2792785657353925
# 数据点 17.05 落在置信水平 40.0% 的正區間: [16.76, 17.32]
# 1452 =====================>Data Ready
# Stock_His 1453 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 20.25
# 17.278678304239403
# 2.414596053403984
# 17.278678304239403
# 3.105680199423509
# 数据点 20.25 落在置信水平 50.0% 的正區間: [14.17, 20.38]
# 1453 =====================>Data Ready
# Stock_His 1454 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 18.8
# 16.197630922693268
# 0.9239035395208303
# 16.197630922693268
# 1.1883349700758703
# 16.197630922693268
# 1.6465856403572736
# 16.197630922693268
# 2.897949279428382
# 数据点 18.8 落在置信水平 90.0% 的正區間: [13.30, 19.10]
# 1454 =====================>Data Ready
# Stock_His 1455 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 11.25
# 11.454563591022445
# 0.8638348702323029
# 数据点 11.25 落在置信水平 40.0% 的負區間: [10.59, 12.32]
# 1455 =====================>Data Ready
# Stock_His 1456 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 20.65
# 17.663216957605986
# 1.1988402316017372
# 17.663216957605986
# 1.5419615899350934
# 17.663216957605986
# 2.1365792271580566
# 17.663216957605986
# 3.760325658154577
# 数据点 20.65 落在置信水平 90.0% 的正區間: [13.90, 21.42]
# 1456 =====================>Data Ready
# Stock_His 1457 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 20.65
# 19.19501246882793
# 0.8623279824373422
# 19.19501246882793
# 1.1091358062517316
# 19.19501246882793
# 1.5368453658008459
# 数据点 20.65 落在置信水平 65.0% 的正區間: [17.66, 20.73]
# 1457 =====================>Data Ready
# Stock_His 1459 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 10.45
# 9.716225
# 0.39856168231677536
# 9.716225
# 0.5126344521582119
# 9.716225
# 0.7103186802810637
# 9.716225
# 1.2501429972621314
# 数据点 10.45 落在置信水平 90.0% 的正區間: [8.47, 10.97]
# 1459 =====================>Data Ready
# Stock_His 1460 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 7.24
# 7.831895261845386
# 0.2860187307992314
# 7.831895261845386
# 0.3678804608560329
# 7.831895261845386
# 0.5097440532065511
# 7.831895261845386
# 0.8971367024446446
# 数据点 7.24 落在置信水平 90.0% 的負區間: [6.93, 8.73]
# 1460 =====================>Data Ready
# Stock_His 1463 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 25.1
# 17.380423940149623
# 1.6622997543640736
# 17.380423940149623
# 2.1380683635911337
# 17.380423940149623
# 2.9625591724920497
# 17.380423940149623
# 5.214029570502293
# 17.380423940149623
# 6.212899436803711
# 17.380423940149623
# 8.16513392876297
# 数据点 25.1 落在置信水平 99.0% 的正區間: [9.22, 25.55]
# 1463 =====================>Data Ready
# Stock_His 1464 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 13.3
# 14.026807980049876
# 0.44126777450155313
# 14.026807980049876
# 0.5675635011418056
# 14.026807980049876
# 0.786429697437356
# 数据点 13.3 落在置信水平 65.0% 的負區間: [13.24, 14.81]
# 1464 =====================>Data Ready
# Stock_His 1465 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 15.55
# 14.28625
# 0.4047705898592048
# 14.28625
# 0.5206204178386371
# 14.28625
# 0.72138422723954
# 14.28625
# 1.269618081368804
# 数据点 15.55 落在置信水平 90.0% 的正區間: [13.02, 15.56]
# 1465 =====================>Data Ready
# Stock_His 1466 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 12.35
# 12.12007481296758
# 0.5091621793533314
# 数据点 12.35 落在置信水平 40.0% 的正區間: [11.61, 12.63]
# 1466 =====================>Data Ready
# Stock_His 1467 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 10.5
# 11.485536159600999
# 0.23976075136777514
# 11.485536159600999
# 0.3083829351381866
# 11.485536159600999
# 0.42730284432961435
# 11.485536159600999
# 0.7520422500186624
# 11.485536159600999
# 0.8961136120183973
# 11.485536159600999
# 1.1776929164786223
# 数据点 10.5 落在置信水平 99.0% 的負區間: [10.31, 12.66]
# 1467 =====================>Data Ready
# Stock_His 1468 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 14.25
# 14.277306733167084
# 0.5108792120442239
# 数据点 14.25 落在置信水平 40.0% 的負區間: [13.77, 14.79]
# 1468 =====================>Data Ready
# Stock_His 1470 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 21.75
# 19.774137931034485
# 0.5164146651365072
# 19.774137931034485
# 0.6642182645603947
# 19.774137931034485
# 0.9203568724552023
# 19.774137931034485
# 1.6198049284395553
# 19.774137931034485
# 1.930116619316469
# 19.774137931034485
# 2.536603216445734
# 数据点 21.75 落在置信水平 99.0% 的正區間: [17.24, 22.31]
# 1470 =====================>Data Ready
# Stock_His 1471 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 13.9
# 14.38845386533666
# 2.0404188165649875
# 数据点 13.9 落在置信水平 40.0% 的負區間: [12.35, 16.43]
# 1471 =====================>Data Ready
# Stock_His 1472 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 61.0
# 51.644962216624684
# 9.31254388471989
# 51.644962216624684
# 11.977897134497704
# 数据点 61.0 落在置信水平 50.0% 的正區間: [39.67, 63.62]
# 1472 =====================>Data Ready
# Stock_His 1473 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 37.6
# 29.58304239401496
# 3.627655885293672
# 29.58304239401496
# 4.665931196812801
# 29.58304239401496
# 6.465226978110782
# 29.58304239401496
# 11.378636739776129
# 数据点 37.6 落在置信水平 90.0% 的正區間: [18.20, 40.96]
# 1473 =====================>Data Ready
# Stock_His 1474 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 12.3
# 12.478304239401494
# 0.4465811876347368
# 数据点 12.3 落在置信水平 40.0% 的負區間: [12.03, 12.92]
# 1474 =====================>Data Ready
# Stock_His 1475 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 59.9
# 55.71022443890274
# 3.7265679522065835
# 55.71022443890274
# 4.793152993296077
# 数据点 59.9 落在置信水平 50.0% 的正區間: [50.92, 60.50]
# 1475 =====================>Data Ready
# Stock_His 1476 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 534.0
# 516.6583541147132
# 17.098315634581443
# 516.6583541147132
# 21.992043031360225
# 数据点 534.0 落在置信水平 50.0% 的正區間: [494.67, 538.65]
# 1476 =====================>Data Ready
# Stock_His 1477 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 384.0
# 326.6109725685786
# 36.35333332057956
# 326.6109725685786
# 46.75806013912891
# 326.6109725685786
# 64.78909763224077
# 数据点 384.0 落在置信水平 65.0% 的正區間: [261.82, 391.40]
# 1477 =====================>Data Ready
# Stock_His 1503 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 219.5
# 160.45386533665837
# 39.74291073962566
# 160.45386533665837
# 51.117772174566106
# 160.45386533665837
# 70.83001994321623
# 数据点 219.5 落在置信水平 65.0% 的正區間: [89.62, 231.28]
# 1503 =====================>Data Ready
# Stock_His 1504 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 48.4
# 47.87032418952619
# 3.9336725614908787
# 数据点 48.4 落在置信水平 40.0% 的正區間: [43.94, 51.80]
# 1504 =====================>Data Ready
# Stock_His 1506 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 15.95
# 17.554738154613464
# 0.9332307157283075
# 17.554738154613464
# 1.2003316874660355
# 17.554738154613464
# 1.663208581769836
# 数据点 15.95 落在置信水平 65.0% 的負區間: [15.89, 19.22]
# 1506 =====================>Data Ready
# Stock_His 1512 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 7.67
# 11.098269720101781
# 1.3555578395475905
# 11.098269720101781
# 1.7435335138236894
# 11.098269720101781
# 2.4158821541374427
# 11.098269720101781
# 4.2518917790679875
# 数据点 7.67 落在置信水平 90.0% 的負區間: [6.85, 15.35]
# 1512 =====================>Data Ready
# Stock_His 1513 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 168.0
# 132.7770618556701
# 20.218951667651964
# 132.7770618556701
# 26.005839676083365
# 132.7770618556701
# 36.034319661011395
# 数据点 168.0 落在置信水平 65.0% 的正區間: [96.74, 168.81]
# 1513 =====================>Data Ready
# Stock_His 1514 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 133.0
# 80.54875311720699
# 20.498060741131418
# 80.54875311720699
# 26.364832859130512
# 80.54875311720699
# 36.53174928740187
# 80.54875311720699
# 64.29495917425449
# 数据点 133.0 落在置信水平 90.0% 的正區間: [16.25, 144.84]
# 1514 =====================>Data Ready
# Stock_His 1515 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 37.6
# 40.795137157107234
# 4.350833289561634
# 数据点 37.6 落在置信水平 40.0% 的負區間: [36.44, 45.15]
# 1515 =====================>Data Ready
# Stock_His 1516 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 20.4
# 19.63129675810474
# 1.187429878049068
# 数据点 20.4 落在置信水平 40.0% 的正區間: [18.44, 20.82]
# 1516 =====================>Data Ready
# Stock_His 1517 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 16.3
# 17.117206982543642
# 0.9668672305170928
# 数据点 16.3 落在置信水平 40.0% 的負區間: [16.15, 18.08]
# 1517 =====================>Data Ready
# Stock_His 1519 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 631.0
# 388.81097256857856
# 151.0837594143147
# 388.81097256857856
# 194.32560548006407
# 388.81097256857856
# 269.26225314801366
# 数据点 631.0 落在置信水平 65.0% 的正區間: [119.55, 658.07]
# 1519 =====================>Data Ready
# Stock_His 1521 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 39.75
# 38.6115
# 1.3276986611698511
# 数据点 39.75 落在置信水平 40.0% 的正區間: [37.28, 39.94]
# 1521 =====================>Data Ready
# Stock_His 1522 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 66.9
# 43.18441396508727
# 7.305266885438592
# 43.18441396508727
# 9.396115215887416
# 43.18441396508727
# 13.01948421886037
# 43.18441396508727
# 22.913964500740484
# 43.18441396508727
# 27.303672757628092
# 数据点 66.9 落在置信水平 95.0% 的正區間: [15.88, 70.49]
# 1522 =====================>Data Ready
# Stock_His 1524 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 30.6
# 28.826433915211968
# 2.685397219104806
# 数据点 30.6 落在置信水平 40.0% 的正區間: [26.14, 31.51]
# 1524 =====================>Data Ready
# Stock_His 1525 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 68.4
# 77.00947630922694
# 6.8633862841061735
# 77.00947630922694
# 8.827763490085172
# 数据点 68.4 落在置信水平 50.0% 的負區間: [68.18, 85.84]
# 1525 =====================>Data Ready
# Stock_His 1526 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 29.9
# 35.474314214463845
# 2.1664462483658338
# 35.474314214463845
# 2.7865071704974786
# 35.474314214463845
# 3.861051647247902
# 35.474314214463845
# 6.795353709358248
# 数据点 29.9 落在置信水平 90.0% 的負區間: [28.68, 42.27]
# 1526 =====================>Data Ready
# Stock_His 1527 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 48.1
# 41.85511221945138
# 0.9519140566774029
# 41.85511221945138
# 1.2243624076201929
# 41.85511221945138
# 1.6965061281096139
# 41.85511221945138
# 2.9858080812816636
# 41.85511221945138
# 3.55780976992268
# 41.85511221945138
# 4.675754623098345
# 1527 =====================>Data Ready
# Stock_His 1528 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 14.3
# 12.580399002493765
# 0.8382246266463038
# 12.580399002493765
# 1.0781338029500374
# 12.580399002493765
# 1.4938882411311756
# 12.580399002493765
# 2.629205700465891
# 数据点 14.3 落在置信水平 90.0% 的正區間: [9.95, 15.21]
# 1528 =====================>Data Ready
# Stock_His 1529 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 30.1
# 33.29675810473815
# 2.5464620790443266
# 33.29675810473815
# 3.2752877427765856
# 数据点 30.1 落在置信水平 50.0% 的負區間: [30.02, 36.57]
# 1529 =====================>Data Ready
# Stock_His 1530 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 34.85
# 31.813375
# 0.6003593623142938
# 31.813375
# 0.77218886424067
# 31.813375
# 1.0699635435463966
# 31.813375
# 1.8831089036839488
# 31.813375
# 2.2438626572673965
# 31.813375
# 2.9489354045884744
# 1530 =====================>Data Ready
# Stock_His 1531 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 14.3
# 14.014713216957604
# 0.32104083774635755
# 数据点 14.3 落在置信水平 40.0% 的正區間: [13.69, 14.34]
# 1531 =====================>Data Ready
# Stock_His 1532 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 38.4
# 38.672568578553616
# 2.7819500645412543
# 数据点 38.4 落在置信水平 40.0% 的負區間: [35.89, 41.45]
# 1532 =====================>Data Ready
# Stock_His 1533 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 40.1
# 52.280299251870325
# 3.088443492972862
# 52.280299251870325
# 3.9723902429320392
# 52.280299251870325
# 5.504239879004511
# 52.280299251870325
# 9.687323635168507
# 52.280299251870325
# 11.543158078268366
# 52.280299251870325
# 15.170281223549308
# 数据点 40.1 落在置信水平 99.0% 的負區間: [37.11, 67.45]
# 1533 =====================>Data Ready
# Stock_His 1535 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 60.7
# 58.53004987531172
# 4.814539027845736
# 数据点 60.7 落在置信水平 40.0% 的正區間: [53.72, 63.34]
# 1535 =====================>Data Ready
# Stock_His 1536 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 66.0
# 63.61895261845387
# 3.77617309662542
# 数据点 66.0 落在置信水平 40.0% 的正區間: [59.84, 67.40]
# 1536 =====================>Data Ready
# Stock_His 1537 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 144.0
# 138.74563591022445
# 2.7326820745300857
# 138.74563591022445
# 3.5148059644275906
# 138.74563591022445
# 4.8702000491486555
# 138.74563591022445
# 8.571429494575254
# 数据点 144.0 落在置信水平 90.0% 的正區間: [130.17, 147.32]
# 1537 =====================>Data Ready
# Stock_His 1538 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 17.65
# 14.33068783068783
# 2.681153871295577
# 14.33068783068783
# 3.448529818456226
# 数据点 17.65 落在置信水平 50.0% 的正區間: [10.88, 17.78]
# 1538 =====================>Data Ready
# Stock_His 1539 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 30.05
# 25.908977556109726
# 1.433556416288464
# 25.908977556109726
# 1.843856147510533
# 25.908977556109726
# 2.554891618801293
# 25.908977556109726
# 4.496544937751506
# 数据点 30.05 落在置信水平 90.0% 的正區間: [21.41, 30.41]
# 1539 =====================>Data Ready
# Stock_His 1540 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 44.9
# 19.75910224438903
# 3.1143474139657394
# 19.75910224438903
# 4.0057081531479515
# 19.75910224438903
# 5.5504059802383505
# 19.75910224438903
# 9.768574811254068
# 19.75910224438903
# 11.639974826105295
# 19.75910224438903
# 15.29751999840424
# 1540 =====================>Data Ready
# Stock_His 1541 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 33.85
# 33.1464824120603
# 1.1261955689244185
# 数据点 33.85 落在置信水平 40.0% 的正區間: [32.02, 34.27]
# 1541 =====================>Data Ready
# Stock_His 1558 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 112.5
# 106.77730673316708
# 3.474449570548852
# 106.77730673316708
# 4.468875537147135
# 106.77730673316708
# 6.19218189593509
# 数据点 112.5 落在置信水平 65.0% 的正區間: [100.59, 112.97]
# 1558 =====================>Data Ready
# Stock_His 1560 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 327.0
# 190.0648379052369
# 39.31281961326958
# 190.0648379052369
# 50.56458420211466
# 190.0648379052369
# 70.06350932559235
# 190.0648379052369
# 123.31001278516474
# 190.0648379052369
# 146.9329428661842
# 数据点 327.0 落在置信水平 95.0% 的正區間: [43.13, 337.00]
# 1560 =====================>Data Ready
# Stock_His 1563 2023-01-01 ===>外部抓取
# Stock_His 1563 2023-02-01 ===>外部抓取
# Stock_His 1563 2023-03-01 ===>外部抓取
# Stock_His 1563 2023-04-01 ===>外部抓取
# Stock_His 1563 2023-05-01 ===>外部抓取
# Stock_His 1563 2023-06-01 ===>外部抓取
# Stock_His 1563 2023-07-01 ===>外部抓取
# Stock_His 1563 2023-08-01 ===>外部抓取
# Stock_His 1563 2023-09-01 ===>外部抓取
# Stock_His 1563 2023-10-01 ===>外部抓取
# Stock_His 1563 2023-11-01 ===>外部抓取
# Stock_His 1563 2023-12-01 ===>外部抓取
# Stock_His 1563 2024-01-01 ===>外部抓取
# Stock_His 1563 2024-02-01 ===>外部抓取
# Stock_His 1563 2024-03-01 ===>外部抓取
# Stock_His 1563 2024-04-01 ===>外部抓取
# Stock_His 1563 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 62.7
# 72.34177215189874
# 3.42405835804348
# 72.34177215189874
# 4.404061801250296
# 72.34177215189874
# 6.102374417813975
# 72.34177215189874
# 10.740025367322573
# 数据点 62.7 落在置信水平 90.0% 的負區間: [61.60, 83.08]
# 1563 =====================>Data Ready
# Stock_His 1568 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 28.2
# 28.199501246882793
# 1.9281847277761255
# 数据点 28.2 落在置信水平 40.0% 的正區間: [26.27, 30.13]
# 1568 =====================>Data Ready
# Stock_His 1582 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 110.0
# 76.8067331670823
# 9.752377432352393
# 76.8067331670823
# 12.543615917148228
# 76.8067331670823
# 17.380737222615373
# 76.8067331670823
# 30.589660006559637
# 76.8067331670823
# 36.44982807576652
# 数据点 110.0 落在置信水平 95.0% 的正區間: [40.36, 113.26]
# 1582 =====================>Data Ready
# Stock_His 1583 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 64.0
# 67.51733668341708
# 2.085751463571202
# 67.51733668341708
# 2.6827166441358843
# 67.51733668341708
# 3.717236986722332
# 数据点 64.0 落在置信水平 65.0% 的負區間: [63.80, 71.23]
# 1583 =====================>Data Ready
# Stock_His 1587 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 48.2
# 32.345635910224445
# 8.480865766268682
# 32.345635910224445
# 10.908183522928418
# 32.345635910224445
# 15.114642591128154
# 32.345635910224445
# 26.601390496927568
# 数据点 48.2 落在置信水平 90.0% 的正區間: [5.74, 58.95]
# 1587 =====================>Data Ready
# Stock_His 1589 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 42.2
# 56.78354114713217
# 6.121355530366724
# 56.78354114713217
# 7.873355312368191
# 56.78354114713217
# 10.90951131224255
# 56.78354114713217
# 19.200465297006517
# 数据点 42.2 落在置信水平 90.0% 的負區間: [37.58, 75.98]
# 1589 =====================>Data Ready
# Stock_His 1590 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 864.0
# 1025.4812967581047
# 46.635985365164835
# 1025.4812967581047
# 59.9837211383715
# 1025.4812967581047
# 83.11489299631704
# 1025.4812967581047
# 146.28011951821833
# 1025.4812967581047
# 174.30351321976997
# 数据点 864.0 落在置信水平 95.0% 的負區間: [851.18, 1199.78]
# 1590 =====================>Data Ready
# Stock_His 1597 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 102.5
# 72.35536159600997
# 5.626588466883843
# 72.35536159600997
# 7.236980432926352
# 72.35536159600997
# 10.027734906801816
# 72.35536159600997
# 17.648561019370845
# 72.35536159600997
# 21.02955753031566
# 72.35536159600997
# 27.637523421108316
# 1597 =====================>Data Ready
# Stock_His 1598 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 28.7
# 35.71408977556109
# 2.963585355214764
# 35.71408977556109
# 3.8117963226257596
# 35.71408977556109
# 5.2817170636672515
# 35.71408977556109
# 9.295689081485005
# 数据点 28.7 落在置信水平 90.0% 的負區間: [26.42, 45.01]
# 1598 =====================>Data Ready
# Stock_His 1603 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 39.85
# 36.014463840399
# 3.437901941897353
# 36.014463840399
# 4.421867572200441
# 数据点 39.85 落在置信水平 50.0% 的正區間: [31.59, 40.44]
# 1603 =====================>Data Ready
# Stock_His 1604 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 28.1
# 28.138653366583544
# 0.5177149690931816
# 数据点 28.1 落在置信水平 40.0% 的負區間: [27.62, 28.66]
# 1604 =====================>Data Ready
# Stock_His 1605 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 34.8
# 40.38453865336658
# 3.2356041915577025
# 40.38453865336658
# 4.161669964102777
# 40.38453865336658
# 5.7665104329634405
# 数据点 34.8 落在置信水平 65.0% 的負區間: [34.62, 46.15]
# 1605 =====================>Data Ready
# Stock_His 1608 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 32.8
# 24.294264339152118
# 4.297017190690035
# 24.294264339152118
# 5.5268711248389115
# 24.294264339152118
# 7.658166139538901
# 24.294264339152118
# 13.478179635408576
# 数据点 32.8 落在置信水平 90.0% 的正區間: [10.82, 37.77]
# 1608 =====================>Data Ready
# Stock_His 1609 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 51.6
# 38.382793017456365
# 5.505626406826675
# 38.382793017456365
# 7.081397690930473
# 38.382793017456365
# 9.81215570118316
# 38.382793017456365
# 17.269147044008605
# 数据点 51.6 落在置信水平 90.0% 的正區間: [21.11, 55.65]
# 1609 =====================>Data Ready
# Stock_His 1611 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 17.5
# 17.048379052369075
# 0.7964832662368037
# 数据点 17.5 落在置信水平 40.0% 的正區間: [16.25, 17.84]
# 1611 =====================>Data Ready
# Stock_His 1612 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 36.1
# 27.748254364089775
# 3.393735797040505
# 27.748254364089775
# 4.365060587291551
# 27.748254364089775
# 6.048333393626265
# 27.748254364089775
# 10.644914525064552
# 数据点 36.1 落在置信水平 90.0% 的正區間: [17.10, 38.39]
# 1612 =====================>Data Ready
# Stock_His 1614 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 41.85
# 39.10897755610972
# 1.4747890814566538
# 39.10897755610972
# 1.8968900583387147
# 39.10897755610972
# 2.6283766867498506
# 39.10897755610972
# 4.625876807586142
# 数据点 41.85 落在置信水平 90.0% 的正區間: [34.48, 43.73]
# 1614 =====================>Data Ready
# Stock_His 1615 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 64.3
# 46.51047381546134
# 7.069713734573363
# 46.51047381546134
# 9.093144143138975
# 46.51047381546134
# 12.59968018178876
# 46.51047381546134
# 22.175119962737085
# 数据点 64.3 落在置信水平 90.0% 的正區間: [24.34, 68.69]
# 1615 =====================>Data Ready
# Stock_His 1616 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 20.3
# 14.49356608478803
# 3.197334626099227
# 14.49356608478803
# 4.112447224954598
# 14.49356608478803
# 5.698306216558641
# 14.49356608478803
# 10.028875504255783
# 数据点 20.3 落在置信水平 90.0% 的正區間: [4.46, 24.52]
# 1616 =====================>Data Ready
# Stock_His 1617 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 23.6
# 18.124064837905237
# 1.8989237470584122
# 18.124064837905237
# 2.442416764965907
# 18.124064837905237
# 3.384271669379521
# 18.124064837905237
# 5.956232949742151
# 数据点 23.6 落在置信水平 90.0% 的正區間: [12.17, 24.08]
# 1617 =====================>Data Ready
# Stock_His 1618 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 49.5
# 31.773441396508726
# 7.089497821645493
# 31.773441396508726
# 9.118590655153673
# 31.773441396508726
# 12.634939483530847
# 31.773441396508726
# 22.237175446261435
# 数据点 49.5 落在置信水平 90.0% 的正區間: [9.54, 54.01]
# 1618 =====================>Data Ready
# Stock_His 1626 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 16.05
# 17.013341645885287
# 0.6006967943160781
# 17.013341645885287
# 0.7726228730203647
# 17.013341645885287
# 1.070564916595604
# 数据点 16.05 落在置信水平 65.0% 的負區間: [15.94, 18.08]
# 1626 =====================>Data Ready
# Stock_His 1702 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 54.4
# 51.807107231920206
# 2.5604277589951674
# 51.807107231920206
# 3.293250555079566
# 数据点 54.4 落在置信水平 50.0% 的正區間: [48.51, 55.10]
# 1702 =====================>Data Ready
# Stock_His 1707 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 145.0
# 161.2930174563591
# 6.312675807068475
# 161.2930174563591
# 8.119433572234145
# 161.2930174563591
# 11.250483293462219
# 161.2930174563591
# 19.800567401058878
# 数据点 145.0 落在置信水平 90.0% 的負區間: [141.49, 181.09]
# 1707 =====================>Data Ready
# Stock_His 1708 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 39.45
# 35.14576059850374
# 2.1389495630403386
# 35.14576059850374
# 2.75114062914793
# 35.14576059850374
# 3.812046913227872
# 35.14576059850374
# 6.709106611022621
# 数据点 39.45 落在置信水平 90.0% 的正區間: [28.44, 41.85]
# 1708 =====================>Data Ready
# Stock_His 1709 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 23.25
# 22.48391521197007
# 1.1371812087982363
# 数据点 23.25 落在置信水平 40.0% 的正區間: [21.35, 23.62]
# 1709 =====================>Data Ready
# Stock_His 1710 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 17.9
# 19.24563591022444
# 0.8199324678167677
# 19.24563591022444
# 1.0546062255726485
# 19.24563591022444
# 1.4612878615769747
# 数据点 17.9 落在置信水平 65.0% 的負區間: [17.78, 20.71]
# 1710 =====================>Data Ready
# Stock_His 1711 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 25.65
# 19.921446384039903
# 0.6248296261811682
# 19.921446384039903
# 0.803662788775121
# 19.921446384039903
# 1.1135745736760636
# 19.921446384039903
# 1.9598632189420215
# 19.921446384039903
# 2.335321064932928
# 19.921446384039903
# 3.0691321267624696
# 1711 =====================>Data Ready
# Stock_His 1712 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 42.7
# 38.79376558603491
# 1.488785988663908
# 38.79376558603491
# 1.9148930354849154
# 38.79376558603491
# 2.653322046769611
# 38.79376558603491
# 4.669780013300156
# 数据点 42.7 落在置信水平 90.0% 的正區間: [34.12, 43.46]
# 1712 =====================>Data Ready
# Stock_His 1713 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 56.1
# 39.75325
# 5.265785980499891
# 39.75325
# 6.772912276977151
# 39.75325
# 9.384710859731781
# 39.75325
# 16.51685488262997
# 数据点 56.1 落在置信水平 90.0% 的正區間: [23.24, 56.27]
# 1713 =====================>Data Ready
# Stock_His 1714 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 8.88
# 9.036932668329177
# 0.258962713609515
# 数据点 8.88 落在置信水平 40.0% 的負區間: [8.78, 9.30]
# 1714 =====================>Data Ready
# Stock_His 1717 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 30.6
# 30.75236907730673
# 0.8435884248156609
# 数据点 30.6 落在置信水平 40.0% 的負區間: [29.91, 31.60]
# 1717 =====================>Data Ready
# Stock_His 1718 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 8.01
# 8.095910224438903
# 0.18385135855996684
# 数据点 8.01 落在置信水平 40.0% 的負區間: [7.91, 8.28]
# 1718 =====================>Data Ready
# Stock_His 1720 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 66.4
# 65.36234413965087
# 2.6588271384908615
# 数据点 66.4 落在置信水平 40.0% 的正區間: [62.70, 68.02]
# 1720 =====================>Data Ready
# Stock_His 1721 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 16.55
# 15.021197007481296
# 0.5841447613708046
# 15.021197007481296
# 0.7513334648372142
# 15.021197007481296
# 1.0410657983429095
# 15.021197007481296
# 1.8322495995354082
# 数据点 16.55 落在置信水平 90.0% 的正區間: [13.19, 16.85]
# 1721 =====================>Data Ready
# Stock_His 1722 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 58.2
# 61.880548628428926
# 1.7914530602252257
# 61.880548628428926
# 2.304186776705246
# 61.880548628428926
# 3.1927368585153526
# 61.880548628428926
# 5.619136503906006
# 数据点 58.2 落在置信水平 90.0% 的負區間: [56.26, 67.50]
# 1722 =====================>Data Ready
# Stock_His 1723 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 99.2
# 112.26783042394015
# 2.7056214385340325
# 112.26783042394015
# 3.4800002745573235
# 112.26783042394015
# 4.821972444486434
# 112.26783042394015
# 8.486550124347591
# 112.26783042394015
# 10.11234818963373
# 112.26783042394015
# 13.289878283483286
# 数据点 99.2 落在置信水平 99.0% 的負區間: [98.98, 125.56]
# 1723 =====================>Data Ready
# Stock_His 1725 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 41.7
# 27.770875
# 5.238773836825917
# 27.770875
# 6.738168958468873
# 27.770875
# 9.336569678335398
# 27.770875
# 16.432127615174746
# 数据点 41.7 落在置信水平 90.0% 的正區間: [11.34, 44.20]
# 1725 =====================>Data Ready
# Stock_His 1726 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 78.5
# 75.85826972010177
# 1.6557080963792272
# 75.85826972010177
# 2.12959010005051
# 75.85826972010177
# 2.9508114857263688
# 数据点 78.5 落在置信水平 65.0% 的正區間: [72.91, 78.81]
# 1726 =====================>Data Ready
# Stock_His 1727 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 35.0
# 30.31920199501247
# 2.0929045771949486
# 30.31920199501247
# 2.691917058140611
# 30.31920199501247
# 3.7299853026155843
# 30.31920199501247
# 6.564680241987232
# 数据点 35.0 落在置信水平 90.0% 的正區間: [23.75, 36.88]
# 1727 =====================>Data Ready
# Stock_His 1730 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 53.8
# 56.958354114713224
# 0.7893728098298831
# 56.958354114713224
# 1.0153000548459863
# 56.958354114713224
# 1.4068242819250005
# 56.958354114713224
# 2.4759753238236097
# 56.958354114713224
# 2.9503065694047588
# 56.958354114713224
# 3.8773600820573146
# 数据点 53.8 落在置信水平 99.0% 的負區間: [53.08, 60.84]
# 1730 =====================>Data Ready
# Stock_His 1731 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 23.05
# 22.622319201995015
# 1.070901969357587
# 数据点 23.05 落在置信水平 40.0% 的正區間: [21.55, 23.69]
# 1731 =====================>Data Ready
# Stock_His 1732 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 29.2
# 28.15411471321696
# 1.2724685986066822
# 数据点 29.2 落在置信水平 40.0% 的正區間: [26.88, 29.43]
# 1732 =====================>Data Ready
# Stock_His 1733 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 29.3
# 29.775062344139652
# 1.9272415574776114
# 数据点 29.3 落在置信水平 40.0% 的負區間: [27.85, 31.70]
# 1733 =====================>Data Ready
# Stock_His 1734 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 37.2
# 34.16309226932668
# 1.2199044845808098
# 34.16309226932668
# 1.5690546655244983
# 34.16309226932668
# 2.1741200471642035
# 34.16309226932668
# 3.8263965563936497
# 数据点 37.2 落在置信水平 90.0% 的正區間: [30.34, 37.99]
# 1734 =====================>Data Ready
# Stock_His 1735 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 26.25
# 16.90251256281407
# 0.5888748832310279
# 16.90251256281407
# 0.7574173999871313
# 16.90251256281407
# 1.0494958458522232
# 16.90251256281407
# 1.8470862709519413
# 16.90251256281407
# 2.2009390428945466
# 16.90251256281407
# 2.8925242130625417
# 1735 =====================>Data Ready
# Stock_His 1736 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 125.0
# 77.0
# 7.555125561898932
# 77.0
# 9.717486214172245
# 77.0
# 13.464783637230004
# 77.0
# 23.697680268062587
# 77.0
# 28.237527693349257
# 77.0
# 37.11040195943773
# 1736 =====================>Data Ready
# Stock_His 1737 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 35.45
# 33.908977556109726
# 0.3486747653016544
# 33.908977556109726
# 0.4484693467089059
# 33.908977556109726
# 0.6214099601765868
# 33.908977556109726
# 1.0936658878748762
# 33.908977556109726
# 1.3031832840515838
# 33.908977556109726
# 1.71267314982979
# 数据点 35.45 落在置信水平 99.0% 的正區間: [32.20, 35.62]
# 1737 =====================>Data Ready
# Stock_His 1752 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 45.5
# 55.15835411471322
# 4.110802888800767
# 55.15835411471322
# 5.287360226354802
# 55.15835411471322
# 7.326294052893312
# 55.15835411471322
# 12.894093116745447
# ...
# 35.39700748129676
# 9.279027164074629
# 数据点 27.95 落在置信水平 90.0% 的負區間: [26.12, 44.68]
# 8289 =====================>Data Ready
# Stock_His 8291 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 8.3
# 7.312279411764706
# 1.0408889125105183
# 数据点 8.3 落在置信水平 40.0% 的正區間: [6.27, 8.35]
# 8291 =====================>Data Ready
# Stock_His 8299 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 516.0
# 488.81296758104736
# 55.56721870773515
# 数据点 516.0 落在置信水平 40.0% 的正區間: [433.25, 544.38]
# 8299 =====================>Data Ready
# Stock_His 8342 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 90.1
# 65.97940379403795
# 5.03761952045526
# 65.97940379403795
# 6.479442047812236
# 65.97940379403795
# 8.978071421035084
# 65.97940379403795
# 15.801179706389174
# 65.97940379403795
# 18.828266923158665
# 65.97940379403795
# 24.744537174285746
# 数据点 90.1 落在置信水平 99.0% 的正區間: [41.23, 90.72]
# 8342 =====================>Data Ready
# Stock_His 8349 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 73.2
# 64.60399002493764
# 2.61461562781873
# 64.60399002493764
# 3.3629475924026613
# 64.60399002493764
# 4.6597814205288834
# 64.60399002493764
# 8.201098004829804
# 64.60399002493764
# 9.772211010009789
# 数据点 73.2 落在置信水平 95.0% 的正區間: [54.83, 74.38]
# 8349 =====================>Data Ready
# Stock_His 8354 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 17.85
# 15.14576059850374
# 0.5754580612133813
# 15.14576059850374
# 0.7401605348395832
# 15.14576059850374
# 1.0255843166411285
# 15.14576059850374
# 1.805002581437749
# 15.14576059850374
# 2.1507932339101608
# 15.14576059850374
# 2.8266214489041186
# 数据点 17.85 落在置信水平 99.0% 的正區間: [12.32, 17.97]
# 8354 =====================>Data Ready
# Stock_His 8358 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 64.0
# 62.48528678304239
# 2.2850903812199173
# 数据点 64.0 落在置信水平 40.0% 的正區間: [60.20, 64.77]
# 8358 =====================>Data Ready
# Stock_His 8383 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 44.85
# 40.52768079800499
# 1.3916901347039607
# 40.52768079800499
# 1.7900072722267437
# 40.52768079800499
# 2.48027731641649
# 40.52768079800499
# 4.365225643733993
# 数据点 44.85 落在置信水平 90.0% 的正區間: [36.16, 44.89]
# 8383 =====================>Data Ready
# Stock_His 8390 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 71.9
# 51.48079800498754
# 5.533206496004328
# 51.48079800498754
# 7.1168715072388435
# 51.48079800498754
# 9.861309077977504
# 51.48079800498754
# 17.355655749885415
# 51.48079800498754
# 20.680539374738235
# 数据点 71.9 落在置信水平 95.0% 的正區間: [30.80, 72.16]
# 8390 =====================>Data Ready
# Stock_His 8401 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 27.0
# 22.98379052369077
# 1.4963021426661578
# 22.98379052369077
# 1.9245603960472326
# 22.98379052369077
# 2.666717375092779
# 22.98379052369077
# 4.693355453963787
# 数据点 27.0 落在置信水平 90.0% 的正區間: [18.29, 27.68]
# 8401 =====================>Data Ready
# Stock_His 8403 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 30.7
# 33.858354114713215
# 1.404479415062521
# 33.858354114713215
# 1.8064569863387427
# 33.858354114713215
# 2.503070437654915
# 33.858354114713215
# 4.405340963368681
# 数据点 30.7 落在置信水平 90.0% 的負區間: [29.45, 38.26]
# 8403 =====================>Data Ready
# Stock_His 8409 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 22.6
# 23.58229426433915
# 1.271146542441316
# 数据点 22.6 落在置信水平 40.0% 的負區間: [22.31, 24.85]
# 8409 =====================>Data Ready
# Stock_His 8410 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 86.4
# 57.9748730964467
# 9.517940387908448
# 57.9748730964467
# 12.242080392846137
# 57.9748730964467
# 16.962922316148617
# 57.9748730964467
# 29.854316288350695
# 数据点 86.4 落在置信水平 90.0% 的正區間: [28.12, 87.83]
# 8410 =====================>Data Ready
# Stock_His 8415 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 33.7
# 34.89638403990025
# 0.7603139503383194
# 34.89638403990025
# 0.9779242277739786
# 34.89638403990025
# 1.3550354330709478
# 数据点 33.7 落在置信水平 65.0% 的負區間: [33.54, 36.25]
# 8415 =====================>Data Ready
# Stock_His 8416 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 159.5
# 142.74238578680203
# 7.783269791887011
# 142.74238578680203
# 10.010927850792095
# 142.74238578680203
# 13.871383457405567
# 142.74238578680203
# 24.41328571670346
# 数据点 159.5 落在置信水平 90.0% 的正區間: [118.33, 167.16]
# 8416 =====================>Data Ready
# Stock_His 8420 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 42.75
# 67.67237499999999
# 10.204124259378162
# 67.67237499999999
# 13.124657691762442
# 67.67237499999999
# 18.185842741361817
# 67.67237499999999
# 32.00662545356112
# 数据点 42.75 落在置信水平 90.0% 的負區間: [35.67, 99.68]
# 8420 =====================>Data Ready
# Stock_His 8421 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 14.8
# 14.234912718204487
# 0.7449331342121693
# 数据点 14.8 落在置信水平 40.0% 的正區間: [13.49, 14.98]
# 8421 =====================>Data Ready
# Stock_His 8423 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 24.4
# 21.913813813813814
# 1.0296608690370006
# 21.913813813813814
# 1.3243612191701013
# 21.913813813813814
# 1.8350668969981703
# 21.913813813813814
# 3.2296715466951653
# 数据点 24.4 落在置信水平 90.0% 的正區間: [18.68, 25.14]
# 8423 =====================>Data Ready
# Stock_His 8424 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 70.0
# 68.77390180878552
# 0.9757503821251694
# 68.77390180878552
# 1.2550209535354742
# 数据点 70.0 落在置信水平 50.0% 的正區間: [67.52, 70.03]
# 8424 =====================>Data Ready
# Stock_His 8426 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 46.5
# 55.55548628428928
# 6.489532511115102
# 55.55548628428928
# 8.346908624683847
# 55.55548628428928
# 11.56567822110058
# 数据点 46.5 落在置信水平 65.0% 的負區間: [43.99, 67.12]
# 8426 =====================>Data Ready
# Stock_His 8431 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 59.5
# 59.077556109725684
# 2.2269706770046027
# 数据点 59.5 落在置信水平 40.0% 的正區間: [56.85, 61.30]
# 8431 =====================>Data Ready
# Stock_His 8432 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 58.6
# 51.99513715710723
# 3.7803319730285727
# 51.99513715710723
# 4.862304872622994
# 51.99513715710723
# 6.7373270869821
# 数据点 58.6 落在置信水平 65.0% 的正區間: [45.26, 58.73]
# 8432 =====================>Data Ready
# Stock_His 8433 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 87.4
# 84.87605985037408
# 5.504427764223283
# 数据点 87.4 落在置信水平 40.0% 的正區間: [79.37, 90.38]
# 8433 =====================>Data Ready
# Stock_His 8435 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 72.5
# 64.83067331670823
# 2.5356883341637144
# 64.83067331670823
# 3.2614304327299686
# 64.83067331670823
# 4.519116791803668
# 64.83067331670823
# 7.953531799061818
# 数据点 72.5 落在置信水平 90.0% 的正區間: [56.88, 72.78]
# 8435 =====================>Data Ready
# Stock_His 8436 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 141.0
# 171.0211970074813
# 10.413644548559533
# 171.0211970074813
# 13.394145009349474
# 171.0211970074813
# 18.5592508784369
# 171.0211970074813
# 32.66381437544109
# 数据点 141.0 落在置信水平 90.0% 的負區間: [138.36, 203.69]
# 8436 =====================>Data Ready
# Stock_His 8437 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 29.75
# 66.462875
# 17.5562986377869
# 66.462875
# 22.581105844878262
# 66.462875
# 31.28892573546863
# 66.462875
# 55.067721694399836
# 数据点 29.75 落在置信水平 90.0% 的負區間: [11.40, 121.53]
# 8437 =====================>Data Ready
# Stock_His 8440 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 50.7
# 41.75349127182045
# 3.1779033553641614
# 41.75349127182045
# 4.087454509222102
# 41.75349127182045
# 5.663675705907229
# 41.75349127182045
# 9.967926677223184
# 数据点 50.7 落在置信水平 90.0% 的正區間: [31.79, 51.72]
# 8440 =====================>Data Ready
# Stock_His 8444 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 39.3
# 39.65193798449612
# 3.500614574195848
# 数据点 39.3 落在置信水平 40.0% 的負區間: [36.15, 43.15]
# 8444 =====================>Data Ready
# Stock_His 8446 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 113.5
# 103.4713216957606
# 5.269009251143832
# 103.4713216957606
# 6.7770580833956435
# 103.4713216957606
# 9.390455389252741
# 103.4713216957606
# 16.526965109986445
# 数据点 113.5 落在置信水平 90.0% 的正區間: [86.94, 120.00]
# 8446 =====================>Data Ready
# Stock_His 8450 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 23.75
# 24.616957605985043
# 0.7678415709499334
# 24.616957605985043
# 0.9876063368163189
# 数据点 23.75 落在置信水平 50.0% 的負區間: [23.63, 25.60]
# 8450 =====================>Data Ready
# Stock_His 8455 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 41.25
# 24.83855799373041
# 3.3703539260143707
# 24.83855799373041
# 4.334986565689069
# 24.83855799373041
# 6.006662102815661
# 24.83855799373041
# 10.57157410218121
# 24.83855799373041
# 12.596807497438691
# 24.83855799373041
# 16.555011285414757
# 数据点 41.25 落在置信水平 99.0% 的正區間: [8.28, 41.39]
# 8455 =====================>Data Ready
# Stock_His 8472 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 26.9
# 33.61141304347826
# 3.2543592481844352
# 33.61141304347826
# 4.185792925756175
# 33.61141304347826
# 5.799935791352782
# 33.61141304347826
# 10.20774099768945
# 数据点 26.9 落在置信水平 90.0% 的負區間: [23.40, 43.82]
# 8472 =====================>Data Ready
# Stock_His 8477 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 12.2
# 17.34650872817955
# 1.0439193313963169
# 17.34650872817955
# 1.3427006114511113
# 17.34650872817955
# 1.8604784019552802
# 17.34650872817955
# 3.2743951557651854
# 17.34650872817955
# 3.9016824787908764
# 17.34650872817955
# 5.127679968247634
# 8477 =====================>Data Ready
# Stock_His 8489 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 28.85
# 25.679250000000003
# 1.1606653683015273
# 25.679250000000003
# 1.4928606577522454
# 25.679250000000003
# 2.068543789426832
# 25.679250000000003
# 3.6405850003251925
# 数据点 28.85 落在置信水平 90.0% 的正區間: [22.04, 29.32]
# 8489 =====================>Data Ready
# Stock_His 8905 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 31.15
# 29.038029925187033
# 1.3799214988389559
# 29.038029925187033
# 1.7748703223718623
# 29.038029925187033
# 2.4593031930443026
# 数据点 31.15 落在置信水平 65.0% 的正區間: [26.58, 31.50]
# 8905 =====================>Data Ready
# Stock_His 8906 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 46.75
# 24.241153846153843
# 7.2658339095617785
# 24.241153846153843
# 9.34539608536771
# 24.241153846153843
# 12.94920656642385
# 24.241153846153843
# 22.790277601470464
# 数据点 46.75 落在置信水平 90.0% 的正區間: [1.45, 47.03]
# 8906 =====================>Data Ready
# Stock_His 8908 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 54.0
# 62.75960099750623
# 3.730327897505563
# 62.75960099750623
# 4.797989076602637
# 62.75960099750623
# 6.648209566382244
# 62.75960099750623
# 11.70068148912434
# 数据点 54.0 落在置信水平 90.0% 的負區間: [51.06, 74.46]
# 8908 =====================>Data Ready
# Stock_His 8916 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 58.8
# 55.927431421446386
# 1.7228209491545419
# 55.927431421446386
# 2.215911394950865
# 55.927431421446386
# 3.0704203571466016
# 数据点 58.8 落在置信水平 65.0% 的正區間: [52.86, 59.00]
# 8916 =====================>Data Ready
# Stock_His 8917 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 61.7
# 67.35492957746479
# 4.646693486916329
# 67.35492957746479
# 5.976628651720803
# 数据点 61.7 落在置信水平 50.0% 的負區間: [61.38, 73.33]
# 8917 =====================>Data Ready
# Stock_His 8921 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 22.05
# 16.062406015037595
# 1.2703602027847327
# 16.062406015037595
# 1.6339513693655854
# 16.062406015037595
# 2.26404248767307
# 16.062406015037595
# 3.9846577881754155
# 16.062406015037595
# 4.748012605848276
# 16.062406015037595
# 6.239946295050723
# 数据点 22.05 落在置信水平 99.0% 的正區間: [9.82, 22.30]
# 8921 =====================>Data Ready
# Stock_His 8923 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 19.7
# 20.258769633507853
# 0.4735735143593361
# 20.258769633507853
# 0.6091155017187141
# 数据点 19.7 落在置信水平 50.0% 的負區間: [19.65, 20.87]
# 8923 =====================>Data Ready
# Stock_His 8924 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 89.1
# 97.43640897755611
# 7.500179940581969
# 97.43640897755611
# 9.646814547195671
# 数据点 89.1 落在置信水平 50.0% 的負區間: [87.79, 107.08]
# 8924 =====================>Data Ready
# Stock_His 8927 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 63.6
# 53.395760598503735
# 4.404111510961692
# 53.395760598503735
# 5.66461702625771
# 53.395760598503735
# 7.849030187981221
# 53.395760598503735
# 13.814095556266594
# 数据点 63.6 落在置信水平 90.0% 的正區間: [39.58, 67.21]
# 8927 =====================>Data Ready
# Stock_His 8928 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 31.75
# 34.6213216957606
# 1.8880539974449841
# 34.6213216957606
# 2.428435972568138
# 34.6213216957606
# 3.3648995457084374
# 数据点 31.75 落在置信水平 65.0% 的負區間: [31.26, 37.99]
# 8928 =====================>Data Ready
# Stock_His 8929 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 23.55
# 21.02468513853904
# 0.6624521254848099
# 21.02468513853904
# 0.8520532642649755
# 21.02468513853904
# 1.1806255854514451
# 21.02468513853904
# 2.0778713118689405
# 21.02468513853904
# 2.4759363806249914
# 21.02468513853904
# 3.253931976935428
# 数据点 23.55 落在置信水平 99.0% 的正區間: [17.77, 24.28]
# 8929 =====================>Data Ready
# Stock_His 8930 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 35.05
# 30.35311720698254
# 4.480830053101176
# 30.35311720698254
# 5.763293265256502
# 数据点 35.05 落在置信水平 50.0% 的正區間: [24.59, 36.12]
# 8930 =====================>Data Ready
# Stock_His 8931 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 49.0
# 53.89351620947631
# 4.7571096016031635
# 53.89351620947631
# 6.118647081924375
# 数据点 49.0 落在置信水平 50.0% 的負區間: [47.77, 60.01]
# 8931 =====================>Data Ready
# Stock_His 8932 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 169.5
# 94.98047858942066
# 20.32473994277763
# 94.98047858942066
# 26.141905727763433
# 94.98047858942066
# 36.222856069076705
# 94.98047858942066
# 63.75131488541476
# 94.98047858942066
# 75.96437706987015
# 数据点 169.5 落在置信水平 95.0% 的正區間: [19.02, 170.94]
# 8932 =====================>Data Ready
# Stock_His 8933 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 9.1
# 11.00351620947631
# 1.0006717231955482
# 11.00351620947631
# 1.2870750585673463
# 11.00351620947631
# 1.7834022921699275
# 11.00351620947631
# 3.138743142690942
# 数据点 9.1 落在置信水平 90.0% 的負區間: [7.86, 14.14]
# 8933 =====================>Data Ready
# Stock_His 8935 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 16.95
# 12.591022443890274
# 1.000907256390232
# 12.591022443890274
# 1.2873780039722331
# 12.591022443890274
# 1.78382206064099
# 12.591022443890274
# 3.1394819246336647
# 12.591022443890274
# 3.740923448489933
# 12.591022443890274
# 4.916406789594584
# 数据点 16.95 落在置信水平 99.0% 的正區間: [7.67, 17.51]
# 8935 =====================>Data Ready
# Stock_His 8936 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 65.5
# 48.389276807980046
# 11.126556896675108
# 48.389276807980046
# 14.311100771099252
# 48.389276807980046
# 19.829806932209895
# 数据点 65.5 落在置信水平 65.0% 的正區間: [28.56, 68.22]
# 8936 =====================>Data Ready
# Stock_His 8937 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 66.4
# 22.606749999999998
# 4.40666056624807
# 22.606749999999998
# 5.667895649412493
# 22.606749999999998
# 7.853573127424014
# 22.606749999999998
# 13.822091015331738
# 22.606749999999998
# 16.470037295229876
# 22.606749999999998
# 21.645298092327984
# 8937 =====================>Data Ready
# Stock_His 8938 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 82.9
# 80.8425
# 5.817938585178124
# 数据点 82.9 落在置信水平 40.0% 的正區間: [75.02, 86.66]
# 8938 =====================>Data Ready
# Stock_His 8941 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 67.8
# 63.801534526854226
# 4.490210847449226
# 数据点 67.8 落在置信水平 40.0% 的正區間: [59.31, 68.29]
# 8941 =====================>Data Ready
# Stock_His 8942 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 62.0
# 70.41246882793018
# 2.1661355897102985
# 70.41246882793018
# 2.786107597892398
# 70.41246882793018
# 3.860497989794092
# 70.41246882793018
# 6.794379286176123
# 70.41246882793018
# 8.096002270360707
# 70.41246882793018
# 10.639950557299317
# 数据点 62.0 落在置信水平 99.0% 的負區間: [59.77, 81.05]
# 8942 =====================>Data Ready
# Stock_His 9949 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 25.1
# 18.612373737373737
# 2.0109912360621314
# 18.612373737373737
# 2.5865592111143236
# 18.612373737373737
# 3.583998924716289
# 18.612373737373737
# 6.307747891631118
# 18.612373737373737
# 7.51614519893094
# 数据点 25.1 落在置信水平 95.0% 的正區間: [11.10, 26.13]
# 9949 =====================>Data Ready
# Stock_His 9950 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 14.55
# 17.659263959390863
# 2.4129730503703875
# 17.659263959390863
# 3.1035926749376057
# 17.659263959390863
# 4.300412981824483
# 数据点 14.55 落在置信水平 65.0% 的負區間: [13.36, 21.96]
# 9950 =====================>Data Ready
# Stock_His 9951 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 66.5
# 72.74962593516209
# 1.8187216902515824
# 72.74962593516209
# 2.3392599908020193
# 72.74962593516209
# 3.241335151208225
# 72.74962593516209
# 5.704668275736714
# 72.74962593516209
# 6.797531513436022
# 数据点 66.5 落在置信水平 95.0% 的負區間: [65.95, 79.55]
# 9951 =====================>Data Ready
# Stock_His 9960 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 26.5
# 27.62437185929648
# 0.7640187003772335
# 27.62437185929648
# 0.982689318325439
# 27.62437185929648
# 1.3616380576461853
# 数据点 26.5 落在置信水平 65.0% 的負區間: [26.26, 28.99]
# 9960 =====================>Data Ready
# Stock_His 9962 2024-09-01 ===>外部抓取
# 【craw_stock】 success
# 15.5
# 18.148877805486283
# 0.8781211440790193
# 18.148877805486283
# 1.129449145755333
# 18.148877805486283
# 1.5649920197129132
# 18.148877805486283
# 2.754346560956374
# 数据点 15.5 落在置信水平 90.0% 的負區間: [15.39, 20.90]
# 9962 =====================>Data Ready
