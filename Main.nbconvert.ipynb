# %% [markdown]
# # 目的

# %% [markdown]
# #每日收盤後開始爬股價
#
# #可以視情況條種是否抓營收，大概都隔月的10 後營收才會公布

# %% [markdown]
# ## 【資料源】
# 來自 _BaseInfo  _CrawBase 會先去取基本相關資料 (股票號碼...等)
#
# ## 【輸出】
# 股票相關推薦圖表/數據

# %%
import pandas as pd

# %% [markdown]
# #  Update Base Info

# %%
 
#%run _BaseInfoETF.ipynb
# %run _CrawBase.ipynb
#%run _LineMsg.ipynb
# %run _genHtml.ipynb
# Out:
# C:\Users\user\anaconda3\lib\site-packages\mpl_finance.py:16: DeprecationWarning:
#
#   =================================================================
#
#    WARNING: `mpl_finance` is deprecated:
#
#     Please use `mplfinance` instead (no hyphen, no underscore).
#
#     To install: `pip install --upgrade mplfinance`
#
#    For more information, see: https://pypi.org/project/mplfinance/
#
#   =================================================================
#
#   __warnings.warn('\n\n  ================================================================='+

# %% [markdown]
# %run RunRealTimeStock.ipynb

# %%
def MainStock(stock_number, start_month,end_time=datetime.now().strftime("%Y-%m-%d"),updateRevenue=False):  
    strmsg ='【stock_number】'+stock_number+'\n' +'【start_month】'+start_month+'\n'+'【end_time】'+end_time+'\n' 
    try:
        #處理 Stock
        RowData_df_craw_stock,His_Stock ,isSuccess= craw_stock(stock_number,start_month,end_time)
        #data_final,df_final=DataCleaning(RowData_df_craw_stock)
        print("【craw_stock】 success")
        
        #處理 Revenue
        if(updateRevenue):
            RowData_df_craw_revenue,His_Stock=craw_revenue(stock_number)
            df_Revenue=RevenueDataCleaning(RowData_df_craw_revenue)
            print("【craw_revenue】 success")
            
        #處理相關指標轉成html 
        stock_data=data_process(RowData_df_craw_stock)
        
        level,interval_type, lower_bound, upper_bound=get_interval(stock_data.iloc[-1]['收盤價'],np.array(stock_data['收盤價']))
        stock_data['stock_number']=stock_number
        stock_data['level']=level
        stock_data['interval_type']=interval_type
        stock_data['lower_bound']=lower_bound
        stock_data['upper_bound']=upper_bound
        save_df_to_excel(stock_data)
        gen_html(stock_number,stock_data)

        #sendLineMessage('成功'+'\n'+strmsg )
    except:
        #sendLineMessage('失败'+'\n'+strmsg)
        print('MainStock Fail'+'\n'+strmsg)
        
    #return data_final,df_final,df_Revenue

# %% [markdown]
# # 清資料使用
# type_='Stock_His'
# strMonth = (datetime.now() - timedelta(days=2)).strftime('%Y-%m-01')
# df=get_DB()
# df[~((df['status'] != 'OK')& (df['status'] != '很抱歉，沒有符合條件的資料!'))].to_csv('BaseInfo/His_Stock.csv',index=False)
# DDD=df[((df['status'] != 'OK')& (df['status'] != '很抱歉，沒有符合條件的資料!'))]['stock_number'].unique()

# %% [markdown]
# start_month='2023-01-01'  #起始月份
# want_update_Stock=True
# want_update_Revenue=False
# file_path = 'D:\Project\Jupyter\Stock\Main\DailyResultLast.xlsx'
#
# stock_number=str(6763)
# if (want_update_Stock):
#     type_='Stock_His'
#     strMonth = (datetime.now() - timedelta(days=2)).strftime('%Y-%m-01')
#     delete_DB_stock_by_Month_Stock_number(strMonth,stock_number,type_)
# try:
#     if(want_update_Revenue):
#         MainStock(stock_number,start_month,want_update_Revenue)
#     else:
#         MainStock(stock_number,start_month)
# except Exception as error:
#     print("An exception occurred:", error)
#     print('Action Fail'+'\n')

# %%
start_month='2023-01-01'  #起始月份
want_update_Stock=True
want_update_Revenue=False
file_path = 'D:\Project\Jupyter\Stock\Main\DailyResultLast.xlsx'   

for code in _baseInfo.dropna()['公司代號']:#.iloc[::-1]:
#for code in DDD:
    stock_number=str(code)
    if (want_update_Stock):        
        type_='Stock_His'
        strMonth = (datetime.now() - timedelta(days=2)).strftime('%Y-%m-01')
        delete_DB_stock_by_Month_Stock_number(strMonth,stock_number,type_)
    try:
        if(want_update_Revenue):
            MainStock(stock_number,start_month,want_update_Revenue)
        else:
            MainStock(stock_number,start_month)
    except Exception as error:
        print("An exception occurred:", error)
        print('Action Fail'+'\n')
        
    print(stock_number,'=====================>Data Ready')
# Out:
# Stock_His 1101 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 32.45
# 1101 =====================>Data Ready
# Stock_His 1102 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 47.1
# 1102 =====================>Data Ready
# Stock_His 1103 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 17.5
# 1103 =====================>Data Ready
# Stock_His 1104 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 30.65
# 1104 =====================>Data Ready
# Stock_His 1108 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 14.45
# 1108 =====================>Data Ready
# Stock_His 1109 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 18.5
# 1109 =====================>Data Ready
# Stock_His 1110 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 21.65
# 1110 =====================>Data Ready
# Stock_His 1201 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 18.0
# 1201 =====================>Data Ready
# Stock_His 1203 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# nan
# 1203 =====================>Data Ready
# Stock_His 1210 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 51.5
# 1210 =====================>Data Ready
# Stock_His 1213 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 12.3
# 1213 =====================>Data Ready
# Stock_His 1215 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 97.3
# 1215 =====================>Data Ready
# Stock_His 1216 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 88.7
# 1216 =====================>Data Ready
# Stock_His 1217 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 11.9
# 1217 =====================>Data Ready
# Stock_His 1218 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 20.1
# 1218 =====================>Data Ready
# Stock_His 1219 2024-10-01 ===>外部抓取
# Stock_His 1219 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 17.25
# 1219 =====================>Data Ready
# Stock_His 1220 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 16.3
# 1220 =====================>Data Ready
# Stock_His 1225 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 89.7
# 1225 =====================>Data Ready
# Stock_His 1227 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 37.65
# 1227 =====================>Data Ready
# Stock_His 1229 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 60.2
# 1229 =====================>Data Ready
# Stock_His 1231 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 117.0
# 1231 =====================>Data Ready
# Stock_His 1232 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 151.5
# 1232 =====================>Data Ready
# Stock_His 1233 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 32.65
# 1233 =====================>Data Ready
# Stock_His 1234 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 41.45
# 1234 =====================>Data Ready
# Stock_His 1235 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 158.5
# 1235 =====================>Data Ready
# Stock_His 1236 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 23.05
# 1236 =====================>Data Ready
# Stock_His 1256 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 141.5
# 1256 =====================>Data Ready
# Stock_His 1301 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 46.8
# 1301 =====================>Data Ready
# Stock_His 1303 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 41.8
# 1303 =====================>Data Ready
# Stock_His 1304 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 14.15
# 1304 =====================>Data Ready
# Stock_His 1305 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 16.05
# 1305 =====================>Data Ready
# Stock_His 1307 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 47.1
# 1307 =====================>Data Ready
# Stock_His 1308 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 16.7
# 1308 =====================>Data Ready
# Stock_His 1309 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 18.6
# 1309 =====================>Data Ready
# Stock_His 1310 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 12.15
# 1310 =====================>Data Ready
# Stock_His 1312 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 12.1
# 1312 =====================>Data Ready
# Stock_His 1313 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 11.15
# 1313 =====================>Data Ready
# Stock_His 1314 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 8.11
# 1314 =====================>Data Ready
# Stock_His 1315 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# nan
# 1315 =====================>Data Ready
# Stock_His 1316 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 14.8
# 1316 =====================>Data Ready
# Stock_His 1319 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 109.0
# 1319 =====================>Data Ready
# Stock_His 1321 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 33.95
# 1321 =====================>Data Ready
# Stock_His 1323 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 24.1
# 1323 =====================>Data Ready
# Stock_His 1324 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 12.9
# 1324 =====================>Data Ready
# Stock_His 1325 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 27.8
# 1325 =====================>Data Ready
# Stock_His 1326 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 38.4
# 1326 =====================>Data Ready
# Stock_His 1337 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 7.07
# 1337 =====================>Data Ready
# Stock_His 1338 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 30.7
# 1338 =====================>Data Ready
# Stock_His 1339 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 55.8
# 1339 =====================>Data Ready
# Stock_His 1340 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 10.25
# 1340 =====================>Data Ready
# Stock_His 1341 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 67.7
# 1341 =====================>Data Ready
# Stock_His 1342 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 95.4
# 1342 =====================>Data Ready
# Stock_His 1402 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 37.45
# 1402 =====================>Data Ready
# Stock_His 1409 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 15.55
# 1409 =====================>Data Ready
# Stock_His 1410 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 37.0
# 1410 =====================>Data Ready
# Stock_His 1413 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 9.65
# 1413 =====================>Data Ready
# Stock_His 1414 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 22.95
# 1414 =====================>Data Ready
# Stock_His 1416 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 13.75
# 1416 =====================>Data Ready
# Stock_His 1417 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 10.2
# 1417 =====================>Data Ready
# Stock_His 1418 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 30.2
# 1418 =====================>Data Ready
# Stock_His 1419 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 46.65
# 1419 =====================>Data Ready
# Stock_His 1423 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 38.95
# 1423 =====================>Data Ready
# Stock_His 1432 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 19.45
# 1432 =====================>Data Ready
# Stock_His 1434 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 19.6
# 1434 =====================>Data Ready
# Stock_His 1435 2023-01-01 ===>外部抓取
# Stock_His 1435 2023-02-01 ===>外部抓取
# Stock_His 1435 2023-05-01 ===>外部抓取
# Stock_His 1435 2023-06-01 ===>外部抓取
# Stock_His 1435 2023-07-01 ===>外部抓取
# Stock_His 1435 2023-08-01 ===>外部抓取
# Stock_His 1435 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 47.0
# 1435 =====================>Data Ready
# Stock_His 1436 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 133.5
# 1436 =====================>Data Ready
# Stock_His 1437 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 33.95
# 1437 =====================>Data Ready
# Stock_His 1438 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 61.3
# 1438 =====================>Data Ready
# Stock_His 1439 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 30.85
# 1439 =====================>Data Ready
# Stock_His 1440 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 15.45
# 1440 =====================>Data Ready
# Stock_His 1441 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 15.65
# 1441 =====================>Data Ready
# Stock_His 1442 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 66.5
# 1442 =====================>Data Ready
# Stock_His 1443 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 33.9
# 1443 =====================>Data Ready
# Stock_His 1444 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 9.09
# 1444 =====================>Data Ready
# Stock_His 1445 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 18.45
# 1445 =====================>Data Ready
# Stock_His 1446 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 43.5
# 1446 =====================>Data Ready
# Stock_His 1447 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 7.89
# 1447 =====================>Data Ready
# Stock_His 1449 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 22.6
# 1449 =====================>Data Ready
# Stock_His 1451 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 19.95
# 1451 =====================>Data Ready
# Stock_His 1452 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 16.65
# 1452 =====================>Data Ready
# Stock_His 1453 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 16.1
# 1453 =====================>Data Ready
# Stock_His 1454 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 16.7
# 1454 =====================>Data Ready
# Stock_His 1455 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 10.3
# 1455 =====================>Data Ready
# Stock_His 1456 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 17.8
# 1456 =====================>Data Ready
# Stock_His 1457 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 19.45
# 1457 =====================>Data Ready
# Stock_His 1459 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 9.92
# 1459 =====================>Data Ready
# Stock_His 1460 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 7.11
# 1460 =====================>Data Ready
# Stock_His 1463 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 24.55
# 1463 =====================>Data Ready
# Stock_His 1464 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 16.2
# 1464 =====================>Data Ready
# Stock_His 1465 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 15.15
# 1465 =====================>Data Ready
# Stock_His 1466 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 12.85
# 1466 =====================>Data Ready
# Stock_His 1467 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 10.5
# 1467 =====================>Data Ready
# Stock_His 1468 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 14.4
# 1468 =====================>Data Ready
# Stock_His 1470 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 20.05
# 1470 =====================>Data Ready
# Stock_His 1471 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 12.6
# 1471 =====================>Data Ready
# Stock_His 1472 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 59.8
# 1472 =====================>Data Ready
# Stock_His 1473 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 36.5
# 1473 =====================>Data Ready
# Stock_His 1474 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 13.8
# 1474 =====================>Data Ready
# Stock_His 1475 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 64.7
# 1475 =====================>Data Ready
# Stock_His 1476 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 529.0
# 1476 =====================>Data Ready
# Stock_His 1477 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 329.0
# 1477 =====================>Data Ready
# Stock_His 1503 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 206.5
# 1503 =====================>Data Ready
# Stock_His 1504 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 49.9
# 1504 =====================>Data Ready
# Stock_His 1506 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 13.4
# 1506 =====================>Data Ready
# Stock_His 1512 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 7.45
# 1512 =====================>Data Ready
# Stock_His 1513 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 160.5
# 1513 =====================>Data Ready
# Stock_His 1514 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 112.0
# 1514 =====================>Data Ready
# Stock_His 1515 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 34.05
# 1515 =====================>Data Ready
# Stock_His 1516 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 19.1
# 1516 =====================>Data Ready
# Stock_His 1517 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 14.8
# 1517 =====================>Data Ready
# Stock_His 1519 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 560.0
# 1519 =====================>Data Ready
# Stock_His 1521 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 37.0
# 1521 =====================>Data Ready
# Stock_His 1522 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 59.7
# 1522 =====================>Data Ready
# Stock_His 1524 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 35.05
# 1524 =====================>Data Ready
# Stock_His 1525 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 68.0
# 1525 =====================>Data Ready
# Stock_His 1526 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 27.45
# 1526 =====================>Data Ready
# Stock_His 1527 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 42.85
# 1527 =====================>Data Ready
# Stock_His 1528 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 20.75
# 1528 =====================>Data Ready
# Stock_His 1529 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 26.95
# 1529 =====================>Data Ready
# Stock_His 1530 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 32.65
# 1530 =====================>Data Ready
# Stock_His 1531 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 16.15
# 1531 =====================>Data Ready
# Stock_His 1532 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 37.85
# 1532 =====================>Data Ready
# Stock_His 1533 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 43.65
# 1533 =====================>Data Ready
# Stock_His 1535 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 63.2
# 1535 =====================>Data Ready
# Stock_His 1536 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 55.8
# 1536 =====================>Data Ready
# Stock_His 1537 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 147.5
# 1537 =====================>Data Ready
# Stock_His 1538 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 17.9
# 1538 =====================>Data Ready
# Stock_His 1539 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 28.0
# 1539 =====================>Data Ready
# Stock_His 1540 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 40.0
# 1540 =====================>Data Ready
# Stock_His 1541 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 30.0
# 1541 =====================>Data Ready
# Stock_His 1558 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 106.0
# 1558 =====================>Data Ready
# Stock_His 1560 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 301.0
# 1560 =====================>Data Ready
# Stock_His 1563 2023-01-01 ===>外部抓取
# Stock_His 1563 2023-02-01 ===>外部抓取
# Stock_His 1563 2023-03-01 ===>外部抓取
# Stock_His 1563 2023-04-01 ===>外部抓取
# Stock_His 1563 2023-05-01 ===>外部抓取
# Stock_His 1563 2023-06-01 ===>外部抓取
# Stock_His 1563 2023-07-01 ===>外部抓取
# Stock_His 1563 2023-08-01 ===>外部抓取
# Stock_His 1563 2023-09-01 ===>外部抓取
# Stock_His 1563 2023-10-01 ===>外部抓取
# Stock_His 1563 2023-11-01 ===>外部抓取
# Stock_His 1563 2023-12-01 ===>外部抓取
# Stock_His 1563 2024-01-01 ===>外部抓取
# Stock_His 1563 2024-02-01 ===>外部抓取
# Stock_His 1563 2024-03-01 ===>外部抓取
# Stock_His 1563 2024-04-01 ===>外部抓取
# Stock_His 1563 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 55.9
# 1563 =====================>Data Ready
# Stock_His 1568 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 28.9
# 1568 =====================>Data Ready
# Stock_His 1582 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 101.5
# 1582 =====================>Data Ready
# Stock_His 1583 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 62.7
# 1583 =====================>Data Ready
# Stock_His 1587 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 39.35
# 1587 =====================>Data Ready
# Stock_His 1589 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 38.55
# 1589 =====================>Data Ready
# Stock_His 1590 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 897.0
# 1590 =====================>Data Ready
# Stock_His 1597 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 93.4
# 1597 =====================>Data Ready
# Stock_His 1598 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 27.95
# 1598 =====================>Data Ready
# Stock_His 1603 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 34.55
# 1603 =====================>Data Ready
# Stock_His 1604 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 28.3
# 1604 =====================>Data Ready
# Stock_His 1605 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 29.6
# 1605 =====================>Data Ready
# Stock_His 1608 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 29.55
# 1608 =====================>Data Ready
# Stock_His 1609 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 46.0
# 1609 =====================>Data Ready
# Stock_His 1611 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 16.25
# 1611 =====================>Data Ready
# Stock_His 1612 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 34.2
# 1612 =====================>Data Ready
# Stock_His 1614 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 39.8
# 1614 =====================>Data Ready
# Stock_His 1615 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 57.8
# 1615 =====================>Data Ready
# Stock_His 1616 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 21.2
# 1616 =====================>Data Ready
# Stock_His 1617 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 20.0
# 1617 =====================>Data Ready
# Stock_His 1618 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 40.6
# 1618 =====================>Data Ready
# Stock_His 1626 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 15.25
# 1626 =====================>Data Ready
# Stock_His 1702 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 55.2
# 1702 =====================>Data Ready
# Stock_His 1707 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 154.0
# 1707 =====================>Data Ready
# Stock_His 1708 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 39.75
# 1708 =====================>Data Ready
# Stock_His 1709 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 22.65
# 1709 =====================>Data Ready
# Stock_His 1710 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 17.75
# 1710 =====================>Data Ready
# Stock_His 1711 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 24.5
# 1711 =====================>Data Ready
# Stock_His 1712 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 43.2
# 1712 =====================>Data Ready
# Stock_His 1713 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 50.3
# 1713 =====================>Data Ready
# Stock_His 1714 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 8.36
# 1714 =====================>Data Ready
# Stock_His 1717 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 31.15
# 1717 =====================>Data Ready
# Stock_His 1718 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 7.77
# 1718 =====================>Data Ready
# Stock_His 1720 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 63.3
# 1720 =====================>Data Ready
# Stock_His 1721 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 21.05
# 1721 =====================>Data Ready
# Stock_His 1722 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 57.3
# 1722 =====================>Data Ready
# Stock_His 1723 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 97.4
# 1723 =====================>Data Ready
# Stock_His 1725 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 39.05
# 1725 =====================>Data Ready
# Stock_His 1726 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 77.8
# 1726 =====================>Data Ready
# Stock_His 1727 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 35.95
# 1727 =====================>Data Ready
# Stock_His 1730 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 52.8
# 1730 =====================>Data Ready
# Stock_His 1731 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 23.5
# 1731 =====================>Data Ready
# Stock_His 1732 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 28.45
# 1732 =====================>Data Ready
# Stock_His 1733 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 29.05
# 1733 =====================>Data Ready
# Stock_His 1734 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 30.65
# 1734 =====================>Data Ready
# Stock_His 1735 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 23.35
# 1735 =====================>Data Ready
# Stock_His 1736 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 173.0
# 1736 =====================>Data Ready
# Stock_His 1737 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 33.3
# 1737 =====================>Data Ready
# Stock_His 1752 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 42.9
# 1752 =====================>Data Ready
# Stock_His 1760 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 87.2
# 1760 =====================>Data Ready
# Stock_His 1762 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 42.25
# 1762 =====================>Data Ready
# Stock_His 1773 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 168.5
# 1773 =====================>Data Ready
# Stock_His 1776 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 19.85
# 1776 =====================>Data Ready
# Stock_His 1783 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 42.1
# 1783 =====================>Data Ready
# Stock_His 1786 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 103.0
# 1786 =====================>Data Ready
# Stock_His 1789 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 24.05
# 1789 =====================>Data Ready
# Stock_His 1795 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 254.5
# 1795 =====================>Data Ready
# Stock_His 1802 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 19.5
# 1802 =====================>Data Ready
# Stock_His 1805 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 18.85
# 1805 =====================>Data Ready
# Stock_His 1806 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 10.3
# 1806 =====================>Data Ready
# Stock_His 1808 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 44.65
# 1808 =====================>Data Ready
# Stock_His 1809 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 20.85
# 1809 =====================>Data Ready
# Stock_His 1810 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 17.1
# 1810 =====================>Data Ready
# Stock_His 1817 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 40.2
# 1817 =====================>Data Ready
# Stock_His 1903 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 54.3
# 1903 =====================>Data Ready
# Stock_His 1904 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 23.95
# 1904 =====================>Data Ready
# Stock_His 1905 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 18.7
# 1905 =====================>Data Ready
# Stock_His 1906 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 15.2
# 1906 =====================>Data Ready
# Stock_His 1907 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 31.1
# 1907 =====================>Data Ready
# Stock_His 1909 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 13.4
# 1909 =====================>Data Ready
# Stock_His 2002 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 22.7
# 2002 =====================>Data Ready
# Stock_His 2006 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 74.3
# 2006 =====================>Data Ready
# Stock_His 2007 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 10.6
# 2007 =====================>Data Ready
# Stock_His 2008 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 31.9
# 2008 =====================>Data Ready
# Stock_His 2009 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 41.0
# 2009 =====================>Data Ready
# Stock_His 2010 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 18.4
# 2010 =====================>Data Ready
# Stock_His 2012 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 25.95
# 2012 =====================>Data Ready
# Stock_His 2013 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 53.3
# 2013 =====================>Data Ready
# Stock_His 2014 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 20.55
# 2014 =====================>Data Ready
# Stock_His 2015 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 80.7
# 2015 =====================>Data Ready
# Stock_His 2017 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 12.0
# 2017 =====================>Data Ready
# Stock_His 2020 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 27.6
# 2020 =====================>Data Ready
# Stock_His 2022 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 9.75
# 2022 =====================>Data Ready
# Stock_His 2023 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 15.2
# 2023 =====================>Data Ready
# Stock_His 2024 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 20.1
# 2024 =====================>Data Ready
# Stock_His 2025 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 10.9
# 2025 =====================>Data Ready
# Stock_His 2027 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 32.55
# 2027 =====================>Data Ready
# Stock_His 2028 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 23.15
# 2028 =====================>Data Ready
# Stock_His 2029 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 26.15
# 2029 =====================>Data Ready
# Stock_His 2030 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 18.5
# 2030 =====================>Data Ready
# Stock_His 2031 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 55.1
# 2031 =====================>Data Ready
# Stock_His 2032 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 15.0
# 2032 =====================>Data Ready
# Stock_His 2033 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 25.2
# 2033 =====================>Data Ready
# Stock_His 2034 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 21.9
# 2034 =====================>Data Ready
# Stock_His 2038 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 18.4
# 2038 =====================>Data Ready
# Stock_His 2049 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 233.0
# 2049 =====================>Data Ready
# Stock_His 2059 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 1275.0
# 2059 =====================>Data Ready
# Stock_His 2062 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 33.05
# 2062 =====================>Data Ready
# Stock_His 2069 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 16.65
# 2069 =====================>Data Ready
# Stock_His 2101 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 48.6
# 2101 =====================>Data Ready
# Stock_His 2102 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 21.85
# 2102 =====================>Data Ready
# Stock_His 2103 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 24.9
# 2103 =====================>Data Ready
# Stock_His 2104 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 15.15
# 2104 =====================>Data Ready
# Stock_His 2105 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 46.35
# 2105 =====================>Data Ready
# Stock_His 2106 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 29.9
# 2106 =====================>Data Ready
# Stock_His 2107 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 25.6
# 2107 =====================>Data Ready
# Stock_His 2108 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 36.15
# 2108 =====================>Data Ready
# Stock_His 2109 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 18.45
# 2109 =====================>Data Ready
# Stock_His 2114 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 94.0
# 2114 =====================>Data Ready
# Stock_His 2115 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 32.55
# 2115 =====================>Data Ready
# Stock_His 2201 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 57.2
# 2201 =====================>Data Ready
# Stock_His 2204 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 70.2
# 2204 =====================>Data Ready
# Stock_His 2206 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 70.4
# 2206 =====================>Data Ready
# Stock_His 2207 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 647.0
# 2207 =====================>Data Ready
# Stock_His 2208 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 17.55
# 2208 =====================>Data Ready
# Stock_His 2211 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 103.5
# 2211 =====================>Data Ready
# Stock_His 2227 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 109.5
# 2227 =====================>Data Ready
# Stock_His 2228 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 109.0
# 2228 =====================>Data Ready
# Stock_His 2231 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 97.4
# 2231 =====================>Data Ready
# Stock_His 2233 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 156.5
# 2233 =====================>Data Ready
# Stock_His 2236 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 118.0
# 2236 =====================>Data Ready
# Stock_His 2239 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 43.4
# 2239 =====================>Data Ready
# Stock_His 2241 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 31.8
# 2241 =====================>Data Ready
# Stock_His 2243 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 20.5
# 2243 =====================>Data Ready
# Stock_His 2247 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 291.5
# 2247 =====================>Data Ready
# Stock_His 2250 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 91.2
# 2250 =====================>Data Ready
# Stock_His 2254 2023-01-01 ===>外部抓取
# Stock_His 2254 2023-02-01 ===>外部抓取
# Stock_His 2254 2023-03-01 ===>外部抓取
# Stock_His 2254 2023-04-01 ===>外部抓取
# Stock_His 2254 2023-05-01 ===>外部抓取
# Stock_His 2254 2023-06-01 ===>外部抓取
# Stock_His 2254 2023-07-01 ===>外部抓取
# Stock_His 2254 2023-08-01 ===>外部抓取
# Stock_His 2254 2023-09-01 ===>外部抓取
# Stock_His 2254 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 75.4
# 2254 =====================>Data Ready
# Stock_His 2258 2023-01-01 ===>外部抓取
# Stock_His 2258 2023-02-01 ===>外部抓取
# Stock_His 2258 2023-03-01 ===>外部抓取
# Stock_His 2258 2023-04-01 ===>外部抓取
# Stock_His 2258 2023-05-01 ===>外部抓取
# Stock_His 2258 2023-06-01 ===>外部抓取
# Stock_His 2258 2023-07-01 ===>外部抓取
# Stock_His 2258 2023-08-01 ===>外部抓取
# Stock_His 2258 2023-09-01 ===>外部抓取
# Stock_His 2258 2023-10-01 ===>外部抓取
# Stock_His 2258 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 42.6
# 2258 =====================>Data Ready
# Stock_His 2301 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 102.0
# 2301 =====================>Data Ready
# Stock_His 2302 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 18.3
# 2302 =====================>Data Ready
# Stock_His 2303 2024-10-01 ===>外部抓取
# Stock_His 2303 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 46.0
# 2303 =====================>Data Ready
# Stock_His 2305 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 18.15
# 2305 =====================>Data Ready
# Stock_His 2308 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 395.0
# 2308 =====================>Data Ready
# Stock_His 2312 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 25.75
# 2312 =====================>Data Ready
# Stock_His 2313 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 62.0
# 2313 =====================>Data Ready
# Stock_His 2314 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 29.5
# 2314 =====================>Data Ready
# Stock_His 2316 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 51.9
# 2316 =====================>Data Ready
# Stock_His 2317 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 214.0
# 2317 =====================>Data Ready
# Stock_His 2321 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 14.35
# 2321 =====================>Data Ready
# Stock_His 2323 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 11.6
# 2323 =====================>Data Ready
# Stock_His 2324 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 36.05
# 2324 =====================>Data Ready
# Stock_His 2327 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 543.0
# 2327 =====================>Data Ready
# Stock_His 2328 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 39.0
# 2328 =====================>Data Ready
# Stock_His 2329 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 37.15
# 2329 =====================>Data Ready
# Stock_His 2330 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 1040.0
# 2330 =====================>Data Ready
# Stock_His 2331 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 23.95
# 2331 =====================>Data Ready
# Stock_His 2332 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 19.45
# 2332 =====================>Data Ready
# Stock_His 2337 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 22.2
# 2337 =====================>Data Ready
# Stock_His 2338 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 55.7
# 2338 =====================>Data Ready
# Stock_His 2340 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 35.35
# 2340 =====================>Data Ready
# Stock_His 2342 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 32.05
# 2342 =====================>Data Ready
# Stock_His 2344 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 19.2
# 2344 =====================>Data Ready
# Stock_His 2345 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 542.0
# 2345 =====================>Data Ready
# Stock_His 2347 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 71.1
# 2347 =====================>Data Ready
# Stock_His 2348 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 148.0
# 2348 =====================>Data Ready
# Stock_His 2349 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 14.2
# 2349 =====================>Data Ready
# Stock_His 2351 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 121.0
# 2351 =====================>Data Ready
# Stock_His 2352 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 36.5
# 2352 =====================>Data Ready
# Stock_His 2353 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 40.1
# 2353 =====================>Data Ready
# Stock_His 2354 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 86.9
# 2354 =====================>Data Ready
# Stock_His 2355 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 38.4
# 2355 =====================>Data Ready
# Stock_His 2356 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 45.95
# 2356 =====================>Data Ready
# Stock_His 2357 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 596.0
# 2357 =====================>Data Ready
# Stock_His 2358 2024-05-01 ===>外部抓取
# Stock_His 2358 2024-06-01 ===>外部抓取
# Stock_His 2358 2024-07-01 ===>外部抓取
# Stock_His 2358 2024-08-01 ===>外部抓取
# Stock_His 2358 2024-09-01 ===>外部抓取
# Stock_His 2358 2024-10-01 ===>外部抓取
# Stock_His 2358 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 4.56
# 2358 =====================>Data Ready
# Stock_His 2359 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 139.5
# 2359 =====================>Data Ready
# Stock_His 2360 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 437.0
# 2360 =====================>Data Ready
# Stock_His 2362 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 58.8
# 2362 =====================>Data Ready
# Stock_His 2363 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 76.2
# 2363 =====================>Data Ready
# Stock_His 2364 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 85.0
# 2364 =====================>Data Ready
# Stock_His 2365 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 44.75
# 2365 =====================>Data Ready
# Stock_His 2367 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 30.6
# 2367 =====================>Data Ready
# Stock_His 2368 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 189.0
# 2368 =====================>Data Ready
# Stock_His 2369 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 20.3
# 2369 =====================>Data Ready
# Stock_His 2371 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 46.85
# 2371 =====================>Data Ready
# Stock_His 2373 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 68.1
# 2373 =====================>Data Ready
# Stock_His 2374 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 46.65
# 2374 =====================>Data Ready
# Stock_His 2375 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 63.8
# 2375 =====================>Data Ready
# Stock_His 2376 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 278.5
# 2376 =====================>Data Ready
# Stock_His 2377 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 182.5
# 2377 =====================>Data Ready
# Stock_His 2379 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 482.5
# 2379 =====================>Data Ready
# Stock_His 2380 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 6.35
# 2380 =====================>Data Ready
# Stock_His 2382 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 313.5
# 2382 =====================>Data Ready
# Stock_His 2383 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 427.0
# 2383 =====================>Data Ready
# Stock_His 2385 2024-10-01 ===>外部抓取
# Stock_His 2385 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 165.0
# 2385 =====================>Data Ready
# Stock_His 2387 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 55.6
# 2387 =====================>Data Ready
# Stock_His 2388 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 115.0
# 2388 =====================>Data Ready
# Stock_His 2390 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 13.5
# 2390 =====================>Data Ready
# Stock_His 2392 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 62.0
# 2392 =====================>Data Ready
# Stock_His 2393 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 81.8
# 2393 =====================>Data Ready
# Stock_His 2395 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 322.0
# 2395 =====================>Data Ready
# Stock_His 2397 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 84.5
# 2397 =====================>Data Ready
# Stock_His 2399 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 34.05
# 2399 =====================>Data Ready
# Stock_His 2401 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 29.1
# 2401 =====================>Data Ready
# Stock_His 2402 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 40.3
# 2402 =====================>Data Ready
# Stock_His 2404 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 342.5
# 2404 =====================>Data Ready
# Stock_His 2405 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 20.25
# 2405 =====================>Data Ready
# Stock_His 2406 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 18.45
# 2406 =====================>Data Ready
# Stock_His 2408 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 40.2
# 2408 =====================>Data Ready
# Stock_His 2409 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 16.05
# 2409 =====================>Data Ready
# Stock_His 2412 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 122.5
# 2412 =====================>Data Ready
# Stock_His 2413 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 28.05
# 2413 =====================>Data Ready
# Stock_His 2414 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 35.95
# 2414 =====================>Data Ready
# Stock_His 2415 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 26.3
# 2415 =====================>Data Ready
# Stock_His 2417 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 39.9
# 2417 =====================>Data Ready
# Stock_His 2419 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 31.15
# 2419 =====================>Data Ready
# Stock_His 2420 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 71.4
# 2420 =====================>Data Ready
# Stock_His 2421 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 97.1
# 2421 =====================>Data Ready
# Stock_His 2423 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 43.95
# 2423 =====================>Data Ready
# Stock_His 2424 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 78.7
# 2424 =====================>Data Ready
# Stock_His 2425 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 43.2
# 2425 =====================>Data Ready
# Stock_His 2426 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 23.45
# 2426 =====================>Data Ready
# Stock_His 2427 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 26.7
# 2427 =====================>Data Ready
# Stock_His 2428 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 166.5
# 2428 =====================>Data Ready
# Stock_His 2429 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 27.9
# 2429 =====================>Data Ready
# Stock_His 2430 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 33.0
# 2430 =====================>Data Ready
# Stock_His 2431 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 18.3
# 2431 =====================>Data Ready
# Stock_His 2432 2023-01-01 ===>外部抓取
# Stock_His 2432 2023-02-01 ===>外部抓取
# Stock_His 2432 2023-03-01 ===>外部抓取
# Stock_His 2432 2023-04-01 ===>外部抓取
# Stock_His 2432 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 34.8
# 2432 =====================>Data Ready
# Stock_His 2433 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 50.4
# 2433 =====================>Data Ready
# Stock_His 2434 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 31.5
# 2434 =====================>Data Ready
# Stock_His 2436 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 57.8
# 2436 =====================>Data Ready
# Stock_His 2438 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 41.85
# 2438 =====================>Data Ready
# Stock_His 2439 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 108.5
# 2439 =====================>Data Ready
# Stock_His 2440 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 13.75
# 2440 =====================>Data Ready
# Stock_His 2441 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 57.0
# 2441 =====================>Data Ready
# Stock_His 2442 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 23.65
# 2442 =====================>Data Ready
# Stock_His 2443 2024-05-01 ===>外部抓取
# Stock_His 2443 2024-06-01 ===>外部抓取
# Stock_His 2443 2024-07-01 ===>外部抓取
# Stock_His 2443 2024-08-01 ===>外部抓取
# Stock_His 2443 2024-09-01 ===>外部抓取
# Stock_His 2443 2024-10-01 ===>外部抓取
# Stock_His 2443 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 3.57
# 2443 =====================>Data Ready
# Stock_His 2444 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 13.95
# 2444 =====================>Data Ready
# Stock_His 2449 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 128.5
# 2449 =====================>Data Ready
# Stock_His 2450 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 35.05
# 2450 =====================>Data Ready
# Stock_His 2451 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 95.1
# 2451 =====================>Data Ready
# Stock_His 2453 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 55.1
# 2453 =====================>Data Ready
# Stock_His 2454 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 1295.0
# 2454 =====================>Data Ready
# Stock_His 2455 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 142.0
# 2455 =====================>Data Ready
# Stock_His 2457 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 37.45
# 2457 =====================>Data Ready
# Stock_His 2458 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 144.5
# 2458 =====================>Data Ready
# Stock_His 2459 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 70.9
# 2459 =====================>Data Ready
# Stock_His 2460 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 26.7
# 2460 =====================>Data Ready
# Stock_His 2461 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 21.75
# 2461 =====================>Data Ready
# Stock_His 2462 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 29.35
# 2462 =====================>Data Ready
# Stock_His 2464 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 77.4
# 2464 =====================>Data Ready
# Stock_His 2465 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 75.4
# 2465 =====================>Data Ready
# Stock_His 2466 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 35.75
# 2466 =====================>Data Ready
# Stock_His 2467 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 228.0
# 2467 =====================>Data Ready
# Stock_His 2468 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 23.65
# 2468 =====================>Data Ready
# Stock_His 2471 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 48.4
# 2471 =====================>Data Ready
# Stock_His 2472 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 72.0
# 2472 =====================>Data Ready
# Stock_His 2474 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 234.0
# 2474 =====================>Data Ready
# Stock_His 2476 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 86.8
# 2476 =====================>Data Ready
# Stock_His 2477 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 35.55
# 2477 =====================>Data Ready
# Stock_His 2478 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 46.7
# 2478 =====================>Data Ready
# Stock_His 2480 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 129.0
# 2480 =====================>Data Ready
# Stock_His 2481 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 54.6
# 2481 =====================>Data Ready
# Stock_His 2482 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 29.75
# 2482 =====================>Data Ready
# Stock_His 2483 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 22.95
# 2483 =====================>Data Ready
# Stock_His 2484 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 28.9
# 2484 =====================>Data Ready
# Stock_His 2485 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 17.75
# 2485 =====================>Data Ready
# Stock_His 2486 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 127.0
# 2486 =====================>Data Ready
# Stock_His 2488 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 48.75
# 2488 =====================>Data Ready
# Stock_His 2489 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 21.5
# 2489 =====================>Data Ready
# Stock_His 2491 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 13.45
# 2491 =====================>Data Ready
# Stock_His 2492 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 101.0
# 2492 =====================>Data Ready
# Stock_His 2493 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 117.5
# 2493 =====================>Data Ready
# Stock_His 2495 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 34.5
# 2495 =====================>Data Ready
# Stock_His 2496 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 74.4
# 2496 =====================>Data Ready
# Stock_His 2497 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 74.6
# 2497 =====================>Data Ready
# Stock_His 2498 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 43.55
# 2498 =====================>Data Ready
# Stock_His 2501 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 24.8
# 2501 =====================>Data Ready
# Stock_His 2504 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 56.8
# 2504 =====================>Data Ready
# Stock_His 2505 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 21.3
# 2505 =====================>Data Ready
# Stock_His 2506 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 10.45
# 2506 =====================>Data Ready
# Stock_His 2509 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 18.45
# 2509 =====================>Data Ready
# Stock_His 2511 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 10.5
# 2511 =====================>Data Ready
# Stock_His 2514 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 21.8
# 2514 =====================>Data Ready
# Stock_His 2515 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 11.0
# 2515 =====================>Data Ready
# Stock_His 2516 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 12.35
# 2516 =====================>Data Ready
# Stock_His 2520 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 46.7
# 2520 =====================>Data Ready
# Stock_His 2524 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 76.3
# 2524 =====================>Data Ready
# Stock_His 2527 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 31.9
# 2527 =====================>Data Ready
# Stock_His 2528 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 37.5
# 2528 =====================>Data Ready
# Stock_His 2530 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 39.85
# 2530 =====================>Data Ready
# Stock_His 2534 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 25.65
# 2534 =====================>Data Ready
# Stock_His 2535 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 49.55
# 2535 =====================>Data Ready
# Stock_His 2536 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 29.25
# 2536 =====================>Data Ready
# Stock_His 2537 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 14.8
# 2537 =====================>Data Ready
# Stock_His 2538 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 15.95
# 2538 =====================>Data Ready
# Stock_His 2539 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 50.0
# 2539 =====================>Data Ready
# Stock_His 2540 2024-10-01 ===>外部抓取
# Stock_His 2540 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 87.9
# 2540 =====================>Data Ready
# Stock_His 2542 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 40.85
# 2542 =====================>Data Ready
# Stock_His 2543 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 93.1
# 2543 =====================>Data Ready
# Stock_His 2545 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 60.6
# 2545 =====================>Data Ready
# Stock_His 2546 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 73.4
# 2546 =====================>Data Ready
# Stock_His 2547 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 9.66
# 2547 =====================>Data Ready
# Stock_His 2548 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 117.5
# 2548 =====================>Data Ready
# Stock_His 2597 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 136.5
# 2597 =====================>Data Ready
# Stock_His 2601 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 7.89
# 2601 =====================>Data Ready
# Stock_His 2603 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 205.5
# 2603 =====================>Data Ready
# Stock_His 2605 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 26.25
# 2605 =====================>Data Ready
# Stock_His 2606 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 56.5
# 2606 =====================>Data Ready
# Stock_His 2607 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 31.65
# 2607 =====================>Data Ready
# Stock_His 2608 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 40.3
# 2608 =====================>Data Ready
# Stock_His 2609 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 68.1
# 2609 =====================>Data Ready
# Stock_His 2610 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 22.65
# 2610 =====================>Data Ready
# Stock_His 2611 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 23.6
# 2611 =====================>Data Ready
# Stock_His 2612 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 42.35
# 2612 =====================>Data Ready
# Stock_His 2613 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 33.0
# 2613 =====================>Data Ready
# Stock_His 2614 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 18.75
# 2614 =====================>Data Ready
# Stock_His 2615 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 89.8
# 2615 =====================>Data Ready
# Stock_His 2616 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 20.4
# 2616 =====================>Data Ready
# Stock_His 2617 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 31.25
# 2617 =====================>Data Ready
# Stock_His 2618 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 37.8
# 2618 =====================>Data Ready
# Stock_His 2630 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 31.95
# 2630 =====================>Data Ready
# Stock_His 2633 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 29.2
# 2633 =====================>Data Ready
# Stock_His 2634 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 44.9
# 2634 =====================>Data Ready
# Stock_His 2636 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 86.6
# 2636 =====================>Data Ready
# Stock_His 2637 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 73.8
# 2637 =====================>Data Ready
# Stock_His 2642 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 43.4
# 2642 =====================>Data Ready
# Stock_His 2645 2023-01-01 ===>外部抓取
# Stock_His 2645 2023-02-01 ===>外部抓取
# Stock_His 2645 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 93.9
# 2645 =====================>Data Ready
# Stock_His 2646 2023-01-01 ===>外部抓取
# Stock_His 2646 2023-02-01 ===>外部抓取
# Stock_His 2646 2023-03-01 ===>外部抓取
# Stock_His 2646 2023-04-01 ===>外部抓取
# Stock_His 2646 2023-05-01 ===>外部抓取
# Stock_His 2646 2023-06-01 ===>外部抓取
# Stock_His 2646 2023-07-01 ===>外部抓取
# Stock_His 2646 2023-08-01 ===>外部抓取
# Stock_His 2646 2023-09-01 ===>外部抓取
# Stock_His 2646 2023-10-01 ===>外部抓取
# Stock_His 2646 2023-11-01 ===>外部抓取
# Stock_His 2646 2023-12-01 ===>外部抓取
# Stock_His 2646 2024-01-01 ===>外部抓取
# Stock_His 2646 2024-02-01 ===>外部抓取
# Stock_His 2646 2024-03-01 ===>外部抓取
# Stock_His 2646 2024-04-01 ===>外部抓取
# Stock_His 2646 2024-05-01 ===>外部抓取
# Stock_His 2646 2024-06-01 ===>外部抓取
# Stock_His 2646 2024-07-01 ===>外部抓取
# Stock_His 2646 2024-08-01 ===>外部抓取
# Stock_His 2646 2024-09-01 ===>外部抓取
# Stock_His 2646 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 27.5
# 2646 =====================>Data Ready
# Stock_His 2701 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 12.75
# 2701 =====================>Data Ready
# Stock_His 2702 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 17.35
# 2702 =====================>Data Ready
# Stock_His 2704 2024-11-01 ===>外部抓取
# 【craw_stock】 success
# 60.6
# 2704 =====================>Data Ready
# ...
# An exception occurred: HTTP Error 404: Not Found
# 【craw_stock】 success
# 153.0
# 8416 =====================>Data Ready
# Stock_His 8420 2024-10-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8420 2024-10-01
# An exception occurred: HTTP Error 404: Not Found
# Stock_His 8420 2024-11-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8420 2024-11-01
# An exception occurred: HTTP Error 404: Not Found
# 【craw_stock】 success
# 42.0
# 8420 =====================>Data Ready
# Stock_His 8421 2024-10-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8421 2024-10-01
# An exception occurred: HTTP Error 404: Not Found
# Stock_His 8421 2024-11-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8421 2024-11-01
# An exception occurred: HTTP Error 404: Not Found
# 【craw_stock】 success
# 14.65
# 8421 =====================>Data Ready
# Stock_His 8423 2024-10-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8423 2024-10-01
# An exception occurred: HTTP Error 404: Not Found
# Stock_His 8423 2024-11-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8423 2024-11-01
# An exception occurred: HTTP Error 404: Not Found
# 【craw_stock】 success
# 23.0
# 8423 =====================>Data Ready
# Stock_His 8424 2024-10-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8424 2024-10-01
# An exception occurred: HTTP Error 404: Not Found
# Stock_His 8424 2024-11-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8424 2024-11-01
# An exception occurred: HTTP Error 404: Not Found
# 【craw_stock】 success
# 69.4
# 8424 =====================>Data Ready
# Stock_His 8426 2024-10-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8426 2024-10-01
# An exception occurred: HTTP Error 404: Not Found
# Stock_His 8426 2024-11-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8426 2024-11-01
# An exception occurred: HTTP Error 404: Not Found
# 【craw_stock】 success
# 46.25
# 8426 =====================>Data Ready
# Stock_His 8431 2024-10-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8431 2024-10-01
# An exception occurred: HTTP Error 404: Not Found
# Stock_His 8431 2024-11-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8431 2024-11-01
# An exception occurred: HTTP Error 404: Not Found
# 【craw_stock】 success
# 58.1
# 8431 =====================>Data Ready
# Stock_His 8432 2024-10-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8432 2024-10-01
# An exception occurred: HTTP Error 404: Not Found
# Stock_His 8432 2024-11-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8432 2024-11-01
# An exception occurred: HTTP Error 404: Not Found
# 【craw_stock】 success
# 59.2
# 8432 =====================>Data Ready
# Stock_His 8433 2024-10-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8433 2024-10-01
# An exception occurred: HTTP Error 404: Not Found
# Stock_His 8433 2024-11-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8433 2024-11-01
# An exception occurred: HTTP Error 404: Not Found
# 【craw_stock】 success
# 88.0
# 8433 =====================>Data Ready
# Stock_His 8435 2024-10-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8435 2024-10-01
# An exception occurred: HTTP Error 404: Not Found
# Stock_His 8435 2024-11-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8435 2024-11-01
# An exception occurred: HTTP Error 404: Not Found
# 【craw_stock】 success
# 73.2
# 8435 =====================>Data Ready
# Stock_His 8436 2024-10-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8436 2024-10-01
# An exception occurred: HTTP Error 404: Not Found
# Stock_His 8436 2024-11-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8436 2024-11-01
# An exception occurred: HTTP Error 404: Not Found
# 【craw_stock】 success
# 137.0
# 8436 =====================>Data Ready
# Stock_His 8437 2024-10-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8437 2024-10-01
# An exception occurred: HTTP Error 404: Not Found
# Stock_His 8437 2024-11-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8437 2024-11-01
# An exception occurred: HTTP Error 404: Not Found
# 【craw_stock】 success
# 34.0
# 8437 =====================>Data Ready
# Stock_His 8440 2024-10-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8440 2024-10-01
# An exception occurred: HTTP Error 404: Not Found
# Stock_His 8440 2024-11-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8440 2024-11-01
# An exception occurred: HTTP Error 404: Not Found
# 【craw_stock】 success
# 47.3
# 8440 =====================>Data Ready
# Stock_His 8444 2024-10-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8444 2024-10-01
# An exception occurred: HTTP Error 404: Not Found
# Stock_His 8444 2024-11-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8444 2024-11-01
# An exception occurred: HTTP Error 404: Not Found
# 【craw_stock】 success
# 36.15
# 8444 =====================>Data Ready
# Stock_His 8446 2024-10-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8446 2024-10-01
# An exception occurred: HTTP Error 404: Not Found
# Stock_His 8446 2024-11-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8446 2024-11-01
# An exception occurred: HTTP Error 404: Not Found
# 【craw_stock】 success
# 119.5
# 8446 =====================>Data Ready
# Stock_His 8450 2024-10-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8450 2024-10-01
# An exception occurred: HTTP Error 404: Not Found
# Stock_His 8450 2024-11-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8450 2024-11-01
# An exception occurred: HTTP Error 404: Not Found
# 【craw_stock】 success
# 24.2
# 8450 =====================>Data Ready
# Stock_His 8455 2024-10-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8455 2024-10-01
# An exception occurred: HTTP Error 404: Not Found
# Stock_His 8455 2024-11-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8455 2024-11-01
# An exception occurred: HTTP Error 404: Not Found
# 【craw_stock】 success
# 33.3
# 8455 =====================>Data Ready
# Stock_His 8472 2024-10-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8472 2024-10-01
# An exception occurred: HTTP Error 404: Not Found
# Stock_His 8472 2024-11-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8472 2024-11-01
# An exception occurred: HTTP Error 404: Not Found
# 【craw_stock】 success
# nan
# 8472 =====================>Data Ready
# Stock_His 8477 2024-10-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8477 2024-10-01
# An exception occurred: HTTP Error 404: Not Found
# Stock_His 8477 2024-11-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8477 2024-11-01
# An exception occurred: HTTP Error 404: Not Found
# 【craw_stock】 success
# 11.6
# 8477 =====================>Data Ready
# Stock_His 8489 2024-10-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8489 2024-10-01
# An exception occurred: HTTP Error 404: Not Found
# Stock_His 8489 2024-11-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8489 2024-11-01
# An exception occurred: HTTP Error 404: Not Found
# 【craw_stock】 success
# 28.85
# 8489 =====================>Data Ready
# Stock_His 8905 2024-10-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8905 2024-10-01
# An exception occurred: HTTP Error 404: Not Found
# Stock_His 8905 2024-11-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8905 2024-11-01
# An exception occurred: HTTP Error 404: Not Found
# 【craw_stock】 success
# 31.0
# 8905 =====================>Data Ready
# Stock_His 8906 2024-10-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8906 2024-10-01
# An exception occurred: HTTP Error 404: Not Found
# Stock_His 8906 2024-11-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8906 2024-11-01
# An exception occurred: HTTP Error 404: Not Found
# 【craw_stock】 success
# 39.55
# 8906 =====================>Data Ready
# Stock_His 8908 2024-10-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8908 2024-10-01
# An exception occurred: HTTP Error 404: Not Found
# Stock_His 8908 2024-11-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8908 2024-11-01
# An exception occurred: HTTP Error 404: Not Found
# 【craw_stock】 success
# 49.0
# 8908 =====================>Data Ready
# Stock_His 8916 2024-10-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8916 2024-10-01
# An exception occurred: HTTP Error 404: Not Found
# Stock_His 8916 2024-11-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8916 2024-11-01
# An exception occurred: HTTP Error 404: Not Found
# 【craw_stock】 success
# 57.6
# 8916 =====================>Data Ready
# Stock_His 8917 2024-10-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8917 2024-10-01
# An exception occurred: HTTP Error 404: Not Found
# Stock_His 8917 2024-11-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8917 2024-11-01
# An exception occurred: HTTP Error 404: Not Found
# 【craw_stock】 success
# 61.5
# 8917 =====================>Data Ready
# Stock_His 8921 2024-10-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8921 2024-10-01
# An exception occurred: HTTP Error 404: Not Found
# Stock_His 8921 2024-11-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8921 2024-11-01
# An exception occurred: HTTP Error 404: Not Found
# 【craw_stock】 success
# 27.95
# 8921 =====================>Data Ready
# Stock_His 8923 2024-10-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8923 2024-10-01
# An exception occurred: HTTP Error 404: Not Found
# Stock_His 8923 2024-11-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8923 2024-11-01
# An exception occurred: HTTP Error 404: Not Found
# 【craw_stock】 success
# 19.15
# 8923 =====================>Data Ready
# Stock_His 8924 2024-10-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8924 2024-10-01
# An exception occurred: HTTP Error 404: Not Found
# Stock_His 8924 2024-11-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8924 2024-11-01
# An exception occurred: HTTP Error 404: Not Found
# 【craw_stock】 success
# 84.9
# 8924 =====================>Data Ready
# Stock_His 8927 2024-10-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8927 2024-10-01
# An exception occurred: HTTP Error 404: Not Found
# Stock_His 8927 2024-11-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8927 2024-11-01
# An exception occurred: HTTP Error 404: Not Found
# 【craw_stock】 success
# 66.1
# 8927 =====================>Data Ready
# Stock_His 8928 2024-10-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8928 2024-10-01
# An exception occurred: HTTP Error 404: Not Found
# Stock_His 8928 2024-11-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8928 2024-11-01
# An exception occurred: HTTP Error 404: Not Found
# 【craw_stock】 success
# 33.25
# 8928 =====================>Data Ready
# Stock_His 8929 2024-10-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8929 2024-10-01
# An exception occurred: HTTP Error 404: Not Found
# Stock_His 8929 2024-11-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8929 2024-11-01
# An exception occurred: HTTP Error 404: Not Found
# 【craw_stock】 success
# 24.5
# 8929 =====================>Data Ready
# Stock_His 8930 2024-10-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8930 2024-10-01
# An exception occurred: HTTP Error 404: Not Found
# Stock_His 8930 2024-11-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8930 2024-11-01
# An exception occurred: HTTP Error 404: Not Found
# 【craw_stock】 success
# 35.75
# 8930 =====================>Data Ready
# Stock_His 8931 2024-10-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8931 2024-10-01
# An exception occurred: HTTP Error 404: Not Found
# Stock_His 8931 2024-11-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8931 2024-11-01
# An exception occurred: HTTP Error 404: Not Found
# 【craw_stock】 success
# 49.5
# 8931 =====================>Data Ready
# Stock_His 8932 2024-10-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8932 2024-10-01
# An exception occurred: HTTP Error 404: Not Found
# Stock_His 8932 2024-11-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8932 2024-11-01
# An exception occurred: HTTP Error 404: Not Found
# 【craw_stock】 success
# 86.0
# MainStock Fail
# 【stock_number】8932
# 【start_month】2023-01-01
# 【end_time】2024-11-04
#
# 8932 =====================>Data Ready
# Stock_His 8933 2024-10-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8933 2024-10-01
# An exception occurred: HTTP Error 404: Not Found
# Stock_His 8933 2024-11-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8933 2024-11-01
# An exception occurred: HTTP Error 404: Not Found
# 【craw_stock】 success
# 9.23
# 8933 =====================>Data Ready
# Stock_His 8935 2024-10-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8935 2024-10-01
# An exception occurred: HTTP Error 404: Not Found
# Stock_His 8935 2024-11-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8935 2024-11-01
# An exception occurred: HTTP Error 404: Not Found
# 【craw_stock】 success
# 18.95
# 8935 =====================>Data Ready
# Stock_His 8936 2024-10-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8936 2024-10-01
# An exception occurred: HTTP Error 404: Not Found
# Stock_His 8936 2024-11-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8936 2024-11-01
# An exception occurred: HTTP Error 404: Not Found
# 【craw_stock】 success
# 63.7
# 8936 =====================>Data Ready
# Stock_His 8937 2024-10-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8937 2024-10-01
# An exception occurred: HTTP Error 404: Not Found
# Stock_His 8937 2024-11-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8937 2024-11-01
# An exception occurred: HTTP Error 404: Not Found
# 【craw_stock】 success
# 70.9
# 8937 =====================>Data Ready
# Stock_His 8938 2024-10-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8938 2024-10-01
# An exception occurred: HTTP Error 404: Not Found
# Stock_His 8938 2024-11-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8938 2024-11-01
# An exception occurred: HTTP Error 404: Not Found
# 【craw_stock】 success
# 81.2
# 8938 =====================>Data Ready
# Stock_His 8941 2024-10-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8941 2024-10-01
# An exception occurred: HTTP Error 404: Not Found
# Stock_His 8941 2024-11-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8941 2024-11-01
# An exception occurred: HTTP Error 404: Not Found
# 【craw_stock】 success
# 68.2
# 8941 =====================>Data Ready
# Stock_His 8942 2024-10-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8942 2024-10-01
# An exception occurred: HTTP Error 404: Not Found
# Stock_His 8942 2024-11-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 8942 2024-11-01
# An exception occurred: HTTP Error 404: Not Found
# 【craw_stock】 success
# 61.6
# 8942 =====================>Data Ready
# Stock_His 9949 2024-10-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 9949 2024-10-01
# An exception occurred: HTTP Error 404: Not Found
# Stock_His 9949 2024-11-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 9949 2024-11-01
# An exception occurred: HTTP Error 404: Not Found
# 【craw_stock】 success
# 25.5
# 9949 =====================>Data Ready
# Stock_His 9950 2024-10-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 9950 2024-10-01
# An exception occurred: HTTP Error 404: Not Found
# Stock_His 9950 2024-11-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 9950 2024-11-01
# An exception occurred: HTTP Error 404: Not Found
# 【craw_stock】 success
# 14.35
# 9950 =====================>Data Ready
# Stock_His 9951 2024-10-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 9951 2024-10-01
# An exception occurred: HTTP Error 404: Not Found
# Stock_His 9951 2024-11-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 9951 2024-11-01
# An exception occurred: HTTP Error 404: Not Found
# 【craw_stock】 success
# 65.2
# 9951 =====================>Data Ready
# Stock_His 9960 2024-10-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 9960 2024-10-01
# An exception occurred: HTTP Error 404: Not Found
# Stock_His 9960 2024-11-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 9960 2024-11-01
# An exception occurred: HTTP Error 404: Not Found
# 【craw_stock】 success
# nan
# 9960 =====================>Data Ready
# Stock_His 9962 2024-10-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 9962 2024-10-01
# An exception occurred: HTTP Error 404: Not Found
# Stock_His 9962 2024-11-01 ===>外部抓取
# 【_CrawStock】 craw_stock error -->Stock_His 9962 2024-11-01
# An exception occurred: HTTP Error 404: Not Found
# 【craw_stock】 success
# 16.95
# 9962 =====================>Data Ready
